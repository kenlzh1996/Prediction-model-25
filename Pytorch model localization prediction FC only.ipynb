# %% [markdown]
# # Training (fc layer only with dataframe)

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Package imports

# %%
# Import packages
import re
import os
import gc
import copy
from pathlib import Path
import numpy as np
from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence
import pandas as pd
import math
import random
import datetime
import time
import warnings
from pdb import set_trace
from collections import Counter

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, matthews_corrcoef
from sklearn.preprocessing import LabelEncoder, StandardScaler

import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import Dataset, DataLoader, Sampler
from torchvision import models, transforms

# %% [markdown]
# ### GPU

# %%
#Check to see if the GPU is available and store it as a variable so tensors can be moved to it
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print('Is cuda available?:', torch.cuda.is_available())
print('cuda version:', torch.version.cuda)
dev = "cuda:0"
# Out:
# Using device: cuda
# Is cuda available?: True
# cuda version: 12.4

# %% [markdown]
# ### Variables and Hyperparameters

# %%
# Create a timestamp for the summary file name
Time_Stamp = datetime.datetime.now().strftime("%Y_%m%d%_H%M")

# Create run name
Run_Name = '0411; protein; FC only' # change run_name before running

# Paths
raw_folder_path = '/home/ec2-user/Feb2025/raw_datasets/' # raw dataset folder with all the proteome and mRNA data
label_path = '/home/ec2-user/Feb2025/labels/' # label folder with all the labels
dataset_folder_path = '/home/ec2-user/Feb2025/processed_dataset2/' # dataset folder with all the processed proteome and mRNA data
fig_bank_path = '/home/ec2-user/Feb2025/figure_bank/'
model_folder_path = '/home/ec2-user/Feb2025/saved_models/' # model folder with all the models
# Define the Model
Model = 'FConly'

# Define loss function
LossFunc_Name = 'Focal' # 'CrossEntropy', 'Focal' are the options

# Define the optimizer
Optim_Name = 'AdamW' # 'Adam', 'AdamW', 'SGD', 'SGD_weight' are the options

# Dataset
Set = 'mRNA' # Define the dataset to use, 'Protein', 'mRNA', 'Protein + mRNA', or 'Protein + mRNA Stack' are the options

# Seed number
Seed = 43

# Validation fraction
Validation_Fraction = 0.15

# Standard deviation for add-noise transformation
StandardDeviation = 0.05

# Learning rate scheduler
LrScheduler = True
Learner_rate = 1e-4

# Optimizer
Weight_Decay = 0.0001 # L2 regulator
#  it works by adding a penalty to the loss function, which discourages large weights in the model; penalizes for too many weights - helps prevent overfitting
#  the penalty is calculated as weight_decay * weight^2, and it's added to the loss.
#  1e-4 or 1e-3 gives higher acc

# Loss Function (CrossEntropyLoss)
Label_Smoothing = 0.1
#  sets the target of the loss function to something greater than 0 and less than 1
#  helps prevent overfitting

# Early stopping
Earlystopping = False

# Transformation
TransformOrNot = True

# Class weight to loss function
ApplyClassWeightToLoss = True
#  makes the loss weights equal to the fraction of each category label
#  note, a layer is added to the model so the outputs of the model are equal to the number of categories

# Batch size
Batch_size = 64

# Epoch amount
epochs = 200

# %% [markdown]
# ### Protein, mRNA dataframe, localization label set up

# %%
# Open the proteomics data and only keep genes (rows) that are fully quantified
PFP = 'K_PD_synthetic_kde_qttumor.csv' # synthetic data
PD = pd.read_csv(dataset_folder_path+PFP)

# Data set wrangling
PD.index = PD.loc[:,'Index']
PD = PD.loc[:,PD.columns!='Index']
PD.dropna(inplace=True)

# Open the mRNA data and only keep genes (rows) that are fully quantified
MFP = 'K_MD_synthetic_kde_qttumor.csv'
MD = pd.read_csv(dataset_folder_path + MFP)

# Data set wrangling
MD.index = MD.loc[:,'Index']
MD = MD.loc[:,MD.columns!='Index']
MD = MD.drop_duplicates()
MD.dropna(inplace=True)

# %%
# Open the labels data
#LFP = 'SubCellBarcode.MCF7.txt'
LFP = 'markers_mcf7_all.txt'
LD = pd.read_csv(filepath_or_buffer=label_path+LFP,sep='\t')
# Data set wrangling
LD.index = LD.loc[:,'Protein']
LD = LD.loc[:,LD.columns!='Protein']

# %%
# Extract the common indices between the proteomics and mRNA data
common_indices = list(set(PD.index).intersection(set(MD.index)))
LD = LD.loc[LD.index.isin(common_indices)]

print('Number of total labels in Krug dataset')
print(len(LD.index))
print(LD.value_counts())
# Out:
# Number of total labels in Krug dataset
# 6444
# Localization
# Cytosol         2825
# Nucleus         1828
# Secretory       1308
# Mitochondria     483
# Name: count, dtype: int64

# %% [markdown]
# ### Set seed function

# %%
def set_seed(seed):
    random.seed(seed) # set random seed for python
    np.random.seed(seed) # set random seed for numpy
    torch.manual_seed(seed) # set random seed for CPU
    rs = RandomState(MT19937(SeedSequence(seed))) # seed for numpy
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed) # set random seed for all GPUs
    torch.backends.cudnn.deterministic = True # set to True to get reproducible results
    torch.backends.cudnn.benchmark = False # set to False to get reproducible results

# %% [markdown]
# ### Transformation

# %%
# Custom transformation to add noise to the data
class AddNoise:
    def __init__(self, set, mean=0, std=0.05):
        self.set = set
        self.mean = mean
        self.std = std

    def __call__(self, array1, array2):
        if self.set == 'Protein + mRNA':
            noise1 = np.random.normal(self.mean, self.std, array1.shape)
            noise2 = np.random.normal(self.mean, self.std, array2.shape)

            return array1 + noise1, array2 + noise2    

        else: # suitable for Protein or mRNA only because same noise will be applied twice
            noise = np.random.normal(self.mean, self.std, array1.shape)
        
        return array1 + noise, array2 + noise

# %% [markdown]
# ### Custom Dataset Class

# %%
class OmicsDatasetDual(Dataset):
    # __init__ will be run whenever we create a new instance of the class
    def __init__(self, set, data1, data2, indices, labels, transform=None):

        assert data1.loc[indices,:].shape[0] == data2.loc[indices,:].shape[0] == len(labels), \
            "Protein, mRNA, and labels must have the same number of samples (rows)"

        self.set = set
        self.data1 = data1.loc[indices,:] 
        self.data2 = data2.loc[indices,:]
        self.indices = indices
        self.labels = labels
        self.transform = transform

    # __len__ will be run whenever we call len() on the dataset
    def __len__(self):
        return len(self.labels)

    # __getitem__ will be run when we call an index on the dataset, i.e. dataset[0]
    def __getitem__(self, idx):
        data1 = self.data1.iloc[idx].values
        data2 = self.data2.iloc[idx].values

        if self.transform:
            data1, data2 = self.transform(data1, data2)
        
        abundance_sum = data1 + data2
        sorted_idx = abundance_sum.argsort()

        # Interleave
        interleaved_data = np.empty((len(data1) + len(data2)), dtype=np.float32)
        interleaved_data[0::2] = data1[sorted_idx]
        interleaved_data[1::2] = data2[sorted_idx]

        sample = torch.tensor(interleaved_data, dtype=torch.float32)
        label = torch.tensor(self.labels[idx], dtype=torch.long)  # Convert label to a tensor

        return sample, label

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Labels to integers

# %%
# Labels
localization_labels = LD.loc[:, 'Localization'].values
unique_labels = set(localization_labels)  # Get unique labels
label_to_int = {
    'Cytosol': 0,
    'Mitochondria': 1,
    'Nucleus': 2,
    'Secretory': 3
}
int_to_label = {v: k for k, v in label_to_int.items()}
int_to_label
# Out:
# {0: 'Cytosol', 1: 'Mitochondria', 2: 'Nucleus', 3: 'Secretory'}

# %% [markdown]
# ### Train Validation split

# %%
# Set seed to ensure reproducibility
set_seed(Seed)

# Split the columns (genes) into training and validation sets
train_indices, val_indices, train_labels, val_labels = train_test_split(LD.index, 
                                                                  localization_labels, 
                                                                  test_size=Validation_Fraction, 
                                                                  random_state=42, 
                                                                  stratify=localization_labels
)

# Convert string labels to integers
train_labels = [label_to_int[label] for label in train_labels]
val_labels = [label_to_int[label] for label in val_labels]


# Define the transformation
transformation = AddNoise(Set, mean=0, std=0.05)

# Create the training and validation datasets    
if Set == 'Protein':
    train_dataset = OmicsDatasetDual(Set, PD, PD, train_indices, train_labels, transform=transformation)
    val_dataset = OmicsDatasetDual(Set, PD, PD, val_indices, val_labels)
elif Set == 'mRNA':
    train_dataset = OmicsDatasetDual(Set, MD, MD, train_indices, train_labels, transform=transformation)
    val_dataset = OmicsDatasetDual(Set, MD, MD, val_indices, val_labels)
elif Set == 'Protein + mRNA':
    train_dataset = OmicsDatasetDual(Set, PD, MD, train_indices, train_labels, transform=transformation)
    val_dataset = OmicsDatasetDual(Set, PD, MD, val_indices, val_labels)
else:
    raise ValueError("Invalid dataset selection. Choose 'Protein', 'mRNA', 'Protein + mRNA'.")
# Create the data loaders
train_loader = DataLoader(train_dataset, batch_size=Batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=Batch_size, shuffle=False)

# %% [markdown]
# ### Check data in loaders

# %%
# Train loader is a Pytorch DataLoader object and is iterable, but not subscriptable
for batch_data, batch_labels in train_loader:
    for i in range(1):
        # Grab the first data point and its label from the batch
        data_point = batch_data[i]  # First data point in the batch
        label = batch_labels[i]     # Corresponding label
        print("Data point:", data_point)
        print("Data point length:", len(data_point))
        print("Data point shape:", data_point.shape)
        print("Label:", label)
    break  # Exit after grabbing the first batch
# Out:
# Data point: tensor([-0.0182, -0.0182, -0.0124, -0.0124, -0.0034, -0.0034, -0.0023, -0.0023,
#         -0.0012, -0.0012,  0.0021,  0.0021,  0.0028,  0.0028,  0.0125,  0.0125,
#          0.0135,  0.0135,  0.0165,  0.0165,  0.0167,  0.0167,  0.0191,  0.0191,
#          0.0195,  0.0195,  0.0255,  0.0255,  0.0261,  0.0261,  0.0360,  0.0360,
#          0.0422,  0.0422,  0.0482,  0.0482,  0.0594,  0.0594,  0.0648,  0.0648,
#          0.0665,  0.0665,  0.0776,  0.0776,  0.0805,  0.0805,  0.0884,  0.0884,
#          0.0903,  0.0903,  0.1012,  0.1012,  0.1068,  0.1068,  0.1088,  0.1088,
#          0.1096,  0.1096,  0.1119,  0.1119,  0.1137,  0.1137,  0.1216,  0.1216,
#          0.1228,  0.1228,  0.1303,  0.1303,  0.1309,  0.1309,  0.1331,  0.1331,
#          0.1363,  0.1363,  0.1463,  0.1463,  0.1497,  0.1497,  0.1525,  0.1525,
#          0.1574,  0.1574,  0.1645,  0.1645,  0.1764,  0.1764,  0.1793,  0.1793,
#          0.1832,  0.1832,  0.1842,  0.1842,  0.1850,  0.1850,  0.1924,  0.1924,
#          0.1950,  0.1950,  0.1971,  0.1971,  0.1978,  0.1978,  0.1985,  0.1985,
#          0.2010,  0.2010,  0.2010,  0.2010,  0.2124,  0.2124,  0.2143,  0.2143,
#          0.2146,  0.2146,  0.2165,  0.2165,  0.2444,  0.2444,  0.2459,  0.2459,
#          0.2487,  0.2487,  0.2547,  0.2547,  0.2709,  0.2709,  0.2755,  0.2755,
#          0.2764,  0.2764,  0.2845,  0.2845,  0.2860,  0.2860,  0.2877,  0.2877,
#          0.2885,  0.2885,  0.2908,  0.2908,  0.2979,  0.2979,  0.3216,  0.3216,
#          0.3280,  0.3280,  0.3327,  0.3327,  0.3418,  0.3418,  0.3437,  0.3437,
#          0.3443,  0.3443,  0.3449,  0.3449,  0.3511,  0.3511,  0.3637,  0.3637,
#          0.3647,  0.3647,  0.3706,  0.3706,  0.3737,  0.3737,  0.3761,  0.3761,
#          0.3776,  0.3776,  0.3801,  0.3801,  0.3944,  0.3944,  0.3953,  0.3953,
#          0.3962,  0.3962,  0.3965,  0.3965,  0.4012,  0.4012,  0.4204,  0.4204,
#          0.4208,  0.4208,  0.4295,  0.4295,  0.4339,  0.4339,  0.4410,  0.4410,
#          0.4489,  0.4489,  0.4525,  0.4525,  0.4776,  0.4776,  0.4822,  0.4822,
#          0.4923,  0.4923,  0.4931,  0.4931,  0.5119,  0.5119,  0.5164,  0.5164,
#          0.5235,  0.5235,  0.5268,  0.5268,  0.5530,  0.5530,  0.5757,  0.5757,
#          0.6029,  0.6029,  0.6048,  0.6048,  0.6126,  0.6126,  0.6194,  0.6194,
#          0.6198,  0.6198,  0.6249,  0.6249,  0.6409,  0.6409,  0.6451,  0.6451,
#          0.6475,  0.6475,  0.6512,  0.6512,  0.6528,  0.6528,  0.6623,  0.6623,
#          0.6651,  0.6651,  0.6709,  0.6709,  0.6896,  0.6896,  0.6956,  0.6956,
#          0.7242,  0.7242,  0.7397,  0.7397,  0.7420,  0.7420,  0.7755,  0.7755,
#          0.7771,  0.7771,  0.7776,  0.7776,  0.7794,  0.7794,  0.7874,  0.7874,
#          0.8053,  0.8053,  0.8064,  0.8064,  0.8158,  0.8158,  0.8160,  0.8160,
#          0.8276,  0.8276,  0.8282,  0.8282,  0.8401,  0.8401,  0.8491,  0.8491,
#          0.8541,  0.8541,  0.8576,  0.8576,  0.8694,  0.8694,  0.8799,  0.8799,
#          0.8810,  0.8810,  0.8861,  0.8861,  0.8917,  0.8917,  0.9092,  0.9092,
#          0.9137,  0.9137,  0.9199,  0.9199,  0.9267,  0.9267,  0.9304,  0.9304,
#          0.9444,  0.9444,  0.9496,  0.9496,  0.9543,  0.9543,  0.9591,  0.9591,
#          0.9625,  0.9625,  0.9664,  0.9664,  0.9737,  0.9737,  1.0220,  1.0220,
#          1.0430,  1.0430,  1.0667,  1.0667])
# Data point length: 324
# Data point shape: torch.Size([324])
# Label: tensor(0)

# %%
# Check the distribution of labels in the training and validation dataset
train_label_counts = Counter(train_labels)
val_label_counts = Counter(val_labels)
print("Training set label distribution:")
print(train_label_counts)
print("Validation set label distribution:")
print(val_label_counts)
# Out:
# Training set label distribution:
# Counter({0: 2401, 2: 1554, 3: 1112, 1: 410})
# Validation set label distribution:
# Counter({0: 424, 2: 274, 3: 196, 1: 73})

# %% [markdown]
# ### Define model

# %%
# Define the fully connected neural network
class FullyConnectedNN(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, output_size):
        super(FullyConnectedNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)  # First hidden layer
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)  # Second hidden layer
        self.fc3 = nn.Linear(hidden_size2, hidden_size3)  # Output layer
        self.fc4 = nn.Linear(hidden_size3, output_size)  # Output layer
        #self.softmax = nn.Softmax(dim=1)  # Softmax activation for output layer

    def forward(self, x):
        x = torch.relu(self.fc1(x))  # Apply ReLU activation to the first layer
        x = torch.relu(self.fc2(x))  # Apply ReLU activation to the second layer
        x = torch.relu(self.fc3(x))
        x = self.fc4(x)  # Output layer (logits)
        #x = self.softmax(x)  # Apply softmax to get probabilities
        return x

# Define the model
input_size = len(train_loader.dataset[0][0])  # Number of input features
hidden_size1 = 128  # Number of neurons in the first hidden layer
hidden_size2 = 64  # Number of neurons in the second hidden layer
hidden_size3 = 32  # Number of neurons in the third hidden layer
output_size = 4  # Number of output classes

model = FullyConnectedNN(input_size, hidden_size1, hidden_size2, hidden_size3, output_size)
model.to(dev)  # Move the model to the GPU if available
# Out:
# FullyConnectedNN(
#   (fc1): Linear(in_features=324, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=4, bias=True)
# )

# %% [markdown]
# ### Define train loop

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    
    model.train()  # Set the model to training mode
    
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for X, y in dataloader:

        X = X.to(torch.float32)
        y = y.to(torch.long)

        # Move data and labels to the same device as the model (e.g., GPU if available)
        X = X.to(device)
        y = y.to(device)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(X)

        # Compute the loss
        loss = criterion(outputs, y)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Accumulate the loss
        running_loss += loss.item()

        # Compute training accuracy
        _, predicted = torch.max(outputs, 1)  # Get the class with the highest probability
        correct_train += (predicted == y).sum().item()
        total_train += y.size(0)

    # Calculate average training loss and accuracy
    avg_training_loss = running_loss / len(train_loader)
    training_accuracy = correct_train / total_train

    return avg_training_loss, training_accuracy

# %% [markdown]
# ### Define test loop

# %%
def test_loop(dataloader, model, loss_fn):
    
    model.eval()  # Set the model to evaluation mode

    test_loss = 0.0
    correct = 0
    total = 0

    y_pred = []
    y_true = []
    
    with torch.no_grad():  # Disable gradient calculation
        for X, y in dataloader:
            
            # Prepare data
            X = X.to(torch.float32)
            y = y.to(torch.long)

            # Move data to GPU
            X = X.to(device)
            y = y.to(device)

            # Forward pass: predict classes
            outputs = model(X)
            
            # Compute the loss
            test_loss += loss_fn(outputs, y).item()

            # Get the predicted class
            _, predicted = torch.max(outputs, 1) 
            
            # Store predictions and true labels
            y_pred.extend(predicted.cpu().numpy())
            y_true.extend(y.cpu().numpy())

            # Count correct predictions
            correct += (predicted == y).sum().item() 

            # Count total predictions
            total += y.size(0) 

    # Calculate precision and recall for each class
    precision = precision_score(y_true, y_pred, average=None, zero_division=0.0)
    recall = recall_score(y_true, y_pred, average=None, zero_division=0.0)
    macro_f1 = f1_score(y_true, y_pred, average='macro')
    mcc = matthews_corrcoef(y_true, y_pred)

    avg_test_loss = test_loss / len(dataloader)
    test_accuracy = correct / total
        
    return avg_test_loss, test_accuracy, precision, recall, macro_f1, mcc

# %% [markdown]
# ### Focal loss

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
        """
        alpha: tensor of class weights (e.g., inverse class frequency), shape (C,)
        gamma: focusing parameter (default 2.0)
        reduction: 'mean', 'sum', or 'none'
        """
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, logits, targets):
        ce_loss = F.cross_entropy(logits, targets, weight=self.alpha, reduction='none')  # shape: (N,)
        pt = torch.exp(-ce_loss)  # pt = softmax prob of true class
        focal_loss = ((1 - pt) ** self.gamma) * ce_loss  # focal modulation

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %% [markdown]
# ### Training and validation

# %%
set_seed(Seed)

# Compute class weights
def compute_class_weights(class_counts): # inverse square root frequency for mild imbalance
    class_weights = 1.0 / torch.sqrt(torch.tensor(class_counts, dtype=torch.float))
    return class_weights / class_weights.sum()

# Given class counts
class_counts = [2414, 402, 1544, 1117]
LossWeights = compute_class_weights(class_counts)
LossWeights = LossWeights.to(device)

# Define the loss function and optimizer
#criterion = nn.CrossEntropyLoss(weight=LossWeights, label_smoothing=Label_Smoothing)  # Suitable for classification tasks
criterion = FocalLoss(alpha=LossWeights, gamma=2.0, reduction='mean')  # Focal loss for imbalanced classification
optimizer = optim.Adam(model.parameters(), lr=Learner_rate) 

# Set up performance dataframe to record loss, accuracy, precision and recall of each epoch
LossAccDF = pd.DataFrame(index=range(epochs),columns=['Epoch','TrainLoss','ValLoss','TrainAcc','ValAcc'])
PrecisionRecallDF = pd.DataFrame(columns=['Epoch','Class','Precision','Recall', 'Macro F1','MCC'])

# Evaluate the model before training
avg_train_loss, train_accuracy, _, _, macro_f1, mcc = test_loop(train_loader, model, criterion) # compute training performance
avg_val_loss, val_accuracy, precision, recall, macro_f1, mcc = test_loop(val_loader, model, criterion) # compute validation performance

# Print initial performance
print(f"Before Training: "
      f"Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}",
      f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}",
      f"Macro F1: {macro_f1:.4f}, Matthews Correlation Coefficient: {mcc:.4f}")

# Record the metric in the dataframe
LossAccDF.loc[0,:]=[0,avg_train_loss,avg_val_loss,train_accuracy,val_accuracy]
index=0
for i in range(4):
    PrecisionRecallDF.loc[index]=[0, i, precision[i], recall[i], macro_f1, mcc]
    index += 1

# Training loop
for epoch in range(epochs):

    # Training phase
    avg_train_loss, train_accuracy = train_loop(train_loader, model, criterion, optimizer)
    
    # Validation phase
    avg_val_loss, val_accuracy, precision, recall, macro_f1, mcc = test_loop(val_loader, model, criterion)
    
    # Print epoch loss and accuracy
    print(f"Epoch [{epoch+1}/{epochs}], "
          f"Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}",
          f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}",
          f"Macro F1: {macro_f1:.4f}, Matthews Correlation Coefficient: {mcc:.4f}")
          

    # Record the metric in the dataframe
    LossAccDF.loc[epoch+1,:]=[epoch+1,avg_train_loss,avg_val_loss,train_accuracy,val_accuracy]
    for i in range(4):
        PrecisionRecallDF.loc[index]=[epoch+1, i, precision[i], recall[i], macro_f1, mcc]
        index += 1
# Out:
# Before Training: Training Loss: 0.0211, Training Accuracy: 0.0749 Validation Loss: 0.0210, Validation Accuracy: 0.0755 Macro F1: 0.0351, Matthews Correlation Coefficient: 0.0000
# Epoch [1/200], Training Loss: 0.0211, Training Accuracy: 0.0749 Validation Loss: 0.0209, Validation Accuracy: 0.0755 Macro F1: 0.0351, Matthews Correlation Coefficient: 0.0000
# Epoch [2/200], Training Loss: 0.0210, Training Accuracy: 0.0749 Validation Loss: 0.0208, Validation Accuracy: 0.0755 Macro F1: 0.0351, Matthews Correlation Coefficient: 0.0000
# Epoch [3/200], Training Loss: 0.0209, Training Accuracy: 0.0749 Validation Loss: 0.0208, Validation Accuracy: 0.0755 Macro F1: 0.0351, Matthews Correlation Coefficient: 0.0000
# Epoch [4/200], Training Loss: 0.0208, Training Accuracy: 0.0887 Validation Loss: 0.0207, Validation Accuracy: 0.1365 Macro F1: 0.1404, Matthews Correlation Coefficient: 0.0546
# Epoch [5/200], Training Loss: 0.0208, Training Accuracy: 0.1318 Validation Loss: 0.0207, Validation Accuracy: 0.1303 Macro F1: 0.1354, Matthews Correlation Coefficient: 0.0561
# Epoch [6/200], Training Loss: 0.0207, Training Accuracy: 0.1526 Validation Loss: 0.0207, Validation Accuracy: 0.1293 Macro F1: 0.1341, Matthews Correlation Coefficient: 0.0547
# Epoch [7/200], Training Loss: 0.0207, Training Accuracy: 0.1625 Validation Loss: 0.0207, Validation Accuracy: 0.1489 Macro F1: 0.1555, Matthews Correlation Coefficient: 0.0671
# Epoch [8/200], Training Loss: 0.0207, Training Accuracy: 0.1543 Validation Loss: 0.0207, Validation Accuracy: 0.1313 Macro F1: 0.1309, Matthews Correlation Coefficient: 0.0626
# Epoch [9/200], Training Loss: 0.0207, Training Accuracy: 0.1680 Validation Loss: 0.0207, Validation Accuracy: 0.1479 Macro F1: 0.1541, Matthews Correlation Coefficient: 0.0621
# Epoch [10/200], Training Loss: 0.0207, Training Accuracy: 0.1565 Validation Loss: 0.0207, Validation Accuracy: 0.1675 Macro F1: 0.1705, Matthews Correlation Coefficient: 0.0637
# Epoch [11/200], Training Loss: 0.0207, Training Accuracy: 0.1629 Validation Loss: 0.0208, Validation Accuracy: 0.1727 Macro F1: 0.1746, Matthews Correlation Coefficient: 0.0644
# Epoch [12/200], Training Loss: 0.0207, Training Accuracy: 0.1703 Validation Loss: 0.0207, Validation Accuracy: 0.1696 Macro F1: 0.1764, Matthews Correlation Coefficient: 0.0717
# Epoch [13/200], Training Loss: 0.0206, Training Accuracy: 0.1638 Validation Loss: 0.0207, Validation Accuracy: 0.1675 Macro F1: 0.1712, Matthews Correlation Coefficient: 0.0665
# Epoch [14/200], Training Loss: 0.0207, Training Accuracy: 0.1798 Validation Loss: 0.0208, Validation Accuracy: 0.1603 Macro F1: 0.1645, Matthews Correlation Coefficient: 0.0644
# Epoch [15/200], Training Loss: 0.0206, Training Accuracy: 0.1654 Validation Loss: 0.0207, Validation Accuracy: 0.1696 Macro F1: 0.1749, Matthews Correlation Coefficient: 0.0656
# Epoch [16/200], Training Loss: 0.0207, Training Accuracy: 0.1669 Validation Loss: 0.0208, Validation Accuracy: 0.1892 Macro F1: 0.1861, Matthews Correlation Coefficient: 0.0656
# Epoch [17/200], Training Loss: 0.0206, Training Accuracy: 0.1729 Validation Loss: 0.0207, Validation Accuracy: 0.1696 Macro F1: 0.1757, Matthews Correlation Coefficient: 0.0687
# Epoch [18/200], Training Loss: 0.0206, Training Accuracy: 0.1714 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1797, Matthews Correlation Coefficient: 0.0677
# Epoch [19/200], Training Loss: 0.0206, Training Accuracy: 0.1778 Validation Loss: 0.0207, Validation Accuracy: 0.1551 Macro F1: 0.1641, Matthews Correlation Coefficient: 0.0651
# Epoch [20/200], Training Loss: 0.0207, Training Accuracy: 0.1711 Validation Loss: 0.0207, Validation Accuracy: 0.1644 Macro F1: 0.1721, Matthews Correlation Coefficient: 0.0642
# Epoch [21/200], Training Loss: 0.0206, Training Accuracy: 0.1766 Validation Loss: 0.0207, Validation Accuracy: 0.1706 Macro F1: 0.1769, Matthews Correlation Coefficient: 0.0719
# Epoch [22/200], Training Loss: 0.0206, Training Accuracy: 0.1793 Validation Loss: 0.0207, Validation Accuracy: 0.1655 Macro F1: 0.1711, Matthews Correlation Coefficient: 0.0682
# Epoch [23/200], Training Loss: 0.0206, Training Accuracy: 0.1683 Validation Loss: 0.0207, Validation Accuracy: 0.1531 Macro F1: 0.1619, Matthews Correlation Coefficient: 0.0656
# Epoch [24/200], Training Loss: 0.0206, Training Accuracy: 0.1689 Validation Loss: 0.0207, Validation Accuracy: 0.1851 Macro F1: 0.1873, Matthews Correlation Coefficient: 0.0705
# Epoch [25/200], Training Loss: 0.0206, Training Accuracy: 0.1747 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1776, Matthews Correlation Coefficient: 0.0652
# Epoch [26/200], Training Loss: 0.0206, Training Accuracy: 0.1762 Validation Loss: 0.0207, Validation Accuracy: 0.1634 Macro F1: 0.1693, Matthews Correlation Coefficient: 0.0681
# Epoch [27/200], Training Loss: 0.0206, Training Accuracy: 0.1745 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1783, Matthews Correlation Coefficient: 0.0715
# Epoch [28/200], Training Loss: 0.0206, Training Accuracy: 0.1713 Validation Loss: 0.0208, Validation Accuracy: 0.1696 Macro F1: 0.1709, Matthews Correlation Coefficient: 0.0624
# Epoch [29/200], Training Loss: 0.0206, Training Accuracy: 0.1731 Validation Loss: 0.0208, Validation Accuracy: 0.1830 Macro F1: 0.1820, Matthews Correlation Coefficient: 0.0676
# Epoch [30/200], Training Loss: 0.0206, Training Accuracy: 0.1742 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1802, Matthews Correlation Coefficient: 0.0679
# Epoch [31/200], Training Loss: 0.0206, Training Accuracy: 0.1811 Validation Loss: 0.0207, Validation Accuracy: 0.1706 Macro F1: 0.1797, Matthews Correlation Coefficient: 0.0696
# Epoch [32/200], Training Loss: 0.0206, Training Accuracy: 0.1753 Validation Loss: 0.0207, Validation Accuracy: 0.1634 Macro F1: 0.1717, Matthews Correlation Coefficient: 0.0648
# Epoch [33/200], Training Loss: 0.0206, Training Accuracy: 0.1738 Validation Loss: 0.0207, Validation Accuracy: 0.1603 Macro F1: 0.1707, Matthews Correlation Coefficient: 0.0676
# Epoch [34/200], Training Loss: 0.0206, Training Accuracy: 0.1729 Validation Loss: 0.0207, Validation Accuracy: 0.1717 Macro F1: 0.1775, Matthews Correlation Coefficient: 0.0696
# Epoch [35/200], Training Loss: 0.0206, Training Accuracy: 0.1687 Validation Loss: 0.0208, Validation Accuracy: 0.1872 Macro F1: 0.1877, Matthews Correlation Coefficient: 0.0674
# Epoch [36/200], Training Loss: 0.0206, Training Accuracy: 0.1804 Validation Loss: 0.0207, Validation Accuracy: 0.1665 Macro F1: 0.1729, Matthews Correlation Coefficient: 0.0684
# Epoch [37/200], Training Loss: 0.0206, Training Accuracy: 0.1736 Validation Loss: 0.0207, Validation Accuracy: 0.1799 Macro F1: 0.1867, Matthews Correlation Coefficient: 0.0743
# Epoch [38/200], Training Loss: 0.0206, Training Accuracy: 0.1840 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1826, Matthews Correlation Coefficient: 0.0708
# Epoch [39/200], Training Loss: 0.0206, Training Accuracy: 0.1683 Validation Loss: 0.0207, Validation Accuracy: 0.1830 Macro F1: 0.1848, Matthews Correlation Coefficient: 0.0720
# Epoch [40/200], Training Loss: 0.0206, Training Accuracy: 0.1762 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1788, Matthews Correlation Coefficient: 0.0637
# Epoch [41/200], Training Loss: 0.0206, Training Accuracy: 0.1903 Validation Loss: 0.0207, Validation Accuracy: 0.1551 Macro F1: 0.1632, Matthews Correlation Coefficient: 0.0713
# Epoch [42/200], Training Loss: 0.0206, Training Accuracy: 0.1769 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1793, Matthews Correlation Coefficient: 0.0699
# Epoch [43/200], Training Loss: 0.0206, Training Accuracy: 0.1667 Validation Loss: 0.0207, Validation Accuracy: 0.1696 Macro F1: 0.1778, Matthews Correlation Coefficient: 0.0736
# Epoch [44/200], Training Loss: 0.0206, Training Accuracy: 0.1837 Validation Loss: 0.0208, Validation Accuracy: 0.1737 Macro F1: 0.1711, Matthews Correlation Coefficient: 0.0592
# Epoch [45/200], Training Loss: 0.0206, Training Accuracy: 0.1767 Validation Loss: 0.0207, Validation Accuracy: 0.1841 Macro F1: 0.1890, Matthews Correlation Coefficient: 0.0695
# Epoch [46/200], Training Loss: 0.0206, Training Accuracy: 0.1773 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1799, Matthews Correlation Coefficient: 0.0676
# Epoch [47/200], Training Loss: 0.0206, Training Accuracy: 0.1722 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1807, Matthews Correlation Coefficient: 0.0700
# Epoch [48/200], Training Loss: 0.0206, Training Accuracy: 0.1795 Validation Loss: 0.0207, Validation Accuracy: 0.1986 Macro F1: 0.1937, Matthews Correlation Coefficient: 0.0724
# Epoch [49/200], Training Loss: 0.0206, Training Accuracy: 0.1780 Validation Loss: 0.0207, Validation Accuracy: 0.1696 Macro F1: 0.1777, Matthews Correlation Coefficient: 0.0682
# Epoch [50/200], Training Loss: 0.0206, Training Accuracy: 0.1815 Validation Loss: 0.0207, Validation Accuracy: 0.1675 Macro F1: 0.1742, Matthews Correlation Coefficient: 0.0657
# Epoch [51/200], Training Loss: 0.0206, Training Accuracy: 0.1725 Validation Loss: 0.0207, Validation Accuracy: 0.1686 Macro F1: 0.1751, Matthews Correlation Coefficient: 0.0668
# Epoch [52/200], Training Loss: 0.0206, Training Accuracy: 0.1844 Validation Loss: 0.0207, Validation Accuracy: 0.1675 Macro F1: 0.1741, Matthews Correlation Coefficient: 0.0699
# Epoch [53/200], Training Loss: 0.0206, Training Accuracy: 0.1711 Validation Loss: 0.0207, Validation Accuracy: 0.1861 Macro F1: 0.1861, Matthews Correlation Coefficient: 0.0686
# Epoch [54/200], Training Loss: 0.0206, Training Accuracy: 0.1824 Validation Loss: 0.0207, Validation Accuracy: 0.1799 Macro F1: 0.1865, Matthews Correlation Coefficient: 0.0699
# Epoch [55/200], Training Loss: 0.0206, Training Accuracy: 0.1751 Validation Loss: 0.0207, Validation Accuracy: 0.1820 Macro F1: 0.1850, Matthews Correlation Coefficient: 0.0696
# Epoch [56/200], Training Loss: 0.0206, Training Accuracy: 0.1787 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1815, Matthews Correlation Coefficient: 0.0706
# Epoch [57/200], Training Loss: 0.0206, Training Accuracy: 0.1817 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1718, Matthews Correlation Coefficient: 0.0658
# Epoch [58/200], Training Loss: 0.0206, Training Accuracy: 0.1755 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1788, Matthews Correlation Coefficient: 0.0719
# Epoch [59/200], Training Loss: 0.0206, Training Accuracy: 0.1751 Validation Loss: 0.0207, Validation Accuracy: 0.1613 Macro F1: 0.1705, Matthews Correlation Coefficient: 0.0724
# Epoch [60/200], Training Loss: 0.0206, Training Accuracy: 0.1760 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1809, Matthews Correlation Coefficient: 0.0712
# Epoch [61/200], Training Loss: 0.0206, Training Accuracy: 0.1824 Validation Loss: 0.0207, Validation Accuracy: 0.1717 Macro F1: 0.1799, Matthews Correlation Coefficient: 0.0684
# Epoch [62/200], Training Loss: 0.0206, Training Accuracy: 0.1702 Validation Loss: 0.0208, Validation Accuracy: 0.1872 Macro F1: 0.1870, Matthews Correlation Coefficient: 0.0660
# Epoch [63/200], Training Loss: 0.0206, Training Accuracy: 0.1804 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1829, Matthews Correlation Coefficient: 0.0681
# Epoch [64/200], Training Loss: 0.0206, Training Accuracy: 0.1802 Validation Loss: 0.0207, Validation Accuracy: 0.1779 Macro F1: 0.1842, Matthews Correlation Coefficient: 0.0696
# Epoch [65/200], Training Loss: 0.0206, Training Accuracy: 0.1756 Validation Loss: 0.0207, Validation Accuracy: 0.1841 Macro F1: 0.1856, Matthews Correlation Coefficient: 0.0719
# Epoch [66/200], Training Loss: 0.0206, Training Accuracy: 0.1877 Validation Loss: 0.0207, Validation Accuracy: 0.1696 Macro F1: 0.1781, Matthews Correlation Coefficient: 0.0691
# Epoch [67/200], Training Loss: 0.0206, Training Accuracy: 0.1787 Validation Loss: 0.0207, Validation Accuracy: 0.1841 Macro F1: 0.1857, Matthews Correlation Coefficient: 0.0665
# Epoch [68/200], Training Loss: 0.0206, Training Accuracy: 0.1859 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1835, Matthews Correlation Coefficient: 0.0691
# Epoch [69/200], Training Loss: 0.0206, Training Accuracy: 0.1853 Validation Loss: 0.0207, Validation Accuracy: 0.1675 Macro F1: 0.1738, Matthews Correlation Coefficient: 0.0694
# Epoch [70/200], Training Loss: 0.0206, Training Accuracy: 0.1735 Validation Loss: 0.0207, Validation Accuracy: 0.1799 Macro F1: 0.1862, Matthews Correlation Coefficient: 0.0691
# Epoch [71/200], Training Loss: 0.0206, Training Accuracy: 0.1740 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1795, Matthews Correlation Coefficient: 0.0676
# Epoch [72/200], Training Loss: 0.0206, Training Accuracy: 0.1771 Validation Loss: 0.0207, Validation Accuracy: 0.1779 Macro F1: 0.1847, Matthews Correlation Coefficient: 0.0710
# Epoch [73/200], Training Loss: 0.0206, Training Accuracy: 0.1822 Validation Loss: 0.0207, Validation Accuracy: 0.1717 Macro F1: 0.1795, Matthews Correlation Coefficient: 0.0673
# Epoch [74/200], Training Loss: 0.0206, Training Accuracy: 0.1862 Validation Loss: 0.0207, Validation Accuracy: 0.1675 Macro F1: 0.1759, Matthews Correlation Coefficient: 0.0711
# Epoch [75/200], Training Loss: 0.0206, Training Accuracy: 0.1709 Validation Loss: 0.0208, Validation Accuracy: 0.1851 Macro F1: 0.1849, Matthews Correlation Coefficient: 0.0670
# Epoch [76/200], Training Loss: 0.0206, Training Accuracy: 0.1837 Validation Loss: 0.0207, Validation Accuracy: 0.1706 Macro F1: 0.1770, Matthews Correlation Coefficient: 0.0687
# Epoch [77/200], Training Loss: 0.0206, Training Accuracy: 0.1738 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1821, Matthews Correlation Coefficient: 0.0680
# Epoch [78/200], Training Loss: 0.0206, Training Accuracy: 0.1769 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1827, Matthews Correlation Coefficient: 0.0672
# Epoch [79/200], Training Loss: 0.0206, Training Accuracy: 0.1720 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1805, Matthews Correlation Coefficient: 0.0711
# Epoch [80/200], Training Loss: 0.0206, Training Accuracy: 0.1740 Validation Loss: 0.0207, Validation Accuracy: 0.1830 Macro F1: 0.1843, Matthews Correlation Coefficient: 0.0641
# Epoch [81/200], Training Loss: 0.0206, Training Accuracy: 0.1862 Validation Loss: 0.0207, Validation Accuracy: 0.1603 Macro F1: 0.1695, Matthews Correlation Coefficient: 0.0623
# Epoch [82/200], Training Loss: 0.0206, Training Accuracy: 0.1716 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1807, Matthews Correlation Coefficient: 0.0642
# Epoch [83/200], Training Loss: 0.0206, Training Accuracy: 0.1857 Validation Loss: 0.0207, Validation Accuracy: 0.1779 Macro F1: 0.1835, Matthews Correlation Coefficient: 0.0692
# Epoch [84/200], Training Loss: 0.0206, Training Accuracy: 0.1753 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1814, Matthews Correlation Coefficient: 0.0707
# Epoch [85/200], Training Loss: 0.0206, Training Accuracy: 0.1777 Validation Loss: 0.0207, Validation Accuracy: 0.1799 Macro F1: 0.1846, Matthews Correlation Coefficient: 0.0668
# Epoch [86/200], Training Loss: 0.0206, Training Accuracy: 0.1913 Validation Loss: 0.0207, Validation Accuracy: 0.1582 Macro F1: 0.1670, Matthews Correlation Coefficient: 0.0702
# Epoch [87/200], Training Loss: 0.0206, Training Accuracy: 0.1789 Validation Loss: 0.0207, Validation Accuracy: 0.1603 Macro F1: 0.1691, Matthews Correlation Coefficient: 0.0619
# Epoch [88/200], Training Loss: 0.0206, Training Accuracy: 0.1727 Validation Loss: 0.0207, Validation Accuracy: 0.1665 Macro F1: 0.1748, Matthews Correlation Coefficient: 0.0654
# Epoch [89/200], Training Loss: 0.0206, Training Accuracy: 0.1831 Validation Loss: 0.0207, Validation Accuracy: 0.1830 Macro F1: 0.1840, Matthews Correlation Coefficient: 0.0633
# Epoch [90/200], Training Loss: 0.0206, Training Accuracy: 0.1848 Validation Loss: 0.0207, Validation Accuracy: 0.1851 Macro F1: 0.1873, Matthews Correlation Coefficient: 0.0674
# Epoch [91/200], Training Loss: 0.0206, Training Accuracy: 0.1806 Validation Loss: 0.0207, Validation Accuracy: 0.1799 Macro F1: 0.1848, Matthews Correlation Coefficient: 0.0683
# Epoch [92/200], Training Loss: 0.0206, Training Accuracy: 0.1842 Validation Loss: 0.0208, Validation Accuracy: 0.2037 Macro F1: 0.1973, Matthews Correlation Coefficient: 0.0765
# Epoch [93/200], Training Loss: 0.0206, Training Accuracy: 0.1760 Validation Loss: 0.0207, Validation Accuracy: 0.1675 Macro F1: 0.1739, Matthews Correlation Coefficient: 0.0652
# Epoch [94/200], Training Loss: 0.0206, Training Accuracy: 0.1733 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1819, Matthews Correlation Coefficient: 0.0687
# Epoch [95/200], Training Loss: 0.0206, Training Accuracy: 0.1846 Validation Loss: 0.0207, Validation Accuracy: 0.1572 Macro F1: 0.1661, Matthews Correlation Coefficient: 0.0621
# Epoch [96/200], Training Loss: 0.0205, Training Accuracy: 0.1793 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1817, Matthews Correlation Coefficient: 0.0684
# Epoch [97/200], Training Loss: 0.0206, Training Accuracy: 0.1820 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1796, Matthews Correlation Coefficient: 0.0659
# Epoch [98/200], Training Loss: 0.0206, Training Accuracy: 0.1775 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1818, Matthews Correlation Coefficient: 0.0699
# Epoch [99/200], Training Loss: 0.0206, Training Accuracy: 0.1795 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1800, Matthews Correlation Coefficient: 0.0684
# Epoch [100/200], Training Loss: 0.0206, Training Accuracy: 0.1800 Validation Loss: 0.0207, Validation Accuracy: 0.1779 Macro F1: 0.1845, Matthews Correlation Coefficient: 0.0697
# Epoch [101/200], Training Loss: 0.0206, Training Accuracy: 0.1778 Validation Loss: 0.0207, Validation Accuracy: 0.1851 Macro F1: 0.1914, Matthews Correlation Coefficient: 0.0764
# Epoch [102/200], Training Loss: 0.0205, Training Accuracy: 0.1870 Validation Loss: 0.0207, Validation Accuracy: 0.1686 Macro F1: 0.1743, Matthews Correlation Coefficient: 0.0653
# Epoch [103/200], Training Loss: 0.0206, Training Accuracy: 0.1787 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1809, Matthews Correlation Coefficient: 0.0689
# Epoch [104/200], Training Loss: 0.0205, Training Accuracy: 0.1751 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1803, Matthews Correlation Coefficient: 0.0697
# Epoch [105/200], Training Loss: 0.0205, Training Accuracy: 0.1831 Validation Loss: 0.0207, Validation Accuracy: 0.1624 Macro F1: 0.1707, Matthews Correlation Coefficient: 0.0634
# Epoch [106/200], Training Loss: 0.0206, Training Accuracy: 0.1831 Validation Loss: 0.0207, Validation Accuracy: 0.1799 Macro F1: 0.1853, Matthews Correlation Coefficient: 0.0681
# Epoch [107/200], Training Loss: 0.0206, Training Accuracy: 0.1767 Validation Loss: 0.0208, Validation Accuracy: 0.1861 Macro F1: 0.1869, Matthews Correlation Coefficient: 0.0651
# Epoch [108/200], Training Loss: 0.0206, Training Accuracy: 0.1831 Validation Loss: 0.0207, Validation Accuracy: 0.1830 Macro F1: 0.1865, Matthews Correlation Coefficient: 0.0666
# Epoch [109/200], Training Loss: 0.0205, Training Accuracy: 0.1828 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1811, Matthews Correlation Coefficient: 0.0729
# Epoch [110/200], Training Loss: 0.0206, Training Accuracy: 0.1826 Validation Loss: 0.0207, Validation Accuracy: 0.1717 Macro F1: 0.1784, Matthews Correlation Coefficient: 0.0675
# Epoch [111/200], Training Loss: 0.0206, Training Accuracy: 0.1850 Validation Loss: 0.0207, Validation Accuracy: 0.1696 Macro F1: 0.1770, Matthews Correlation Coefficient: 0.0670
# Epoch [112/200], Training Loss: 0.0205, Training Accuracy: 0.1793 Validation Loss: 0.0207, Validation Accuracy: 0.1779 Macro F1: 0.1835, Matthews Correlation Coefficient: 0.0686
# Epoch [113/200], Training Loss: 0.0206, Training Accuracy: 0.1808 Validation Loss: 0.0207, Validation Accuracy: 0.1686 Macro F1: 0.1761, Matthews Correlation Coefficient: 0.0664
# Epoch [114/200], Training Loss: 0.0205, Training Accuracy: 0.1833 Validation Loss: 0.0207, Validation Accuracy: 0.1799 Macro F1: 0.1855, Matthews Correlation Coefficient: 0.0683
# Epoch [115/200], Training Loss: 0.0206, Training Accuracy: 0.1840 Validation Loss: 0.0207, Validation Accuracy: 0.1851 Macro F1: 0.1852, Matthews Correlation Coefficient: 0.0630
# Epoch [116/200], Training Loss: 0.0206, Training Accuracy: 0.1762 Validation Loss: 0.0207, Validation Accuracy: 0.1644 Macro F1: 0.1729, Matthews Correlation Coefficient: 0.0646
# Epoch [117/200], Training Loss: 0.0206, Training Accuracy: 0.1879 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1810, Matthews Correlation Coefficient: 0.0676
# Epoch [118/200], Training Loss: 0.0206, Training Accuracy: 0.1800 Validation Loss: 0.0207, Validation Accuracy: 0.1696 Macro F1: 0.1772, Matthews Correlation Coefficient: 0.0661
# Epoch [119/200], Training Loss: 0.0205, Training Accuracy: 0.1804 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1805, Matthews Correlation Coefficient: 0.0680
# Epoch [120/200], Training Loss: 0.0205, Training Accuracy: 0.1784 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1820, Matthews Correlation Coefficient: 0.0666
# Epoch [121/200], Training Loss: 0.0205, Training Accuracy: 0.1835 Validation Loss: 0.0207, Validation Accuracy: 0.1820 Macro F1: 0.1860, Matthews Correlation Coefficient: 0.0647
# Epoch [122/200], Training Loss: 0.0205, Training Accuracy: 0.1835 Validation Loss: 0.0207, Validation Accuracy: 0.1706 Macro F1: 0.1765, Matthews Correlation Coefficient: 0.0669
# Epoch [123/200], Training Loss: 0.0205, Training Accuracy: 0.1786 Validation Loss: 0.0207, Validation Accuracy: 0.1851 Macro F1: 0.1881, Matthews Correlation Coefficient: 0.0686
# Epoch [124/200], Training Loss: 0.0205, Training Accuracy: 0.1882 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1810, Matthews Correlation Coefficient: 0.0662
# Epoch [125/200], Training Loss: 0.0205, Training Accuracy: 0.1837 Validation Loss: 0.0207, Validation Accuracy: 0.1810 Macro F1: 0.1864, Matthews Correlation Coefficient: 0.0697
# Epoch [126/200], Training Loss: 0.0205, Training Accuracy: 0.1848 Validation Loss: 0.0208, Validation Accuracy: 0.1799 Macro F1: 0.1810, Matthews Correlation Coefficient: 0.0603
# Epoch [127/200], Training Loss: 0.0206, Training Accuracy: 0.1819 Validation Loss: 0.0207, Validation Accuracy: 0.1593 Macro F1: 0.1677, Matthews Correlation Coefficient: 0.0609
# Epoch [128/200], Training Loss: 0.0206, Training Accuracy: 0.1837 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1797, Matthews Correlation Coefficient: 0.0678
# Epoch [129/200], Training Loss: 0.0206, Training Accuracy: 0.1738 Validation Loss: 0.0207, Validation Accuracy: 0.1954 Macro F1: 0.1948, Matthews Correlation Coefficient: 0.0693
# Epoch [130/200], Training Loss: 0.0205, Training Accuracy: 0.1804 Validation Loss: 0.0207, Validation Accuracy: 0.1675 Macro F1: 0.1744, Matthews Correlation Coefficient: 0.0675
# Epoch [131/200], Training Loss: 0.0206, Training Accuracy: 0.1808 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1804, Matthews Correlation Coefficient: 0.0642
# Epoch [132/200], Training Loss: 0.0205, Training Accuracy: 0.1809 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1807, Matthews Correlation Coefficient: 0.0653
# Epoch [133/200], Training Loss: 0.0205, Training Accuracy: 0.1868 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1814, Matthews Correlation Coefficient: 0.0689
# Epoch [134/200], Training Loss: 0.0205, Training Accuracy: 0.1791 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1804, Matthews Correlation Coefficient: 0.0681
# Epoch [135/200], Training Loss: 0.0205, Training Accuracy: 0.1811 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1810, Matthews Correlation Coefficient: 0.0629
# Epoch [136/200], Training Loss: 0.0205, Training Accuracy: 0.1809 Validation Loss: 0.0207, Validation Accuracy: 0.1810 Macro F1: 0.1855, Matthews Correlation Coefficient: 0.0678
# Epoch [137/200], Training Loss: 0.0205, Training Accuracy: 0.1826 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1805, Matthews Correlation Coefficient: 0.0706
# Epoch [138/200], Training Loss: 0.0205, Training Accuracy: 0.1840 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1801, Matthews Correlation Coefficient: 0.0668
# Epoch [139/200], Training Loss: 0.0205, Training Accuracy: 0.1828 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1825, Matthews Correlation Coefficient: 0.0726
# Epoch [140/200], Training Loss: 0.0205, Training Accuracy: 0.1859 Validation Loss: 0.0207, Validation Accuracy: 0.1810 Macro F1: 0.1853, Matthews Correlation Coefficient: 0.0671
# Epoch [141/200], Training Loss: 0.0205, Training Accuracy: 0.1793 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1804, Matthews Correlation Coefficient: 0.0683
# Epoch [142/200], Training Loss: 0.0205, Training Accuracy: 0.1749 Validation Loss: 0.0207, Validation Accuracy: 0.1789 Macro F1: 0.1847, Matthews Correlation Coefficient: 0.0698
# Epoch [143/200], Training Loss: 0.0205, Training Accuracy: 0.1831 Validation Loss: 0.0207, Validation Accuracy: 0.1810 Macro F1: 0.1847, Matthews Correlation Coefficient: 0.0659
# Epoch [144/200], Training Loss: 0.0205, Training Accuracy: 0.1809 Validation Loss: 0.0208, Validation Accuracy: 0.1830 Macro F1: 0.1866, Matthews Correlation Coefficient: 0.0653
# Epoch [145/200], Training Loss: 0.0205, Training Accuracy: 0.1839 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1818, Matthews Correlation Coefficient: 0.0708
# Epoch [146/200], Training Loss: 0.0205, Training Accuracy: 0.1826 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1791, Matthews Correlation Coefficient: 0.0639
# Epoch [147/200], Training Loss: 0.0205, Training Accuracy: 0.1873 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1818, Matthews Correlation Coefficient: 0.0695
# Epoch [148/200], Training Loss: 0.0205, Training Accuracy: 0.1784 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1825, Matthews Correlation Coefficient: 0.0697
# Epoch [149/200], Training Loss: 0.0205, Training Accuracy: 0.1861 Validation Loss: 0.0207, Validation Accuracy: 0.1665 Macro F1: 0.1746, Matthews Correlation Coefficient: 0.0676
# Epoch [150/200], Training Loss: 0.0205, Training Accuracy: 0.1881 Validation Loss: 0.0207, Validation Accuracy: 0.1541 Macro F1: 0.1621, Matthews Correlation Coefficient: 0.0633
# Epoch [151/200], Training Loss: 0.0206, Training Accuracy: 0.1680 Validation Loss: 0.0207, Validation Accuracy: 0.1820 Macro F1: 0.1868, Matthews Correlation Coefficient: 0.0678
# Epoch [152/200], Training Loss: 0.0205, Training Accuracy: 0.1804 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1832, Matthews Correlation Coefficient: 0.0717
# Epoch [153/200], Training Loss: 0.0205, Training Accuracy: 0.1846 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1794, Matthews Correlation Coefficient: 0.0665
# Epoch [154/200], Training Loss: 0.0205, Training Accuracy: 0.1839 Validation Loss: 0.0207, Validation Accuracy: 0.1799 Macro F1: 0.1846, Matthews Correlation Coefficient: 0.0680
# Epoch [155/200], Training Loss: 0.0205, Training Accuracy: 0.1773 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1822, Matthews Correlation Coefficient: 0.0721
# Epoch [156/200], Training Loss: 0.0205, Training Accuracy: 0.1835 Validation Loss: 0.0207, Validation Accuracy: 0.1675 Macro F1: 0.1754, Matthews Correlation Coefficient: 0.0678
# Epoch [157/200], Training Loss: 0.0205, Training Accuracy: 0.1833 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1814, Matthews Correlation Coefficient: 0.0688
# Epoch [158/200], Training Loss: 0.0205, Training Accuracy: 0.1815 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1797, Matthews Correlation Coefficient: 0.0692
# Epoch [159/200], Training Loss: 0.0205, Training Accuracy: 0.1808 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1826, Matthews Correlation Coefficient: 0.0687
# Epoch [160/200], Training Loss: 0.0205, Training Accuracy: 0.1758 Validation Loss: 0.0207, Validation Accuracy: 0.1841 Macro F1: 0.1877, Matthews Correlation Coefficient: 0.0657
# Epoch [161/200], Training Loss: 0.0205, Training Accuracy: 0.1833 Validation Loss: 0.0207, Validation Accuracy: 0.1799 Macro F1: 0.1856, Matthews Correlation Coefficient: 0.0718
# Epoch [162/200], Training Loss: 0.0205, Training Accuracy: 0.1800 Validation Loss: 0.0207, Validation Accuracy: 0.1789 Macro F1: 0.1844, Matthews Correlation Coefficient: 0.0675
# Epoch [163/200], Training Loss: 0.0205, Training Accuracy: 0.1839 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1801, Matthews Correlation Coefficient: 0.0667
# Epoch [164/200], Training Loss: 0.0205, Training Accuracy: 0.1817 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1815, Matthews Correlation Coefficient: 0.0686
# Epoch [165/200], Training Loss: 0.0205, Training Accuracy: 0.1824 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1823, Matthews Correlation Coefficient: 0.0699
# Epoch [166/200], Training Loss: 0.0205, Training Accuracy: 0.1864 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1808, Matthews Correlation Coefficient: 0.0685
# Epoch [167/200], Training Loss: 0.0205, Training Accuracy: 0.1806 Validation Loss: 0.0208, Validation Accuracy: 0.1923 Macro F1: 0.1904, Matthews Correlation Coefficient: 0.0723
# Epoch [168/200], Training Loss: 0.0205, Training Accuracy: 0.1767 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1834, Matthews Correlation Coefficient: 0.0696
# Epoch [169/200], Training Loss: 0.0205, Training Accuracy: 0.1817 Validation Loss: 0.0207, Validation Accuracy: 0.1665 Macro F1: 0.1745, Matthews Correlation Coefficient: 0.0699
# Epoch [170/200], Training Loss: 0.0205, Training Accuracy: 0.1855 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1827, Matthews Correlation Coefficient: 0.0670
# Epoch [171/200], Training Loss: 0.0205, Training Accuracy: 0.1853 Validation Loss: 0.0207, Validation Accuracy: 0.1655 Macro F1: 0.1740, Matthews Correlation Coefficient: 0.0655
# Epoch [172/200], Training Loss: 0.0205, Training Accuracy: 0.1745 Validation Loss: 0.0207, Validation Accuracy: 0.1830 Macro F1: 0.1879, Matthews Correlation Coefficient: 0.0705
# Epoch [173/200], Training Loss: 0.0205, Training Accuracy: 0.1893 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1807, Matthews Correlation Coefficient: 0.0678
# Epoch [174/200], Training Loss: 0.0205, Training Accuracy: 0.1756 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1801, Matthews Correlation Coefficient: 0.0704
# Epoch [175/200], Training Loss: 0.0205, Training Accuracy: 0.1795 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1825, Matthews Correlation Coefficient: 0.0670
# Epoch [176/200], Training Loss: 0.0205, Training Accuracy: 0.1797 Validation Loss: 0.0207, Validation Accuracy: 0.1799 Macro F1: 0.1845, Matthews Correlation Coefficient: 0.0682
# Epoch [177/200], Training Loss: 0.0205, Training Accuracy: 0.1835 Validation Loss: 0.0207, Validation Accuracy: 0.1686 Macro F1: 0.1762, Matthews Correlation Coefficient: 0.0657
# Epoch [178/200], Training Loss: 0.0205, Training Accuracy: 0.1764 Validation Loss: 0.0207, Validation Accuracy: 0.1665 Macro F1: 0.1747, Matthews Correlation Coefficient: 0.0653
# Epoch [179/200], Training Loss: 0.0205, Training Accuracy: 0.1762 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1819, Matthews Correlation Coefficient: 0.0696
# Epoch [180/200], Training Loss: 0.0205, Training Accuracy: 0.1809 Validation Loss: 0.0207, Validation Accuracy: 0.1727 Macro F1: 0.1797, Matthews Correlation Coefficient: 0.0671
# Epoch [181/200], Training Loss: 0.0205, Training Accuracy: 0.1806 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1825, Matthews Correlation Coefficient: 0.0699
# Epoch [182/200], Training Loss: 0.0204, Training Accuracy: 0.1859 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1816, Matthews Correlation Coefficient: 0.0676
# Epoch [183/200], Training Loss: 0.0205, Training Accuracy: 0.1808 Validation Loss: 0.0207, Validation Accuracy: 0.1810 Macro F1: 0.1850, Matthews Correlation Coefficient: 0.0638
# Epoch [184/200], Training Loss: 0.0205, Training Accuracy: 0.1859 Validation Loss: 0.0207, Validation Accuracy: 0.1675 Macro F1: 0.1753, Matthews Correlation Coefficient: 0.0651
# Epoch [185/200], Training Loss: 0.0205, Training Accuracy: 0.1766 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1824, Matthews Correlation Coefficient: 0.0690
# Epoch [186/200], Training Loss: 0.0205, Training Accuracy: 0.1820 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1807, Matthews Correlation Coefficient: 0.0696
# Epoch [187/200], Training Loss: 0.0204, Training Accuracy: 0.1829 Validation Loss: 0.0207, Validation Accuracy: 0.1644 Macro F1: 0.1733, Matthews Correlation Coefficient: 0.0729
# Epoch [188/200], Training Loss: 0.0205, Training Accuracy: 0.1738 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1835, Matthews Correlation Coefficient: 0.0706
# Epoch [189/200], Training Loss: 0.0205, Training Accuracy: 0.1811 Validation Loss: 0.0206, Validation Accuracy: 0.1768 Macro F1: 0.1834, Matthews Correlation Coefficient: 0.0702
# Epoch [190/200], Training Loss: 0.0205, Training Accuracy: 0.1868 Validation Loss: 0.0207, Validation Accuracy: 0.1655 Macro F1: 0.1738, Matthews Correlation Coefficient: 0.0696
# Epoch [191/200], Training Loss: 0.0205, Training Accuracy: 0.1840 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1814, Matthews Correlation Coefficient: 0.0700
# Epoch [192/200], Training Loss: 0.0205, Training Accuracy: 0.1802 Validation Loss: 0.0206, Validation Accuracy: 0.1737 Macro F1: 0.1809, Matthews Correlation Coefficient: 0.0698
# Epoch [193/200], Training Loss: 0.0205, Training Accuracy: 0.1861 Validation Loss: 0.0207, Validation Accuracy: 0.1758 Macro F1: 0.1778, Matthews Correlation Coefficient: 0.0575
# Epoch [194/200], Training Loss: 0.0204, Training Accuracy: 0.1868 Validation Loss: 0.0207, Validation Accuracy: 0.1686 Macro F1: 0.1760, Matthews Correlation Coefficient: 0.0669
# Epoch [195/200], Training Loss: 0.0205, Training Accuracy: 0.1835 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1806, Matthews Correlation Coefficient: 0.0694
# Epoch [196/200], Training Loss: 0.0205, Training Accuracy: 0.1811 Validation Loss: 0.0207, Validation Accuracy: 0.1737 Macro F1: 0.1807, Matthews Correlation Coefficient: 0.0692
# Epoch [197/200], Training Loss: 0.0205, Training Accuracy: 0.1777 Validation Loss: 0.0207, Validation Accuracy: 0.1768 Macro F1: 0.1805, Matthews Correlation Coefficient: 0.0622
# Epoch [198/200], Training Loss: 0.0205, Training Accuracy: 0.1829 Validation Loss: 0.0207, Validation Accuracy: 0.1830 Macro F1: 0.1860, Matthews Correlation Coefficient: 0.0650
# Epoch [199/200], Training Loss: 0.0205, Training Accuracy: 0.1855 Validation Loss: 0.0207, Validation Accuracy: 0.1665 Macro F1: 0.1744, Matthews Correlation Coefficient: 0.0665
# Epoch [200/200], Training Loss: 0.0205, Training Accuracy: 0.1840 Validation Loss: 0.0207, Validation Accuracy: 0.1748 Macro F1: 0.1797, Matthews Correlation Coefficient: 0.0664

# %% [markdown]
# ### Helper function to calculate cf, precision and recall

# %%
# Function to calculate the precision and recall
def calculate_metrics(dataloader, model):
    y_pred = []
    y_true = []
    
    model.eval()
    with torch.no_grad():
        
        # iterate over validation data
        for X, y in dataloader:
            
            X = X.to(torch.float32)
            X = X.to(device)
            output = model(X)  # Feed Network

            output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
            y_pred.extend(output)  # Save Prediction

            labels = y.cpu().numpy()
            y_true.extend(labels)  # Save Truth

    # Calculate confusion matrix
    cf_matrix = confusion_matrix(y_true, y_pred)

    # Calculate precision and recall for each class
    precision = precision_score(y_true, y_pred, average=None, zero_division=0)
    recall = recall_score(y_true, y_pred, average=None, zero_division=0)
    macro_f1 = f1_score(y_true, y_pred, average='macro')
    mcc = matthews_corrcoef(y_true, y_pred)

    return cf_matrix, precision, recall, macro_f1, mcc

# %% [markdown]
# ### Helper function to visualize confusion matrices

# %%
# make a function that visualize 5 confusion matrices from 5 data loaders, and stack them into one figure, 3 by 2
def plot_confusion_matrices(cf_matrices, labels, title):
    fig, axes = plt.subplots(2, 3, figsize=(10, 6))
    axes = axes.flatten()
    
    for i, cf_matrix in enumerate(cf_matrices):
        sns.heatmap(cf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
                    xticklabels=labels, yticklabels=labels, ax=axes[i])
        #axes[i].set_xlabel('Predicted')
        #axes[i].set_ylabel('True')
        axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
        axes[i].set_title(title[i])
    
    # remove the last empty subplot
    for j in range(i+1, len(axes)):
        fig.delaxes(axes[j])

    # set an overall x and y label for the entire figure
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to make space for the title
    fig.subplots_adjust(hspace=0.4, wspace=0.4)
    fig.text(0.5, 0, 'Predicted', ha='center', fontdict={'size': 16})
    fig.text(0, 0.5, 'True', va='center', rotation='vertical', fontdict={'size': 16})

    #fig.xlabel('Predicted')
    #fig.ylabel('True')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Testing

# %%
# Read in the synthetic data
# Mertins 
#   proteome
M_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'M_PD_synthetic_kde_qttumor.csv'))
M_PD_synthetic.index = M_PD_synthetic.loc[:,'Index']
M_PD_synthetic = M_PD_synthetic.loc[:, M_PD_synthetic.columns!='Index']

#   transcriptome
M_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'M_MD_synthetic_kde_qttumor.csv'))
M_MD_synthetic.index = M_MD_synthetic.loc[:,'gene_name']
M_MD_synthetic = M_MD_synthetic.loc[:, M_MD_synthetic.columns!='gene_name']


# LCSCC tumor
#   proteome
lung_tumor_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_tumor_PD_synthetic_kde_qttumor.csv'))
lung_tumor_PD_synthetic.index = lung_tumor_PD_synthetic.loc[:,'Gene']
lung_tumor_PD_synthetic = lung_tumor_PD_synthetic.loc[:, lung_tumor_PD_synthetic.columns!='Gene']

#   transcriptome
lung_tumor_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_tumor_MD_synthetic_kde_qttumor.csv'))
lung_tumor_MD_synthetic.index = lung_tumor_MD_synthetic.loc[:,'gene_name']
lung_tumor_MD_synthetic = lung_tumor_MD_synthetic.loc[:, lung_tumor_MD_synthetic.columns!='gene_name']

# LCSCC NAT
#   proteome
lung_nat_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_nat_PD_synthetic_kde_qttumor.csv'))
lung_nat_PD_synthetic.index = lung_nat_PD_synthetic.loc[:,'Gene']
lung_nat_PD_synthetic = lung_nat_PD_synthetic.loc[:, lung_nat_PD_synthetic.columns!='Gene']

#   transcriptome
lung_nat_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_nat_MD_synthetic_kde_qttumor.csv'))
lung_nat_MD_synthetic.index = lung_nat_MD_synthetic.loc[:,'gene_name']
lung_nat_MD_synthetic = lung_nat_MD_synthetic.loc[:, lung_nat_MD_synthetic.columns!='gene_name']

# Brain glioma
#   proteome
glioma_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'glioma_tumor_PD_synthetic_kde_qttumor.csv'))
glioma_PD_synthetic.index = glioma_PD_synthetic.loc[:,'gene_name']
glioma_PD_synthetic = glioma_PD_synthetic.loc[:, glioma_PD_synthetic.columns!='gene_name']

#   transcriptome
glioma_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'glioma_tumor_MD_synthetic_kde_qttumor.csv'))
glioma_MD_synthetic.index = glioma_MD_synthetic.loc[:,'gene_name']
glioma_MD_synthetic = glioma_MD_synthetic.loc[:, glioma_MD_synthetic.columns!='gene_name']

# %%
# Breast
# Read in the label
LD_mcf7 = pd.read_csv(Path(label_path+'markers_mcf7_all.txt'), sep='\t')
LD_mcf7.index = LD_mcf7.loc[:,'Protein']
LD_mcf7 = LD_mcf7.loc[:,LD_mcf7.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_mcf7.loc[:,'Localization'] != 'Unclassified'
LD_mcf7 = LD_mcf7.loc[NotUnclassInd,:]

# Lung
LD_h322 = pd.read_csv(Path(label_path+'markers_h322_all.txt'), sep='\t')
LD_h322.index = LD_h322.loc[:,'Protein']
LD_h322 = LD_h322.loc[:,LD_h322.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_h322.loc[:,'Localization'] != 'Unclassified'
LD_h322 = LD_h322.loc[NotUnclassInd,:]

# Lung
LD_u251 = pd.read_csv(Path(label_path+'markers_u251_all.txt'), sep='\t')
LD_u251.index = LD_u251.loc[:,'Protein']
LD_u251 = LD_u251.loc[:,LD_u251.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_u251.loc[:,'Localization'] != 'Unclassified'
LD_u251 = LD_u251.loc[NotUnclassInd,:]

# %%
M_common_indices = list(set(M_PD_synthetic.index).intersection(set(M_MD_synthetic.index)))
M_LD = LD_mcf7.loc[LD_mcf7.index.isin(M_common_indices)]

lung_tumor_common_indices = list(set(lung_tumor_PD_synthetic.index).intersection(set(lung_tumor_MD_synthetic.index)))
lung_tumor_LD = LD_h322.loc[LD_h322.index.isin(lung_tumor_common_indices)]

lung_nat_common_indices = list(set(lung_nat_PD_synthetic.index).intersection(set(lung_nat_MD_synthetic.index)))
lung_nat_LD = LD_h322.loc[LD_h322.index.isin(lung_nat_common_indices)]

glioma_common_indices = list(set(glioma_PD_synthetic.index).intersection(set(glioma_MD_synthetic.index)))
glioma_LD = LD_u251.loc[LD_u251.index.isin(glioma_common_indices)]

# Convert string labels to integers
M_test_labels = [label_to_int[label] for label in M_LD['Localization'].values]
lung_tumor_test_labels = [label_to_int[label] for label in lung_tumor_LD['Localization'].values]
lung_nat_test_labels = [label_to_int[label] for label in lung_nat_LD['Localization'].values]
glioma_test_labels = [label_to_int[label] for label in glioma_LD['Localization'].values]

# Create the test datasets
if Set == 'Protein':
    M_test_dataset = OmicsDatasetDual(Set, M_PD_synthetic, M_PD_synthetic, M_PD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = OmicsDatasetDual(Set, lung_tumor_PD_synthetic, lung_tumor_PD_synthetic, lung_tumor_PD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = OmicsDatasetDual(Set, lung_nat_PD_synthetic, lung_nat_PD_synthetic, lung_nat_PD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = OmicsDatasetDual(Set, glioma_PD_synthetic, glioma_PD_synthetic, glioma_PD_synthetic.index, glioma_test_labels)
elif Set == 'mRNA':
    M_test_dataset = OmicsDatasetDual(Set, M_MD_synthetic, M_MD_synthetic, M_MD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = OmicsDatasetDual(Set, lung_tumor_MD_synthetic, lung_tumor_MD_synthetic, lung_tumor_MD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = OmicsDatasetDual(Set, lung_nat_MD_synthetic, lung_nat_MD_synthetic, lung_nat_MD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = OmicsDatasetDual(Set, glioma_MD_synthetic, glioma_MD_synthetic, glioma_MD_synthetic.index, glioma_test_labels)
elif Set == 'Protein + mRNA':
    M_test_dataset = OmicsDatasetDual(Set, M_PD_synthetic, M_MD_synthetic, M_PD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = OmicsDatasetDual(Set, lung_tumor_PD_synthetic, lung_tumor_MD_synthetic, lung_tumor_PD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = OmicsDatasetDual(Set, lung_nat_PD_synthetic, lung_nat_MD_synthetic, lung_nat_PD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = OmicsDatasetDual(Set, glioma_PD_synthetic, glioma_MD_synthetic, glioma_PD_synthetic.index, glioma_test_labels)
else:
    raise ValueError("Invalid dataset selection. Choose 'Protein', 'mRNA', 'Protein + mRNA', 'Protein + mRNA Stack'.")

# Create the test data loaders
set_seed(Seed)
M_test_loader = DataLoader(M_test_dataset, batch_size=Batch_size, shuffle=False)
lung_tumor_test_loader = DataLoader(lung_tumor_test_dataset, batch_size=Batch_size, shuffle=False)
lung_nat_test_loader = DataLoader(lung_nat_test_dataset, batch_size=Batch_size, shuffle=False)
glioma_test_loader = DataLoader(glioma_test_dataset, batch_size=Batch_size, shuffle=False)

# %% [markdown]
# ## Metrics

# %% [markdown]
# ### Fig 1: training and validation loss

# %%
# Graph loss for training and validation
figure1 = plt.gcf()
plt.plot(LossAccDF['Epoch'], LossAccDF['TrainLoss'])
plt.plot(LossAccDF['Epoch'], LossAccDF['ValLoss'])
plt.xlim([0,epochs])
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(axis='x', labelsize=13)
plt.tick_params(axis='y', labelsize=13)
plt.legend(['Training', 'Validation'], fontsize=14)

# Save figure into figure bank
figure1.savefig(Path(fig_bank_path+Set+'_Loss.png'), dpi=300)

# %% [markdown]
# ### Fig 2: training and validation accuracy

# %%
# Graph accuracy for training and validation
figure2 = plt.gcf()
plt.plot(LossAccDF['Epoch'], (LossAccDF['TrainAcc'])*100)
plt.plot(LossAccDF['Epoch'], (LossAccDF['ValAcc'])*100)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Accuracy (%)', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(axis='x', labelsize=13)
plt.tick_params(axis='y', labelsize=13)
plt.xlim([0,epochs])
plt.ylim([0,100])
plt.legend(['Training', 'Validation'], fontsize=14)

# Save figure into figure bank
figure2.savefig(Path(fig_bank_path+Set+'_Acc.png'), dpi=300)

# %% [markdown]
# ### Fig 3: confusion matrices

# %%
# Set seed
set_seed(Seed)

# Get the confusion matrix and precision and recall for the validation loader and all test loaders
cf_matrix_val, precision_val, recall_val, macro_f1_val, mcc_val = calculate_metrics(val_loader, model)
cf_matrix_M, precision_M, recall_M, macro_f1_M, mcc_M = calculate_metrics(M_test_loader, model)
cf_matrix_lung_tumor, precision_lung_tumor, recall_lung_tumor, macro_f1_lung_tumor, mcc_lung_tumor = calculate_metrics(lung_tumor_test_loader, model)
cf_matrix_lung_nat, precision_lung_nat, recall_lung_nat, macro_f1_lung_nat, mcc_lung_nat = calculate_metrics(lung_nat_test_loader, model)
cf_matrix_glioma, precision_glioma, recall_glioma, macro_f1_glioma, mcc_glioma = calculate_metrics(glioma_test_loader, model)

# Put them into a list
cf_matrices = [cf_matrix_val, cf_matrix_M, cf_matrix_lung_tumor, cf_matrix_lung_nat, cf_matrix_glioma]
titles = ['Krug Validation', 'Mertins Test ', 'Lung Tumor Test', 'Lung NAT Test', 'Glioma Test']

# Plot the confusion matrices
plot_confusion_matrices(cf_matrices, labels=int_to_label.values(), title=titles)

# Save figure into figure bank
figure3 = plt.gcf()
figure3.savefig(Path(fig_bank_path+Set+'_Confusion_Matrices.png'), dpi=300)

# %% [markdown]
# ### Fig 4: macro F1 and MCC

# %%
PrecisionRecallDF
# Out:
#      Epoch  Class  Precision    Recall  Macro F1       MCC
# 0      0.0    0.0   0.000000  0.000000  0.035096  0.000000
# 1      0.0    1.0   0.075491  1.000000  0.035096  0.000000
# 2      0.0    2.0   0.000000  0.000000  0.035096  0.000000
# 3      0.0    3.0   0.000000  0.000000  0.035096  0.000000
# 4      1.0    0.0   0.000000  0.000000  0.035096  0.000000
# ..     ...    ...        ...       ...       ...       ...
# 799  199.0    3.0   0.293103  0.260204  0.174367  0.066539
# 800  200.0    0.0   0.000000  0.000000  0.179687  0.066375
# 801  200.0    1.0   0.083994  0.726027  0.179687  0.066375
# 802  200.0    2.0   0.385027  0.262774  0.179687  0.066375
# 803  200.0    3.0   0.297297  0.224490  0.179687  0.066375
#
# [804 rows x 6 columns]

# %%
# Plot macro F1 and MCC score in PrecisionRecallDF vs epoch
figure4 = plt.gcf()
plt.plot(PrecisionRecallDF['Epoch'], PrecisionRecallDF['Macro F1'])
plt.plot(PrecisionRecallDF['Epoch'], PrecisionRecallDF['MCC'])
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Score', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(axis='x', labelsize=13)
plt.tick_params(axis='y', labelsize=13)
plt.xlim([0,epochs])
plt.ylim([-1,1])
plt.legend(['Macro F1', 'MCC'], fontsize=14)
# Save figure into figure bank
figure4.savefig(Path(fig_bank_path+Set+'_MacroF1_MCC.png'), dpi=300)
# Save the model

# %% [markdown]
# ### Fig 5: Precision and recall of validation and testing

# %%
def compute_bootstrap_ci(dataloader, num_iterations=10000, confidence_percentile=95):
    """
    Computes precision, recall, and F1-score confidence intervals using bootstrapping.

    Parameters:
    - dataloader: DataLoader containing the dataset (can be any dataset, not specifically validation)
    - num_iterations: Number of bootstrap iterations (default: 10000)
    - confidence_percentile: The percentile for confidence intervals (default: 95)

    Returns:
    - f1_final_array: The confidence interval values for F1-score
    """
    
    # Initialize a Counter to store class counts in the dataset
    class_counts = Counter()

    # Iterate over the DataLoader to count occurrences of each class
    for _, labels in dataloader:
        class_counts.update(labels.numpy())

    # Sort the class distribution and convert counts to percentages
    class_names = ['Cytosolic', 'Mitochondrial', 'Nuclear', 'Secretory']
    total_samples = len(dataloader.dataset)

    class_distribution = [(class_names[label], round(count / total_samples * 10000)) for label, count in sorted(class_counts.items())]

    # Create a vector of 10,000 true labels based on the class distribution
    true_labels_vector = np.array([class_name for class_name, count in class_distribution for _ in range(count)])
    random.shuffle(true_labels_vector)

    # Sample predicted labels randomly from true_labels_vector
    pred_labels_vector = np.random.choice(true_labels_vector, size=10000, replace=True)

    # Ensure both vectors have the same shape
    assert true_labels_vector.shape == pred_labels_vector.shape

    # Initialize arrays for storing precision, recall, and F1 scores
    precision_array = np.zeros((len(class_counts), num_iterations))
    recall_array = np.zeros((len(class_counts), num_iterations))
    f1_array = np.zeros((len(class_counts), num_iterations))

    # Perform bootstrapping by shuffling labels and computing metrics
    for i in range(num_iterations):
        # Shuffle the true and predicted labels independently
        #shuffled_true = np.random.permutation(true_labels_vector)
        shuffled_pred = np.random.permutation(pred_labels_vector)

        # Compute precision and recall for each class
        precision = precision_score(shuffled_true, shuffled_pred, average=None, zero_division=0)
        recall = recall_score(shuffled_true, shuffled_pred, average=None, zero_division=0)

        # Compute F1-score, handling division by zero safely
        f1 = np.where((precision + recall) == 0, 0, 
                      2 * (precision * recall) / (precision + recall))

        # Store results in the respective arrays
        precision_array[:, i] = precision
        recall_array[:, i] = recall
        f1_array[:, i] = f1

    # Sort each row in the arrays from smallest to largest
    f1_array_sorted = np.sort(f1_array, axis=1)

    # Extract the confidence percentile value (e.g., 95th percentile)
    ci_index = int(num_iterations * (confidence_percentile / 100)) - 1  # Zero-based index

    f1_final_array = f1_array_sorted[:, ci_index]

    return f1_final_array

# %%
# val_ci_f1_array = compute_bootstrap_ci(val_dataloader, num_iterations=10000, confidence_percentile=95)
# M_ci_f1_array = compute_bootstrap_ci(M_test_dataloader, num_iterations=10000, confidence_percentile=95)
# JM_ci_f1_array = compute_bootstrap_ci(JM_test_dataloader, num_iterations=10000, confidence_percentile=95)

# %%
val_ci_f1_array = np.array([0.43314056, 0.09879518, 0.30857335, 0.20966921])

# %%
M_ci_f1_array = np.array([0.45134342, 0.0976801 , 0.29827316, 0.20153805])

# %%
JM_ci_f1_array = np.array([0.44705614, 0.09885473, 0.29755245, 0.20585948])

# %%
set_seed(Seed)
fig, axes = plt.subplots(2, 2, figsize=(14, 12))
axes = axes.flatten()
compartment_class = ['Cytosolic', 'Mitochondria', 'Nuclear', 'Secretory']
colormaps = [cm.Blues, cm.Oranges, cm.Greens, cm.Purples]

# Function to filter improvement epochs using precision as the guide
def filter_improvement_epochs(df):
    improved_epochs = []
    for class_label in df['Class'].unique():
        class_df = df[df['Class'] == class_label].copy()
        class_df = class_df.sort_values(by='Epoch')
        max_precision = float('-inf')
        
        for _, row in class_df.iterrows():
            if row['Precision'] >= max_precision:
                max_precision = row['Precision']
                improved_epochs.append(row)
    
    # Ensure starting (0) and ending (last) epochs are included
    start_epoch = df[df['Epoch'] == 0]
    last_epoch = df[df['Epoch'] == df['Epoch'].max()]
    
    return pd.concat([start_epoch, pd.DataFrame(improved_epochs), last_epoch]).drop_duplicates()

# Get improvement epochs based on precision
improved_epochs_df = filter_improvement_epochs(PrecisionRecallDF)

for i, f1_score in enumerate(np.array([0.43314056, 0.09879518, 0.30857335, 0.20966921])):
    # Select the subplot
    ax = axes[i]

    # Filter the metrics for the current class
    class_metrics = improved_epochs_df[improved_epochs_df['Class'] == i]
    # Normalize epoch for color mapping
    norm = plt.Normalize(class_metrics['Epoch'].min(), class_metrics['Epoch'].max())

    # Scatter plot with gradient color based on epoch
    for idx, row in class_metrics.iterrows():
        color = colormaps[i](norm(row['Epoch']))
        edge_color = colormaps[i](0.8)
        ax.scatter(row['Recall'], row['Precision'], s=100, color=color, edgecolors=edge_color, linewidths=1)

    # Connect the dots with colored lines
    ax.plot(class_metrics['Recall'], class_metrics['Precision'], color=colormaps[i](0.5), linewidth=2)

    # Plot the F1 score curve
    x_left = np.linspace(0, (f1_score / 2), 10000)
    x_right = np.linspace((f1_score / 2), 1, 10000)
    y_right = f1_score * x_right / (2 * x_right - f1_score)
    ax.plot(x_right, y_right, color=colormaps[i](0.5), linestyle='--', linewidth=2)
    # Fill the area on the left of the curve
    ax.fill_between(x_left, 0, 1, color=colormaps[i](0.5), alpha=0.3)
    ax.fill_between(x_right, 0, y_right, color=colormaps[i](0.5), alpha=0.3)

    # Add in a scatter dot to label the precision and recall of testing set
    ax.scatter(recall_M[i], precision_M[i], s=100, color='red', edgecolors='red', linewidths=1, marker='s')
    ax.scatter(recall_lung_tumor[i], precision_lung_tumor[i], s=100, color='purple', edgecolors='purple', linewidths=1, marker='s')
    ax.scatter(recall_lung_nat[i], precision_lung_nat[i], s=100, color='orange', edgecolors='orange', linewidths=1, marker='s')
    ax.scatter(recall_glioma[i], precision_glioma[i], s=100, color='green', edgecolors='green', linewidths=1, marker='s')

    # Aesthetics
    ax.tick_params(axis='x', labelsize=14)
    ax.tick_params(axis='y', labelsize=14)
    ax.set_title(compartment_class[i], fontsize=16)
    ax.set_xlim([0, 1])
    ax.set_ylim([0, 1])
    ax.set_xlabel('Recall (Sensitivity)', fontsize=14)
    ax.set_ylabel('Precision (Positive Predictive Value)', fontsize=14)
    ax.grid(True)

    # Create custom legend handles
    mertins_handle = mlines.Line2D([], [], color='red', marker='s', linestyle='None', markersize=10, label='Mertins test set')
    lung_tumor_handle = mlines.Line2D([], [], color='purple', marker='s', linestyle='None', markersize=10, label='LSCC Tumor test set')
    lung_nat_handle = mlines.Line2D([], [], color='orange', marker='s', linestyle='None', markersize=10, label='LSCC NAT test set')
    glioma_handle = mlines.Line2D([], [], color='green', marker='s', linestyle='None', markersize=10, label='Glioma test set')

    # Add the legend to the plot
    ax.legend(handles=[mertins_handle, lung_tumor_handle, lung_nat_handle, glioma_handle], loc='upper right', fontsize=14)

plt.tight_layout()
plt.show()

# Save figure into figure bank
figure5 = plt.gcf()
figure5.savefig(Path(fig_bank_path+Set+'_Precision_Recall_F1curve.png'), dpi=300)
# Save the model
# Out:
# /tmp/ipykernel_18777/2350277031.py:50: RuntimeWarning: divide by zero encountered in divide
#   y_right = f1_score * x_right / (2 * x_right - f1_score)

# %%
# export dataframes
LossAccDF.to_excel(Path(fig_bank_path + Set+ f'LossAccDF.xlsx'), index=False)
PrecisionRecallDF.to_excel(Path(fig_bank_path + Set+ f'PrecisionRecallDF.xlsx'), index=False)
