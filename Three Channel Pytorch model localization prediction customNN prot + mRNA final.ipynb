# %% [markdown]
# # Training (Protein + mRNA)

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Package imports

# %%
# Import packages
import re
import os
import gc
import copy
from pathlib import Path
import numpy as np
from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence
import pandas as pd
import math
import random
import datetime
import time
import warnings
from pdb import set_trace
from collections import Counter

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
import seaborn as sns

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, matthews_corrcoef
from sklearn.preprocessing import LabelEncoder

import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Sampler
from torchvision import models, transforms

# %% [markdown]
# ### GPU

# %%
# Check to see if the GPU is available and store it as a variable so tensors can be moved to it
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print('Is cuda available?:', torch.cuda.is_available())
print('cuda version:', torch.version.cuda)
dev = "cuda:0"
# Out:
# Using device: cuda
# Is cuda available?: True
# cuda version: 12.4

# %% [markdown]
# ### Variables and Hyperparameters

# %%
# Create run name
Run_Name = 'Prot + mRNA' # change run_name before running

# Paths
label_path = '/home/ec2-user/Feb2025/labels/' # label folder with all the labels
dataset_folder_path = '/home/ec2-user/Feb2025/processed_dataset2/' # dataset folder with all the processed proteome and mRNA data
model_folder_path = '/home/ec2-user/Feb2025/saved_models/' # model folder with all the models
fig_bank_path = '/home/ec2-user/Feb2025/NN_figure_bank/' # figure bank folder with all the figures
cv_folder_path = '/home/ec2-user/Feb2025/NN_CV_bank/' # cross-validation folder with all the cross-validation results

# Define the Model
Model = 'PixelPreserve' # 'PixelPreserve' are the options

# Dataset
Set = 'Protein + mRNA' # Define the dataset to use, 'Protein', 'mRNA', or 'Protein + mRNA' are the options

# Image size
Canvas_Size = 18

# Seed number
Seed = 43

# Validation fraction
Validation_Fraction = 0.2

# Standard deviation for add-noise transformation
StandardDeviation = 0.005 # 0.005 so far is better

# Learning rate scheduler
Learner_rate = 1e-4

# Optimizer
Weight_Decay = 0.0001 # L2 regulator
#  it works by adding a penalty to the loss function, which discourages large weights in the model; penalizes for too many weights - helps prevent overfitting
#  the penalty is calculated as weight_decay * weight^2, and it's added to the loss.
#  1e-4 or 1e-3 gives higher acc

# Batch size
Batch_size = 64

# Epoch amount
epochs = 250

# %% [markdown]
# ### Protein, mRNA dataframe, localization label set up

# %%
# Open the proteomics data and only keep genes (rows) that are fully quantified
PFP = 'K_PD_synthetic_kde_qttumor.csv' # synthetic data
PD = pd.read_csv(dataset_folder_path+PFP)

# Data set wrangling
PD.index = PD.loc[:,'Index']
PD = PD.loc[:,PD.columns!='Index']
PD.dropna(inplace=True)

# Open the mRNA data and only keep genes (rows) that are fully quantified
MFP = 'K_MD_synthetic_kde_qttumor.csv'
MD = pd.read_csv(dataset_folder_path + MFP)

# Data set wrangling
MD.index = MD.loc[:,'Index']
MD = MD.loc[:,MD.columns!='Index']
MD = MD.drop_duplicates()
MD.dropna(inplace=True)

# %%
# Open the labels data
LFP = 'markers.txt'
LD = pd.read_csv(filepath_or_buffer=label_path+LFP,sep='\t')
# Data set wrangling
LD.index = LD.loc[:,'Protein']
LD = LD.loc[:,LD.columns!='Protein']

# %%
# Select the localization labels that are both common in the proteomics and mRNA data
common_genes = set(PD.index).intersection(set(MD.index))
# Select only the common genes
LD = LD.loc[LD.index.isin(common_genes),:]

print('Number of total labels in Krug dataset')
print(len(LD.index))
print(LD['Localization'].value_counts())
# Out:
# Number of total labels in Krug dataset
# 2693
# Localization
# Cytosol         1036
# Secretory        769
# Nucleus          624
# Mitochondria     264
# Name: count, dtype: int64

# %% [markdown]
# ### Set seed function

# %%
def set_seed(seed):
    random.seed(seed) # set random seed for python
    np.random.seed(seed) # set random seed for numpy
    torch.manual_seed(seed) # set random seed for CPU
    rs = RandomState(MT19937(SeedSequence(seed))) # seed for numpy
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed) # set random seed for all GPUs
    torch.backends.cudnn.deterministic = True # set to True to get reproducible results
    torch.backends.cudnn.benchmark = False # set to False to get reproducible results

# %% [markdown]
# ### Pixel coordinates and RGB tensor generation functions

# %%
def gen_horizontal_coords(n, num_points):
    """
    Generate coordinates for a horizontal pattern starting from the top-left corner.

    Parameters:
    n (int): Size of the canvas (n x n).
    num_points (int): Number of points to generate in the horizontal pattern.

    Returns:
    list: List of (x, y) coordinates in horizontal order.
    """
    coords = [(x, y) for x in range(n) for y in range(n)]
    return coords[:num_points]

def create_rgb_tensors(set, interleaved_array):
    """
    Create RGB tensors from abundance data using the specified pattern.
    
    Parameters:
    set (str): Dataset used for plotting ('Protein', 'mRNA', 'Protein + mRNA').
    df1 (pd.DataFrame): DataFrame containing normalized abundance data.
    df2 (pd.DataFrame): DataFrame containing normalized abundance data.
    
    Returns:
    torch.Tensor: RGB tensor.
    """

    interleaved_array = interleaved_array.flatten()
    num_pixels = len(interleaved_array)
    
    # Generate coordinates based on the pattern, spiral or horizontal arrangment
    coords = gen_horizontal_coords(Canvas_Size, num_pixels)

    # Create RGB tensor
    rgb_tensor = np.zeros((Canvas_Size, Canvas_Size, 3), dtype=np.float32)
    for i, (x, y) in enumerate(coords):
        if i < len(interleaved_array):
            value = interleaved_array[i]
            # Assign colors based on the value, if abundance > 1, set it to red, if abundance < 0, set it to blue.
            if value > 1:
                rgb_tensor[x, y] = [255, 0, 0]  # Red for value > 1
            elif value < 0:
                rgb_tensor[x, y] = [0, 0, 255]  # Blue for value < 0
            else:
                rgb_tensor[x, y] = [255 * value, 0, 255 * (1 - value)]

    return torch.from_numpy(rgb_tensor.transpose(2, 0, 1))  # Convert to CHW format for PyTorch

# %% [markdown]
# ### Custom Transformation

# %%
# Custom transformation to add noise to the data
class AddNoise:
    def __init__(self, set, mean=0, std=0.005):
        self.set = set
        self.mean = mean
        self.std = std

    def __call__(self, array1, array2):
        if self.set == 'Protein + mRNA':
            noise1 = np.random.normal(self.mean, self.std, array1.shape)
            noise2 = np.random.normal(self.mean, self.std, array2.shape)

            return array1 + noise1, array2 + noise2    

        else: # suitable for Protein or mRNA only because same noise will be applied twice
            noise = np.random.normal(self.mean, self.std, array1.shape)
        
        return array1 + noise, array2 + noise

# %% [markdown]
# ### Custom Dataset class

# %%
class MyDataset(Dataset):
    def __init__(self, set, data1, data2, indices, labels, transform=None):

        assert data1.loc[indices,:].shape[0] == data2.loc[indices,:].shape[0] == len(labels), \
            "Protein, mRNA, and labels must have the same number of samples (rows)"

        self.set = set
        self.data1 = data1.loc[indices,:]
        self.data2 = data2.loc[indices,:]
        self.indices = indices
        self.labels = labels
        self.transform = transform

    def __getitem__(self, idx):
        data1 = self.data1.iloc[idx].values
        data2 = self.data2.iloc[idx].values

        if self.transform:  
            data1, data2 = self.transform(data1, data2)

        abundance_sum = data1 + data2
        sorted_idx = abundance_sum.argsort()

        # Interleave
        interleaved_data = np.empty((len(data1) + len(data2)), dtype=np.float32)
        interleaved_data[0::2] = data1[sorted_idx]
        interleaved_data[1::2] = data2[sorted_idx]

        # Create RGB tensor
        sample = create_rgb_tensors(self.set, interleaved_data)
        label = torch.tensor(self.labels[idx], dtype=torch.long)

        return sample, label

    def __len__(self):
        return len(self.labels)

    def get_labels(self):
        return self.labels

# %% [markdown]
# ### Labels to integers

# %%
# Labels
localization_labels = LD.loc[:, 'Localization'].values
unique_labels = set(localization_labels)  # Get unique labels
label_to_int = {
    'Cytosol': 0,
    'Mitochondria': 1,
    'Nucleus': 2,
    'Secretory': 3
}
int_to_label = {v: k for k, v in label_to_int.items()}
int_to_label
# Out:
# {0: 'Cytosol', 1: 'Mitochondria', 2: 'Nucleus', 3: 'Secretory'}

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Dataloaders

# %%
# Set seed to ensure reproducibility
set_seed(Seed)

# Split the data into training and validation sets using the labels indices, random state is set
train_indices, val_indices, train_labels, val_labels = train_test_split(LD.index, localization_labels, test_size=Validation_Fraction, random_state=42, stratify=localization_labels)

# Convert string labels to integers
train_labels = [label_to_int[label] for label in train_labels]
val_labels = [label_to_int[label] for label in val_labels]

# Define the transformation
transformation = AddNoise(set=Set, mean=0, std=StandardDeviation)

# Check Dataset argument to determine which dataset to use
if Set == 'Protein':
    train_dataset = MyDataset(Set, PD, PD, train_indices, train_labels, transform=transformation)
    val_dataset = MyDataset(Set, PD, PD, val_indices, val_labels, transform=None)
elif Set == 'mRNA':
    train_dataset = MyDataset(Set, MD, MD, train_indices, train_labels, transform=transformation)
    val_dataset = MyDataset(Set, MD, MD, val_indices, val_labels, transform=None)
elif Set == 'Protein + mRNA':
    train_dataset = MyDataset(Set, PD, MD, train_indices, train_labels, transform=transformation)
    val_dataset = MyDataset(Set, PD, MD, val_indices, val_labels, transform=None)
else:
    raise ValueError("Set must be 'Protein' or 'mRNA', or 'Protein + mRNA'")

# Create the dataloaders
train_loader = DataLoader(train_dataset, batch_size=Batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=Batch_size, shuffle=False)

# %% [markdown]
# ### Visualize the tensors in data loader

# %%
# Visualize the train data loader to see the transformed tensors
train_batch_images, train_batch_labels = next(iter(train_loader))

# Use first image in the batch
first_image_in_train_batch = train_batch_images[0]
image_to_plot = first_image_in_train_batch.permute(1, 2, 0).numpy().astype('uint8')
first_label_in_train_batch = train_batch_labels[0]

# Visualize the tensor as an image 
plt.imshow(image_to_plot)
#plt.title(f"Label: {int_to_label[first_label_in_train_batch.item()]}")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(17.5), np.float64(17.5), np.float64(-0.5))

# %%
# Visualize the train data loader to see the transformed tensors
val_batch_images, val_batch_labels = next(iter(val_loader))

# Use first image in the batch
first_image_in_val_batch = val_batch_images[0]
image_to_plot = first_image_in_val_batch.permute(1, 2, 0).numpy().astype('uint8')
first_label_in_val_batch = val_batch_labels[0]

# Visualize the tensor as an image
plt.imshow(image_to_plot)
#plt.title(f"Label: {int_to_label[first_label_in_val_batch.item()]}")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(17.5), np.float64(17.5), np.float64(-0.5))

# %% [markdown]
# ### Define model

# %%
class PixelPreservingNet(nn.Module):
    def __init__(self, in_channels=3):
        super(PixelPreservingNet, self).__init__()
        
        # Convolutional layers
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=16, kernel_size=3, padding=1), 
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.pool = nn.AvgPool2d(kernel_size=2, stride=2)  # Shape is reduced by half

        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )

        # Fully connected layers
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)  # Global Average Pooling layer
        self.fc1 = nn.Sequential(
            nn.Linear(256, 512), #256->512
            nn.ReLU(),
            nn.Dropout(0.4)
        )
        self.fc2 = nn.Sequential(
            nn.Linear(512, 256), #512->256
            nn.ReLU(),
            nn.Dropout(0.4)
        )

        # Output layer
        self.output = nn.Linear(256, 4) #256->4
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = self.pool(x)
        x = self.conv3(x)
        x = self.pool(x)
        x = self.conv4(x)
        x = self.pool(x)
        x = self.conv5(x)
        
        # Global Average Pooling
        x = self.global_avg_pool(x)
        x = torch.flatten(x, 1)
        
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.output(x)
        return x

model = PixelPreservingNet(in_channels=3).to(device)

# %% [markdown]
# ### Define train loop

# %%
def train_loop(dataloader, model, loss_fn, optimizer, scheduler=None):
    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for X, y in dataloader:
        X = X.to(torch.float32).to(device)
        y = y.to(torch.long).to(device)

        optimizer.zero_grad()

        outputs = model(X)
        loss = loss_fn(outputs, y)

        # Confidence penalty
        softmax_probs = F.softmax(outputs, dim=1)
        entropy = -torch.sum(softmax_probs * torch.log(softmax_probs + 1e-10), dim=1)
        penalty = torch.mean(entropy)
        total_loss_with_penalty = loss - 0.15 * penalty

        total_loss_with_penalty.backward()
        optimizer.step()

        # Scheduler step (per batch)
        if scheduler is not None:
            scheduler.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == y).sum().item()
        total_train += y.size(0)

    avg_training_loss = running_loss / len(dataloader)
    training_accuracy = correct_train / total_train

    return avg_training_loss, training_accuracy

# %% [markdown]
# ### Define test loop

# %%
def test_loop(dataloader, model, loss_fn):
    
    model.eval()  # Set the model to evaluation mode

    test_loss = 0.0
    correct = 0
    total = 0

    y_pred = []
    y_true = []
    
    with torch.no_grad():  # Disable gradient calculation
        for X, y in dataloader:
            
            # Prepare data
            X = X.to(torch.float32).to(device)
            y = y.to(torch.long).to(device)

            # Forward pass: predict classes
            outputs = model(X)
            
            # Compute the loss
            test_loss += loss_fn(outputs, y).item()
            
            # Apply softmax and get prediction
            probs = F.softmax(outputs, dim=1)
            confidences, predicted = probs.max(dim=1)

            # Store predictions and true labels
            y_pred.extend(predicted.cpu().numpy())
            y_true.extend(y.cpu().numpy())

            # Count correct predictions
            correct += (predicted == y).sum().item() 

            # Count total predictions
            total += y.size(0) 

    # Calculate precision and recall for each class
    precision = precision_score(y_true, y_pred, average=None, zero_division=0.0)
    recall = recall_score(y_true, y_pred, average=None, zero_division=0.0)
    macro_f1 = f1_score(y_true, y_pred, average='macro')
    mcc = matthews_corrcoef(y_true, y_pred)

    # Per_class F1
    per_class_f1 = f1_score(y_true, y_pred, average=None, zero_division=0.0)

    # Global metrics
    avg_test_loss = test_loss / len(dataloader)
    test_accuracy = correct / total
        
    return avg_test_loss, test_accuracy, precision, per_class_f1, recall, macro_f1, mcc

# %% [markdown]
# ### Define focal loss

# %%
# Focal loss
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=None, reduction='mean'):
        """
        :param gamma: focusing parameter (default=2.0)
        :param alpha: balance parameter, it can be a float or a tensor (default=None)
        :param reduction: specify the reduction to apply to the output: 'none' | 'mean' | 'sum' (default='mean')
        """
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        # Compute cross-entropy loss
        BCE_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)  # pt is the probability of the true class
        
        # Compute the focal loss
        F_loss = (1 - pt) ** self.gamma * BCE_loss
        
        # Apply class weighting (alpha) if provided
        if self.alpha is not None:
            alpha = self.alpha[targets]
            F_loss = alpha * F_loss
        
        # Apply the specified reduction
        if self.reduction == 'mean':
            return F_loss.mean()
        elif self.reduction == 'sum':
            return F_loss.sum()
        else:
            return F_loss

# %% [markdown]
# ### Define early stopping

# %%
class EarlyStoppingWithCheckpoint:
    def __init__(self, patience=10, delta=0.0, save_path=None):
        self.patience = patience
        self.delta = delta
        self.save_path = save_path
        self.best_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss, model, save_path=None):
        # Allow override save_path if given in call
        if save_path is not None:
            self.save_path = save_path

        if self.best_loss is None:
            self.best_loss = val_loss
            if self.save_path is not None:
                self.save_checkpoint(model)
        elif val_loss > self.best_loss - self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            if self.save_path is not None:
                self.save_checkpoint(model)
            self.counter = 0

    def save_checkpoint(self, model):
        torch.save(model.state_dict(), self.save_path)

# %% [markdown]
# ### Training and validation

# %%
set_seed(Seed)

# Compute class weights
def compute_class_weights(class_counts): # inverse square root frequency for mild imbalance
    class_weights = 1.0 / torch.sqrt(torch.tensor(class_counts, dtype=torch.float))
    return class_weights / class_weights.sum()

# Given class counts
#class_counts = [2401, 410, 1554, 1112]
#LossWeights = compute_class_weights(class_counts)
LossWeights = torch.tensor([0.16, 0.39, 0.20, 0.24], dtype=torch.float32) # manually set weights
LossWeights = LossWeights.to(device)

# Define the loss function, optimizer and scheduler
criterion = FocalLoss(alpha=LossWeights, gamma=2.0, reduction='mean')  # Focal loss for imbalanced classification
optimizer = optim.AdamW(model.parameters(), lr=Learner_rate, weight_decay=Weight_Decay)  # AdamW optimizer with weight decay
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,        # reduce LR by half
    patience=10,       # fewer stagnant epochs before reducing
    threshold=1e-4,    # stricter improvement requirement
    cooldown=2,        # wait a bit after LR drop before checking again
    min_lr=1e-7,       # don’t shrink forever
    verbose=True
)
model_path = os.path.join(model_folder_path, f"{Set}_NN_model.pth")
#early_stopping = EarlyStoppingWithCheckpoint(patience=15, delta=0, save_path=model_path)
best_macro_f1 = float('-inf')

# Set up performance dataframe to record loss, accuracy, precision and recall of each epoch
LossAccDF = pd.DataFrame(index=range(epochs),columns=['Epoch','TrainLoss','ValLoss','TrainAcc','ValAcc'])
PrecisionRecallDF = pd.DataFrame(columns=['Epoch','Class','Precision','Recall','Class F1','Macro F1','MCC'])

# Evaluate the model before training
avg_train_loss, train_accuracy, _, _, _, macro_f1, mcc = test_loop(train_loader, model, criterion) # compute training performance
avg_val_loss, val_accuracy, precision, recall, per_class_f1, macro_f1, mcc = test_loop(val_loader, model, criterion) # compute validation performance

# Print initial performance
print(f"Before Training: "
      f"Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}",
      f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}",
      f"Macro F1: {macro_f1:.4f}, Matthews Correlation Coefficient: {mcc:.4f}")

# Record the metric in the dataframe
LossAccDF.loc[0,:]=[0,avg_train_loss,avg_val_loss,train_accuracy,val_accuracy]
index=0
for i in range(4):
    PrecisionRecallDF.loc[index]=[0, i, precision[i], recall[i], per_class_f1[i], macro_f1, mcc]
    index += 1

# Training loop
for epoch in range(epochs):

    # Training phase
    avg_train_loss, train_accuracy = train_loop(train_loader, model, criterion, optimizer)
    
    # Validation phase
    avg_val_loss, val_accuracy, precision, recall, per_class_f1, macro_f1, mcc = test_loop(val_loader, model, criterion)
    
    # Print epoch loss and accuracy
    print(f"Epoch [{epoch+1}/{epochs}], "
          f"Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}",
          f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}",
          f"Macro F1: {macro_f1:.4f}, Matthews Correlation Coefficient: {mcc:.4f}")   

    # Record the metric in the dataframe
    LossAccDF.loc[epoch+1,:]=[epoch+1,avg_train_loss,avg_val_loss,train_accuracy,val_accuracy]
    for i in range(4):
        PrecisionRecallDF.loc[index]=[epoch+1, i, precision[i], recall[i], per_class_f1[i], macro_f1, mcc]
        index += 1

    # Save best model based on macro F1
    if macro_f1 > best_macro_f1:
        best_macro_f1 = macro_f1
        torch.save(model.state_dict(), model_path)
        print(f"Best Macro F1 achieved: {best_macro_f1:.4f}")
        print(f"Saved new best model at epoch {epoch+1} with Macro F1: {macro_f1:.4f}")
        
    #Check for early stopping
    # early_stopping(avg_val_loss, model)

    # if early_stopping.early_stop:
    #    print(f"Early stopping at epoch {epoch}")
    #    break
# Out:
# /opt/conda/envs/pytorch/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Before Training: Training Loss: 0.1675, Training Accuracy: 0.2317 Validation Loss: 0.1671, Validation Accuracy: 0.2319 Macro F1: 0.0941, Matthews Correlation Coefficient: 0.0000
# Epoch [1/250], Training Loss: 0.1643, Training Accuracy: 0.3213 Validation Loss: 0.1650, Validation Accuracy: 0.3469 Macro F1: 0.2795, Matthews Correlation Coefficient: 0.1046
# Best Macro F1 achieved: 0.2795
# Saved new best model at epoch 1 with Macro F1: 0.2795
# Epoch [2/250], Training Loss: 0.1594, Training Accuracy: 0.3881 Validation Loss: 0.1561, Validation Accuracy: 0.4750 Macro F1: 0.3681, Matthews Correlation Coefficient: 0.2944
# Best Macro F1 achieved: 0.3681
# Saved new best model at epoch 2 with Macro F1: 0.3681
# Epoch [3/250], Training Loss: 0.1550, Training Accuracy: 0.4299 Validation Loss: 0.1500, Validation Accuracy: 0.4694 Macro F1: 0.3654, Matthews Correlation Coefficient: 0.2828
# Epoch [4/250], Training Loss: 0.1508, Training Accuracy: 0.4629 Validation Loss: 0.1464, Validation Accuracy: 0.5028 Macro F1: 0.3943, Matthews Correlation Coefficient: 0.3030
# Best Macro F1 achieved: 0.3943
# Saved new best model at epoch 4 with Macro F1: 0.3943
# Epoch [5/250], Training Loss: 0.1482, Training Accuracy: 0.4633 Validation Loss: 0.1433, Validation Accuracy: 0.5046 Macro F1: 0.3958, Matthews Correlation Coefficient: 0.3059
# Best Macro F1 achieved: 0.3958
# Saved new best model at epoch 5 with Macro F1: 0.3958
# Epoch [6/250], Training Loss: 0.1458, Training Accuracy: 0.4698 Validation Loss: 0.1428, Validation Accuracy: 0.5009 Macro F1: 0.3938, Matthews Correlation Coefficient: 0.3119
# Epoch [7/250], Training Loss: 0.1467, Training Accuracy: 0.4749 Validation Loss: 0.1419, Validation Accuracy: 0.5046 Macro F1: 0.3960, Matthews Correlation Coefficient: 0.3153
# Best Macro F1 achieved: 0.3960
# Saved new best model at epoch 7 with Macro F1: 0.3960
# Epoch [8/250], Training Loss: 0.1462, Training Accuracy: 0.4958 Validation Loss: 0.1411, Validation Accuracy: 0.5288 Macro F1: 0.4148, Matthews Correlation Coefficient: 0.3349
# Best Macro F1 achieved: 0.4148
# Saved new best model at epoch 8 with Macro F1: 0.4148
# Epoch [9/250], Training Loss: 0.1449, Training Accuracy: 0.4842 Validation Loss: 0.1406, Validation Accuracy: 0.5158 Macro F1: 0.4063, Matthews Correlation Coefficient: 0.3288
# Epoch [10/250], Training Loss: 0.1430, Training Accuracy: 0.5060 Validation Loss: 0.1381, Validation Accuracy: 0.5213 Macro F1: 0.4099, Matthews Correlation Coefficient: 0.3315
# Epoch [11/250], Training Loss: 0.1430, Training Accuracy: 0.5005 Validation Loss: 0.1381, Validation Accuracy: 0.5288 Macro F1: 0.4155, Matthews Correlation Coefficient: 0.3424
# Best Macro F1 achieved: 0.4155
# Saved new best model at epoch 11 with Macro F1: 0.4155
# Epoch [12/250], Training Loss: 0.1425, Training Accuracy: 0.4991 Validation Loss: 0.1376, Validation Accuracy: 0.5473 Macro F1: 0.4301, Matthews Correlation Coefficient: 0.3639
# Best Macro F1 achieved: 0.4301
# Saved new best model at epoch 12 with Macro F1: 0.4301
# Epoch [13/250], Training Loss: 0.1443, Training Accuracy: 0.5051 Validation Loss: 0.1382, Validation Accuracy: 0.5399 Macro F1: 0.4246, Matthews Correlation Coefficient: 0.3555
# Epoch [14/250], Training Loss: 0.1425, Training Accuracy: 0.4954 Validation Loss: 0.1378, Validation Accuracy: 0.5380 Macro F1: 0.4234, Matthews Correlation Coefficient: 0.3542
# Epoch [15/250], Training Loss: 0.1411, Training Accuracy: 0.5167 Validation Loss: 0.1374, Validation Accuracy: 0.5510 Macro F1: 0.4324, Matthews Correlation Coefficient: 0.3707
# Best Macro F1 achieved: 0.4324
# Saved new best model at epoch 15 with Macro F1: 0.4324
# Epoch [16/250], Training Loss: 0.1414, Training Accuracy: 0.5088 Validation Loss: 0.1376, Validation Accuracy: 0.5343 Macro F1: 0.4198, Matthews Correlation Coefficient: 0.3411
# Epoch [17/250], Training Loss: 0.1421, Training Accuracy: 0.5200 Validation Loss: 0.1375, Validation Accuracy: 0.5399 Macro F1: 0.4242, Matthews Correlation Coefficient: 0.3570
# Epoch [18/250], Training Loss: 0.1409, Training Accuracy: 0.5144 Validation Loss: 0.1365, Validation Accuracy: 0.5492 Macro F1: 0.4310, Matthews Correlation Coefficient: 0.3665
# Epoch [19/250], Training Loss: 0.1415, Training Accuracy: 0.5167 Validation Loss: 0.1371, Validation Accuracy: 0.5417 Macro F1: 0.4251, Matthews Correlation Coefficient: 0.3531
# Epoch [20/250], Training Loss: 0.1398, Training Accuracy: 0.5158 Validation Loss: 0.1361, Validation Accuracy: 0.5436 Macro F1: 0.4275, Matthews Correlation Coefficient: 0.3536
# Epoch [21/250], Training Loss: 0.1401, Training Accuracy: 0.5297 Validation Loss: 0.1370, Validation Accuracy: 0.5417 Macro F1: 0.4273, Matthews Correlation Coefficient: 0.3565
# Epoch [22/250], Training Loss: 0.1391, Training Accuracy: 0.5283 Validation Loss: 0.1353, Validation Accuracy: 0.5473 Macro F1: 0.4382, Matthews Correlation Coefficient: 0.3607
# Best Macro F1 achieved: 0.4382
# Saved new best model at epoch 22 with Macro F1: 0.4382
# Epoch [23/250], Training Loss: 0.1401, Training Accuracy: 0.5102 Validation Loss: 0.1355, Validation Accuracy: 0.5510 Macro F1: 0.4338, Matthews Correlation Coefficient: 0.3725
# Epoch [24/250], Training Loss: 0.1406, Training Accuracy: 0.5144 Validation Loss: 0.1349, Validation Accuracy: 0.5399 Macro F1: 0.4342, Matthews Correlation Coefficient: 0.3518
# Epoch [25/250], Training Loss: 0.1381, Training Accuracy: 0.5237 Validation Loss: 0.1349, Validation Accuracy: 0.5455 Macro F1: 0.4527, Matthews Correlation Coefficient: 0.3655
# Best Macro F1 achieved: 0.4527
# Saved new best model at epoch 25 with Macro F1: 0.4527
# Epoch [26/250], Training Loss: 0.1381, Training Accuracy: 0.5209 Validation Loss: 0.1352, Validation Accuracy: 0.5455 Macro F1: 0.4453, Matthews Correlation Coefficient: 0.3574
# Epoch [27/250], Training Loss: 0.1397, Training Accuracy: 0.5144 Validation Loss: 0.1350, Validation Accuracy: 0.5529 Macro F1: 0.4515, Matthews Correlation Coefficient: 0.3677
# Epoch [28/250], Training Loss: 0.1375, Training Accuracy: 0.5260 Validation Loss: 0.1342, Validation Accuracy: 0.5510 Macro F1: 0.4495, Matthews Correlation Coefficient: 0.3614
# Epoch [29/250], Training Loss: 0.1386, Training Accuracy: 0.5237 Validation Loss: 0.1345, Validation Accuracy: 0.5436 Macro F1: 0.4445, Matthews Correlation Coefficient: 0.3580
# Epoch [30/250], Training Loss: 0.1386, Training Accuracy: 0.5260 Validation Loss: 0.1350, Validation Accuracy: 0.5473 Macro F1: 0.4540, Matthews Correlation Coefficient: 0.3639
# Best Macro F1 achieved: 0.4540
# Saved new best model at epoch 30 with Macro F1: 0.4540
# Epoch [31/250], Training Loss: 0.1376, Training Accuracy: 0.5292 Validation Loss: 0.1343, Validation Accuracy: 0.5659 Macro F1: 0.4789, Matthews Correlation Coefficient: 0.3831
# Best Macro F1 achieved: 0.4789
# Saved new best model at epoch 31 with Macro F1: 0.4789
# Epoch [32/250], Training Loss: 0.1374, Training Accuracy: 0.5246 Validation Loss: 0.1343, Validation Accuracy: 0.5547 Macro F1: 0.4705, Matthews Correlation Coefficient: 0.3724
# Epoch [33/250], Training Loss: 0.1377, Training Accuracy: 0.5255 Validation Loss: 0.1340, Validation Accuracy: 0.5566 Macro F1: 0.4811, Matthews Correlation Coefficient: 0.3740
# Best Macro F1 achieved: 0.4811
# Saved new best model at epoch 33 with Macro F1: 0.4811
# Epoch [34/250], Training Loss: 0.1371, Training Accuracy: 0.5381 Validation Loss: 0.1339, Validation Accuracy: 0.5584 Macro F1: 0.4736, Matthews Correlation Coefficient: 0.3764
# Epoch [35/250], Training Loss: 0.1369, Training Accuracy: 0.5241 Validation Loss: 0.1342, Validation Accuracy: 0.5399 Macro F1: 0.4491, Matthews Correlation Coefficient: 0.3581
# Epoch [36/250], Training Loss: 0.1360, Training Accuracy: 0.5232 Validation Loss: 0.1335, Validation Accuracy: 0.5622 Macro F1: 0.4953, Matthews Correlation Coefficient: 0.3789
# Best Macro F1 achieved: 0.4953
# Saved new best model at epoch 36 with Macro F1: 0.4953
# Epoch [37/250], Training Loss: 0.1345, Training Accuracy: 0.5432 Validation Loss: 0.1327, Validation Accuracy: 0.5547 Macro F1: 0.4801, Matthews Correlation Coefficient: 0.3703
# Epoch [38/250], Training Loss: 0.1369, Training Accuracy: 0.5167 Validation Loss: 0.1333, Validation Accuracy: 0.5603 Macro F1: 0.4729, Matthews Correlation Coefficient: 0.3733
# Epoch [39/250], Training Loss: 0.1358, Training Accuracy: 0.5279 Validation Loss: 0.1325, Validation Accuracy: 0.5566 Macro F1: 0.4647, Matthews Correlation Coefficient: 0.3686
# Epoch [40/250], Training Loss: 0.1366, Training Accuracy: 0.5283 Validation Loss: 0.1331, Validation Accuracy: 0.5455 Macro F1: 0.4836, Matthews Correlation Coefficient: 0.3583
# Epoch [41/250], Training Loss: 0.1355, Training Accuracy: 0.5353 Validation Loss: 0.1318, Validation Accuracy: 0.5529 Macro F1: 0.4701, Matthews Correlation Coefficient: 0.3662
# Epoch [42/250], Training Loss: 0.1348, Training Accuracy: 0.5283 Validation Loss: 0.1329, Validation Accuracy: 0.5603 Macro F1: 0.4783, Matthews Correlation Coefficient: 0.3757
# Epoch [43/250], Training Loss: 0.1369, Training Accuracy: 0.5227 Validation Loss: 0.1352, Validation Accuracy: 0.5492 Macro F1: 0.4884, Matthews Correlation Coefficient: 0.3713
# Epoch [44/250], Training Loss: 0.1355, Training Accuracy: 0.5311 Validation Loss: 0.1329, Validation Accuracy: 0.5473 Macro F1: 0.4689, Matthews Correlation Coefficient: 0.3634
# Epoch [45/250], Training Loss: 0.1358, Training Accuracy: 0.5362 Validation Loss: 0.1332, Validation Accuracy: 0.5492 Macro F1: 0.4656, Matthews Correlation Coefficient: 0.3647
# Epoch [46/250], Training Loss: 0.1352, Training Accuracy: 0.5362 Validation Loss: 0.1338, Validation Accuracy: 0.5547 Macro F1: 0.4789, Matthews Correlation Coefficient: 0.3738
# Epoch [47/250], Training Loss: 0.1364, Training Accuracy: 0.5316 Validation Loss: 0.1338, Validation Accuracy: 0.5566 Macro F1: 0.4755, Matthews Correlation Coefficient: 0.3729
# Epoch [48/250], Training Loss: 0.1353, Training Accuracy: 0.5311 Validation Loss: 0.1339, Validation Accuracy: 0.5492 Macro F1: 0.4689, Matthews Correlation Coefficient: 0.3641
# Epoch [49/250], Training Loss: 0.1346, Training Accuracy: 0.5469 Validation Loss: 0.1326, Validation Accuracy: 0.5603 Macro F1: 0.4661, Matthews Correlation Coefficient: 0.3735
# Epoch [50/250], Training Loss: 0.1334, Training Accuracy: 0.5436 Validation Loss: 0.1326, Validation Accuracy: 0.5547 Macro F1: 0.4769, Matthews Correlation Coefficient: 0.3714
# Epoch [51/250], Training Loss: 0.1338, Training Accuracy: 0.5255 Validation Loss: 0.1325, Validation Accuracy: 0.5566 Macro F1: 0.4769, Matthews Correlation Coefficient: 0.3691
# Epoch [52/250], Training Loss: 0.1343, Training Accuracy: 0.5357 Validation Loss: 0.1330, Validation Accuracy: 0.5380 Macro F1: 0.4677, Matthews Correlation Coefficient: 0.3507
# Epoch [53/250], Training Loss: 0.1351, Training Accuracy: 0.5344 Validation Loss: 0.1319, Validation Accuracy: 0.5584 Macro F1: 0.4757, Matthews Correlation Coefficient: 0.3738
# Epoch [54/250], Training Loss: 0.1355, Training Accuracy: 0.5371 Validation Loss: 0.1329, Validation Accuracy: 0.5399 Macro F1: 0.4715, Matthews Correlation Coefficient: 0.3573
# Epoch [55/250], Training Loss: 0.1348, Training Accuracy: 0.5422 Validation Loss: 0.1325, Validation Accuracy: 0.5603 Macro F1: 0.4818, Matthews Correlation Coefficient: 0.3770
# Epoch [56/250], Training Loss: 0.1354, Training Accuracy: 0.5344 Validation Loss: 0.1339, Validation Accuracy: 0.5380 Macro F1: 0.4724, Matthews Correlation Coefficient: 0.3532
# Epoch [57/250], Training Loss: 0.1348, Training Accuracy: 0.5357 Validation Loss: 0.1320, Validation Accuracy: 0.5492 Macro F1: 0.4714, Matthews Correlation Coefficient: 0.3620
# Epoch [58/250], Training Loss: 0.1333, Training Accuracy: 0.5404 Validation Loss: 0.1319, Validation Accuracy: 0.5510 Macro F1: 0.4693, Matthews Correlation Coefficient: 0.3641
# Epoch [59/250], Training Loss: 0.1337, Training Accuracy: 0.5450 Validation Loss: 0.1319, Validation Accuracy: 0.5510 Macro F1: 0.4743, Matthews Correlation Coefficient: 0.3670
# Epoch [60/250], Training Loss: 0.1337, Training Accuracy: 0.5362 Validation Loss: 0.1326, Validation Accuracy: 0.5417 Macro F1: 0.4733, Matthews Correlation Coefficient: 0.3621
# Epoch [61/250], Training Loss: 0.1324, Training Accuracy: 0.5316 Validation Loss: 0.1319, Validation Accuracy: 0.5362 Macro F1: 0.4674, Matthews Correlation Coefficient: 0.3529
# Epoch [62/250], Training Loss: 0.1328, Training Accuracy: 0.5399 Validation Loss: 0.1326, Validation Accuracy: 0.5325 Macro F1: 0.4704, Matthews Correlation Coefficient: 0.3491
# Epoch [63/250], Training Loss: 0.1339, Training Accuracy: 0.5432 Validation Loss: 0.1320, Validation Accuracy: 0.5455 Macro F1: 0.4731, Matthews Correlation Coefficient: 0.3581
# Epoch [64/250], Training Loss: 0.1335, Training Accuracy: 0.5362 Validation Loss: 0.1330, Validation Accuracy: 0.5325 Macro F1: 0.4516, Matthews Correlation Coefficient: 0.3427
# Epoch [65/250], Training Loss: 0.1342, Training Accuracy: 0.5330 Validation Loss: 0.1324, Validation Accuracy: 0.5529 Macro F1: 0.4782, Matthews Correlation Coefficient: 0.3672
# Epoch [66/250], Training Loss: 0.1350, Training Accuracy: 0.5149 Validation Loss: 0.1319, Validation Accuracy: 0.5455 Macro F1: 0.4796, Matthews Correlation Coefficient: 0.3569
# Epoch [67/250], Training Loss: 0.1338, Training Accuracy: 0.5422 Validation Loss: 0.1324, Validation Accuracy: 0.5399 Macro F1: 0.4709, Matthews Correlation Coefficient: 0.3588
# Epoch [68/250], Training Loss: 0.1345, Training Accuracy: 0.5371 Validation Loss: 0.1319, Validation Accuracy: 0.5584 Macro F1: 0.4656, Matthews Correlation Coefficient: 0.3732
# Epoch [69/250], Training Loss: 0.1326, Training Accuracy: 0.5450 Validation Loss: 0.1320, Validation Accuracy: 0.5399 Macro F1: 0.4629, Matthews Correlation Coefficient: 0.3551
# Epoch [70/250], Training Loss: 0.1332, Training Accuracy: 0.5390 Validation Loss: 0.1325, Validation Accuracy: 0.5455 Macro F1: 0.4862, Matthews Correlation Coefficient: 0.3605
# Epoch [71/250], Training Loss: 0.1322, Training Accuracy: 0.5571 Validation Loss: 0.1314, Validation Accuracy: 0.5510 Macro F1: 0.4877, Matthews Correlation Coefficient: 0.3721
# Epoch [72/250], Training Loss: 0.1324, Training Accuracy: 0.5381 Validation Loss: 0.1313, Validation Accuracy: 0.5547 Macro F1: 0.4835, Matthews Correlation Coefficient: 0.3731
# Epoch [73/250], Training Loss: 0.1320, Training Accuracy: 0.5427 Validation Loss: 0.1315, Validation Accuracy: 0.5417 Macro F1: 0.4784, Matthews Correlation Coefficient: 0.3578
# Epoch [74/250], Training Loss: 0.1327, Training Accuracy: 0.5409 Validation Loss: 0.1311, Validation Accuracy: 0.5436 Macro F1: 0.4740, Matthews Correlation Coefficient: 0.3580
# Epoch [75/250], Training Loss: 0.1332, Training Accuracy: 0.5330 Validation Loss: 0.1314, Validation Accuracy: 0.5325 Macro F1: 0.4715, Matthews Correlation Coefficient: 0.3466
# Epoch [76/250], Training Loss: 0.1323, Training Accuracy: 0.5325 Validation Loss: 0.1312, Validation Accuracy: 0.5529 Macro F1: 0.4759, Matthews Correlation Coefficient: 0.3693
# Epoch [77/250], Training Loss: 0.1317, Training Accuracy: 0.5436 Validation Loss: 0.1317, Validation Accuracy: 0.5436 Macro F1: 0.4916, Matthews Correlation Coefficient: 0.3647
# Epoch [78/250], Training Loss: 0.1321, Training Accuracy: 0.5297 Validation Loss: 0.1306, Validation Accuracy: 0.5473 Macro F1: 0.4918, Matthews Correlation Coefficient: 0.3684
# Epoch [79/250], Training Loss: 0.1315, Training Accuracy: 0.5492 Validation Loss: 0.1309, Validation Accuracy: 0.5510 Macro F1: 0.4905, Matthews Correlation Coefficient: 0.3685
# Epoch [80/250], Training Loss: 0.1316, Training Accuracy: 0.5381 Validation Loss: 0.1314, Validation Accuracy: 0.5455 Macro F1: 0.4844, Matthews Correlation Coefficient: 0.3662
# Epoch [81/250], Training Loss: 0.1318, Training Accuracy: 0.5497 Validation Loss: 0.1310, Validation Accuracy: 0.5492 Macro F1: 0.4786, Matthews Correlation Coefficient: 0.3640
# Epoch [82/250], Training Loss: 0.1317, Training Accuracy: 0.5325 Validation Loss: 0.1315, Validation Accuracy: 0.5417 Macro F1: 0.4683, Matthews Correlation Coefficient: 0.3587
# Epoch [83/250], Training Loss: 0.1313, Training Accuracy: 0.5381 Validation Loss: 0.1319, Validation Accuracy: 0.5195 Macro F1: 0.4598, Matthews Correlation Coefficient: 0.3408
# Epoch [84/250], Training Loss: 0.1331, Training Accuracy: 0.5367 Validation Loss: 0.1313, Validation Accuracy: 0.5417 Macro F1: 0.4706, Matthews Correlation Coefficient: 0.3555
# Epoch [85/250], Training Loss: 0.1322, Training Accuracy: 0.5409 Validation Loss: 0.1310, Validation Accuracy: 0.5473 Macro F1: 0.4749, Matthews Correlation Coefficient: 0.3632
# Epoch [86/250], Training Loss: 0.1308, Training Accuracy: 0.5455 Validation Loss: 0.1309, Validation Accuracy: 0.5362 Macro F1: 0.4712, Matthews Correlation Coefficient: 0.3505
# Epoch [87/250], Training Loss: 0.1312, Training Accuracy: 0.5325 Validation Loss: 0.1307, Validation Accuracy: 0.5288 Macro F1: 0.4652, Matthews Correlation Coefficient: 0.3425
# Epoch [88/250], Training Loss: 0.1316, Training Accuracy: 0.5362 Validation Loss: 0.1309, Validation Accuracy: 0.5362 Macro F1: 0.4670, Matthews Correlation Coefficient: 0.3492
# Epoch [89/250], Training Loss: 0.1312, Training Accuracy: 0.5469 Validation Loss: 0.1313, Validation Accuracy: 0.5362 Macro F1: 0.4684, Matthews Correlation Coefficient: 0.3509
# Epoch [90/250], Training Loss: 0.1323, Training Accuracy: 0.5436 Validation Loss: 0.1305, Validation Accuracy: 0.5436 Macro F1: 0.4704, Matthews Correlation Coefficient: 0.3567
# Epoch [91/250], Training Loss: 0.1321, Training Accuracy: 0.5515 Validation Loss: 0.1315, Validation Accuracy: 0.5380 Macro F1: 0.4603, Matthews Correlation Coefficient: 0.3493
# Epoch [92/250], Training Loss: 0.1295, Training Accuracy: 0.5604 Validation Loss: 0.1312, Validation Accuracy: 0.5436 Macro F1: 0.4680, Matthews Correlation Coefficient: 0.3580
# Epoch [93/250], Training Loss: 0.1307, Training Accuracy: 0.5399 Validation Loss: 0.1316, Validation Accuracy: 0.5343 Macro F1: 0.4612, Matthews Correlation Coefficient: 0.3472
# Epoch [94/250], Training Loss: 0.1305, Training Accuracy: 0.5418 Validation Loss: 0.1314, Validation Accuracy: 0.5306 Macro F1: 0.4605, Matthews Correlation Coefficient: 0.3425
# Epoch [95/250], Training Loss: 0.1303, Training Accuracy: 0.5460 Validation Loss: 0.1307, Validation Accuracy: 0.5455 Macro F1: 0.4666, Matthews Correlation Coefficient: 0.3558
# Epoch [96/250], Training Loss: 0.1309, Training Accuracy: 0.5483 Validation Loss: 0.1312, Validation Accuracy: 0.5306 Macro F1: 0.4608, Matthews Correlation Coefficient: 0.3389
# Epoch [97/250], Training Loss: 0.1311, Training Accuracy: 0.5371 Validation Loss: 0.1307, Validation Accuracy: 0.5455 Macro F1: 0.4687, Matthews Correlation Coefficient: 0.3575
# Epoch [98/250], Training Loss: 0.1306, Training Accuracy: 0.5474 Validation Loss: 0.1307, Validation Accuracy: 0.5417 Macro F1: 0.4661, Matthews Correlation Coefficient: 0.3539
# Epoch [99/250], Training Loss: 0.1316, Training Accuracy: 0.5469 Validation Loss: 0.1315, Validation Accuracy: 0.5306 Macro F1: 0.4658, Matthews Correlation Coefficient: 0.3456
# Epoch [100/250], Training Loss: 0.1307, Training Accuracy: 0.5469 Validation Loss: 0.1303, Validation Accuracy: 0.5436 Macro F1: 0.4729, Matthews Correlation Coefficient: 0.3601
# Epoch [101/250], Training Loss: 0.1308, Training Accuracy: 0.5371 Validation Loss: 0.1305, Validation Accuracy: 0.5362 Macro F1: 0.4720, Matthews Correlation Coefficient: 0.3535
# Epoch [102/250], Training Loss: 0.1301, Training Accuracy: 0.5362 Validation Loss: 0.1314, Validation Accuracy: 0.5288 Macro F1: 0.4612, Matthews Correlation Coefficient: 0.3451
# Epoch [103/250], Training Loss: 0.1306, Training Accuracy: 0.5432 Validation Loss: 0.1303, Validation Accuracy: 0.5380 Macro F1: 0.4639, Matthews Correlation Coefficient: 0.3506
# Epoch [104/250], Training Loss: 0.1290, Training Accuracy: 0.5552 Validation Loss: 0.1310, Validation Accuracy: 0.5250 Macro F1: 0.4559, Matthews Correlation Coefficient: 0.3377
# Epoch [105/250], Training Loss: 0.1281, Training Accuracy: 0.5687 Validation Loss: 0.1309, Validation Accuracy: 0.5213 Macro F1: 0.4523, Matthews Correlation Coefficient: 0.3319
# Epoch [106/250], Training Loss: 0.1296, Training Accuracy: 0.5515 Validation Loss: 0.1307, Validation Accuracy: 0.5288 Macro F1: 0.4589, Matthews Correlation Coefficient: 0.3403
# Epoch [107/250], Training Loss: 0.1309, Training Accuracy: 0.5422 Validation Loss: 0.1311, Validation Accuracy: 0.5455 Macro F1: 0.4695, Matthews Correlation Coefficient: 0.3585
# Epoch [108/250], Training Loss: 0.1296, Training Accuracy: 0.5576 Validation Loss: 0.1305, Validation Accuracy: 0.5269 Macro F1: 0.4494, Matthews Correlation Coefficient: 0.3392
# Epoch [109/250], Training Loss: 0.1314, Training Accuracy: 0.5529 Validation Loss: 0.1301, Validation Accuracy: 0.5492 Macro F1: 0.4734, Matthews Correlation Coefficient: 0.3658
# Epoch [110/250], Training Loss: 0.1296, Training Accuracy: 0.5534 Validation Loss: 0.1295, Validation Accuracy: 0.5547 Macro F1: 0.4757, Matthews Correlation Coefficient: 0.3704
# Epoch [111/250], Training Loss: 0.1306, Training Accuracy: 0.5539 Validation Loss: 0.1298, Validation Accuracy: 0.5547 Macro F1: 0.4716, Matthews Correlation Coefficient: 0.3699
# Epoch [112/250], Training Loss: 0.1284, Training Accuracy: 0.5604 Validation Loss: 0.1305, Validation Accuracy: 0.5325 Macro F1: 0.4474, Matthews Correlation Coefficient: 0.3431
# Epoch [113/250], Training Loss: 0.1301, Training Accuracy: 0.5432 Validation Loss: 0.1300, Validation Accuracy: 0.5343 Macro F1: 0.4571, Matthews Correlation Coefficient: 0.3405
# Epoch [114/250], Training Loss: 0.1293, Training Accuracy: 0.5580 Validation Loss: 0.1311, Validation Accuracy: 0.5250 Macro F1: 0.4560, Matthews Correlation Coefficient: 0.3348
# Epoch [115/250], Training Loss: 0.1289, Training Accuracy: 0.5520 Validation Loss: 0.1302, Validation Accuracy: 0.5510 Macro F1: 0.4744, Matthews Correlation Coefficient: 0.3672
# Epoch [116/250], Training Loss: 0.1287, Training Accuracy: 0.5515 Validation Loss: 0.1314, Validation Accuracy: 0.5269 Macro F1: 0.4532, Matthews Correlation Coefficient: 0.3422
# Epoch [117/250], Training Loss: 0.1308, Training Accuracy: 0.5474 Validation Loss: 0.1302, Validation Accuracy: 0.5288 Macro F1: 0.4571, Matthews Correlation Coefficient: 0.3388
# Epoch [118/250], Training Loss: 0.1292, Training Accuracy: 0.5604 Validation Loss: 0.1297, Validation Accuracy: 0.5436 Macro F1: 0.4618, Matthews Correlation Coefficient: 0.3607
# Epoch [119/250], Training Loss: 0.1310, Training Accuracy: 0.5418 Validation Loss: 0.1298, Validation Accuracy: 0.5510 Macro F1: 0.4784, Matthews Correlation Coefficient: 0.3723
# Epoch [120/250], Training Loss: 0.1292, Training Accuracy: 0.5460 Validation Loss: 0.1294, Validation Accuracy: 0.5473 Macro F1: 0.4683, Matthews Correlation Coefficient: 0.3600
# Epoch [121/250], Training Loss: 0.1300, Training Accuracy: 0.5557 Validation Loss: 0.1302, Validation Accuracy: 0.5436 Macro F1: 0.4689, Matthews Correlation Coefficient: 0.3610
# Epoch [122/250], Training Loss: 0.1292, Training Accuracy: 0.5548 Validation Loss: 0.1300, Validation Accuracy: 0.5399 Macro F1: 0.4670, Matthews Correlation Coefficient: 0.3572
# Epoch [123/250], Training Loss: 0.1298, Training Accuracy: 0.5539 Validation Loss: 0.1301, Validation Accuracy: 0.5380 Macro F1: 0.4593, Matthews Correlation Coefficient: 0.3497
# Epoch [124/250], Training Loss: 0.1294, Training Accuracy: 0.5506 Validation Loss: 0.1301, Validation Accuracy: 0.5250 Macro F1: 0.4563, Matthews Correlation Coefficient: 0.3360
# Epoch [125/250], Training Loss: 0.1292, Training Accuracy: 0.5478 Validation Loss: 0.1292, Validation Accuracy: 0.5399 Macro F1: 0.4680, Matthews Correlation Coefficient: 0.3567
# Epoch [126/250], Training Loss: 0.1300, Training Accuracy: 0.5487 Validation Loss: 0.1299, Validation Accuracy: 0.5362 Macro F1: 0.4606, Matthews Correlation Coefficient: 0.3474
# Epoch [127/250], Training Loss: 0.1287, Training Accuracy: 0.5580 Validation Loss: 0.1304, Validation Accuracy: 0.5473 Macro F1: 0.4672, Matthews Correlation Coefficient: 0.3590
# Epoch [128/250], Training Loss: 0.1287, Training Accuracy: 0.5506 Validation Loss: 0.1293, Validation Accuracy: 0.5250 Macro F1: 0.4607, Matthews Correlation Coefficient: 0.3409
# Epoch [129/250], Training Loss: 0.1279, Training Accuracy: 0.5599 Validation Loss: 0.1297, Validation Accuracy: 0.5250 Macro F1: 0.4501, Matthews Correlation Coefficient: 0.3328
# Epoch [130/250], Training Loss: 0.1283, Training Accuracy: 0.5552 Validation Loss: 0.1294, Validation Accuracy: 0.5380 Macro F1: 0.4621, Matthews Correlation Coefficient: 0.3510
# Epoch [131/250], Training Loss: 0.1272, Training Accuracy: 0.5613 Validation Loss: 0.1290, Validation Accuracy: 0.5232 Macro F1: 0.4526, Matthews Correlation Coefficient: 0.3353
# Epoch [132/250], Training Loss: 0.1276, Training Accuracy: 0.5566 Validation Loss: 0.1302, Validation Accuracy: 0.5399 Macro F1: 0.4674, Matthews Correlation Coefficient: 0.3502
# Epoch [133/250], Training Loss: 0.1282, Training Accuracy: 0.5617 Validation Loss: 0.1292, Validation Accuracy: 0.5343 Macro F1: 0.4633, Matthews Correlation Coefficient: 0.3435
# Epoch [134/250], Training Loss: 0.1276, Training Accuracy: 0.5576 Validation Loss: 0.1290, Validation Accuracy: 0.5213 Macro F1: 0.4486, Matthews Correlation Coefficient: 0.3278
# Epoch [135/250], Training Loss: 0.1278, Training Accuracy: 0.5497 Validation Loss: 0.1296, Validation Accuracy: 0.5288 Macro F1: 0.4640, Matthews Correlation Coefficient: 0.3420
# Epoch [136/250], Training Loss: 0.1279, Training Accuracy: 0.5460 Validation Loss: 0.1292, Validation Accuracy: 0.5325 Macro F1: 0.4661, Matthews Correlation Coefficient: 0.3486
# Epoch [137/250], Training Loss: 0.1284, Training Accuracy: 0.5529 Validation Loss: 0.1290, Validation Accuracy: 0.5436 Macro F1: 0.4808, Matthews Correlation Coefficient: 0.3613
# Epoch [138/250], Training Loss: 0.1286, Training Accuracy: 0.5492 Validation Loss: 0.1301, Validation Accuracy: 0.5139 Macro F1: 0.4541, Matthews Correlation Coefficient: 0.3256
# Epoch [139/250], Training Loss: 0.1284, Training Accuracy: 0.5590 Validation Loss: 0.1289, Validation Accuracy: 0.5325 Macro F1: 0.4640, Matthews Correlation Coefficient: 0.3451
# Epoch [140/250], Training Loss: 0.1279, Training Accuracy: 0.5622 Validation Loss: 0.1290, Validation Accuracy: 0.5325 Macro F1: 0.4718, Matthews Correlation Coefficient: 0.3473
# Epoch [141/250], Training Loss: 0.1274, Training Accuracy: 0.5515 Validation Loss: 0.1286, Validation Accuracy: 0.5362 Macro F1: 0.4769, Matthews Correlation Coefficient: 0.3494
# Epoch [142/250], Training Loss: 0.1288, Training Accuracy: 0.5520 Validation Loss: 0.1306, Validation Accuracy: 0.5250 Macro F1: 0.4749, Matthews Correlation Coefficient: 0.3478
# Epoch [143/250], Training Loss: 0.1286, Training Accuracy: 0.5385 Validation Loss: 0.1295, Validation Accuracy: 0.5288 Macro F1: 0.4635, Matthews Correlation Coefficient: 0.3445
# Epoch [144/250], Training Loss: 0.1280, Training Accuracy: 0.5650 Validation Loss: 0.1282, Validation Accuracy: 0.5399 Macro F1: 0.4616, Matthews Correlation Coefficient: 0.3499
# Epoch [145/250], Training Loss: 0.1283, Training Accuracy: 0.5529 Validation Loss: 0.1289, Validation Accuracy: 0.5306 Macro F1: 0.4658, Matthews Correlation Coefficient: 0.3473
# Epoch [146/250], Training Loss: 0.1265, Training Accuracy: 0.5566 Validation Loss: 0.1289, Validation Accuracy: 0.5325 Macro F1: 0.4728, Matthews Correlation Coefficient: 0.3520
# Epoch [147/250], Training Loss: 0.1265, Training Accuracy: 0.5543 Validation Loss: 0.1284, Validation Accuracy: 0.5362 Macro F1: 0.4685, Matthews Correlation Coefficient: 0.3512
# Epoch [148/250], Training Loss: 0.1265, Training Accuracy: 0.5571 Validation Loss: 0.1291, Validation Accuracy: 0.5306 Macro F1: 0.4616, Matthews Correlation Coefficient: 0.3433
# Epoch [149/250], Training Loss: 0.1274, Training Accuracy: 0.5580 Validation Loss: 0.1291, Validation Accuracy: 0.5417 Macro F1: 0.4698, Matthews Correlation Coefficient: 0.3567
# Epoch [150/250], Training Loss: 0.1286, Training Accuracy: 0.5552 Validation Loss: 0.1296, Validation Accuracy: 0.5399 Macro F1: 0.4649, Matthews Correlation Coefficient: 0.3524
# Epoch [151/250], Training Loss: 0.1272, Training Accuracy: 0.5687 Validation Loss: 0.1289, Validation Accuracy: 0.5343 Macro F1: 0.4610, Matthews Correlation Coefficient: 0.3476
# Epoch [152/250], Training Loss: 0.1264, Training Accuracy: 0.5794 Validation Loss: 0.1282, Validation Accuracy: 0.5399 Macro F1: 0.4657, Matthews Correlation Coefficient: 0.3550
# Epoch [153/250], Training Loss: 0.1269, Training Accuracy: 0.5664 Validation Loss: 0.1279, Validation Accuracy: 0.5436 Macro F1: 0.4665, Matthews Correlation Coefficient: 0.3566
# Epoch [154/250], Training Loss: 0.1282, Training Accuracy: 0.5599 Validation Loss: 0.1301, Validation Accuracy: 0.5343 Macro F1: 0.4642, Matthews Correlation Coefficient: 0.3464
# Epoch [155/250], Training Loss: 0.1280, Training Accuracy: 0.5590 Validation Loss: 0.1285, Validation Accuracy: 0.5325 Macro F1: 0.4634, Matthews Correlation Coefficient: 0.3419
# Epoch [156/250], Training Loss: 0.1284, Training Accuracy: 0.5580 Validation Loss: 0.1292, Validation Accuracy: 0.5269 Macro F1: 0.4595, Matthews Correlation Coefficient: 0.3377
# Epoch [157/250], Training Loss: 0.1268, Training Accuracy: 0.5627 Validation Loss: 0.1290, Validation Accuracy: 0.5380 Macro F1: 0.4677, Matthews Correlation Coefficient: 0.3489
# Epoch [158/250], Training Loss: 0.1281, Training Accuracy: 0.5613 Validation Loss: 0.1285, Validation Accuracy: 0.5417 Macro F1: 0.4641, Matthews Correlation Coefficient: 0.3531
# Epoch [159/250], Training Loss: 0.1284, Training Accuracy: 0.5552 Validation Loss: 0.1297, Validation Accuracy: 0.5417 Macro F1: 0.4734, Matthews Correlation Coefficient: 0.3552
# Epoch [160/250], Training Loss: 0.1264, Training Accuracy: 0.5734 Validation Loss: 0.1283, Validation Accuracy: 0.5325 Macro F1: 0.4639, Matthews Correlation Coefficient: 0.3445
# Epoch [161/250], Training Loss: 0.1283, Training Accuracy: 0.5474 Validation Loss: 0.1293, Validation Accuracy: 0.5306 Macro F1: 0.4652, Matthews Correlation Coefficient: 0.3428
# Epoch [162/250], Training Loss: 0.1267, Training Accuracy: 0.5650 Validation Loss: 0.1294, Validation Accuracy: 0.5399 Macro F1: 0.4659, Matthews Correlation Coefficient: 0.3537
# Epoch [163/250], Training Loss: 0.1279, Training Accuracy: 0.5641 Validation Loss: 0.1292, Validation Accuracy: 0.5362 Macro F1: 0.4710, Matthews Correlation Coefficient: 0.3554
# Epoch [164/250], Training Loss: 0.1278, Training Accuracy: 0.5483 Validation Loss: 0.1282, Validation Accuracy: 0.5343 Macro F1: 0.4646, Matthews Correlation Coefficient: 0.3472
# Epoch [165/250], Training Loss: 0.1275, Training Accuracy: 0.5487 Validation Loss: 0.1279, Validation Accuracy: 0.5510 Macro F1: 0.4719, Matthews Correlation Coefficient: 0.3618
# Epoch [166/250], Training Loss: 0.1265, Training Accuracy: 0.5664 Validation Loss: 0.1283, Validation Accuracy: 0.5232 Macro F1: 0.4564, Matthews Correlation Coefficient: 0.3395
# Epoch [167/250], Training Loss: 0.1249, Training Accuracy: 0.5743 Validation Loss: 0.1284, Validation Accuracy: 0.5325 Macro F1: 0.4573, Matthews Correlation Coefficient: 0.3456
# Epoch [168/250], Training Loss: 0.1270, Training Accuracy: 0.5571 Validation Loss: 0.1286, Validation Accuracy: 0.5325 Macro F1: 0.4690, Matthews Correlation Coefficient: 0.3510
# Epoch [169/250], Training Loss: 0.1273, Training Accuracy: 0.5669 Validation Loss: 0.1280, Validation Accuracy: 0.5455 Macro F1: 0.4707, Matthews Correlation Coefficient: 0.3636
# Epoch [170/250], Training Loss: 0.1259, Training Accuracy: 0.5682 Validation Loss: 0.1280, Validation Accuracy: 0.5473 Macro F1: 0.4745, Matthews Correlation Coefficient: 0.3647
# Epoch [171/250], Training Loss: 0.1261, Training Accuracy: 0.5682 Validation Loss: 0.1292, Validation Accuracy: 0.5325 Macro F1: 0.4698, Matthews Correlation Coefficient: 0.3490
# Epoch [172/250], Training Loss: 0.1272, Training Accuracy: 0.5539 Validation Loss: 0.1282, Validation Accuracy: 0.5380 Macro F1: 0.4662, Matthews Correlation Coefficient: 0.3515
# Epoch [173/250], Training Loss: 0.1268, Training Accuracy: 0.5604 Validation Loss: 0.1280, Validation Accuracy: 0.5306 Macro F1: 0.4621, Matthews Correlation Coefficient: 0.3460
# Epoch [174/250], Training Loss: 0.1268, Training Accuracy: 0.5664 Validation Loss: 0.1296, Validation Accuracy: 0.5288 Macro F1: 0.4623, Matthews Correlation Coefficient: 0.3460
# Epoch [175/250], Training Loss: 0.1270, Training Accuracy: 0.5515 Validation Loss: 0.1287, Validation Accuracy: 0.5232 Macro F1: 0.4654, Matthews Correlation Coefficient: 0.3420
# Epoch [176/250], Training Loss: 0.1269, Training Accuracy: 0.5659 Validation Loss: 0.1277, Validation Accuracy: 0.5399 Macro F1: 0.4688, Matthews Correlation Coefficient: 0.3544
# Epoch [177/250], Training Loss: 0.1264, Training Accuracy: 0.5738 Validation Loss: 0.1280, Validation Accuracy: 0.5436 Macro F1: 0.4753, Matthews Correlation Coefficient: 0.3588
# Epoch [178/250], Training Loss: 0.1256, Training Accuracy: 0.5622 Validation Loss: 0.1278, Validation Accuracy: 0.5288 Macro F1: 0.4644, Matthews Correlation Coefficient: 0.3412
# Epoch [179/250], Training Loss: 0.1277, Training Accuracy: 0.5492 Validation Loss: 0.1279, Validation Accuracy: 0.5492 Macro F1: 0.4797, Matthews Correlation Coefficient: 0.3639
# Epoch [180/250], Training Loss: 0.1269, Training Accuracy: 0.5692 Validation Loss: 0.1268, Validation Accuracy: 0.5603 Macro F1: 0.4713, Matthews Correlation Coefficient: 0.3762
# Epoch [181/250], Training Loss: 0.1253, Training Accuracy: 0.5511 Validation Loss: 0.1269, Validation Accuracy: 0.5436 Macro F1: 0.4796, Matthews Correlation Coefficient: 0.3603
# Epoch [182/250], Training Loss: 0.1246, Training Accuracy: 0.5548 Validation Loss: 0.1282, Validation Accuracy: 0.5343 Macro F1: 0.4572, Matthews Correlation Coefficient: 0.3430
# Epoch [183/250], Training Loss: 0.1276, Training Accuracy: 0.5627 Validation Loss: 0.1286, Validation Accuracy: 0.5306 Macro F1: 0.4552, Matthews Correlation Coefficient: 0.3422
# Epoch [184/250], Training Loss: 0.1255, Training Accuracy: 0.5678 Validation Loss: 0.1275, Validation Accuracy: 0.5436 Macro F1: 0.4654, Matthews Correlation Coefficient: 0.3558
# Epoch [185/250], Training Loss: 0.1244, Training Accuracy: 0.5729 Validation Loss: 0.1274, Validation Accuracy: 0.5492 Macro F1: 0.4798, Matthews Correlation Coefficient: 0.3702
# Epoch [186/250], Training Loss: 0.1263, Training Accuracy: 0.5613 Validation Loss: 0.1272, Validation Accuracy: 0.5399 Macro F1: 0.4697, Matthews Correlation Coefficient: 0.3533
# Epoch [187/250], Training Loss: 0.1257, Training Accuracy: 0.5608 Validation Loss: 0.1286, Validation Accuracy: 0.5325 Macro F1: 0.4496, Matthews Correlation Coefficient: 0.3351
# Epoch [188/250], Training Loss: 0.1264, Training Accuracy: 0.5566 Validation Loss: 0.1274, Validation Accuracy: 0.5343 Macro F1: 0.4651, Matthews Correlation Coefficient: 0.3501
# Epoch [189/250], Training Loss: 0.1250, Training Accuracy: 0.5613 Validation Loss: 0.1274, Validation Accuracy: 0.5306 Macro F1: 0.4607, Matthews Correlation Coefficient: 0.3428
# Epoch [190/250], Training Loss: 0.1272, Training Accuracy: 0.5631 Validation Loss: 0.1281, Validation Accuracy: 0.5473 Macro F1: 0.4673, Matthews Correlation Coefficient: 0.3580
# Epoch [191/250], Training Loss: 0.1241, Training Accuracy: 0.5771 Validation Loss: 0.1286, Validation Accuracy: 0.5343 Macro F1: 0.4577, Matthews Correlation Coefficient: 0.3456
# Epoch [192/250], Training Loss: 0.1264, Training Accuracy: 0.5655 Validation Loss: 0.1287, Validation Accuracy: 0.5306 Macro F1: 0.4608, Matthews Correlation Coefficient: 0.3436
# Epoch [193/250], Training Loss: 0.1256, Training Accuracy: 0.5608 Validation Loss: 0.1281, Validation Accuracy: 0.5473 Macro F1: 0.4760, Matthews Correlation Coefficient: 0.3601
# Epoch [194/250], Training Loss: 0.1256, Training Accuracy: 0.5594 Validation Loss: 0.1280, Validation Accuracy: 0.5473 Macro F1: 0.4717, Matthews Correlation Coefficient: 0.3610
# Epoch [195/250], Training Loss: 0.1260, Training Accuracy: 0.5659 Validation Loss: 0.1292, Validation Accuracy: 0.5325 Macro F1: 0.4598, Matthews Correlation Coefficient: 0.3475
# Epoch [196/250], Training Loss: 0.1254, Training Accuracy: 0.5664 Validation Loss: 0.1275, Validation Accuracy: 0.5455 Macro F1: 0.4660, Matthews Correlation Coefficient: 0.3610
# Epoch [197/250], Training Loss: 0.1246, Training Accuracy: 0.5738 Validation Loss: 0.1274, Validation Accuracy: 0.5399 Macro F1: 0.4697, Matthews Correlation Coefficient: 0.3564
# Epoch [198/250], Training Loss: 0.1260, Training Accuracy: 0.5655 Validation Loss: 0.1279, Validation Accuracy: 0.5455 Macro F1: 0.4649, Matthews Correlation Coefficient: 0.3567
# Epoch [199/250], Training Loss: 0.1259, Training Accuracy: 0.5706 Validation Loss: 0.1285, Validation Accuracy: 0.5269 Macro F1: 0.4539, Matthews Correlation Coefficient: 0.3375
# Epoch [200/250], Training Loss: 0.1254, Training Accuracy: 0.5799 Validation Loss: 0.1290, Validation Accuracy: 0.5380 Macro F1: 0.4635, Matthews Correlation Coefficient: 0.3470
# Epoch [201/250], Training Loss: 0.1245, Training Accuracy: 0.5706 Validation Loss: 0.1286, Validation Accuracy: 0.5325 Macro F1: 0.4618, Matthews Correlation Coefficient: 0.3448
# Epoch [202/250], Training Loss: 0.1254, Training Accuracy: 0.5641 Validation Loss: 0.1275, Validation Accuracy: 0.5176 Macro F1: 0.4459, Matthews Correlation Coefficient: 0.3230
# Epoch [203/250], Training Loss: 0.1248, Training Accuracy: 0.5715 Validation Loss: 0.1285, Validation Accuracy: 0.5306 Macro F1: 0.4501, Matthews Correlation Coefficient: 0.3347
# Epoch [204/250], Training Loss: 0.1254, Training Accuracy: 0.5673 Validation Loss: 0.1275, Validation Accuracy: 0.5325 Macro F1: 0.4660, Matthews Correlation Coefficient: 0.3528
# Epoch [205/250], Training Loss: 0.1241, Training Accuracy: 0.5831 Validation Loss: 0.1274, Validation Accuracy: 0.5492 Macro F1: 0.4682, Matthews Correlation Coefficient: 0.3616
# Epoch [206/250], Training Loss: 0.1246, Training Accuracy: 0.5720 Validation Loss: 0.1271, Validation Accuracy: 0.5306 Macro F1: 0.4740, Matthews Correlation Coefficient: 0.3543
# Epoch [207/250], Training Loss: 0.1259, Training Accuracy: 0.5757 Validation Loss: 0.1265, Validation Accuracy: 0.5473 Macro F1: 0.4677, Matthews Correlation Coefficient: 0.3643
# Epoch [208/250], Training Loss: 0.1256, Training Accuracy: 0.5710 Validation Loss: 0.1291, Validation Accuracy: 0.5343 Macro F1: 0.4532, Matthews Correlation Coefficient: 0.3470
# Epoch [209/250], Training Loss: 0.1248, Training Accuracy: 0.5766 Validation Loss: 0.1274, Validation Accuracy: 0.5343 Macro F1: 0.4570, Matthews Correlation Coefficient: 0.3474
# Epoch [210/250], Training Loss: 0.1253, Training Accuracy: 0.5752 Validation Loss: 0.1273, Validation Accuracy: 0.5529 Macro F1: 0.4810, Matthews Correlation Coefficient: 0.3696
# Epoch [211/250], Training Loss: 0.1247, Training Accuracy: 0.5743 Validation Loss: 0.1278, Validation Accuracy: 0.5492 Macro F1: 0.4741, Matthews Correlation Coefficient: 0.3646
# Epoch [212/250], Training Loss: 0.1244, Training Accuracy: 0.5692 Validation Loss: 0.1279, Validation Accuracy: 0.5455 Macro F1: 0.4738, Matthews Correlation Coefficient: 0.3654
# Epoch [213/250], Training Loss: 0.1261, Training Accuracy: 0.5655 Validation Loss: 0.1282, Validation Accuracy: 0.5399 Macro F1: 0.4692, Matthews Correlation Coefficient: 0.3531
# Epoch [214/250], Training Loss: 0.1261, Training Accuracy: 0.5650 Validation Loss: 0.1281, Validation Accuracy: 0.5417 Macro F1: 0.4670, Matthews Correlation Coefficient: 0.3528
# Epoch [215/250], Training Loss: 0.1263, Training Accuracy: 0.5664 Validation Loss: 0.1283, Validation Accuracy: 0.5417 Macro F1: 0.4686, Matthews Correlation Coefficient: 0.3612
# Epoch [216/250], Training Loss: 0.1261, Training Accuracy: 0.5715 Validation Loss: 0.1279, Validation Accuracy: 0.5455 Macro F1: 0.4670, Matthews Correlation Coefficient: 0.3583
# Epoch [217/250], Training Loss: 0.1242, Training Accuracy: 0.5743 Validation Loss: 0.1272, Validation Accuracy: 0.5492 Macro F1: 0.4719, Matthews Correlation Coefficient: 0.3658
# Epoch [218/250], Training Loss: 0.1231, Training Accuracy: 0.5720 Validation Loss: 0.1276, Validation Accuracy: 0.5473 Macro F1: 0.4719, Matthews Correlation Coefficient: 0.3598
# Epoch [219/250], Training Loss: 0.1242, Training Accuracy: 0.5743 Validation Loss: 0.1282, Validation Accuracy: 0.5455 Macro F1: 0.4779, Matthews Correlation Coefficient: 0.3661
# Epoch [220/250], Training Loss: 0.1238, Training Accuracy: 0.5511 Validation Loss: 0.1283, Validation Accuracy: 0.5288 Macro F1: 0.4613, Matthews Correlation Coefficient: 0.3408
# Epoch [221/250], Training Loss: 0.1256, Training Accuracy: 0.5706 Validation Loss: 0.1286, Validation Accuracy: 0.5362 Macro F1: 0.4616, Matthews Correlation Coefficient: 0.3499
# Epoch [222/250], Training Loss: 0.1244, Training Accuracy: 0.5761 Validation Loss: 0.1273, Validation Accuracy: 0.5306 Macro F1: 0.4649, Matthews Correlation Coefficient: 0.3464
# Epoch [223/250], Training Loss: 0.1244, Training Accuracy: 0.5673 Validation Loss: 0.1280, Validation Accuracy: 0.5473 Macro F1: 0.4678, Matthews Correlation Coefficient: 0.3598
# Epoch [224/250], Training Loss: 0.1242, Training Accuracy: 0.5743 Validation Loss: 0.1277, Validation Accuracy: 0.5362 Macro F1: 0.4702, Matthews Correlation Coefficient: 0.3535
# Epoch [225/250], Training Loss: 0.1239, Training Accuracy: 0.5826 Validation Loss: 0.1274, Validation Accuracy: 0.5362 Macro F1: 0.4667, Matthews Correlation Coefficient: 0.3518
# Epoch [226/250], Training Loss: 0.1242, Training Accuracy: 0.5701 Validation Loss: 0.1276, Validation Accuracy: 0.5436 Macro F1: 0.4700, Matthews Correlation Coefficient: 0.3574
# Epoch [227/250], Training Loss: 0.1229, Training Accuracy: 0.5710 Validation Loss: 0.1278, Validation Accuracy: 0.5325 Macro F1: 0.4655, Matthews Correlation Coefficient: 0.3507
# Epoch [228/250], Training Loss: 0.1226, Training Accuracy: 0.5687 Validation Loss: 0.1279, Validation Accuracy: 0.5399 Macro F1: 0.4671, Matthews Correlation Coefficient: 0.3531
# Epoch [229/250], Training Loss: 0.1235, Training Accuracy: 0.5803 Validation Loss: 0.1279, Validation Accuracy: 0.5306 Macro F1: 0.4705, Matthews Correlation Coefficient: 0.3515
# Epoch [230/250], Training Loss: 0.1220, Training Accuracy: 0.5850 Validation Loss: 0.1273, Validation Accuracy: 0.5399 Macro F1: 0.4739, Matthews Correlation Coefficient: 0.3557
# Epoch [231/250], Training Loss: 0.1218, Training Accuracy: 0.5785 Validation Loss: 0.1269, Validation Accuracy: 0.5566 Macro F1: 0.4870, Matthews Correlation Coefficient: 0.3779
# Epoch [232/250], Training Loss: 0.1240, Training Accuracy: 0.5724 Validation Loss: 0.1276, Validation Accuracy: 0.5436 Macro F1: 0.4886, Matthews Correlation Coefficient: 0.3637
# Epoch [233/250], Training Loss: 0.1241, Training Accuracy: 0.5789 Validation Loss: 0.1262, Validation Accuracy: 0.5547 Macro F1: 0.4811, Matthews Correlation Coefficient: 0.3765
# Epoch [234/250], Training Loss: 0.1226, Training Accuracy: 0.5812 Validation Loss: 0.1281, Validation Accuracy: 0.5399 Macro F1: 0.4778, Matthews Correlation Coefficient: 0.3600
# Epoch [235/250], Training Loss: 0.1243, Training Accuracy: 0.5669 Validation Loss: 0.1269, Validation Accuracy: 0.5436 Macro F1: 0.4808, Matthews Correlation Coefficient: 0.3639
# Epoch [236/250], Training Loss: 0.1230, Training Accuracy: 0.5701 Validation Loss: 0.1268, Validation Accuracy: 0.5380 Macro F1: 0.4786, Matthews Correlation Coefficient: 0.3566
# Epoch [237/250], Training Loss: 0.1241, Training Accuracy: 0.5785 Validation Loss: 0.1269, Validation Accuracy: 0.5380 Macro F1: 0.4676, Matthews Correlation Coefficient: 0.3489
# Epoch [238/250], Training Loss: 0.1225, Training Accuracy: 0.5747 Validation Loss: 0.1271, Validation Accuracy: 0.5417 Macro F1: 0.4710, Matthews Correlation Coefficient: 0.3499
# Epoch [239/250], Training Loss: 0.1249, Training Accuracy: 0.5664 Validation Loss: 0.1273, Validation Accuracy: 0.5250 Macro F1: 0.4628, Matthews Correlation Coefficient: 0.3429
# Epoch [240/250], Training Loss: 0.1228, Training Accuracy: 0.5780 Validation Loss: 0.1270, Validation Accuracy: 0.5306 Macro F1: 0.4668, Matthews Correlation Coefficient: 0.3427
# Epoch [241/250], Training Loss: 0.1228, Training Accuracy: 0.5631 Validation Loss: 0.1256, Validation Accuracy: 0.5492 Macro F1: 0.4841, Matthews Correlation Coefficient: 0.3691
# Epoch [242/250], Training Loss: 0.1221, Training Accuracy: 0.5729 Validation Loss: 0.1267, Validation Accuracy: 0.5362 Macro F1: 0.4567, Matthews Correlation Coefficient: 0.3387
# Epoch [243/250], Training Loss: 0.1237, Training Accuracy: 0.5766 Validation Loss: 0.1257, Validation Accuracy: 0.5417 Macro F1: 0.4798, Matthews Correlation Coefficient: 0.3619
# Epoch [244/250], Training Loss: 0.1226, Training Accuracy: 0.5706 Validation Loss: 0.1266, Validation Accuracy: 0.5436 Macro F1: 0.4764, Matthews Correlation Coefficient: 0.3560
# Epoch [245/250], Training Loss: 0.1232, Training Accuracy: 0.5785 Validation Loss: 0.1275, Validation Accuracy: 0.5343 Macro F1: 0.4733, Matthews Correlation Coefficient: 0.3561
# Epoch [246/250], Training Loss: 0.1222, Training Accuracy: 0.5757 Validation Loss: 0.1279, Validation Accuracy: 0.5380 Macro F1: 0.4787, Matthews Correlation Coefficient: 0.3596
# Epoch [247/250], Training Loss: 0.1241, Training Accuracy: 0.5590 Validation Loss: 0.1265, Validation Accuracy: 0.5325 Macro F1: 0.4612, Matthews Correlation Coefficient: 0.3424
# Epoch [248/250], Training Loss: 0.1234, Training Accuracy: 0.5613 Validation Loss: 0.1264, Validation Accuracy: 0.5343 Macro F1: 0.4665, Matthews Correlation Coefficient: 0.3512
# Epoch [249/250], Training Loss: 0.1222, Training Accuracy: 0.5808 Validation Loss: 0.1281, Validation Accuracy: 0.5399 Macro F1: 0.4798, Matthews Correlation Coefficient: 0.3526
# Epoch [250/250], Training Loss: 0.1232, Training Accuracy: 0.5715 Validation Loss: 0.1267, Validation Accuracy: 0.5473 Macro F1: 0.4938, Matthews Correlation Coefficient: 0.3694

# %% [markdown]
# ### 5-fold cross validation

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=Seed)

# Create a full label for the full dataset
full_labels = [label_to_int[label] for label in LD['Localization'].values]

# Create the training and validation datasets    
if Set == 'Protein':
    train_dataset = MyDataset(Set, PD, PD, LD.index, full_labels, transform=transformation)
    val_dataset = MyDataset(Set, PD, PD, LD.index, full_labels)
elif Set == 'mRNA':
    train_dataset = MyDataset(Set, MD, MD, LD.index, full_labels, transform=transformation)
    val_dataset = MyDataset(Set, MD, MD, LD.index, full_labels)
elif Set == 'Protein + mRNA':
    train_dataset = MyDataset(Set, PD, MD, LD.index, full_labels, transform=transformation)
    val_dataset = MyDataset(Set, PD, MD, LD.index, full_labels)
else:
    raise ValueError("Invalid dataset selection. Choose 'Protein', 'mRNA', 'Protein + mRNA'.")

for fold, (train_ids, val_ids) in enumerate(kfold.split(train_dataset)):
    print(f'\n--- Fold {fold+1} ---')

    # Create subset loaders
    train_subsampler = torch.utils.data.Subset(train_dataset, train_ids)
    val_subsampler = torch.utils.data.Subset(val_dataset, val_ids)

    train_loader = DataLoader(train_subsampler, batch_size=Batch_size, shuffle=True)
    val_loader = DataLoader(val_subsampler, batch_size=Batch_size, shuffle=False)

    # Reset model, optimizer, scheduler per fold
    model = PixelPreservingNet(in_channels=3).to(device)  # fresh model per fold
    optimizer = optim.AdamW(model.parameters(), lr=Learner_rate, weight_decay=Weight_Decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10, threshold=1e-4, cooldown=2, min_lr=1e-7, verbose=True)
    criterion = FocalLoss(alpha=LossWeights, gamma=2.0, reduction='mean')
    #early_stopping = EarlyStoppingWithCheckpoint(patience=15, delta=0, save_path=None)

    # Initialize tracking DataFrames
    LossAccDF = pd.DataFrame(index=range(epochs),columns=['Epoch','TrainLoss','ValLoss','TrainAcc','ValAcc'])
    PrecisionRecallDF = pd.DataFrame(columns=['Epoch','Class','Precision','Recall','Class F1','Macro F1','MCC'])
    index = 0

    # Evaluate before training
    avg_train_loss, train_accuracy, _, _, _, macro_f1, mcc = test_loop(train_loader, model, criterion)
    avg_val_loss, val_accuracy, precision, recall, per_class_f1, macro_f1, mcc = test_loop(val_loader, model, criterion)

    print(f"Before Training: Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}, Macro F1: {macro_f1:.4f}, MCC: {mcc:.4f}")

    LossAccDF.loc[0, :] = [0, avg_train_loss, avg_val_loss, train_accuracy, val_accuracy]
    for i in range(4):
        PrecisionRecallDF.loc[index] = [0, i, precision[i], recall[i], per_class_f1[i], macro_f1, mcc]
        index += 1

    # Training loop
    for epoch in range(epochs):

        avg_train_loss, train_accuracy = train_loop(train_loader, model, criterion, optimizer)
        avg_val_loss, val_accuracy, precision, recall, per_class_f1, macro_f1, mcc = test_loop(val_loader, model, criterion)

        print(f"Epoch [{epoch+1}/{epochs}] Fold [{fold+1}] Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f} Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}, Macro F1: {macro_f1:.4f}, MCC: {mcc:.4f}")

        LossAccDF.loc[epoch+1, :] = [epoch+1, avg_train_loss, avg_val_loss, train_accuracy, val_accuracy]
        for i in range(4):
            PrecisionRecallDF.loc[index] = [epoch+1, i, precision[i], recall[i], per_class_f1[i], macro_f1, mcc]
            index += 1

        # Early stopping check
    #    early_stopping(avg_val_loss, model)
    #    if early_stopping.early_stop:
    #        print(f"Early stopping at epoch {epoch}")
    #        break

    # Optionally save LossAccDF, PrecisionRecallDF per fold
    LossAccDF.to_csv(cv_folder_path+f'{Set}_Fold{fold+1}_LossAcc.csv', index=False)
    PrecisionRecallDF.to_csv(cv_folder_path+f'{Set}_Fold{fold+1}_PrecisionRecall.csv', index=False)
# Out:
# --- Fold 1 ---
# /opt/conda/envs/pytorch/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Before Training: Training Loss: 0.1679, Training Accuracy: 0.0989, Validation Loss: 0.1662, Validation Accuracy: 0.0946, Macro F1: 0.0432, MCC: 0.0000
# Epoch [1/250] Fold [1] Train Loss: 0.1639, Train Acc: 0.3236 Val Loss: 0.1640, Val Acc: 0.3711, Macro F1: 0.2442, MCC: 0.1799
# Epoch [2/250] Fold [1] Train Loss: 0.1595, Train Acc: 0.4048 Val Loss: 0.1553, Val Acc: 0.4731, Macro F1: 0.3452, MCC: 0.2332
# Epoch [3/250] Fold [1] Train Loss: 0.1563, Train Acc: 0.4318 Val Loss: 0.1492, Val Acc: 0.4879, Macro F1: 0.3525, MCC: 0.2520
# Epoch [4/250] Fold [1] Train Loss: 0.1510, Train Acc: 0.4680 Val Loss: 0.1452, Val Acc: 0.5232, Macro F1: 0.3871, MCC: 0.3051
# Epoch [5/250] Fold [1] Train Loss: 0.1493, Train Acc: 0.4740 Val Loss: 0.1425, Val Acc: 0.5306, Macro F1: 0.3909, MCC: 0.3215
# Epoch [6/250] Fold [1] Train Loss: 0.1477, Train Acc: 0.4791 Val Loss: 0.1411, Val Acc: 0.5399, Macro F1: 0.4106, MCC: 0.3367
# Epoch [7/250] Fold [1] Train Loss: 0.1484, Train Acc: 0.4670 Val Loss: 0.1396, Val Acc: 0.5343, Macro F1: 0.4147, MCC: 0.3330
# Epoch [8/250] Fold [1] Train Loss: 0.1460, Train Acc: 0.4847 Val Loss: 0.1392, Val Acc: 0.5473, Macro F1: 0.4255, MCC: 0.3521
# Epoch [9/250] Fold [1] Train Loss: 0.1451, Train Acc: 0.4958 Val Loss: 0.1375, Val Acc: 0.5417, Macro F1: 0.4236, MCC: 0.3467
# Epoch [10/250] Fold [1] Train Loss: 0.1444, Train Acc: 0.4773 Val Loss: 0.1370, Val Acc: 0.5362, Macro F1: 0.4209, MCC: 0.3499
# Epoch [11/250] Fold [1] Train Loss: 0.1432, Train Acc: 0.5079 Val Loss: 0.1349, Val Acc: 0.5343, Macro F1: 0.4182, MCC: 0.3419
# Epoch [12/250] Fold [1] Train Loss: 0.1435, Train Acc: 0.4921 Val Loss: 0.1359, Val Acc: 0.5250, Macro F1: 0.4128, MCC: 0.3391
# Epoch [13/250] Fold [1] Train Loss: 0.1438, Train Acc: 0.5023 Val Loss: 0.1364, Val Acc: 0.5399, Macro F1: 0.4233, MCC: 0.3488
# Epoch [14/250] Fold [1] Train Loss: 0.1425, Train Acc: 0.5218 Val Loss: 0.1361, Val Acc: 0.5306, Macro F1: 0.4169, MCC: 0.3369
# Epoch [15/250] Fold [1] Train Loss: 0.1411, Train Acc: 0.5162 Val Loss: 0.1353, Val Acc: 0.5362, Macro F1: 0.4204, MCC: 0.3417
# Epoch [16/250] Fold [1] Train Loss: 0.1407, Train Acc: 0.5060 Val Loss: 0.1357, Val Acc: 0.5399, Macro F1: 0.4241, MCC: 0.3495
# Epoch [17/250] Fold [1] Train Loss: 0.1412, Train Acc: 0.5056 Val Loss: 0.1350, Val Acc: 0.5417, Macro F1: 0.4272, MCC: 0.3482
# Epoch [18/250] Fold [1] Train Loss: 0.1419, Train Acc: 0.5181 Val Loss: 0.1350, Val Acc: 0.5306, Macro F1: 0.4191, MCC: 0.3376
# Epoch [19/250] Fold [1] Train Loss: 0.1407, Train Acc: 0.5111 Val Loss: 0.1351, Val Acc: 0.5325, Macro F1: 0.4187, MCC: 0.3389
# Epoch [20/250] Fold [1] Train Loss: 0.1399, Train Acc: 0.5079 Val Loss: 0.1347, Val Acc: 0.5399, Macro F1: 0.4416, MCC: 0.3509
# Epoch [21/250] Fold [1] Train Loss: 0.1392, Train Acc: 0.5181 Val Loss: 0.1351, Val Acc: 0.5213, Macro F1: 0.4271, MCC: 0.3242
# Epoch [22/250] Fold [1] Train Loss: 0.1408, Train Acc: 0.5009 Val Loss: 0.1351, Val Acc: 0.5306, Macro F1: 0.4328, MCC: 0.3312
# Epoch [23/250] Fold [1] Train Loss: 0.1409, Train Acc: 0.5121 Val Loss: 0.1353, Val Acc: 0.5362, Macro F1: 0.4374, MCC: 0.3394
# Epoch [24/250] Fold [1] Train Loss: 0.1395, Train Acc: 0.5190 Val Loss: 0.1352, Val Acc: 0.5250, Macro F1: 0.4348, MCC: 0.3253
# Epoch [25/250] Fold [1] Train Loss: 0.1387, Train Acc: 0.5251 Val Loss: 0.1352, Val Acc: 0.5195, Macro F1: 0.4289, MCC: 0.3170
# Epoch [26/250] Fold [1] Train Loss: 0.1391, Train Acc: 0.5144 Val Loss: 0.1348, Val Acc: 0.5139, Macro F1: 0.4206, MCC: 0.3124
# Epoch [27/250] Fold [1] Train Loss: 0.1397, Train Acc: 0.5223 Val Loss: 0.1344, Val Acc: 0.5269, Macro F1: 0.4529, MCC: 0.3289
# Epoch [28/250] Fold [1] Train Loss: 0.1393, Train Acc: 0.5306 Val Loss: 0.1344, Val Acc: 0.5269, Macro F1: 0.4453, MCC: 0.3297
# Epoch [29/250] Fold [1] Train Loss: 0.1394, Train Acc: 0.5325 Val Loss: 0.1340, Val Acc: 0.5213, Macro F1: 0.4424, MCC: 0.3238
# Epoch [30/250] Fold [1] Train Loss: 0.1393, Train Acc: 0.5172 Val Loss: 0.1344, Val Acc: 0.5232, Macro F1: 0.4642, MCC: 0.3303
# Epoch [31/250] Fold [1] Train Loss: 0.1390, Train Acc: 0.5176 Val Loss: 0.1336, Val Acc: 0.5325, Macro F1: 0.4690, MCC: 0.3401
# Epoch [32/250] Fold [1] Train Loss: 0.1380, Train Acc: 0.5167 Val Loss: 0.1334, Val Acc: 0.5325, Macro F1: 0.4680, MCC: 0.3375
# Epoch [33/250] Fold [1] Train Loss: 0.1380, Train Acc: 0.5306 Val Loss: 0.1332, Val Acc: 0.5325, Macro F1: 0.4659, MCC: 0.3433
# Epoch [34/250] Fold [1] Train Loss: 0.1377, Train Acc: 0.5302 Val Loss: 0.1334, Val Acc: 0.5325, Macro F1: 0.4513, MCC: 0.3372
# Epoch [35/250] Fold [1] Train Loss: 0.1378, Train Acc: 0.5149 Val Loss: 0.1333, Val Acc: 0.5343, Macro F1: 0.4579, MCC: 0.3392
# Epoch [36/250] Fold [1] Train Loss: 0.1376, Train Acc: 0.5316 Val Loss: 0.1331, Val Acc: 0.5362, Macro F1: 0.4759, MCC: 0.3502
# Epoch [37/250] Fold [1] Train Loss: 0.1362, Train Acc: 0.5520 Val Loss: 0.1325, Val Acc: 0.5343, Macro F1: 0.4696, MCC: 0.3459
# Epoch [38/250] Fold [1] Train Loss: 0.1363, Train Acc: 0.5367 Val Loss: 0.1326, Val Acc: 0.5362, Macro F1: 0.4659, MCC: 0.3442
# Epoch [39/250] Fold [1] Train Loss: 0.1359, Train Acc: 0.5441 Val Loss: 0.1325, Val Acc: 0.5380, Macro F1: 0.4625, MCC: 0.3435
# Epoch [40/250] Fold [1] Train Loss: 0.1360, Train Acc: 0.5353 Val Loss: 0.1320, Val Acc: 0.5343, Macro F1: 0.4579, MCC: 0.3380
# Epoch [41/250] Fold [1] Train Loss: 0.1368, Train Acc: 0.5121 Val Loss: 0.1314, Val Acc: 0.5288, Macro F1: 0.4579, MCC: 0.3338
# Epoch [42/250] Fold [1] Train Loss: 0.1357, Train Acc: 0.5246 Val Loss: 0.1320, Val Acc: 0.5399, Macro F1: 0.4722, MCC: 0.3484
# Epoch [43/250] Fold [1] Train Loss: 0.1362, Train Acc: 0.5339 Val Loss: 0.1316, Val Acc: 0.5547, Macro F1: 0.4991, MCC: 0.3703
# Epoch [44/250] Fold [1] Train Loss: 0.1362, Train Acc: 0.5316 Val Loss: 0.1323, Val Acc: 0.5417, Macro F1: 0.4622, MCC: 0.3489
# Epoch [45/250] Fold [1] Train Loss: 0.1365, Train Acc: 0.5265 Val Loss: 0.1315, Val Acc: 0.5455, Macro F1: 0.4570, MCC: 0.3502
# Epoch [46/250] Fold [1] Train Loss: 0.1356, Train Acc: 0.5297 Val Loss: 0.1315, Val Acc: 0.5492, Macro F1: 0.4637, MCC: 0.3580
# Epoch [47/250] Fold [1] Train Loss: 0.1355, Train Acc: 0.5381 Val Loss: 0.1307, Val Acc: 0.5473, Macro F1: 0.4704, MCC: 0.3531
# Epoch [48/250] Fold [1] Train Loss: 0.1354, Train Acc: 0.5427 Val Loss: 0.1314, Val Acc: 0.5436, Macro F1: 0.4584, MCC: 0.3491
# Epoch [49/250] Fold [1] Train Loss: 0.1368, Train Acc: 0.5241 Val Loss: 0.1318, Val Acc: 0.5455, Macro F1: 0.4679, MCC: 0.3521
# Epoch [50/250] Fold [1] Train Loss: 0.1350, Train Acc: 0.5413 Val Loss: 0.1307, Val Acc: 0.5492, Macro F1: 0.4662, MCC: 0.3574
# Epoch [51/250] Fold [1] Train Loss: 0.1352, Train Acc: 0.5330 Val Loss: 0.1309, Val Acc: 0.5417, Macro F1: 0.4552, MCC: 0.3451
# Epoch [52/250] Fold [1] Train Loss: 0.1347, Train Acc: 0.5274 Val Loss: 0.1318, Val Acc: 0.5529, Macro F1: 0.4673, MCC: 0.3574
# Epoch [53/250] Fold [1] Train Loss: 0.1352, Train Acc: 0.5297 Val Loss: 0.1321, Val Acc: 0.5436, Macro F1: 0.4573, MCC: 0.3474
# Epoch [54/250] Fold [1] Train Loss: 0.1348, Train Acc: 0.5292 Val Loss: 0.1319, Val Acc: 0.5417, Macro F1: 0.4517, MCC: 0.3434
# Epoch [55/250] Fold [1] Train Loss: 0.1351, Train Acc: 0.5260 Val Loss: 0.1310, Val Acc: 0.5510, Macro F1: 0.4653, MCC: 0.3553
# Epoch [56/250] Fold [1] Train Loss: 0.1355, Train Acc: 0.5306 Val Loss: 0.1320, Val Acc: 0.5492, Macro F1: 0.4565, MCC: 0.3521
# Epoch [57/250] Fold [1] Train Loss: 0.1371, Train Acc: 0.5214 Val Loss: 0.1316, Val Acc: 0.5380, Macro F1: 0.4414, MCC: 0.3429
# Epoch [58/250] Fold [1] Train Loss: 0.1340, Train Acc: 0.5344 Val Loss: 0.1318, Val Acc: 0.5529, Macro F1: 0.4508, MCC: 0.3553
# Epoch [59/250] Fold [1] Train Loss: 0.1342, Train Acc: 0.5330 Val Loss: 0.1312, Val Acc: 0.5473, Macro F1: 0.4582, MCC: 0.3524
# Epoch [60/250] Fold [1] Train Loss: 0.1338, Train Acc: 0.5432 Val Loss: 0.1315, Val Acc: 0.5399, Macro F1: 0.4419, MCC: 0.3440
# Epoch [61/250] Fold [1] Train Loss: 0.1325, Train Acc: 0.5483 Val Loss: 0.1312, Val Acc: 0.5603, Macro F1: 0.4673, MCC: 0.3690
# Epoch [62/250] Fold [1] Train Loss: 0.1337, Train Acc: 0.5474 Val Loss: 0.1306, Val Acc: 0.5362, Macro F1: 0.4449, MCC: 0.3391
# Epoch [63/250] Fold [1] Train Loss: 0.1340, Train Acc: 0.5385 Val Loss: 0.1312, Val Acc: 0.5399, Macro F1: 0.4474, MCC: 0.3431
# Epoch [64/250] Fold [1] Train Loss: 0.1334, Train Acc: 0.5339 Val Loss: 0.1320, Val Acc: 0.5529, Macro F1: 0.4600, MCC: 0.3578
# Epoch [65/250] Fold [1] Train Loss: 0.1345, Train Acc: 0.5487 Val Loss: 0.1303, Val Acc: 0.5622, Macro F1: 0.4758, MCC: 0.3715
# Epoch [66/250] Fold [1] Train Loss: 0.1320, Train Acc: 0.5460 Val Loss: 0.1295, Val Acc: 0.5529, Macro F1: 0.4624, MCC: 0.3585
# Epoch [67/250] Fold [1] Train Loss: 0.1326, Train Acc: 0.5399 Val Loss: 0.1306, Val Acc: 0.5529, Macro F1: 0.4695, MCC: 0.3604
# Epoch [68/250] Fold [1] Train Loss: 0.1324, Train Acc: 0.5381 Val Loss: 0.1297, Val Acc: 0.5547, Macro F1: 0.4635, MCC: 0.3634
# Epoch [69/250] Fold [1] Train Loss: 0.1334, Train Acc: 0.5320 Val Loss: 0.1308, Val Acc: 0.5510, Macro F1: 0.4492, MCC: 0.3562
# Epoch [70/250] Fold [1] Train Loss: 0.1344, Train Acc: 0.5357 Val Loss: 0.1297, Val Acc: 0.5510, Macro F1: 0.4707, MCC: 0.3575
# Epoch [71/250] Fold [1] Train Loss: 0.1328, Train Acc: 0.5381 Val Loss: 0.1301, Val Acc: 0.5492, Macro F1: 0.4593, MCC: 0.3555
# Epoch [72/250] Fold [1] Train Loss: 0.1328, Train Acc: 0.5432 Val Loss: 0.1299, Val Acc: 0.5603, Macro F1: 0.4713, MCC: 0.3670
# Epoch [73/250] Fold [1] Train Loss: 0.1333, Train Acc: 0.5357 Val Loss: 0.1313, Val Acc: 0.5510, Macro F1: 0.4563, MCC: 0.3557
# Epoch [74/250] Fold [1] Train Loss: 0.1329, Train Acc: 0.5390 Val Loss: 0.1310, Val Acc: 0.5492, Macro F1: 0.4527, MCC: 0.3528
# Epoch [75/250] Fold [1] Train Loss: 0.1334, Train Acc: 0.5404 Val Loss: 0.1304, Val Acc: 0.5492, Macro F1: 0.4718, MCC: 0.3572
# Epoch [76/250] Fold [1] Train Loss: 0.1323, Train Acc: 0.5404 Val Loss: 0.1303, Val Acc: 0.5455, Macro F1: 0.4544, MCC: 0.3472
# Epoch [77/250] Fold [1] Train Loss: 0.1314, Train Acc: 0.5511 Val Loss: 0.1302, Val Acc: 0.5473, Macro F1: 0.4562, MCC: 0.3529
# Epoch [78/250] Fold [1] Train Loss: 0.1334, Train Acc: 0.5325 Val Loss: 0.1311, Val Acc: 0.5492, Macro F1: 0.4616, MCC: 0.3548
# Epoch [79/250] Fold [1] Train Loss: 0.1322, Train Acc: 0.5330 Val Loss: 0.1292, Val Acc: 0.5584, Macro F1: 0.4803, MCC: 0.3736
# Epoch [80/250] Fold [1] Train Loss: 0.1314, Train Acc: 0.5441 Val Loss: 0.1290, Val Acc: 0.5492, Macro F1: 0.4656, MCC: 0.3609
# Epoch [81/250] Fold [1] Train Loss: 0.1313, Train Acc: 0.5446 Val Loss: 0.1314, Val Acc: 0.5473, Macro F1: 0.4469, MCC: 0.3502
# Epoch [82/250] Fold [1] Train Loss: 0.1314, Train Acc: 0.5464 Val Loss: 0.1291, Val Acc: 0.5603, Macro F1: 0.4689, MCC: 0.3714
# Epoch [83/250] Fold [1] Train Loss: 0.1309, Train Acc: 0.5441 Val Loss: 0.1296, Val Acc: 0.5529, Macro F1: 0.4663, MCC: 0.3618
# Epoch [84/250] Fold [1] Train Loss: 0.1306, Train Acc: 0.5455 Val Loss: 0.1298, Val Acc: 0.5417, Macro F1: 0.4484, MCC: 0.3453
# Epoch [85/250] Fold [1] Train Loss: 0.1311, Train Acc: 0.5487 Val Loss: 0.1285, Val Acc: 0.5455, Macro F1: 0.4689, MCC: 0.3576
# Epoch [86/250] Fold [1] Train Loss: 0.1302, Train Acc: 0.5409 Val Loss: 0.1306, Val Acc: 0.5436, Macro F1: 0.4443, MCC: 0.3490
# Epoch [87/250] Fold [1] Train Loss: 0.1314, Train Acc: 0.5474 Val Loss: 0.1290, Val Acc: 0.5510, Macro F1: 0.4765, MCC: 0.3626
# Epoch [88/250] Fold [1] Train Loss: 0.1316, Train Acc: 0.5511 Val Loss: 0.1292, Val Acc: 0.5510, Macro F1: 0.4560, MCC: 0.3595
# Epoch [89/250] Fold [1] Train Loss: 0.1315, Train Acc: 0.5357 Val Loss: 0.1291, Val Acc: 0.5584, Macro F1: 0.4746, MCC: 0.3687
# Epoch [90/250] Fold [1] Train Loss: 0.1305, Train Acc: 0.5464 Val Loss: 0.1303, Val Acc: 0.5659, Macro F1: 0.4749, MCC: 0.3744
# Epoch [91/250] Fold [1] Train Loss: 0.1306, Train Acc: 0.5409 Val Loss: 0.1292, Val Acc: 0.5473, Macro F1: 0.4524, MCC: 0.3534
# Epoch [92/250] Fold [1] Train Loss: 0.1297, Train Acc: 0.5483 Val Loss: 0.1299, Val Acc: 0.5547, Macro F1: 0.4611, MCC: 0.3616
# Epoch [93/250] Fold [1] Train Loss: 0.1306, Train Acc: 0.5515 Val Loss: 0.1294, Val Acc: 0.5584, Macro F1: 0.4695, MCC: 0.3677
# Epoch [94/250] Fold [1] Train Loss: 0.1315, Train Acc: 0.5385 Val Loss: 0.1294, Val Acc: 0.5473, Macro F1: 0.4593, MCC: 0.3537
# Epoch [95/250] Fold [1] Train Loss: 0.1315, Train Acc: 0.5515 Val Loss: 0.1316, Val Acc: 0.5566, Macro F1: 0.4599, MCC: 0.3621
# Epoch [96/250] Fold [1] Train Loss: 0.1314, Train Acc: 0.5362 Val Loss: 0.1275, Val Acc: 0.5677, Macro F1: 0.4926, MCC: 0.3837
# Epoch [97/250] Fold [1] Train Loss: 0.1307, Train Acc: 0.5534 Val Loss: 0.1306, Val Acc: 0.5622, Macro F1: 0.4585, MCC: 0.3683
# Epoch [98/250] Fold [1] Train Loss: 0.1301, Train Acc: 0.5409 Val Loss: 0.1288, Val Acc: 0.5566, Macro F1: 0.4602, MCC: 0.3650
# Epoch [99/250] Fold [1] Train Loss: 0.1316, Train Acc: 0.5497 Val Loss: 0.1294, Val Acc: 0.5603, Macro F1: 0.4611, MCC: 0.3666
# Epoch [100/250] Fold [1] Train Loss: 0.1307, Train Acc: 0.5483 Val Loss: 0.1287, Val Acc: 0.5677, Macro F1: 0.4810, MCC: 0.3797
# Epoch [101/250] Fold [1] Train Loss: 0.1300, Train Acc: 0.5381 Val Loss: 0.1296, Val Acc: 0.5584, Macro F1: 0.4633, MCC: 0.3660
# Epoch [102/250] Fold [1] Train Loss: 0.1284, Train Acc: 0.5548 Val Loss: 0.1280, Val Acc: 0.5547, Macro F1: 0.4683, MCC: 0.3659
# Epoch [103/250] Fold [1] Train Loss: 0.1301, Train Acc: 0.5562 Val Loss: 0.1285, Val Acc: 0.5566, Macro F1: 0.4645, MCC: 0.3651
# Epoch [104/250] Fold [1] Train Loss: 0.1317, Train Acc: 0.5395 Val Loss: 0.1285, Val Acc: 0.5529, Macro F1: 0.4655, MCC: 0.3603
# Epoch [105/250] Fold [1] Train Loss: 0.1294, Train Acc: 0.5580 Val Loss: 0.1287, Val Acc: 0.5659, Macro F1: 0.4759, MCC: 0.3776
# Epoch [106/250] Fold [1] Train Loss: 0.1298, Train Acc: 0.5460 Val Loss: 0.1282, Val Acc: 0.5603, Macro F1: 0.4736, MCC: 0.3712
# Epoch [107/250] Fold [1] Train Loss: 0.1306, Train Acc: 0.5511 Val Loss: 0.1293, Val Acc: 0.5547, Macro F1: 0.4709, MCC: 0.3640
# Epoch [108/250] Fold [1] Train Loss: 0.1305, Train Acc: 0.5455 Val Loss: 0.1296, Val Acc: 0.5473, Macro F1: 0.4641, MCC: 0.3541
# Epoch [109/250] Fold [1] Train Loss: 0.1301, Train Acc: 0.5520 Val Loss: 0.1290, Val Acc: 0.5677, Macro F1: 0.4788, MCC: 0.3782
# Epoch [110/250] Fold [1] Train Loss: 0.1313, Train Acc: 0.5501 Val Loss: 0.1289, Val Acc: 0.5603, Macro F1: 0.4749, MCC: 0.3703
# Epoch [111/250] Fold [1] Train Loss: 0.1290, Train Acc: 0.5571 Val Loss: 0.1272, Val Acc: 0.5659, Macro F1: 0.4912, MCC: 0.3795
# Epoch [112/250] Fold [1] Train Loss: 0.1297, Train Acc: 0.5487 Val Loss: 0.1286, Val Acc: 0.5622, Macro F1: 0.4701, MCC: 0.3731
# Epoch [113/250] Fold [1] Train Loss: 0.1291, Train Acc: 0.5599 Val Loss: 0.1272, Val Acc: 0.5751, Macro F1: 0.5037, MCC: 0.3943
# Epoch [114/250] Fold [1] Train Loss: 0.1295, Train Acc: 0.5613 Val Loss: 0.1289, Val Acc: 0.5603, Macro F1: 0.4641, MCC: 0.3703
# Epoch [115/250] Fold [1] Train Loss: 0.1300, Train Acc: 0.5455 Val Loss: 0.1275, Val Acc: 0.5622, Macro F1: 0.4823, MCC: 0.3757
# Epoch [116/250] Fold [1] Train Loss: 0.1284, Train Acc: 0.5557 Val Loss: 0.1281, Val Acc: 0.5584, Macro F1: 0.4750, MCC: 0.3685
# Epoch [117/250] Fold [1] Train Loss: 0.1301, Train Acc: 0.5464 Val Loss: 0.1279, Val Acc: 0.5603, Macro F1: 0.4671, MCC: 0.3682
# Epoch [118/250] Fold [1] Train Loss: 0.1284, Train Acc: 0.5548 Val Loss: 0.1284, Val Acc: 0.5696, Macro F1: 0.4760, MCC: 0.3810
# Epoch [119/250] Fold [1] Train Loss: 0.1290, Train Acc: 0.5585 Val Loss: 0.1288, Val Acc: 0.5584, Macro F1: 0.4745, MCC: 0.3707
# Epoch [120/250] Fold [1] Train Loss: 0.1297, Train Acc: 0.5594 Val Loss: 0.1274, Val Acc: 0.5677, Macro F1: 0.4916, MCC: 0.3857
# Epoch [121/250] Fold [1] Train Loss: 0.1308, Train Acc: 0.5450 Val Loss: 0.1289, Val Acc: 0.5696, Macro F1: 0.4771, MCC: 0.3824
# Epoch [122/250] Fold [1] Train Loss: 0.1304, Train Acc: 0.5501 Val Loss: 0.1280, Val Acc: 0.5566, Macro F1: 0.4728, MCC: 0.3657
# Epoch [123/250] Fold [1] Train Loss: 0.1282, Train Acc: 0.5594 Val Loss: 0.1288, Val Acc: 0.5640, Macro F1: 0.4640, MCC: 0.3736
# Epoch [124/250] Fold [1] Train Loss: 0.1292, Train Acc: 0.5585 Val Loss: 0.1285, Val Acc: 0.5733, Macro F1: 0.4718, MCC: 0.3869
# Epoch [125/250] Fold [1] Train Loss: 0.1273, Train Acc: 0.5585 Val Loss: 0.1280, Val Acc: 0.5584, Macro F1: 0.4702, MCC: 0.3694
# Epoch [126/250] Fold [1] Train Loss: 0.1293, Train Acc: 0.5506 Val Loss: 0.1285, Val Acc: 0.5696, Macro F1: 0.4756, MCC: 0.3817
# Epoch [127/250] Fold [1] Train Loss: 0.1288, Train Acc: 0.5525 Val Loss: 0.1278, Val Acc: 0.5696, Macro F1: 0.4878, MCC: 0.3868
# Epoch [128/250] Fold [1] Train Loss: 0.1285, Train Acc: 0.5562 Val Loss: 0.1276, Val Acc: 0.5622, Macro F1: 0.4718, MCC: 0.3747
# Epoch [129/250] Fold [1] Train Loss: 0.1301, Train Acc: 0.5390 Val Loss: 0.1283, Val Acc: 0.5714, Macro F1: 0.4894, MCC: 0.3898
# Epoch [130/250] Fold [1] Train Loss: 0.1296, Train Acc: 0.5515 Val Loss: 0.1279, Val Acc: 0.5751, Macro F1: 0.4971, MCC: 0.3958
# Epoch [131/250] Fold [1] Train Loss: 0.1309, Train Acc: 0.5487 Val Loss: 0.1290, Val Acc: 0.5788, Macro F1: 0.4851, MCC: 0.3948
# Epoch [132/250] Fold [1] Train Loss: 0.1299, Train Acc: 0.5464 Val Loss: 0.1271, Val Acc: 0.5844, Macro F1: 0.5049, MCC: 0.4085
# Epoch [133/250] Fold [1] Train Loss: 0.1290, Train Acc: 0.5432 Val Loss: 0.1273, Val Acc: 0.5770, Macro F1: 0.4794, MCC: 0.3914
# Epoch [134/250] Fold [1] Train Loss: 0.1288, Train Acc: 0.5464 Val Loss: 0.1269, Val Acc: 0.5677, Macro F1: 0.4784, MCC: 0.3805
# Epoch [135/250] Fold [1] Train Loss: 0.1301, Train Acc: 0.5497 Val Loss: 0.1272, Val Acc: 0.5826, Macro F1: 0.5042, MCC: 0.4052
# Epoch [136/250] Fold [1] Train Loss: 0.1294, Train Acc: 0.5566 Val Loss: 0.1271, Val Acc: 0.5751, Macro F1: 0.4899, MCC: 0.3941
# Epoch [137/250] Fold [1] Train Loss: 0.1288, Train Acc: 0.5515 Val Loss: 0.1274, Val Acc: 0.5844, Macro F1: 0.4888, MCC: 0.4043
# Epoch [138/250] Fold [1] Train Loss: 0.1289, Train Acc: 0.5664 Val Loss: 0.1281, Val Acc: 0.5659, Macro F1: 0.4725, MCC: 0.3785
# Epoch [139/250] Fold [1] Train Loss: 0.1284, Train Acc: 0.5599 Val Loss: 0.1271, Val Acc: 0.5696, Macro F1: 0.4865, MCC: 0.3897
# Epoch [140/250] Fold [1] Train Loss: 0.1289, Train Acc: 0.5478 Val Loss: 0.1271, Val Acc: 0.5807, Macro F1: 0.5007, MCC: 0.4024
# Epoch [141/250] Fold [1] Train Loss: 0.1282, Train Acc: 0.5534 Val Loss: 0.1271, Val Acc: 0.5659, Macro F1: 0.4833, MCC: 0.3834
# Epoch [142/250] Fold [1] Train Loss: 0.1273, Train Acc: 0.5599 Val Loss: 0.1268, Val Acc: 0.5900, Macro F1: 0.5147, MCC: 0.4145
# Epoch [143/250] Fold [1] Train Loss: 0.1267, Train Acc: 0.5673 Val Loss: 0.1274, Val Acc: 0.5733, Macro F1: 0.4876, MCC: 0.3921
# Epoch [144/250] Fold [1] Train Loss: 0.1276, Train Acc: 0.5571 Val Loss: 0.1274, Val Acc: 0.5807, Macro F1: 0.4965, MCC: 0.4002
# Epoch [145/250] Fold [1] Train Loss: 0.1264, Train Acc: 0.5682 Val Loss: 0.1282, Val Acc: 0.5714, Macro F1: 0.4881, MCC: 0.3887
# Epoch [146/250] Fold [1] Train Loss: 0.1285, Train Acc: 0.5506 Val Loss: 0.1282, Val Acc: 0.5751, Macro F1: 0.4932, MCC: 0.3935
# Epoch [147/250] Fold [1] Train Loss: 0.1289, Train Acc: 0.5539 Val Loss: 0.1271, Val Acc: 0.5900, Macro F1: 0.5191, MCC: 0.4194
# Epoch [148/250] Fold [1] Train Loss: 0.1279, Train Acc: 0.5627 Val Loss: 0.1295, Val Acc: 0.5770, Macro F1: 0.4902, MCC: 0.3973
# Epoch [149/250] Fold [1] Train Loss: 0.1285, Train Acc: 0.5585 Val Loss: 0.1279, Val Acc: 0.5640, Macro F1: 0.4762, MCC: 0.3805
# Epoch [150/250] Fold [1] Train Loss: 0.1289, Train Acc: 0.5501 Val Loss: 0.1278, Val Acc: 0.5696, Macro F1: 0.4955, MCC: 0.3926
# Epoch [151/250] Fold [1] Train Loss: 0.1279, Train Acc: 0.5548 Val Loss: 0.1278, Val Acc: 0.5603, Macro F1: 0.4726, MCC: 0.3739
# Epoch [152/250] Fold [1] Train Loss: 0.1271, Train Acc: 0.5599 Val Loss: 0.1286, Val Acc: 0.5659, Macro F1: 0.4851, MCC: 0.3804
# Epoch [153/250] Fold [1] Train Loss: 0.1275, Train Acc: 0.5645 Val Loss: 0.1273, Val Acc: 0.5714, Macro F1: 0.4974, MCC: 0.3939
# Epoch [154/250] Fold [1] Train Loss: 0.1289, Train Acc: 0.5525 Val Loss: 0.1282, Val Acc: 0.5733, Macro F1: 0.4906, MCC: 0.3909
# Epoch [155/250] Fold [1] Train Loss: 0.1274, Train Acc: 0.5636 Val Loss: 0.1265, Val Acc: 0.5770, Macro F1: 0.4937, MCC: 0.3951
# Epoch [156/250] Fold [1] Train Loss: 0.1271, Train Acc: 0.5571 Val Loss: 0.1270, Val Acc: 0.5826, Macro F1: 0.4996, MCC: 0.4049
# Epoch [157/250] Fold [1] Train Loss: 0.1275, Train Acc: 0.5566 Val Loss: 0.1282, Val Acc: 0.5826, Macro F1: 0.4938, MCC: 0.4035
# Epoch [158/250] Fold [1] Train Loss: 0.1265, Train Acc: 0.5622 Val Loss: 0.1279, Val Acc: 0.5770, Macro F1: 0.4986, MCC: 0.3991
# Epoch [159/250] Fold [1] Train Loss: 0.1284, Train Acc: 0.5460 Val Loss: 0.1276, Val Acc: 0.5788, Macro F1: 0.5127, MCC: 0.4054
# Epoch [160/250] Fold [1] Train Loss: 0.1269, Train Acc: 0.5594 Val Loss: 0.1271, Val Acc: 0.5826, Macro F1: 0.5104, MCC: 0.4061
# Epoch [161/250] Fold [1] Train Loss: 0.1271, Train Acc: 0.5636 Val Loss: 0.1275, Val Acc: 0.5733, Macro F1: 0.4976, MCC: 0.3912
# Epoch [162/250] Fold [1] Train Loss: 0.1271, Train Acc: 0.5631 Val Loss: 0.1273, Val Acc: 0.5863, Macro F1: 0.5063, MCC: 0.4099
# Epoch [163/250] Fold [1] Train Loss: 0.1247, Train Acc: 0.5687 Val Loss: 0.1268, Val Acc: 0.5863, Macro F1: 0.5057, MCC: 0.4106
# Epoch [164/250] Fold [1] Train Loss: 0.1261, Train Acc: 0.5562 Val Loss: 0.1277, Val Acc: 0.5788, Macro F1: 0.5008, MCC: 0.3982
# Epoch [165/250] Fold [1] Train Loss: 0.1271, Train Acc: 0.5460 Val Loss: 0.1275, Val Acc: 0.5751, Macro F1: 0.5011, MCC: 0.3974
# Epoch [166/250] Fold [1] Train Loss: 0.1254, Train Acc: 0.5617 Val Loss: 0.1278, Val Acc: 0.5770, Macro F1: 0.5015, MCC: 0.3998
# Epoch [167/250] Fold [1] Train Loss: 0.1264, Train Acc: 0.5585 Val Loss: 0.1265, Val Acc: 0.5770, Macro F1: 0.5001, MCC: 0.3994
# Epoch [168/250] Fold [1] Train Loss: 0.1267, Train Acc: 0.5576 Val Loss: 0.1273, Val Acc: 0.5714, Macro F1: 0.5072, MCC: 0.3975
# Epoch [169/250] Fold [1] Train Loss: 0.1280, Train Acc: 0.5539 Val Loss: 0.1272, Val Acc: 0.5677, Macro F1: 0.4888, MCC: 0.3820
# Epoch [170/250] Fold [1] Train Loss: 0.1276, Train Acc: 0.5525 Val Loss: 0.1273, Val Acc: 0.5714, Macro F1: 0.4956, MCC: 0.3918
# Epoch [171/250] Fold [1] Train Loss: 0.1273, Train Acc: 0.5659 Val Loss: 0.1274, Val Acc: 0.5696, Macro F1: 0.4912, MCC: 0.3883
# Epoch [172/250] Fold [1] Train Loss: 0.1261, Train Acc: 0.5687 Val Loss: 0.1276, Val Acc: 0.5733, Macro F1: 0.4925, MCC: 0.3886
# Epoch [173/250] Fold [1] Train Loss: 0.1268, Train Acc: 0.5543 Val Loss: 0.1266, Val Acc: 0.5733, Macro F1: 0.5001, MCC: 0.3965
# Epoch [174/250] Fold [1] Train Loss: 0.1274, Train Acc: 0.5627 Val Loss: 0.1262, Val Acc: 0.5696, Macro F1: 0.4985, MCC: 0.3883
# Epoch [175/250] Fold [1] Train Loss: 0.1282, Train Acc: 0.5501 Val Loss: 0.1267, Val Acc: 0.5844, Macro F1: 0.5109, MCC: 0.4095
# Epoch [176/250] Fold [1] Train Loss: 0.1259, Train Acc: 0.5715 Val Loss: 0.1267, Val Acc: 0.5770, Macro F1: 0.4977, MCC: 0.3983
# Epoch [177/250] Fold [1] Train Loss: 0.1262, Train Acc: 0.5552 Val Loss: 0.1271, Val Acc: 0.5770, Macro F1: 0.5150, MCC: 0.4021
# Epoch [178/250] Fold [1] Train Loss: 0.1270, Train Acc: 0.5543 Val Loss: 0.1268, Val Acc: 0.5807, Macro F1: 0.5089, MCC: 0.4055
# Epoch [179/250] Fold [1] Train Loss: 0.1263, Train Acc: 0.5594 Val Loss: 0.1259, Val Acc: 0.5751, Macro F1: 0.5067, MCC: 0.3997
# Epoch [180/250] Fold [1] Train Loss: 0.1251, Train Acc: 0.5673 Val Loss: 0.1263, Val Acc: 0.5770, Macro F1: 0.5004, MCC: 0.3994
# Epoch [181/250] Fold [1] Train Loss: 0.1271, Train Acc: 0.5604 Val Loss: 0.1261, Val Acc: 0.5807, Macro F1: 0.5077, MCC: 0.4045
# Epoch [182/250] Fold [1] Train Loss: 0.1268, Train Acc: 0.5576 Val Loss: 0.1265, Val Acc: 0.5807, Macro F1: 0.5044, MCC: 0.4040
# Epoch [183/250] Fold [1] Train Loss: 0.1267, Train Acc: 0.5627 Val Loss: 0.1256, Val Acc: 0.5807, Macro F1: 0.5146, MCC: 0.4057
# Epoch [184/250] Fold [1] Train Loss: 0.1264, Train Acc: 0.5580 Val Loss: 0.1256, Val Acc: 0.5844, Macro F1: 0.5165, MCC: 0.4114
# Epoch [185/250] Fold [1] Train Loss: 0.1256, Train Acc: 0.5664 Val Loss: 0.1260, Val Acc: 0.5751, Macro F1: 0.4989, MCC: 0.3974
# Epoch [186/250] Fold [1] Train Loss: 0.1253, Train Acc: 0.5715 Val Loss: 0.1258, Val Acc: 0.5826, Macro F1: 0.5142, MCC: 0.4112
# Epoch [187/250] Fold [1] Train Loss: 0.1268, Train Acc: 0.5631 Val Loss: 0.1253, Val Acc: 0.5714, Macro F1: 0.4864, MCC: 0.3883
# Epoch [188/250] Fold [1] Train Loss: 0.1246, Train Acc: 0.5743 Val Loss: 0.1259, Val Acc: 0.5714, Macro F1: 0.4969, MCC: 0.3888
# Epoch [189/250] Fold [1] Train Loss: 0.1256, Train Acc: 0.5738 Val Loss: 0.1260, Val Acc: 0.5900, Macro F1: 0.5199, MCC: 0.4185
# Epoch [190/250] Fold [1] Train Loss: 0.1282, Train Acc: 0.5594 Val Loss: 0.1264, Val Acc: 0.5714, Macro F1: 0.4907, MCC: 0.3892
# Epoch [191/250] Fold [1] Train Loss: 0.1263, Train Acc: 0.5613 Val Loss: 0.1260, Val Acc: 0.5733, Macro F1: 0.5007, MCC: 0.3953
# Epoch [192/250] Fold [1] Train Loss: 0.1265, Train Acc: 0.5562 Val Loss: 0.1261, Val Acc: 0.5751, Macro F1: 0.5015, MCC: 0.3977
# Epoch [193/250] Fold [1] Train Loss: 0.1261, Train Acc: 0.5669 Val Loss: 0.1263, Val Acc: 0.5696, Macro F1: 0.4990, MCC: 0.3900
# Epoch [194/250] Fold [1] Train Loss: 0.1251, Train Acc: 0.5734 Val Loss: 0.1258, Val Acc: 0.5696, Macro F1: 0.4951, MCC: 0.3878
# Epoch [195/250] Fold [1] Train Loss: 0.1253, Train Acc: 0.5566 Val Loss: 0.1261, Val Acc: 0.5659, Macro F1: 0.4907, MCC: 0.3837
# Epoch [196/250] Fold [1] Train Loss: 0.1249, Train Acc: 0.5687 Val Loss: 0.1254, Val Acc: 0.5751, Macro F1: 0.5119, MCC: 0.4005
# Epoch [197/250] Fold [1] Train Loss: 0.1268, Train Acc: 0.5608 Val Loss: 0.1251, Val Acc: 0.5807, Macro F1: 0.5088, MCC: 0.4066
# Epoch [198/250] Fold [1] Train Loss: 0.1258, Train Acc: 0.5641 Val Loss: 0.1250, Val Acc: 0.5881, Macro F1: 0.5239, MCC: 0.4168
# Epoch [199/250] Fold [1] Train Loss: 0.1251, Train Acc: 0.5650 Val Loss: 0.1264, Val Acc: 0.5881, Macro F1: 0.5101, MCC: 0.4108
# Epoch [200/250] Fold [1] Train Loss: 0.1241, Train Acc: 0.5738 Val Loss: 0.1256, Val Acc: 0.5826, Macro F1: 0.5066, MCC: 0.4053
# Epoch [201/250] Fold [1] Train Loss: 0.1253, Train Acc: 0.5497 Val Loss: 0.1255, Val Acc: 0.5807, Macro F1: 0.5029, MCC: 0.4011
# Epoch [202/250] Fold [1] Train Loss: 0.1238, Train Acc: 0.5692 Val Loss: 0.1245, Val Acc: 0.5844, Macro F1: 0.5134, MCC: 0.4089
# Epoch [203/250] Fold [1] Train Loss: 0.1249, Train Acc: 0.5669 Val Loss: 0.1251, Val Acc: 0.5881, Macro F1: 0.5176, MCC: 0.4139
# Epoch [204/250] Fold [1] Train Loss: 0.1229, Train Acc: 0.5757 Val Loss: 0.1260, Val Acc: 0.5807, Macro F1: 0.5160, MCC: 0.4032
# Epoch [205/250] Fold [1] Train Loss: 0.1251, Train Acc: 0.5715 Val Loss: 0.1254, Val Acc: 0.5770, Macro F1: 0.5056, MCC: 0.4028
# Epoch [206/250] Fold [1] Train Loss: 0.1259, Train Acc: 0.5710 Val Loss: 0.1249, Val Acc: 0.5881, Macro F1: 0.5202, MCC: 0.4207
# Epoch [207/250] Fold [1] Train Loss: 0.1247, Train Acc: 0.5627 Val Loss: 0.1241, Val Acc: 0.6048, Macro F1: 0.5348, MCC: 0.4391
# Epoch [208/250] Fold [1] Train Loss: 0.1261, Train Acc: 0.5622 Val Loss: 0.1258, Val Acc: 0.5844, Macro F1: 0.5031, MCC: 0.4064
# Epoch [209/250] Fold [1] Train Loss: 0.1238, Train Acc: 0.5724 Val Loss: 0.1251, Val Acc: 0.5788, Macro F1: 0.5084, MCC: 0.4026
# Epoch [210/250] Fold [1] Train Loss: 0.1251, Train Acc: 0.5673 Val Loss: 0.1249, Val Acc: 0.5863, Macro F1: 0.5095, MCC: 0.4131
# Epoch [211/250] Fold [1] Train Loss: 0.1236, Train Acc: 0.5771 Val Loss: 0.1246, Val Acc: 0.5863, Macro F1: 0.5117, MCC: 0.4143
# Epoch [212/250] Fold [1] Train Loss: 0.1238, Train Acc: 0.5613 Val Loss: 0.1255, Val Acc: 0.5788, Macro F1: 0.5050, MCC: 0.4045
# Epoch [213/250] Fold [1] Train Loss: 0.1261, Train Acc: 0.5590 Val Loss: 0.1262, Val Acc: 0.5826, Macro F1: 0.5059, MCC: 0.4062
# Epoch [214/250] Fold [1] Train Loss: 0.1237, Train Acc: 0.5655 Val Loss: 0.1256, Val Acc: 0.5918, Macro F1: 0.5210, MCC: 0.4266
# Epoch [215/250] Fold [1] Train Loss: 0.1233, Train Acc: 0.5562 Val Loss: 0.1250, Val Acc: 0.5770, Macro F1: 0.5069, MCC: 0.4060
# Epoch [216/250] Fold [1] Train Loss: 0.1252, Train Acc: 0.5766 Val Loss: 0.1259, Val Acc: 0.5863, Macro F1: 0.5180, MCC: 0.4172
# Epoch [217/250] Fold [1] Train Loss: 0.1254, Train Acc: 0.5641 Val Loss: 0.1254, Val Acc: 0.5751, Macro F1: 0.5024, MCC: 0.4017
# Epoch [218/250] Fold [1] Train Loss: 0.1235, Train Acc: 0.5627 Val Loss: 0.1258, Val Acc: 0.5807, Macro F1: 0.5168, MCC: 0.4122
# Epoch [219/250] Fold [1] Train Loss: 0.1241, Train Acc: 0.5525 Val Loss: 0.1261, Val Acc: 0.5881, Macro F1: 0.5223, MCC: 0.4208
# Epoch [220/250] Fold [1] Train Loss: 0.1253, Train Acc: 0.5747 Val Loss: 0.1258, Val Acc: 0.5955, Macro F1: 0.5281, MCC: 0.4311
# Epoch [221/250] Fold [1] Train Loss: 0.1244, Train Acc: 0.5757 Val Loss: 0.1264, Val Acc: 0.5751, Macro F1: 0.5092, MCC: 0.4034
# Epoch [222/250] Fold [1] Train Loss: 0.1246, Train Acc: 0.5636 Val Loss: 0.1256, Val Acc: 0.5826, Macro F1: 0.5150, MCC: 0.4141
# Epoch [223/250] Fold [1] Train Loss: 0.1234, Train Acc: 0.5650 Val Loss: 0.1258, Val Acc: 0.5863, Macro F1: 0.5149, MCC: 0.4142
# Epoch [224/250] Fold [1] Train Loss: 0.1240, Train Acc: 0.5636 Val Loss: 0.1249, Val Acc: 0.5770, Macro F1: 0.5065, MCC: 0.4045
# Epoch [225/250] Fold [1] Train Loss: 0.1245, Train Acc: 0.5506 Val Loss: 0.1255, Val Acc: 0.5788, Macro F1: 0.5127, MCC: 0.4041
# Epoch [226/250] Fold [1] Train Loss: 0.1251, Train Acc: 0.5757 Val Loss: 0.1249, Val Acc: 0.5900, Macro F1: 0.5148, MCC: 0.4184
# Epoch [227/250] Fold [1] Train Loss: 0.1258, Train Acc: 0.5673 Val Loss: 0.1254, Val Acc: 0.5826, Macro F1: 0.5050, MCC: 0.4065
# Epoch [228/250] Fold [1] Train Loss: 0.1249, Train Acc: 0.5580 Val Loss: 0.1249, Val Acc: 0.5844, Macro F1: 0.5065, MCC: 0.4075
# Epoch [229/250] Fold [1] Train Loss: 0.1235, Train Acc: 0.5771 Val Loss: 0.1252, Val Acc: 0.5863, Macro F1: 0.5134, MCC: 0.4102
# Epoch [230/250] Fold [1] Train Loss: 0.1233, Train Acc: 0.5706 Val Loss: 0.1249, Val Acc: 0.5881, Macro F1: 0.5205, MCC: 0.4178
# Epoch [231/250] Fold [1] Train Loss: 0.1246, Train Acc: 0.5701 Val Loss: 0.1247, Val Acc: 0.5900, Macro F1: 0.5100, MCC: 0.4190
# Epoch [232/250] Fold [1] Train Loss: 0.1233, Train Acc: 0.5710 Val Loss: 0.1250, Val Acc: 0.5918, Macro F1: 0.5180, MCC: 0.4185
# Epoch [233/250] Fold [1] Train Loss: 0.1251, Train Acc: 0.5775 Val Loss: 0.1259, Val Acc: 0.5918, Macro F1: 0.5227, MCC: 0.4205
# Epoch [234/250] Fold [1] Train Loss: 0.1241, Train Acc: 0.5664 Val Loss: 0.1254, Val Acc: 0.5826, Macro F1: 0.5181, MCC: 0.4143
# Epoch [235/250] Fold [1] Train Loss: 0.1226, Train Acc: 0.5817 Val Loss: 0.1250, Val Acc: 0.5826, Macro F1: 0.5102, MCC: 0.4110
# Epoch [236/250] Fold [1] Train Loss: 0.1231, Train Acc: 0.5682 Val Loss: 0.1253, Val Acc: 0.5844, Macro F1: 0.5161, MCC: 0.4157
# Epoch [237/250] Fold [1] Train Loss: 0.1227, Train Acc: 0.5734 Val Loss: 0.1247, Val Acc: 0.5751, Macro F1: 0.5080, MCC: 0.4008
# Epoch [238/250] Fold [1] Train Loss: 0.1232, Train Acc: 0.5692 Val Loss: 0.1245, Val Acc: 0.5900, Macro F1: 0.5248, MCC: 0.4223
# Epoch [239/250] Fold [1] Train Loss: 0.1229, Train Acc: 0.5599 Val Loss: 0.1245, Val Acc: 0.6030, Macro F1: 0.5414, MCC: 0.4385
# Epoch [240/250] Fold [1] Train Loss: 0.1224, Train Acc: 0.5673 Val Loss: 0.1248, Val Acc: 0.5751, Macro F1: 0.5051, MCC: 0.3993
# Epoch [241/250] Fold [1] Train Loss: 0.1230, Train Acc: 0.5585 Val Loss: 0.1251, Val Acc: 0.5788, Macro F1: 0.5124, MCC: 0.4073
# Epoch [242/250] Fold [1] Train Loss: 0.1243, Train Acc: 0.5687 Val Loss: 0.1265, Val Acc: 0.5751, Macro F1: 0.5071, MCC: 0.3991
# Epoch [243/250] Fold [1] Train Loss: 0.1235, Train Acc: 0.5664 Val Loss: 0.1258, Val Acc: 0.5770, Macro F1: 0.5071, MCC: 0.4045
# Epoch [244/250] Fold [1] Train Loss: 0.1232, Train Acc: 0.5627 Val Loss: 0.1251, Val Acc: 0.5770, Macro F1: 0.5087, MCC: 0.4031
# Epoch [245/250] Fold [1] Train Loss: 0.1234, Train Acc: 0.5696 Val Loss: 0.1255, Val Acc: 0.5807, Macro F1: 0.5125, MCC: 0.4090
# Epoch [246/250] Fold [1] Train Loss: 0.1234, Train Acc: 0.5831 Val Loss: 0.1249, Val Acc: 0.5826, Macro F1: 0.5065, MCC: 0.4082
# Epoch [247/250] Fold [1] Train Loss: 0.1215, Train Acc: 0.5799 Val Loss: 0.1245, Val Acc: 0.5770, Macro F1: 0.5069, MCC: 0.4027
# Epoch [248/250] Fold [1] Train Loss: 0.1250, Train Acc: 0.5622 Val Loss: 0.1246, Val Acc: 0.5900, Macro F1: 0.5166, MCC: 0.4191
# Epoch [249/250] Fold [1] Train Loss: 0.1241, Train Acc: 0.5696 Val Loss: 0.1238, Val Acc: 0.5955, Macro F1: 0.5225, MCC: 0.4273
# Epoch [250/250] Fold [1] Train Loss: 0.1235, Train Acc: 0.5775 Val Loss: 0.1238, Val Acc: 0.5881, Macro F1: 0.5141, MCC: 0.4138
#
# --- Fold 2 ---
# /opt/conda/envs/pytorch/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Before Training: Training Loss: 0.1678, Training Accuracy: 0.3798, Validation Loss: 0.1670, Validation Accuracy: 0.3970, Macro F1: 0.1425, MCC: -0.0092
# Epoch [1/250] Fold [2] Train Loss: 0.1641, Train Acc: 0.3528 Val Loss: 0.1647, Val Acc: 0.4007, Macro F1: 0.1486, MCC: 0.0276
# Epoch [2/250] Fold [2] Train Loss: 0.1578, Train Acc: 0.4183 Val Loss: 0.1572, Val Acc: 0.4434, Macro F1: 0.3054, MCC: 0.1625
# Epoch [3/250] Fold [2] Train Loss: 0.1548, Train Acc: 0.4364 Val Loss: 0.1541, Val Acc: 0.4694, Macro F1: 0.3424, MCC: 0.2124
# Epoch [4/250] Fold [2] Train Loss: 0.1496, Train Acc: 0.4689 Val Loss: 0.1501, Val Acc: 0.4805, Macro F1: 0.3501, MCC: 0.2296
# Epoch [5/250] Fold [2] Train Loss: 0.1472, Train Acc: 0.4824 Val Loss: 0.1475, Val Acc: 0.5028, Macro F1: 0.3903, MCC: 0.2941
# Epoch [6/250] Fold [2] Train Loss: 0.1449, Train Acc: 0.4972 Val Loss: 0.1466, Val Acc: 0.4879, Macro F1: 0.3818, MCC: 0.2805
# Epoch [7/250] Fold [2] Train Loss: 0.1443, Train Acc: 0.4977 Val Loss: 0.1476, Val Acc: 0.4787, Macro F1: 0.3763, MCC: 0.2732
# Epoch [8/250] Fold [2] Train Loss: 0.1433, Train Acc: 0.4995 Val Loss: 0.1459, Val Acc: 0.4805, Macro F1: 0.3764, MCC: 0.2715
# Epoch [9/250] Fold [2] Train Loss: 0.1420, Train Acc: 0.5172 Val Loss: 0.1467, Val Acc: 0.4712, Macro F1: 0.3700, MCC: 0.2629
# Epoch [10/250] Fold [2] Train Loss: 0.1417, Train Acc: 0.5032 Val Loss: 0.1458, Val Acc: 0.4879, Macro F1: 0.3826, MCC: 0.2843
# Epoch [11/250] Fold [2] Train Loss: 0.1424, Train Acc: 0.5056 Val Loss: 0.1459, Val Acc: 0.4898, Macro F1: 0.3843, MCC: 0.2916
# Epoch [12/250] Fold [2] Train Loss: 0.1405, Train Acc: 0.5125 Val Loss: 0.1452, Val Acc: 0.4842, Macro F1: 0.3796, MCC: 0.2795
# Epoch [13/250] Fold [2] Train Loss: 0.1392, Train Acc: 0.5167 Val Loss: 0.1447, Val Acc: 0.4972, Macro F1: 0.3876, MCC: 0.2931
# Epoch [14/250] Fold [2] Train Loss: 0.1399, Train Acc: 0.5241 Val Loss: 0.1449, Val Acc: 0.4805, Macro F1: 0.3861, MCC: 0.2706
# Epoch [15/250] Fold [2] Train Loss: 0.1409, Train Acc: 0.5149 Val Loss: 0.1448, Val Acc: 0.4972, Macro F1: 0.3983, MCC: 0.2955
# Epoch [16/250] Fold [2] Train Loss: 0.1395, Train Acc: 0.5195 Val Loss: 0.1446, Val Acc: 0.4824, Macro F1: 0.3931, MCC: 0.2724
# Epoch [17/250] Fold [2] Train Loss: 0.1391, Train Acc: 0.5251 Val Loss: 0.1445, Val Acc: 0.4935, Macro F1: 0.3854, MCC: 0.2898
# Epoch [18/250] Fold [2] Train Loss: 0.1400, Train Acc: 0.5232 Val Loss: 0.1445, Val Acc: 0.4824, Macro F1: 0.3778, MCC: 0.2700
# Epoch [19/250] Fold [2] Train Loss: 0.1392, Train Acc: 0.5311 Val Loss: 0.1449, Val Acc: 0.4787, Macro F1: 0.3842, MCC: 0.2694
# Epoch [20/250] Fold [2] Train Loss: 0.1385, Train Acc: 0.5297 Val Loss: 0.1437, Val Acc: 0.4787, Macro F1: 0.3754, MCC: 0.2701
# Epoch [21/250] Fold [2] Train Loss: 0.1375, Train Acc: 0.5344 Val Loss: 0.1439, Val Acc: 0.4842, Macro F1: 0.3790, MCC: 0.2813
# Epoch [22/250] Fold [2] Train Loss: 0.1381, Train Acc: 0.5316 Val Loss: 0.1434, Val Acc: 0.4898, Macro F1: 0.3931, MCC: 0.2881
# Epoch [23/250] Fold [2] Train Loss: 0.1376, Train Acc: 0.5381 Val Loss: 0.1433, Val Acc: 0.4824, Macro F1: 0.4020, MCC: 0.2778
# Epoch [24/250] Fold [2] Train Loss: 0.1382, Train Acc: 0.5306 Val Loss: 0.1429, Val Acc: 0.4879, Macro F1: 0.3915, MCC: 0.2827
# Epoch [25/250] Fold [2] Train Loss: 0.1385, Train Acc: 0.5269 Val Loss: 0.1427, Val Acc: 0.4768, Macro F1: 0.4083, MCC: 0.2751
# Epoch [26/250] Fold [2] Train Loss: 0.1380, Train Acc: 0.5339 Val Loss: 0.1433, Val Acc: 0.4917, Macro F1: 0.4239, MCC: 0.2950
# Epoch [27/250] Fold [2] Train Loss: 0.1371, Train Acc: 0.5306 Val Loss: 0.1417, Val Acc: 0.4898, Macro F1: 0.4064, MCC: 0.2837
# Epoch [28/250] Fold [2] Train Loss: 0.1362, Train Acc: 0.5436 Val Loss: 0.1422, Val Acc: 0.4842, Macro F1: 0.4187, MCC: 0.2782
# Epoch [29/250] Fold [2] Train Loss: 0.1364, Train Acc: 0.5339 Val Loss: 0.1429, Val Acc: 0.4657, Macro F1: 0.4136, MCC: 0.2717
# Epoch [30/250] Fold [2] Train Loss: 0.1362, Train Acc: 0.5279 Val Loss: 0.1423, Val Acc: 0.4657, Macro F1: 0.4114, MCC: 0.2718
# Epoch [31/250] Fold [2] Train Loss: 0.1370, Train Acc: 0.5353 Val Loss: 0.1421, Val Acc: 0.4805, Macro F1: 0.4198, MCC: 0.2848
# Epoch [32/250] Fold [2] Train Loss: 0.1355, Train Acc: 0.5506 Val Loss: 0.1417, Val Acc: 0.4842, Macro F1: 0.4177, MCC: 0.2899
# Epoch [33/250] Fold [2] Train Loss: 0.1348, Train Acc: 0.5316 Val Loss: 0.1423, Val Acc: 0.4768, Macro F1: 0.4222, MCC: 0.2802
# Epoch [34/250] Fold [2] Train Loss: 0.1354, Train Acc: 0.5297 Val Loss: 0.1419, Val Acc: 0.4768, Macro F1: 0.4230, MCC: 0.2823
# Epoch [35/250] Fold [2] Train Loss: 0.1349, Train Acc: 0.5395 Val Loss: 0.1416, Val Acc: 0.4750, Macro F1: 0.4144, MCC: 0.2749
# Epoch [36/250] Fold [2] Train Loss: 0.1339, Train Acc: 0.5316 Val Loss: 0.1411, Val Acc: 0.4583, Macro F1: 0.4077, MCC: 0.2582
# Epoch [37/250] Fold [2] Train Loss: 0.1350, Train Acc: 0.5279 Val Loss: 0.1408, Val Acc: 0.4824, Macro F1: 0.4266, MCC: 0.2842
# Epoch [38/250] Fold [2] Train Loss: 0.1351, Train Acc: 0.5422 Val Loss: 0.1412, Val Acc: 0.4972, Macro F1: 0.4231, MCC: 0.2990
# Epoch [39/250] Fold [2] Train Loss: 0.1366, Train Acc: 0.5316 Val Loss: 0.1410, Val Acc: 0.4935, Macro F1: 0.4250, MCC: 0.2959
# Epoch [40/250] Fold [2] Train Loss: 0.1355, Train Acc: 0.5362 Val Loss: 0.1408, Val Acc: 0.4972, Macro F1: 0.4313, MCC: 0.2973
# Epoch [41/250] Fold [2] Train Loss: 0.1356, Train Acc: 0.5432 Val Loss: 0.1402, Val Acc: 0.5102, Macro F1: 0.4426, MCC: 0.3105
# Epoch [42/250] Fold [2] Train Loss: 0.1338, Train Acc: 0.5492 Val Loss: 0.1399, Val Acc: 0.4935, Macro F1: 0.4323, MCC: 0.2920
# Epoch [43/250] Fold [2] Train Loss: 0.1327, Train Acc: 0.5436 Val Loss: 0.1406, Val Acc: 0.4935, Macro F1: 0.4371, MCC: 0.2995
# Epoch [44/250] Fold [2] Train Loss: 0.1353, Train Acc: 0.5381 Val Loss: 0.1393, Val Acc: 0.5028, Macro F1: 0.4212, MCC: 0.3037
# Epoch [45/250] Fold [2] Train Loss: 0.1339, Train Acc: 0.5497 Val Loss: 0.1396, Val Acc: 0.4954, Macro F1: 0.4370, MCC: 0.2951
# Epoch [46/250] Fold [2] Train Loss: 0.1344, Train Acc: 0.5506 Val Loss: 0.1402, Val Acc: 0.4879, Macro F1: 0.4136, MCC: 0.2878
# Epoch [47/250] Fold [2] Train Loss: 0.1340, Train Acc: 0.5599 Val Loss: 0.1398, Val Acc: 0.4935, Macro F1: 0.4247, MCC: 0.2922
# Epoch [48/250] Fold [2] Train Loss: 0.1326, Train Acc: 0.5478 Val Loss: 0.1395, Val Acc: 0.4991, Macro F1: 0.4366, MCC: 0.3016
# Epoch [49/250] Fold [2] Train Loss: 0.1341, Train Acc: 0.5460 Val Loss: 0.1403, Val Acc: 0.4935, Macro F1: 0.4239, MCC: 0.2901
# Epoch [50/250] Fold [2] Train Loss: 0.1330, Train Acc: 0.5511 Val Loss: 0.1409, Val Acc: 0.5065, Macro F1: 0.4262, MCC: 0.3135
# Epoch [51/250] Fold [2] Train Loss: 0.1341, Train Acc: 0.5441 Val Loss: 0.1407, Val Acc: 0.4972, Macro F1: 0.4229, MCC: 0.2957
# Epoch [52/250] Fold [2] Train Loss: 0.1327, Train Acc: 0.5455 Val Loss: 0.1402, Val Acc: 0.4898, Macro F1: 0.4114, MCC: 0.2889
# Epoch [53/250] Fold [2] Train Loss: 0.1337, Train Acc: 0.5478 Val Loss: 0.1401, Val Acc: 0.4935, Macro F1: 0.4335, MCC: 0.3026
# Epoch [54/250] Fold [2] Train Loss: 0.1328, Train Acc: 0.5543 Val Loss: 0.1401, Val Acc: 0.4861, Macro F1: 0.4146, MCC: 0.2891
# Epoch [55/250] Fold [2] Train Loss: 0.1335, Train Acc: 0.5325 Val Loss: 0.1395, Val Acc: 0.4991, Macro F1: 0.4335, MCC: 0.3020
# Epoch [56/250] Fold [2] Train Loss: 0.1315, Train Acc: 0.5515 Val Loss: 0.1383, Val Acc: 0.4972, Macro F1: 0.4318, MCC: 0.2989
# Epoch [57/250] Fold [2] Train Loss: 0.1332, Train Acc: 0.5432 Val Loss: 0.1384, Val Acc: 0.4935, Macro F1: 0.4244, MCC: 0.2916
# Epoch [58/250] Fold [2] Train Loss: 0.1319, Train Acc: 0.5576 Val Loss: 0.1394, Val Acc: 0.4861, Macro F1: 0.4238, MCC: 0.2918
# Epoch [59/250] Fold [2] Train Loss: 0.1328, Train Acc: 0.5399 Val Loss: 0.1378, Val Acc: 0.4861, Macro F1: 0.4127, MCC: 0.2774
# Epoch [60/250] Fold [2] Train Loss: 0.1321, Train Acc: 0.5525 Val Loss: 0.1381, Val Acc: 0.4879, Macro F1: 0.4284, MCC: 0.2903
# Epoch [61/250] Fold [2] Train Loss: 0.1317, Train Acc: 0.5501 Val Loss: 0.1388, Val Acc: 0.4972, Macro F1: 0.4348, MCC: 0.3013
# Epoch [62/250] Fold [2] Train Loss: 0.1333, Train Acc: 0.5511 Val Loss: 0.1380, Val Acc: 0.4879, Macro F1: 0.4246, MCC: 0.2898
# Epoch [63/250] Fold [2] Train Loss: 0.1319, Train Acc: 0.5478 Val Loss: 0.1395, Val Acc: 0.4954, Macro F1: 0.4280, MCC: 0.3054
# Epoch [64/250] Fold [2] Train Loss: 0.1316, Train Acc: 0.5673 Val Loss: 0.1381, Val Acc: 0.5009, Macro F1: 0.4392, MCC: 0.3069
# Epoch [65/250] Fold [2] Train Loss: 0.1319, Train Acc: 0.5520 Val Loss: 0.1373, Val Acc: 0.4879, Macro F1: 0.4235, MCC: 0.2863
# Epoch [66/250] Fold [2] Train Loss: 0.1310, Train Acc: 0.5580 Val Loss: 0.1386, Val Acc: 0.4972, Macro F1: 0.4413, MCC: 0.3015
# Epoch [67/250] Fold [2] Train Loss: 0.1331, Train Acc: 0.5525 Val Loss: 0.1374, Val Acc: 0.4954, Macro F1: 0.4335, MCC: 0.2989
# Epoch [68/250] Fold [2] Train Loss: 0.1307, Train Acc: 0.5613 Val Loss: 0.1375, Val Acc: 0.4917, Macro F1: 0.4344, MCC: 0.2958
# Epoch [69/250] Fold [2] Train Loss: 0.1306, Train Acc: 0.5552 Val Loss: 0.1388, Val Acc: 0.4898, Macro F1: 0.4396, MCC: 0.2998
# Epoch [70/250] Fold [2] Train Loss: 0.1308, Train Acc: 0.5487 Val Loss: 0.1374, Val Acc: 0.4824, Macro F1: 0.4114, MCC: 0.2799
# Epoch [71/250] Fold [2] Train Loss: 0.1305, Train Acc: 0.5604 Val Loss: 0.1367, Val Acc: 0.5009, Macro F1: 0.4436, MCC: 0.3036
# Epoch [72/250] Fold [2] Train Loss: 0.1302, Train Acc: 0.5539 Val Loss: 0.1375, Val Acc: 0.4917, Macro F1: 0.4393, MCC: 0.2952
# Epoch [73/250] Fold [2] Train Loss: 0.1303, Train Acc: 0.5511 Val Loss: 0.1369, Val Acc: 0.4935, Macro F1: 0.4313, MCC: 0.2944
# Epoch [74/250] Fold [2] Train Loss: 0.1295, Train Acc: 0.5631 Val Loss: 0.1369, Val Acc: 0.4935, Macro F1: 0.4320, MCC: 0.2982
# Epoch [75/250] Fold [2] Train Loss: 0.1292, Train Acc: 0.5562 Val Loss: 0.1351, Val Acc: 0.5102, Macro F1: 0.4438, MCC: 0.3056
# Epoch [76/250] Fold [2] Train Loss: 0.1279, Train Acc: 0.5687 Val Loss: 0.1357, Val Acc: 0.4991, Macro F1: 0.4560, MCC: 0.3085
# Epoch [77/250] Fold [2] Train Loss: 0.1318, Train Acc: 0.5432 Val Loss: 0.1367, Val Acc: 0.5083, Macro F1: 0.4593, MCC: 0.3179
# Epoch [78/250] Fold [2] Train Loss: 0.1303, Train Acc: 0.5539 Val Loss: 0.1359, Val Acc: 0.4991, Macro F1: 0.4439, MCC: 0.3006
# Epoch [79/250] Fold [2] Train Loss: 0.1310, Train Acc: 0.5460 Val Loss: 0.1364, Val Acc: 0.5065, Macro F1: 0.4621, MCC: 0.3160
# Epoch [80/250] Fold [2] Train Loss: 0.1303, Train Acc: 0.5566 Val Loss: 0.1372, Val Acc: 0.5009, Macro F1: 0.4418, MCC: 0.3093
# Epoch [81/250] Fold [2] Train Loss: 0.1300, Train Acc: 0.5590 Val Loss: 0.1362, Val Acc: 0.4991, Macro F1: 0.4388, MCC: 0.3010
# Epoch [82/250] Fold [2] Train Loss: 0.1305, Train Acc: 0.5385 Val Loss: 0.1353, Val Acc: 0.5046, Macro F1: 0.4493, MCC: 0.3068
# Epoch [83/250] Fold [2] Train Loss: 0.1285, Train Acc: 0.5687 Val Loss: 0.1358, Val Acc: 0.5009, Macro F1: 0.4513, MCC: 0.3114
# Epoch [84/250] Fold [2] Train Loss: 0.1291, Train Acc: 0.5539 Val Loss: 0.1368, Val Acc: 0.4879, Macro F1: 0.4377, MCC: 0.2957
# Epoch [85/250] Fold [2] Train Loss: 0.1317, Train Acc: 0.5353 Val Loss: 0.1362, Val Acc: 0.4917, Macro F1: 0.4344, MCC: 0.2945
# Epoch [86/250] Fold [2] Train Loss: 0.1311, Train Acc: 0.5562 Val Loss: 0.1361, Val Acc: 0.4954, Macro F1: 0.4363, MCC: 0.2978
# Epoch [87/250] Fold [2] Train Loss: 0.1291, Train Acc: 0.5464 Val Loss: 0.1357, Val Acc: 0.4954, Macro F1: 0.4339, MCC: 0.3034
# Epoch [88/250] Fold [2] Train Loss: 0.1282, Train Acc: 0.5520 Val Loss: 0.1352, Val Acc: 0.5065, Macro F1: 0.4484, MCC: 0.3103
# Epoch [89/250] Fold [2] Train Loss: 0.1300, Train Acc: 0.5501 Val Loss: 0.1368, Val Acc: 0.5065, Macro F1: 0.4619, MCC: 0.3228
# Epoch [90/250] Fold [2] Train Loss: 0.1288, Train Acc: 0.5562 Val Loss: 0.1347, Val Acc: 0.5028, Macro F1: 0.4462, MCC: 0.3080
# Epoch [91/250] Fold [2] Train Loss: 0.1300, Train Acc: 0.5529 Val Loss: 0.1355, Val Acc: 0.5102, Macro F1: 0.4551, MCC: 0.3172
# Epoch [92/250] Fold [2] Train Loss: 0.1313, Train Acc: 0.5506 Val Loss: 0.1359, Val Acc: 0.5009, Macro F1: 0.4481, MCC: 0.3087
# Epoch [93/250] Fold [2] Train Loss: 0.1305, Train Acc: 0.5511 Val Loss: 0.1352, Val Acc: 0.5065, Macro F1: 0.4480, MCC: 0.3105
# Epoch [94/250] Fold [2] Train Loss: 0.1287, Train Acc: 0.5511 Val Loss: 0.1351, Val Acc: 0.5028, Macro F1: 0.4449, MCC: 0.3054
# Epoch [95/250] Fold [2] Train Loss: 0.1286, Train Acc: 0.5534 Val Loss: 0.1360, Val Acc: 0.4991, Macro F1: 0.4483, MCC: 0.3061
# Epoch [96/250] Fold [2] Train Loss: 0.1285, Train Acc: 0.5720 Val Loss: 0.1348, Val Acc: 0.5046, Macro F1: 0.4501, MCC: 0.3075
# Epoch [97/250] Fold [2] Train Loss: 0.1287, Train Acc: 0.5617 Val Loss: 0.1350, Val Acc: 0.4991, Macro F1: 0.4391, MCC: 0.3018
# Epoch [98/250] Fold [2] Train Loss: 0.1282, Train Acc: 0.5613 Val Loss: 0.1352, Val Acc: 0.4935, Macro F1: 0.4354, MCC: 0.3010
# Epoch [99/250] Fold [2] Train Loss: 0.1275, Train Acc: 0.5627 Val Loss: 0.1346, Val Acc: 0.5102, Macro F1: 0.4616, MCC: 0.3188
# Epoch [100/250] Fold [2] Train Loss: 0.1276, Train Acc: 0.5687 Val Loss: 0.1346, Val Acc: 0.4972, Macro F1: 0.4443, MCC: 0.3012
# Epoch [101/250] Fold [2] Train Loss: 0.1278, Train Acc: 0.5752 Val Loss: 0.1341, Val Acc: 0.4991, Macro F1: 0.4372, MCC: 0.2963
# Epoch [102/250] Fold [2] Train Loss: 0.1282, Train Acc: 0.5669 Val Loss: 0.1349, Val Acc: 0.5083, Macro F1: 0.4536, MCC: 0.3126
# Epoch [103/250] Fold [2] Train Loss: 0.1289, Train Acc: 0.5641 Val Loss: 0.1342, Val Acc: 0.5176, Macro F1: 0.4455, MCC: 0.3176
# Epoch [104/250] Fold [2] Train Loss: 0.1288, Train Acc: 0.5511 Val Loss: 0.1341, Val Acc: 0.5195, Macro F1: 0.4672, MCC: 0.3269
# Epoch [105/250] Fold [2] Train Loss: 0.1286, Train Acc: 0.5585 Val Loss: 0.1344, Val Acc: 0.5046, Macro F1: 0.4529, MCC: 0.3161
# Epoch [106/250] Fold [2] Train Loss: 0.1278, Train Acc: 0.5701 Val Loss: 0.1349, Val Acc: 0.4972, Macro F1: 0.4517, MCC: 0.3047
# Epoch [107/250] Fold [2] Train Loss: 0.1282, Train Acc: 0.5617 Val Loss: 0.1333, Val Acc: 0.5065, Macro F1: 0.4556, MCC: 0.3102
# Epoch [108/250] Fold [2] Train Loss: 0.1285, Train Acc: 0.5515 Val Loss: 0.1346, Val Acc: 0.5028, Macro F1: 0.4503, MCC: 0.3106
# Epoch [109/250] Fold [2] Train Loss: 0.1285, Train Acc: 0.5474 Val Loss: 0.1336, Val Acc: 0.5176, Macro F1: 0.4573, MCC: 0.3221
# Epoch [110/250] Fold [2] Train Loss: 0.1280, Train Acc: 0.5720 Val Loss: 0.1351, Val Acc: 0.4972, Macro F1: 0.4500, MCC: 0.3081
# Epoch [111/250] Fold [2] Train Loss: 0.1277, Train Acc: 0.5576 Val Loss: 0.1335, Val Acc: 0.5176, Macro F1: 0.4647, MCC: 0.3268
# Epoch [112/250] Fold [2] Train Loss: 0.1280, Train Acc: 0.5613 Val Loss: 0.1334, Val Acc: 0.5306, Macro F1: 0.4759, MCC: 0.3393
# Epoch [113/250] Fold [2] Train Loss: 0.1284, Train Acc: 0.5599 Val Loss: 0.1338, Val Acc: 0.5102, Macro F1: 0.4643, MCC: 0.3222
# Epoch [114/250] Fold [2] Train Loss: 0.1273, Train Acc: 0.5687 Val Loss: 0.1331, Val Acc: 0.5176, Macro F1: 0.4686, MCC: 0.3249
# Epoch [115/250] Fold [2] Train Loss: 0.1277, Train Acc: 0.5645 Val Loss: 0.1333, Val Acc: 0.5083, Macro F1: 0.4633, MCC: 0.3202
# Epoch [116/250] Fold [2] Train Loss: 0.1274, Train Acc: 0.5608 Val Loss: 0.1345, Val Acc: 0.5102, Macro F1: 0.4646, MCC: 0.3272
# Epoch [117/250] Fold [2] Train Loss: 0.1261, Train Acc: 0.5613 Val Loss: 0.1339, Val Acc: 0.5046, Macro F1: 0.4606, MCC: 0.3172
# Epoch [118/250] Fold [2] Train Loss: 0.1264, Train Acc: 0.5720 Val Loss: 0.1338, Val Acc: 0.5102, Macro F1: 0.4672, MCC: 0.3244
# Epoch [119/250] Fold [2] Train Loss: 0.1267, Train Acc: 0.5757 Val Loss: 0.1335, Val Acc: 0.5009, Macro F1: 0.4466, MCC: 0.3100
# Epoch [120/250] Fold [2] Train Loss: 0.1263, Train Acc: 0.5701 Val Loss: 0.1328, Val Acc: 0.5362, Macro F1: 0.4787, MCC: 0.3455
# ...
# Epoch [126/250] Fold [5] Train Loss: 0.1300, Train Acc: 0.5559 Val Loss: 0.1263, Val Acc: 0.5967, Macro F1: 0.5024, MCC: 0.4309
# Epoch [127/250] Fold [5] Train Loss: 0.1298, Train Acc: 0.5610 Val Loss: 0.1254, Val Acc: 0.6022, Macro F1: 0.5062, MCC: 0.4367
# Epoch [128/250] Fold [5] Train Loss: 0.1297, Train Acc: 0.5578 Val Loss: 0.1263, Val Acc: 0.5967, Macro F1: 0.5028, MCC: 0.4313
# Epoch [129/250] Fold [5] Train Loss: 0.1298, Train Acc: 0.5508 Val Loss: 0.1266, Val Acc: 0.5929, Macro F1: 0.5098, MCC: 0.4256
# Epoch [130/250] Fold [5] Train Loss: 0.1301, Train Acc: 0.5629 Val Loss: 0.1258, Val Acc: 0.5985, Macro F1: 0.5025, MCC: 0.4311
# Epoch [131/250] Fold [5] Train Loss: 0.1295, Train Acc: 0.5698 Val Loss: 0.1252, Val Acc: 0.5911, Macro F1: 0.4923, MCC: 0.4222
# Epoch [132/250] Fold [5] Train Loss: 0.1284, Train Acc: 0.5573 Val Loss: 0.1257, Val Acc: 0.5874, Macro F1: 0.5098, MCC: 0.4205
# Epoch [133/250] Fold [5] Train Loss: 0.1292, Train Acc: 0.5555 Val Loss: 0.1252, Val Acc: 0.6004, Macro F1: 0.5044, MCC: 0.4355
# Epoch [134/250] Fold [5] Train Loss: 0.1288, Train Acc: 0.5624 Val Loss: 0.1252, Val Acc: 0.6134, Macro F1: 0.5140, MCC: 0.4511
# Epoch [135/250] Fold [5] Train Loss: 0.1287, Train Acc: 0.5684 Val Loss: 0.1252, Val Acc: 0.5948, Macro F1: 0.4941, MCC: 0.4268
# Epoch [136/250] Fold [5] Train Loss: 0.1286, Train Acc: 0.5629 Val Loss: 0.1250, Val Acc: 0.6022, Macro F1: 0.5053, MCC: 0.4365
# Epoch [137/250] Fold [5] Train Loss: 0.1285, Train Acc: 0.5675 Val Loss: 0.1251, Val Acc: 0.5874, Macro F1: 0.4812, MCC: 0.4121
# Epoch [138/250] Fold [5] Train Loss: 0.1267, Train Acc: 0.5568 Val Loss: 0.1253, Val Acc: 0.5948, Macro F1: 0.5059, MCC: 0.4302
# Epoch [139/250] Fold [5] Train Loss: 0.1284, Train Acc: 0.5545 Val Loss: 0.1250, Val Acc: 0.5929, Macro F1: 0.5038, MCC: 0.4263
# Epoch [140/250] Fold [5] Train Loss: 0.1292, Train Acc: 0.5499 Val Loss: 0.1246, Val Acc: 0.5967, Macro F1: 0.5017, MCC: 0.4312
# Epoch [141/250] Fold [5] Train Loss: 0.1273, Train Acc: 0.5573 Val Loss: 0.1258, Val Acc: 0.6022, Macro F1: 0.5075, MCC: 0.4394
# Epoch [142/250] Fold [5] Train Loss: 0.1282, Train Acc: 0.5643 Val Loss: 0.1254, Val Acc: 0.5911, Macro F1: 0.4898, MCC: 0.4192
# Epoch [143/250] Fold [5] Train Loss: 0.1272, Train Acc: 0.5647 Val Loss: 0.1245, Val Acc: 0.5874, Macro F1: 0.4990, MCC: 0.4176
# Epoch [144/250] Fold [5] Train Loss: 0.1290, Train Acc: 0.5480 Val Loss: 0.1241, Val Acc: 0.6059, Macro F1: 0.5079, MCC: 0.4411
# Epoch [145/250] Fold [5] Train Loss: 0.1285, Train Acc: 0.5503 Val Loss: 0.1250, Val Acc: 0.5874, Macro F1: 0.5004, MCC: 0.4206
# Epoch [146/250] Fold [5] Train Loss: 0.1275, Train Acc: 0.5578 Val Loss: 0.1246, Val Acc: 0.5967, Macro F1: 0.5006, MCC: 0.4287
# Epoch [147/250] Fold [5] Train Loss: 0.1282, Train Acc: 0.5638 Val Loss: 0.1244, Val Acc: 0.5874, Macro F1: 0.5005, MCC: 0.4207
# Epoch [148/250] Fold [5] Train Loss: 0.1285, Train Acc: 0.5671 Val Loss: 0.1238, Val Acc: 0.5911, Macro F1: 0.4985, MCC: 0.4247
# Epoch [149/250] Fold [5] Train Loss: 0.1268, Train Acc: 0.5573 Val Loss: 0.1240, Val Acc: 0.5948, Macro F1: 0.5094, MCC: 0.4262
# Epoch [150/250] Fold [5] Train Loss: 0.1278, Train Acc: 0.5541 Val Loss: 0.1238, Val Acc: 0.6022, Macro F1: 0.4997, MCC: 0.4348
# Epoch [151/250] Fold [5] Train Loss: 0.1282, Train Acc: 0.5559 Val Loss: 0.1242, Val Acc: 0.5967, Macro F1: 0.5013, MCC: 0.4300
# Epoch [152/250] Fold [5] Train Loss: 0.1282, Train Acc: 0.5592 Val Loss: 0.1243, Val Acc: 0.5929, Macro F1: 0.5051, MCC: 0.4271
# Epoch [153/250] Fold [5] Train Loss: 0.1282, Train Acc: 0.5555 Val Loss: 0.1252, Val Acc: 0.5948, Macro F1: 0.5006, MCC: 0.4281
# Epoch [154/250] Fold [5] Train Loss: 0.1291, Train Acc: 0.5494 Val Loss: 0.1253, Val Acc: 0.5948, Macro F1: 0.4999, MCC: 0.4259
# Epoch [155/250] Fold [5] Train Loss: 0.1266, Train Acc: 0.5689 Val Loss: 0.1240, Val Acc: 0.6004, Macro F1: 0.5043, MCC: 0.4344
# Epoch [156/250] Fold [5] Train Loss: 0.1272, Train Acc: 0.5596 Val Loss: 0.1239, Val Acc: 0.6078, Macro F1: 0.5080, MCC: 0.4415
# Epoch [157/250] Fold [5] Train Loss: 0.1271, Train Acc: 0.5657 Val Loss: 0.1233, Val Acc: 0.6022, Macro F1: 0.5090, MCC: 0.4349
# Epoch [158/250] Fold [5] Train Loss: 0.1287, Train Acc: 0.5587 Val Loss: 0.1240, Val Acc: 0.6097, Macro F1: 0.5105, MCC: 0.4453
# Epoch [159/250] Fold [5] Train Loss: 0.1285, Train Acc: 0.5564 Val Loss: 0.1250, Val Acc: 0.5985, Macro F1: 0.4974, MCC: 0.4314
# Epoch [160/250] Fold [5] Train Loss: 0.1280, Train Acc: 0.5587 Val Loss: 0.1247, Val Acc: 0.6115, Macro F1: 0.5215, MCC: 0.4476
# Epoch [161/250] Fold [5] Train Loss: 0.1272, Train Acc: 0.5712 Val Loss: 0.1237, Val Acc: 0.5911, Macro F1: 0.4942, MCC: 0.4181
# Epoch [162/250] Fold [5] Train Loss: 0.1263, Train Acc: 0.5536 Val Loss: 0.1248, Val Acc: 0.5985, Macro F1: 0.5061, MCC: 0.4280
# Epoch [163/250] Fold [5] Train Loss: 0.1277, Train Acc: 0.5550 Val Loss: 0.1235, Val Acc: 0.5836, Macro F1: 0.5044, MCC: 0.4113
# Epoch [164/250] Fold [5] Train Loss: 0.1260, Train Acc: 0.5592 Val Loss: 0.1229, Val Acc: 0.5948, Macro F1: 0.5105, MCC: 0.4295
# Epoch [165/250] Fold [5] Train Loss: 0.1274, Train Acc: 0.5671 Val Loss: 0.1244, Val Acc: 0.5781, Macro F1: 0.4818, MCC: 0.4030
# Epoch [166/250] Fold [5] Train Loss: 0.1281, Train Acc: 0.5578 Val Loss: 0.1240, Val Acc: 0.6004, Macro F1: 0.5081, MCC: 0.4328
# Epoch [167/250] Fold [5] Train Loss: 0.1274, Train Acc: 0.5735 Val Loss: 0.1242, Val Acc: 0.5892, Macro F1: 0.4910, MCC: 0.4205
# Epoch [168/250] Fold [5] Train Loss: 0.1280, Train Acc: 0.5527 Val Loss: 0.1256, Val Acc: 0.5892, Macro F1: 0.4893, MCC: 0.4172
# Epoch [169/250] Fold [5] Train Loss: 0.1261, Train Acc: 0.5731 Val Loss: 0.1239, Val Acc: 0.5967, Macro F1: 0.5053, MCC: 0.4281
# Epoch [170/250] Fold [5] Train Loss: 0.1268, Train Acc: 0.5731 Val Loss: 0.1243, Val Acc: 0.5836, Macro F1: 0.4928, MCC: 0.4166
# Epoch [171/250] Fold [5] Train Loss: 0.1284, Train Acc: 0.5606 Val Loss: 0.1243, Val Acc: 0.6078, Macro F1: 0.5096, MCC: 0.4444
# Epoch [172/250] Fold [5] Train Loss: 0.1269, Train Acc: 0.5592 Val Loss: 0.1243, Val Acc: 0.5948, Macro F1: 0.5033, MCC: 0.4250
# Epoch [173/250] Fold [5] Train Loss: 0.1262, Train Acc: 0.5619 Val Loss: 0.1234, Val Acc: 0.5967, Macro F1: 0.5007, MCC: 0.4288
# Epoch [174/250] Fold [5] Train Loss: 0.1254, Train Acc: 0.5643 Val Loss: 0.1235, Val Acc: 0.5892, Macro F1: 0.4948, MCC: 0.4184
# Epoch [175/250] Fold [5] Train Loss: 0.1272, Train Acc: 0.5666 Val Loss: 0.1247, Val Acc: 0.5855, Macro F1: 0.5080, MCC: 0.4209
# Epoch [176/250] Fold [5] Train Loss: 0.1264, Train Acc: 0.5610 Val Loss: 0.1241, Val Acc: 0.5781, Macro F1: 0.4908, MCC: 0.4030
# Epoch [177/250] Fold [5] Train Loss: 0.1276, Train Acc: 0.5503 Val Loss: 0.1238, Val Acc: 0.5818, Macro F1: 0.4902, MCC: 0.4114
# Epoch [178/250] Fold [5] Train Loss: 0.1268, Train Acc: 0.5684 Val Loss: 0.1234, Val Acc: 0.5948, Macro F1: 0.5084, MCC: 0.4270
# Epoch [179/250] Fold [5] Train Loss: 0.1254, Train Acc: 0.5694 Val Loss: 0.1236, Val Acc: 0.5967, Macro F1: 0.5060, MCC: 0.4304
# Epoch [180/250] Fold [5] Train Loss: 0.1268, Train Acc: 0.5587 Val Loss: 0.1237, Val Acc: 0.5818, Macro F1: 0.4916, MCC: 0.4136
# Epoch [181/250] Fold [5] Train Loss: 0.1270, Train Acc: 0.5568 Val Loss: 0.1236, Val Acc: 0.5799, Macro F1: 0.4898, MCC: 0.4108
# Epoch [182/250] Fold [5] Train Loss: 0.1267, Train Acc: 0.5610 Val Loss: 0.1228, Val Acc: 0.5874, Macro F1: 0.4898, MCC: 0.4187
# Epoch [183/250] Fold [5] Train Loss: 0.1264, Train Acc: 0.5763 Val Loss: 0.1235, Val Acc: 0.6004, Macro F1: 0.5080, MCC: 0.4338
# Epoch [184/250] Fold [5] Train Loss: 0.1263, Train Acc: 0.5703 Val Loss: 0.1241, Val Acc: 0.5874, Macro F1: 0.4845, MCC: 0.4187
# Epoch [185/250] Fold [5] Train Loss: 0.1250, Train Acc: 0.5773 Val Loss: 0.1235, Val Acc: 0.5948, Macro F1: 0.4945, MCC: 0.4264
# Epoch [186/250] Fold [5] Train Loss: 0.1269, Train Acc: 0.5624 Val Loss: 0.1237, Val Acc: 0.5911, Macro F1: 0.5092, MCC: 0.4268
# Epoch [187/250] Fold [5] Train Loss: 0.1269, Train Acc: 0.5587 Val Loss: 0.1240, Val Acc: 0.6078, Macro F1: 0.5214, MCC: 0.4421
# Epoch [188/250] Fold [5] Train Loss: 0.1271, Train Acc: 0.5503 Val Loss: 0.1240, Val Acc: 0.5874, Macro F1: 0.4952, MCC: 0.4195
# Epoch [189/250] Fold [5] Train Loss: 0.1257, Train Acc: 0.5712 Val Loss: 0.1236, Val Acc: 0.5948, Macro F1: 0.5042, MCC: 0.4252
# Epoch [190/250] Fold [5] Train Loss: 0.1255, Train Acc: 0.5661 Val Loss: 0.1228, Val Acc: 0.5967, Macro F1: 0.5027, MCC: 0.4311
# Epoch [191/250] Fold [5] Train Loss: 0.1266, Train Acc: 0.5773 Val Loss: 0.1233, Val Acc: 0.6171, Macro F1: 0.5148, MCC: 0.4543
# Epoch [192/250] Fold [5] Train Loss: 0.1262, Train Acc: 0.5666 Val Loss: 0.1236, Val Acc: 0.6134, Macro F1: 0.5304, MCC: 0.4498
# Epoch [193/250] Fold [5] Train Loss: 0.1266, Train Acc: 0.5661 Val Loss: 0.1229, Val Acc: 0.5967, Macro F1: 0.5239, MCC: 0.4296
# Epoch [194/250] Fold [5] Train Loss: 0.1253, Train Acc: 0.5555 Val Loss: 0.1231, Val Acc: 0.5967, Macro F1: 0.5109, MCC: 0.4301
# Epoch [195/250] Fold [5] Train Loss: 0.1240, Train Acc: 0.5684 Val Loss: 0.1225, Val Acc: 0.5985, Macro F1: 0.5128, MCC: 0.4347
# Epoch [196/250] Fold [5] Train Loss: 0.1249, Train Acc: 0.5671 Val Loss: 0.1229, Val Acc: 0.5948, Macro F1: 0.5169, MCC: 0.4266
# Epoch [197/250] Fold [5] Train Loss: 0.1246, Train Acc: 0.5606 Val Loss: 0.1226, Val Acc: 0.5985, Macro F1: 0.5317, MCC: 0.4352
# Epoch [198/250] Fold [5] Train Loss: 0.1263, Train Acc: 0.5647 Val Loss: 0.1236, Val Acc: 0.6041, Macro F1: 0.5198, MCC: 0.4399
# Epoch [199/250] Fold [5] Train Loss: 0.1236, Train Acc: 0.5745 Val Loss: 0.1221, Val Acc: 0.6022, Macro F1: 0.5279, MCC: 0.4373
# Epoch [200/250] Fold [5] Train Loss: 0.1265, Train Acc: 0.5661 Val Loss: 0.1226, Val Acc: 0.5874, Macro F1: 0.5086, MCC: 0.4216
# Epoch [201/250] Fold [5] Train Loss: 0.1271, Train Acc: 0.5578 Val Loss: 0.1237, Val Acc: 0.5948, Macro F1: 0.5099, MCC: 0.4285
# Epoch [202/250] Fold [5] Train Loss: 0.1245, Train Acc: 0.5671 Val Loss: 0.1222, Val Acc: 0.5985, Macro F1: 0.5103, MCC: 0.4298
# Epoch [203/250] Fold [5] Train Loss: 0.1269, Train Acc: 0.5657 Val Loss: 0.1235, Val Acc: 0.5855, Macro F1: 0.4959, MCC: 0.4113
# Epoch [204/250] Fold [5] Train Loss: 0.1270, Train Acc: 0.5517 Val Loss: 0.1246, Val Acc: 0.6041, Macro F1: 0.5241, MCC: 0.4398
# Epoch [205/250] Fold [5] Train Loss: 0.1246, Train Acc: 0.5754 Val Loss: 0.1235, Val Acc: 0.5818, Macro F1: 0.4947, MCC: 0.4085
# Epoch [206/250] Fold [5] Train Loss: 0.1252, Train Acc: 0.5582 Val Loss: 0.1232, Val Acc: 0.5855, Macro F1: 0.4936, MCC: 0.4154
# Epoch [207/250] Fold [5] Train Loss: 0.1250, Train Acc: 0.5629 Val Loss: 0.1225, Val Acc: 0.5911, Macro F1: 0.5010, MCC: 0.4206
# Epoch [208/250] Fold [5] Train Loss: 0.1269, Train Acc: 0.5601 Val Loss: 0.1238, Val Acc: 0.5929, Macro F1: 0.5091, MCC: 0.4279
# Epoch [209/250] Fold [5] Train Loss: 0.1258, Train Acc: 0.5647 Val Loss: 0.1236, Val Acc: 0.5967, Macro F1: 0.5158, MCC: 0.4320
# Epoch [210/250] Fold [5] Train Loss: 0.1254, Train Acc: 0.5615 Val Loss: 0.1236, Val Acc: 0.6022, Macro F1: 0.5237, MCC: 0.4375
# Epoch [211/250] Fold [5] Train Loss: 0.1254, Train Acc: 0.5652 Val Loss: 0.1232, Val Acc: 0.5948, Macro F1: 0.5018, MCC: 0.4233
# Epoch [212/250] Fold [5] Train Loss: 0.1240, Train Acc: 0.5740 Val Loss: 0.1229, Val Acc: 0.5967, Macro F1: 0.5203, MCC: 0.4314
# Epoch [213/250] Fold [5] Train Loss: 0.1252, Train Acc: 0.5661 Val Loss: 0.1236, Val Acc: 0.5818, Macro F1: 0.5161, MCC: 0.4136
# Epoch [214/250] Fold [5] Train Loss: 0.1248, Train Acc: 0.5796 Val Loss: 0.1239, Val Acc: 0.5985, Macro F1: 0.5150, MCC: 0.4302
# Epoch [215/250] Fold [5] Train Loss: 0.1250, Train Acc: 0.5749 Val Loss: 0.1228, Val Acc: 0.5929, Macro F1: 0.5178, MCC: 0.4251
# Epoch [216/250] Fold [5] Train Loss: 0.1245, Train Acc: 0.5852 Val Loss: 0.1242, Val Acc: 0.6078, Macro F1: 0.5317, MCC: 0.4440
# Epoch [217/250] Fold [5] Train Loss: 0.1258, Train Acc: 0.5684 Val Loss: 0.1231, Val Acc: 0.5874, Macro F1: 0.5210, MCC: 0.4222
# Epoch [218/250] Fold [5] Train Loss: 0.1249, Train Acc: 0.5573 Val Loss: 0.1234, Val Acc: 0.5948, Macro F1: 0.5159, MCC: 0.4243
# Epoch [219/250] Fold [5] Train Loss: 0.1234, Train Acc: 0.5768 Val Loss: 0.1231, Val Acc: 0.5948, Macro F1: 0.5147, MCC: 0.4280
# Epoch [220/250] Fold [5] Train Loss: 0.1260, Train Acc: 0.5624 Val Loss: 0.1236, Val Acc: 0.5781, Macro F1: 0.5017, MCC: 0.4071
# Epoch [221/250] Fold [5] Train Loss: 0.1256, Train Acc: 0.5684 Val Loss: 0.1247, Val Acc: 0.5967, Macro F1: 0.5014, MCC: 0.4296
# Epoch [222/250] Fold [5] Train Loss: 0.1270, Train Acc: 0.5680 Val Loss: 0.1247, Val Acc: 0.5911, Macro F1: 0.5039, MCC: 0.4248
# Epoch [223/250] Fold [5] Train Loss: 0.1249, Train Acc: 0.5735 Val Loss: 0.1237, Val Acc: 0.5948, Macro F1: 0.5099, MCC: 0.4277
# Epoch [224/250] Fold [5] Train Loss: 0.1239, Train Acc: 0.5731 Val Loss: 0.1230, Val Acc: 0.5985, Macro F1: 0.5181, MCC: 0.4307
# Epoch [225/250] Fold [5] Train Loss: 0.1224, Train Acc: 0.5759 Val Loss: 0.1232, Val Acc: 0.5911, Macro F1: 0.5224, MCC: 0.4260
# Epoch [226/250] Fold [5] Train Loss: 0.1246, Train Acc: 0.5638 Val Loss: 0.1235, Val Acc: 0.5874, Macro F1: 0.5154, MCC: 0.4182
# Epoch [227/250] Fold [5] Train Loss: 0.1258, Train Acc: 0.5555 Val Loss: 0.1236, Val Acc: 0.5911, Macro F1: 0.5192, MCC: 0.4256
# Epoch [228/250] Fold [5] Train Loss: 0.1251, Train Acc: 0.5680 Val Loss: 0.1227, Val Acc: 0.5948, Macro F1: 0.5211, MCC: 0.4275
# Epoch [229/250] Fold [5] Train Loss: 0.1240, Train Acc: 0.5717 Val Loss: 0.1230, Val Acc: 0.5855, Macro F1: 0.5023, MCC: 0.4146
# Epoch [230/250] Fold [5] Train Loss: 0.1259, Train Acc: 0.5601 Val Loss: 0.1243, Val Acc: 0.5985, Macro F1: 0.5193, MCC: 0.4304
# Epoch [231/250] Fold [5] Train Loss: 0.1249, Train Acc: 0.5745 Val Loss: 0.1227, Val Acc: 0.5929, Macro F1: 0.5203, MCC: 0.4260
# Epoch [232/250] Fold [5] Train Loss: 0.1239, Train Acc: 0.5745 Val Loss: 0.1233, Val Acc: 0.6134, Macro F1: 0.5311, MCC: 0.4503
# Epoch [233/250] Fold [5] Train Loss: 0.1249, Train Acc: 0.5652 Val Loss: 0.1230, Val Acc: 0.5985, Macro F1: 0.5169, MCC: 0.4328
# Epoch [234/250] Fold [5] Train Loss: 0.1232, Train Acc: 0.5787 Val Loss: 0.1223, Val Acc: 0.6041, Macro F1: 0.5146, MCC: 0.4388
# Epoch [235/250] Fold [5] Train Loss: 0.1257, Train Acc: 0.5592 Val Loss: 0.1228, Val Acc: 0.6041, Macro F1: 0.5311, MCC: 0.4390
# Epoch [236/250] Fold [5] Train Loss: 0.1254, Train Acc: 0.5638 Val Loss: 0.1235, Val Acc: 0.6004, Macro F1: 0.5153, MCC: 0.4315
# Epoch [237/250] Fold [5] Train Loss: 0.1247, Train Acc: 0.5661 Val Loss: 0.1238, Val Acc: 0.5874, Macro F1: 0.5115, MCC: 0.4182
# Epoch [238/250] Fold [5] Train Loss: 0.1243, Train Acc: 0.5842 Val Loss: 0.1231, Val Acc: 0.5799, Macro F1: 0.5047, MCC: 0.4073
# Epoch [239/250] Fold [5] Train Loss: 0.1229, Train Acc: 0.5680 Val Loss: 0.1226, Val Acc: 0.6022, Macro F1: 0.5291, MCC: 0.4366
# Epoch [240/250] Fold [5] Train Loss: 0.1229, Train Acc: 0.5768 Val Loss: 0.1230, Val Acc: 0.5781, Macro F1: 0.5085, MCC: 0.4074
# Epoch [241/250] Fold [5] Train Loss: 0.1245, Train Acc: 0.5745 Val Loss: 0.1234, Val Acc: 0.6059, Macro F1: 0.5347, MCC: 0.4418
# Epoch [242/250] Fold [5] Train Loss: 0.1256, Train Acc: 0.5513 Val Loss: 0.1237, Val Acc: 0.5799, Macro F1: 0.5017, MCC: 0.4074
# Epoch [243/250] Fold [5] Train Loss: 0.1243, Train Acc: 0.5680 Val Loss: 0.1241, Val Acc: 0.5985, Macro F1: 0.5192, MCC: 0.4295
# Epoch [244/250] Fold [5] Train Loss: 0.1246, Train Acc: 0.5805 Val Loss: 0.1231, Val Acc: 0.6004, Macro F1: 0.5178, MCC: 0.4341
# Epoch [245/250] Fold [5] Train Loss: 0.1249, Train Acc: 0.5536 Val Loss: 0.1225, Val Acc: 0.5892, Macro F1: 0.5053, MCC: 0.4201
# Epoch [246/250] Fold [5] Train Loss: 0.1248, Train Acc: 0.5782 Val Loss: 0.1225, Val Acc: 0.6097, Macro F1: 0.5394, MCC: 0.4466
# Epoch [247/250] Fold [5] Train Loss: 0.1255, Train Acc: 0.5675 Val Loss: 0.1240, Val Acc: 0.6022, Macro F1: 0.5266, MCC: 0.4374
# Epoch [248/250] Fold [5] Train Loss: 0.1230, Train Acc: 0.5717 Val Loss: 0.1227, Val Acc: 0.5967, Macro F1: 0.5254, MCC: 0.4309
# Epoch [249/250] Fold [5] Train Loss: 0.1235, Train Acc: 0.5680 Val Loss: 0.1231, Val Acc: 0.6022, Macro F1: 0.5109, MCC: 0.4325
# Epoch [250/250] Fold [5] Train Loss: 0.1231, Train Acc: 0.5629 Val Loss: 0.1219, Val Acc: 0.6041, Macro F1: 0.5298, MCC: 0.4398

# %% [markdown]
# ### Caculating metrics helper function

# %%
# Function to calculate the precision and recall
def calculate_metrics(dataloader, model):
    y_pred = []
    y_true = []
    
    model.eval()
    with torch.no_grad():
        
        # iterate over validation data
        for X, y in dataloader:
            
            X = X.to(torch.float32)
            X = X.to(device)
            output = model(X)  # Feed Network

            output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
            y_pred.extend(output)  # Save Prediction

            labels = y.cpu().numpy()
            y_true.extend(labels)  # Save Truth

    # Calculate confusion matrix
    cf_matrix = confusion_matrix(y_true, y_pred)

    # Calculate precision and recall for each class
    precision = precision_score(y_true, y_pred, average=None, zero_division=0)
    recall = recall_score(y_true, y_pred, average=None, zero_division=0)
    macro_f1 = f1_score(y_true, y_pred, average='macro')
    mcc = matthews_corrcoef(y_true, y_pred)

    return cf_matrix, precision, recall, macro_f1, mcc

# %% [markdown]
# ### Confusion matrix

# %%
# make a function that visualize 5 confusion matrices from 5 data loaders, and stack them into one figure, 3 by 2
def plot_confusion_matrices(cf_matrices, labels, title):
    fig, axes = plt.subplots(2, 3, figsize=(10, 6))
    axes = axes.flatten()
    
    for i, cf_matrix in enumerate(cf_matrices):
        sns.heatmap(cf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
                    xticklabels=labels, yticklabels=labels, ax=axes[i])
        #axes[i].set_xlabel('Predicted')
        #axes[i].set_ylabel('True')
        axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
        axes[i].set_title(title[i])
    
    # remove the last empty subplot
    for j in range(i+1, len(axes)):
        fig.delaxes(axes[j])

    # set an overall x and y label for the entire figure
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to make space for the title
    fig.subplots_adjust(hspace=0.4, wspace=0.4)
    fig.text(0.5, 0, 'Predicted', ha='center', fontdict={'size': 16})
    fig.text(0, 0.5, 'True', va='center', rotation='vertical', fontdict={'size': 16})

    #fig.xlabel('Predicted')
    #fig.ylabel('True')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Testing

# %%
model_path
# Out:
# '/home/ec2-user/Feb2025/saved_models/Protein + mRNA_NN_model.pth'

# %%
# Load the model
last_model = PixelPreservingNet(in_channels=3)
last_model.load_state_dict(torch.load(model_path))
last_model.to(device)
# Out:
# /tmp/ipykernel_6994/3050491375.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   last_model.load_state_dict(torch.load(model_path))
# PixelPreservingNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (global_avg_pool): AdaptiveAvgPool2d(output_size=1)
#   (fc1): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#   )
#   (output): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
# Read in the synthetic data
# Mertins 
#   proteome
M_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'M_PD_synthetic_kde_qttumor.csv'))
M_PD_synthetic.index = M_PD_synthetic.loc[:,'Index']
M_PD_synthetic = M_PD_synthetic.loc[:, M_PD_synthetic.columns!='Index']

#   transcriptome
M_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'M_MD_synthetic_kde_qttumor.csv'))
M_MD_synthetic.index = M_MD_synthetic.loc[:,'gene_name']
M_MD_synthetic = M_MD_synthetic.loc[:, M_MD_synthetic.columns!='gene_name']

# LCSCC tumor
#   proteome
lung_tumor_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_tumor_PD_synthetic_kde_qttumor.csv'))
lung_tumor_PD_synthetic.index = lung_tumor_PD_synthetic.loc[:,'Gene']
lung_tumor_PD_synthetic = lung_tumor_PD_synthetic.loc[:, lung_tumor_PD_synthetic.columns!='Gene']

#   transcriptome
lung_tumor_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_tumor_MD_synthetic_kde_qttumor.csv'))
lung_tumor_MD_synthetic.index = lung_tumor_MD_synthetic.loc[:,'gene_name']
lung_tumor_MD_synthetic = lung_tumor_MD_synthetic.loc[:, lung_tumor_MD_synthetic.columns!='gene_name']

# LCSCC NAT
#   proteome
lung_nat_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_nat_PD_synthetic_kde_qttumor.csv'))
lung_nat_PD_synthetic.index = lung_nat_PD_synthetic.loc[:,'Gene']
lung_nat_PD_synthetic = lung_nat_PD_synthetic.loc[:, lung_nat_PD_synthetic.columns!='Gene']

#   transcriptome
lung_nat_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_nat_MD_synthetic_kde_qttumor.csv'))
lung_nat_MD_synthetic.index = lung_nat_MD_synthetic.loc[:,'gene_name']
lung_nat_MD_synthetic = lung_nat_MD_synthetic.loc[:, lung_nat_MD_synthetic.columns!='gene_name']

# Brain glioma
#   proteome
glioma_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'glioma_tumor_PD_synthetic_kde_qttumor.csv'))
glioma_PD_synthetic.index = glioma_PD_synthetic.loc[:,'gene_name']
glioma_PD_synthetic = glioma_PD_synthetic.loc[:, glioma_PD_synthetic.columns!='gene_name']

#   transcriptome
glioma_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'glioma_tumor_MD_synthetic_kde_qttumor.csv'))
glioma_MD_synthetic.index = glioma_MD_synthetic.loc[:,'gene_name']
glioma_MD_synthetic = glioma_MD_synthetic.loc[:, glioma_MD_synthetic.columns!='gene_name']

# %%
# Breast
# Read in the label
LD_mcf7 = pd.read_csv(Path(label_path+'markers.txt'), sep='\t')
LD_mcf7.index = LD_mcf7.loc[:,'Protein']
LD_mcf7 = LD_mcf7.loc[:,LD_mcf7.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_mcf7.loc[:,'Localization'] != 'Unclassified'
LD_mcf7 = LD_mcf7.loc[NotUnclassInd,:]

# Lung
LD_h322 = pd.read_csv(Path(label_path+'markers.txt'), sep='\t')
LD_h322.index = LD_h322.loc[:,'Protein']
LD_h322 = LD_h322.loc[:,LD_h322.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_h322.loc[:,'Localization'] != 'Unclassified'
LD_h322 = LD_h322.loc[NotUnclassInd,:]

# Lung
LD_u251 = pd.read_csv(Path(label_path+'markers.txt'), sep='\t')
LD_u251.index = LD_u251.loc[:,'Protein']
LD_u251 = LD_u251.loc[:,LD_u251.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_u251.loc[:,'Localization'] != 'Unclassified'
LD_u251 = LD_u251.loc[NotUnclassInd,:]

# %%
M_common_indices = list(set(M_PD_synthetic.index).intersection(set(M_MD_synthetic.index).intersection(set(LD_mcf7.index))))
M_LD = LD_mcf7.loc[LD_mcf7.index.isin(M_common_indices)]
M_PD_synthetic = M_PD_synthetic.loc[M_PD_synthetic.index.isin(M_common_indices)]
M_MD_synthetic = M_MD_synthetic.loc[M_MD_synthetic.index.isin(M_common_indices)]

lung_tumor_common_indices = list(set(lung_tumor_PD_synthetic.index).intersection(set(lung_tumor_MD_synthetic.index).intersection(set(LD_h322.index))))
lung_tumor_LD = LD_h322.loc[LD_h322.index.isin(lung_tumor_common_indices)]
lung_tumor_PD_synthetic = lung_tumor_PD_synthetic.loc[lung_tumor_PD_synthetic.index.isin(lung_tumor_common_indices)]
lung_tumor_MD_synthetic = lung_tumor_MD_synthetic.loc[lung_tumor_MD_synthetic.index.isin(lung_tumor_common_indices)]

lung_nat_common_indices = list(set(lung_nat_PD_synthetic.index).intersection(set(lung_nat_MD_synthetic.index).intersection(set(LD_h322.index))))
lung_nat_LD = LD_h322.loc[LD_h322.index.isin(lung_nat_common_indices)]
lung_nat_PD_synthetic = lung_nat_PD_synthetic.loc[lung_nat_PD_synthetic.index.isin(lung_nat_common_indices)]
lung_nat_MD_synthetic = lung_nat_MD_synthetic.loc[lung_nat_MD_synthetic.index.isin(lung_nat_common_indices)]

glioma_common_indices = list(set(glioma_PD_synthetic.index).intersection(set(glioma_MD_synthetic.index).intersection(set(LD_u251.index))))
glioma_LD = LD_u251.loc[LD_u251.index.isin(glioma_common_indices)]
glioma_PD_synthetic = glioma_PD_synthetic.loc[glioma_PD_synthetic.index.isin(glioma_common_indices)]
glioma_MD_synthetic = glioma_MD_synthetic.loc[glioma_MD_synthetic.index.isin(glioma_common_indices)]

# Convert string labels to integers
M_test_labels = [label_to_int[label] for label in M_LD['Localization'].values]
lung_tumor_test_labels = [label_to_int[label] for label in lung_tumor_LD['Localization'].values]
lung_nat_test_labels = [label_to_int[label] for label in lung_nat_LD['Localization'].values]
glioma_test_labels = [label_to_int[label] for label in glioma_LD['Localization'].values]

# Create the test datasets
if Set == 'Protein':
    M_test_dataset = MyDataset(Set, M_PD_synthetic, M_PD_synthetic, M_PD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = MyDataset(Set, lung_tumor_PD_synthetic, lung_tumor_PD_synthetic, lung_tumor_PD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = MyDataset(Set, lung_nat_PD_synthetic, lung_nat_PD_synthetic, lung_nat_PD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = MyDataset(Set, glioma_PD_synthetic, glioma_PD_synthetic, glioma_PD_synthetic.index, glioma_test_labels)
elif Set == 'mRNA':
    M_test_dataset = MyDataset(Set, M_MD_synthetic, M_MD_synthetic, M_MD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = MyDataset(Set, lung_tumor_MD_synthetic, lung_tumor_MD_synthetic, lung_tumor_MD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = MyDataset(Set, lung_nat_MD_synthetic, lung_nat_MD_synthetic, lung_nat_MD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = MyDataset(Set, glioma_MD_synthetic, glioma_MD_synthetic, glioma_MD_synthetic.index, glioma_test_labels)
elif Set == 'Protein + mRNA':
    M_test_dataset = MyDataset(Set, M_PD_synthetic, M_MD_synthetic, M_PD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = MyDataset(Set, lung_tumor_PD_synthetic, lung_tumor_MD_synthetic, lung_tumor_PD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = MyDataset(Set, lung_nat_PD_synthetic, lung_nat_MD_synthetic, lung_nat_PD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = MyDataset(Set, glioma_PD_synthetic, glioma_MD_synthetic, glioma_PD_synthetic.index, glioma_test_labels)
else:
    raise ValueError("Invalid dataset selection. Choose 'Protein', 'mRNA', 'Protein + mRNA', 'Protein + mRNA Stack'.")

# Create the test data loaders
set_seed(Seed)
M_test_loader = DataLoader(M_test_dataset, batch_size=Batch_size, shuffle=False)
lung_tumor_test_loader = DataLoader(lung_tumor_test_dataset, batch_size=Batch_size, shuffle=False)
lung_nat_test_loader = DataLoader(lung_nat_test_dataset, batch_size=Batch_size, shuffle=False)
glioma_test_loader = DataLoader(glioma_test_dataset, batch_size=Batch_size, shuffle=False)

# %% [markdown]
# ## Metrics

# %% [markdown]
# ### Fig: 5-fold CV

# %%
precision_per_class = [[] for _ in range(4)]
recall_per_class = [[] for _ in range(4)]
f1_per_class = [[] for _ in range(4)]

for fold in range(5):  # 5 folds
    df = pd.read_csv(cv_folder_path + f'{Set}_Fold{fold+1}_PrecisionRecall.csv')
    max_epoch = df['Epoch'].max()
    df_last = df[df['Epoch'] == max_epoch]
    
    for class_idx in range(4):
        class_df = df_last[df_last['Class'] == class_idx]
        precision_per_class[class_idx].append(class_df['Precision'].values[0])
        recall_per_class[class_idx].append(class_df['Recall'].values[0])
        f1_per_class[class_idx].append(class_df['Class F1'].values[0])

# Prepare for plotting
fig, ax = plt.subplots(figsize=(8, 4))

# Colors
precision_color = '#1f77b4'  # blue
recall_color = '#ff7f0e'     # orange
f1_color = '#d62728'         # red
class_labels = ['Cytosol', 'Mitochondria', 'Nucleus', 'Secretory']

# Positions setup
positions = []
data = []
colors = []

for i in range(4): 
    base = i * 4
    positions += [base - 0.55, base, base + 0.55]
    data += [
        np.array(precision_per_class[i]),
        np.array(recall_per_class[i]),
        np.array(f1_per_class[i])
    ]
    colors += [precision_color, recall_color, f1_color]


# Boxplot
bp = ax.boxplot(data, positions=positions, widths=0.5, patch_artist=True, showfliers=False,
                boxprops=dict(linewidth=1),
                medianprops=dict(color='black', linewidth=1),
                whiskerprops=dict(linewidth=1),
                capprops=dict(linewidth=1))

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.8)

# X-ticks
class_centers = [(i * 4) for i in range(4)]
ax.set_xticks(class_centers)
ax.set_xticklabels(class_labels, fontsize=16)

# Axes labels and limits
ax.set_ylabel('Score', fontsize=18)
ax.set_ylim(0, 1.05)
ax.set_yticks([0.0, 0.25, 0.5, 0.75, 1.0])
ax.tick_params(axis='both', which='major', labelsize=16)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add dashed horizontal threshold lines (class-specific)
ci_baselines = [0.43314056, 0.09879518, 0.30857335, 0.20966921]
for i, y_val in enumerate(ci_baselines):
    left = i * 4 - 1
    right = i * 4 + 1
    ax.hlines(y=y_val, xmin=left, xmax=right, colors='gray', linestyles=(0, (5, 5)), linewidth=1)

# Legend handles
legend_handles = [
    mpatches.Patch(color=precision_color, label='Precision'),
    mpatches.Patch(color=recall_color, label='Recall'),
    mpatches.Patch(color=f1_color, label='F1'),
    plt.Line2D([0], [0], color='gray', linestyle=(0, (5, 5)), linewidth=1, label='95% CI')
]

# Legend outside the plot
ax.legend(handles=legend_handles, loc='center left', bbox_to_anchor=(1.01, 0.5), frameon=False, fontsize=14)

# Save figure
plt.tight_layout()
plt.savefig(fig_bank_path + f'{Set}_CV_Boxplot.pdf', dpi=600, bbox_inches='tight')

# %% [markdown]
# ### Fig: training and validation loss

# %%
# Find last completed epoch
last_epoch = LossAccDF['Epoch'].max()

# Create figure
fig, ax = plt.subplots(figsize=(8, 4))

# Plot curves
ax.plot(LossAccDF['Epoch'], LossAccDF['TrainLoss'], label='Training', color='tab:blue', linewidth=2)
ax.plot(LossAccDF['Epoch'], LossAccDF['ValLoss'], label='Validation', color='tab:orange', linewidth=2, linestyle='--')

# Axes labels
ax.set_xlabel('Epoch', fontsize=18)
ax.set_ylabel('Loss', fontsize=18)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Ticks
ax.set_xlim([0, last_epoch])
ax.set_xticks(range(0, last_epoch+1, max(1, last_epoch // 5)))  # adaptive ticks
ax.tick_params(axis='both', which='major', labelsize=16)

# Legend outside the plot
ax.legend(frameon=False, fontsize=14, loc='center left', bbox_to_anchor=(1.02, 0.5))

# Tight layout
plt.tight_layout()

# Save high-quality figure
fig.savefig(Path(fig_bank_path) / f"{Set}_Loss.pdf", dpi=600, bbox_inches='tight')

# %% [markdown]
# ### Fig: training and validation accuracy

# %%
# Find last completed epoch
last_epoch = LossAccDF['Epoch'].max()

# Create figure
fig, ax = plt.subplots(figsize=(8, 4))  # Compact

# Plot accuracy curves (scale to %)
ax.plot(LossAccDF['Epoch'], LossAccDF['TrainAcc'] * 100, label='Training', color='tab:blue', linewidth=2)
ax.plot(LossAccDF['Epoch'], LossAccDF['ValAcc'] * 100, label='Validation', color='tab:orange', linewidth=2, linestyle='--')

# Axes labels
ax.set_xlabel('Epoch', fontsize=18)
ax.set_ylabel('Accuracy (%)', fontsize=18)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# X and Y limits
ax.set_xlim([0, last_epoch])
ax.set_ylim([0, 100])

# Ticks
ax.set_xticks(range(0, last_epoch + 1, max(1, last_epoch // 5)))
ax.set_yticks([0, 25, 50, 75, 100])
ax.tick_params(axis='both', which='major', labelsize=16)

# Legend outside the plot
ax.legend(frameon=False, fontsize=14, loc='center left', bbox_to_anchor=(1.02, 0.5))

# Tight layout
plt.tight_layout()

# Save figure
fig.savefig(Path(fig_bank_path) / f"{Set}_Acc.pdf", dpi=600, bbox_inches='tight')

# %% [markdown]
# ### Fig: confusion matrices

# %%
# Set seed
set_seed(Seed)

# Get the confusion matrix and precision and recall for the validation loader and all test loaders
cf_matrix_val, precision_val, recall_val, macro_f1_val, mcc_val = calculate_metrics(val_loader, last_model)
cf_matrix_M, precision_M, recall_M, macro_f1_M, mcc_M = calculate_metrics(M_test_loader, last_model)
cf_matrix_lung_tumor, precision_lung_tumor, recall_lung_tumor, macro_f1_lung_tumor, mcc_lung_tumor = calculate_metrics(lung_tumor_test_loader, last_model)
cf_matrix_lung_nat, precision_lung_nat, recall_lung_nat, macro_f1_lung_nat, mcc_lung_nat = calculate_metrics(lung_nat_test_loader, last_model)
cf_matrix_glioma, precision_glioma, recall_glioma, macro_f1_glioma, mcc_glioma = calculate_metrics(glioma_test_loader, last_model)

# Put them into a list
cf_matrices = [cf_matrix_val, cf_matrix_M, cf_matrix_lung_tumor, cf_matrix_lung_nat, cf_matrix_glioma]
titles = ['Krug Validation', 'Mertins Test ', 'Lung Tumor Test', 'Lung NAT Test', 'Glioma Test']

# Plot the confusion matrices
plot_confusion_matrices(cf_matrices, labels=int_to_label.values(), title=titles)

# Save figure into figure bank
figure3 = plt.gcf()
figure3.savefig(Path(fig_bank_path+Set+'_Confusion_Matrices.png'), dpi=300)

# %% [markdown]
# ### Fig: macro F1 and MCC

# %%
# Find last completed epoch
last_epoch = int(PrecisionRecallDF['Epoch'].max())

# Create figure
fig, ax = plt.subplots(figsize=(6, 4))  # Compact and tight

# Plot Macro F1 and MCC curves
ax.plot(PrecisionRecallDF['Epoch'], PrecisionRecallDF['Macro F1'], label='Macro F1', color='tab:blue', linewidth=2)
ax.plot(PrecisionRecallDF['Epoch'], PrecisionRecallDF['MCC'], label='MCC', color='tab:orange', linewidth=2, linestyle='--')

# Axes labels
ax.set_xlabel('Epoch', fontsize=14)
ax.set_ylabel('Score', fontsize=14)

# Limits
ax.set_xlim([0, last_epoch])
ax.set_ylim([-1.05, 1.05])  # Slightly more padding for aesthetics

# Ticks
ax.set_xticks(range(0, last_epoch+1, max(1, last_epoch // 10)))
ax.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax.tick_params(axis='both', which='major', labelsize=12)

# Legend
ax.legend(frameon=False, fontsize=12, loc='lower right')

# Tight layout
plt.tight_layout()

# Save figure
fig.savefig(Path(fig_bank_path) / f"{Set}_MacroF1_MCC.png", dpi=600, bbox_inches='tight')

# %% [markdown]
# ### Fig: Precision and recall of validation and testing

# %%
set_seed(Seed)

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()

compartment_class = ['Cytosol', 'Mitochondria', 'Nucleus', 'Secretory']
colormaps = [cm.Blues, cm.Oranges, cm.Greens, cm.Purples]

# Filter improvement epochs
def filter_improvement_epochs(df):
    improved_epochs = []
    for class_label in df['Class'].unique():
        class_df = df[df['Class'] == class_label].copy()
        class_df = class_df.sort_values(by='Epoch')
        max_precision = float('-inf')
        for _, row in class_df.iterrows():
            if row['Precision'] >= max_precision:
                max_precision = row['Precision']
                improved_epochs.append(row)
    start_epoch = df[df['Epoch'] == 0]
    last_epoch = df[df['Epoch'] == df['Epoch'].max()]
    return pd.concat([start_epoch, pd.DataFrame(improved_epochs), last_epoch]).drop_duplicates()

improved_epochs_df = filter_improvement_epochs(PrecisionRecallDF)

for i, f1_score in enumerate(np.array([0.43314056, 0.09879518, 0.30857335, 0.20966921])):
    ax = axes[i]
    class_metrics = improved_epochs_df[improved_epochs_df['Class'] == i]
    norm = plt.Normalize(class_metrics['Epoch'].min(), class_metrics['Epoch'].max())

    # # Scatter points
    # for _, row in class_metrics.iterrows():
    #     color = colormaps[i](norm(row['Epoch']))
    #     edge_color = colormaps[i](0.8)
    #     ax.scatter(row['Recall'], row['Precision'], s=100, color=color, edgecolors=edge_color, linewidths=1)

    # # Connect dots
    # ax.plot(class_metrics['Recall'], class_metrics['Precision'], color=colormaps[i](0.5), linewidth=2)

    # Plot F1 curve
    x_left = np.linspace(0, f1_score / 2, 10000)
    x_right = np.linspace(f1_score / 2, 1, 10000)
    y_right = f1_score * x_right / (2 * x_right - f1_score)
    ax.plot(x_right, y_right, color=colormaps[i](0.5), linestyle='--', linewidth=2)
    ax.fill_between(x_left, 0, 1, color=colormaps[i](0.5), alpha=0.2)
    ax.fill_between(x_right, 0, y_right, color=colormaps[i](0.5), alpha=0.2)

    # Add external test points
    ax.scatter(recall_M[i], precision_M[i], s=75, color='red', edgecolors='red', marker='s', label='Mertins test set')
    ax.scatter(recall_lung_tumor[i], precision_lung_tumor[i], s=75, color='purple', edgecolors='purple', marker='s', label='LSCC Tumor')
    ax.scatter(recall_lung_nat[i], precision_lung_nat[i], s=75, color='orange', edgecolors='orange', marker='s', label='LSCC NAT')
    ax.scatter(recall_glioma[i], precision_glioma[i], s=75, color='green', edgecolors='green', marker='s', label='Glioma')

    # Plot settings
    ax.set_title(compartment_class[i], fontsize=18)
    ax.set_xlim([0, 1])
    ax.set_ylim([0, 1])
    ax.set_xlabel('Recall (Sensitivity)', fontsize=18)
    ax.set_ylabel('Precision\n(Positive Predictive Value)', fontsize=18)
    ax.tick_params(axis='both', labelsize=16)
    ax.grid(True, linestyle='--', alpha=0.4)

    # Remove top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Legend (only once per subplot)
    mertins_handle = mlines.Line2D([], [], color='red', marker='s', linestyle='None', markersize=8, label='Breast Tumor')
    lung_tumor_handle = mlines.Line2D([], [], color='purple', marker='s', linestyle='None', markersize=8, label='Lung Tumor')
    lung_nat_handle = mlines.Line2D([], [], color='orange', marker='s', linestyle='None', markersize=8, label='Lung NAT')
    glioma_handle = mlines.Line2D([], [], color='green', marker='s', linestyle='None', markersize=8, label='Brain Tumor')

# Global legend outside the subplots
fig.legend(handles=[mertins_handle, lung_tumor_handle, lung_nat_handle, glioma_handle],
           loc='center left', bbox_to_anchor=(1.01, 0.5), fontsize=16, frameon=False)

# Tight layout
plt.tight_layout()  # reserve space on the right

# Save figure at high quality
fig.savefig(Path(fig_bank_path) / f"{Set}_Precision_Recall_F1curve.pdf", dpi=600, bbox_inches='tight')
# Out:
# /tmp/ipykernel_6994/2455325278.py:43: RuntimeWarning: divide by zero encountered in divide
#   y_right = f1_score * x_right / (2 * x_right - f1_score)

# %%
# export dataframes
LossAccDF.to_excel(Path(fig_bank_path + Set+ f'LossAccDF.xlsx'), index=False)
PrecisionRecallDF.to_excel(Path(fig_bank_path + Set+ f'PrecisionRecallDF.xlsx'), index=False)
