# %% [markdown]
# # Training (Protein)

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Package imports

# %%
# Import packages
import re
import os
import gc
import copy
from pathlib import Path
import numpy as np
from numpy.random import MT19937
from numpy.random import RandomState, SeedSequence
import pandas as pd
import math
import random
import datetime
import time
import warnings
from pdb import set_trace
from collections import Counter

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
import seaborn as sns

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, matthews_corrcoef
from sklearn.preprocessing import LabelEncoder

import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Sampler
from torchvision import models, transforms

# %% [markdown]
# ### GPU

# %%
# Check to see if the GPU is available and store it as a variable so tensors can be moved to it
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print('Is cuda available?:', torch.cuda.is_available())
print('cuda version:', torch.version.cuda)
dev = "cuda:0"
# Out:
# Using device: cuda
# Is cuda available?: True
# cuda version: 12.4

# %% [markdown]
# ### Variables and Hyperparameters

# %%
# Create run name
Run_Name = 'Prot' # change run_name before running

# Paths
label_path = '/home/ec2-user/Feb2025/labels/' # label folder with all the labels
dataset_folder_path = '/home/ec2-user/Feb2025/processed_dataset2/' # dataset folder with all the processed proteome and mRNA data
model_folder_path = '/home/ec2-user/Feb2025/saved_models/' # model folder with all the models
fig_bank_path = '/home/ec2-user/Feb2025/NN_figure_bank/' # figure bank folder with all the figures
cv_folder_path = '/home/ec2-user/Feb2025/NN_CV_bank/' # cross-validation folder with all the cross-validation results

# Define the Model
Model = 'PixelPreserve' # 'PixelPreserve' are the options

# Dataset
Set = 'Protein' # Define the dataset to use, 'Protein', 'mRNA', or 'Protein + mRNA' are the options

# Image size
Canvas_Size = 18

# Seed number
Seed = 43

# Validation fraction
Validation_Fraction = 0.2

# Standard deviation for add-noise transformation
StandardDeviation = 0.005 # 0.005 so far is better

# Learning rate scheduler
Learner_rate = 1e-4

# Optimizer
Weight_Decay = 0.0001 # L2 regulator
#  it works by adding a penalty to the loss function, which discourages large weights in the model; penalizes for too many weights - helps prevent overfitting
#  the penalty is calculated as weight_decay * weight^2, and it's added to the loss.
#  1e-4 or 1e-3 gives higher acc

# Batch size
Batch_size = 64

# Epoch amount
epochs = 250

# %% [markdown]
# ### Protein, mRNA dataframe, localization label set up

# %%
# Open the proteomics data and only keep genes (rows) that are fully quantified
PFP = 'K_PD_synthetic_kde_qttumor.csv' # synthetic data
PD = pd.read_csv(dataset_folder_path+PFP)

# Data set wrangling
PD.index = PD.loc[:,'Index']
PD = PD.loc[:,PD.columns!='Index']
PD.dropna(inplace=True)

# Open the mRNA data and only keep genes (rows) that are fully quantified
MFP = 'K_MD_synthetic_kde_qttumor.csv'
MD = pd.read_csv(dataset_folder_path + MFP)

# Data set wrangling
MD.index = MD.loc[:,'Index']
MD = MD.loc[:,MD.columns!='Index']
MD = MD.drop_duplicates()
MD.dropna(inplace=True)

# %%
# Open the labels data
LFP = 'markers.txt'
LD = pd.read_csv(filepath_or_buffer=label_path+LFP,sep='\t')
# Data set wrangling
LD.index = LD.loc[:,'Protein']
LD = LD.loc[:,LD.columns!='Protein']

# %%
# Select the localization labels that are both common in the proteomics and mRNA data
common_genes = set(PD.index).intersection(set(MD.index))
# Select only the common genes
LD = LD.loc[LD.index.isin(common_genes),:]

print('Number of total labels in Krug dataset')
print(len(LD.index))
print(LD['Localization'].value_counts())
# Out:
# Number of total labels in Krug dataset
# 2693
# Localization
# Cytosol         1036
# Secretory        769
# Nucleus          624
# Mitochondria     264
# Name: count, dtype: int64

# %% [markdown]
# ### Set seed function

# %%
def set_seed(seed):
    random.seed(seed) # set random seed for python
    np.random.seed(seed) # set random seed for numpy
    torch.manual_seed(seed) # set random seed for CPU
    rs = RandomState(MT19937(SeedSequence(seed))) # seed for numpy
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed) # set random seed for all GPUs
    torch.backends.cudnn.deterministic = True # set to True to get reproducible results
    torch.backends.cudnn.benchmark = False # set to False to get reproducible results

# %% [markdown]
# ### Pixel coordinates and RGB tensor generation functions

# %%
def gen_horizontal_coords(n, num_points):
    """
    Generate coordinates for a horizontal pattern starting from the top-left corner.

    Parameters:
    n (int): Size of the canvas (n x n).
    num_points (int): Number of points to generate in the horizontal pattern.

    Returns:
    list: List of (x, y) coordinates in horizontal order.
    """
    coords = [(x, y) for x in range(n) for y in range(n)]
    return coords[:num_points]

def create_rgb_tensors(set, interleaved_array):
    """
    Create RGB tensors from abundance data using the specified pattern.
    
    Parameters:
    set (str): Dataset used for plotting ('Protein', 'mRNA', 'Protein + mRNA').
    df1 (pd.DataFrame): DataFrame containing normalized abundance data.
    df2 (pd.DataFrame): DataFrame containing normalized abundance data.
    
    Returns:
    torch.Tensor: RGB tensor.
    """

    interleaved_array = interleaved_array.flatten()
    num_pixels = len(interleaved_array)
    
    # Generate coordinates based on the pattern, spiral or horizontal arrangment
    coords = gen_horizontal_coords(Canvas_Size, num_pixels)

    # Create RGB tensor
    rgb_tensor = np.zeros((Canvas_Size, Canvas_Size, 3), dtype=np.float32)
    for i, (x, y) in enumerate(coords):
        if i < len(interleaved_array):
            value = interleaved_array[i]
            # Assign colors based on the value, if abundance > 1, set it to red, if abundance < 0, set it to blue.
            if value > 1:
                rgb_tensor[x, y] = [255, 0, 0]  # Red for value > 1
            elif value < 0:
                rgb_tensor[x, y] = [0, 0, 255]  # Blue for value < 0
            else:
                rgb_tensor[x, y] = [255 * value, 0, 255 * (1 - value)]

    return torch.from_numpy(rgb_tensor.transpose(2, 0, 1))  # Convert to CHW format for PyTorch

# %% [markdown]
# ### Custom Transformation

# %%
# Custom transformation to add noise to the data
class AddNoise:
    def __init__(self, set, mean=0, std=0.005):
        self.set = set
        self.mean = mean
        self.std = std

    def __call__(self, array1, array2):
        if self.set == 'Protein + mRNA':
            noise1 = np.random.normal(self.mean, self.std, array1.shape)
            noise2 = np.random.normal(self.mean, self.std, array2.shape)

            return array1 + noise1, array2 + noise2    

        else: # suitable for Protein or mRNA only because same noise will be applied twice
            noise = np.random.normal(self.mean, self.std, array1.shape)
        
        return array1 + noise, array2 + noise

# %% [markdown]
# ### Custom Dataset class

# %%
class MyDataset(Dataset):
    def __init__(self, set, data1, data2, indices, labels, transform=None):

        assert data1.loc[indices,:].shape[0] == data2.loc[indices,:].shape[0] == len(labels), \
            "Protein, mRNA, and labels must have the same number of samples (rows)"

        self.set = set
        self.data1 = data1.loc[indices,:]
        self.data2 = data2.loc[indices,:]
        self.indices = indices
        self.labels = labels
        self.transform = transform

    def __getitem__(self, idx):
        data1 = self.data1.iloc[idx].values
        data2 = self.data2.iloc[idx].values

        if self.transform:  
            data1, data2 = self.transform(data1, data2)

        abundance_sum = data1 + data2
        sorted_idx = abundance_sum.argsort()

        # Interleave
        interleaved_data = np.empty((len(data1) + len(data2)), dtype=np.float32)
        interleaved_data[0::2] = data1[sorted_idx]
        interleaved_data[1::2] = data2[sorted_idx]

        # Create RGB tensor
        sample = create_rgb_tensors(self.set, interleaved_data)
        label = torch.tensor(self.labels[idx], dtype=torch.long)

        return sample, label

    def __len__(self):
        return len(self.labels)

    def get_labels(self):
        return self.labels

# %% [markdown]
# ### Labels to integers

# %%
# Labels
localization_labels = LD.loc[:, 'Localization'].values
unique_labels = set(localization_labels)  # Get unique labels
label_to_int = {
    'Cytosol': 0,
    'Mitochondria': 1,
    'Nucleus': 2,
    'Secretory': 3
}
int_to_label = {v: k for k, v in label_to_int.items()}
int_to_label
# Out:
# {0: 'Cytosol', 1: 'Mitochondria', 2: 'Nucleus', 3: 'Secretory'}

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Dataloaders

# %%
# Set seed to ensure reproducibility
set_seed(Seed)

# Split the data into training and validation sets using the labels indices, random state is set
train_indices, val_indices, train_labels, val_labels = train_test_split(LD.index, localization_labels, test_size=Validation_Fraction, random_state=42, stratify=localization_labels)

# Convert string labels to integers
train_labels = [label_to_int[label] for label in train_labels]
val_labels = [label_to_int[label] for label in val_labels]

# Define the transformation
transformation = AddNoise(set=Set, mean=0, std=StandardDeviation)

# Check Dataset argument to determine which dataset to use
if Set == 'Protein':
    train_dataset = MyDataset(Set, PD, PD, train_indices, train_labels, transform=transformation)
    val_dataset = MyDataset(Set, PD, PD, val_indices, val_labels, transform=None)
elif Set == 'mRNA':
    train_dataset = MyDataset(Set, MD, MD, train_indices, train_labels, transform=transformation)
    val_dataset = MyDataset(Set, MD, MD, val_indices, val_labels, transform=None)
elif Set == 'Protein + mRNA':
    train_dataset = MyDataset(Set, PD, MD, train_indices, train_labels, transform=transformation)
    val_dataset = MyDataset(Set, PD, MD, val_indices, val_labels, transform=None)
else:
    raise ValueError("Set must be 'Protein' or 'mRNA', or 'Protein + mRNA'")

# Create the dataloaders
train_loader = DataLoader(train_dataset, batch_size=Batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=Batch_size, shuffle=False)

# %% [markdown]
# ### Visualize the tensors in data loader

# %%
# Visualize the train data loader to see the transformed tensors
train_batch_images, train_batch_labels = next(iter(train_loader))

# Use first image in the batch
first_image_in_train_batch = train_batch_images[0]
image_to_plot = first_image_in_train_batch.permute(1, 2, 0).numpy().astype('uint8')
first_label_in_train_batch = train_batch_labels[0]

# Visualize the tensor as an image 
plt.imshow(image_to_plot)
#plt.title(f"Label: {int_to_label[first_label_in_train_batch.item()]}")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(17.5), np.float64(17.5), np.float64(-0.5))

# %%
# Visualize the train data loader to see the transformed tensors
val_batch_images, val_batch_labels = next(iter(val_loader))

# Use first image in the batch
first_image_in_val_batch = val_batch_images[0]
image_to_plot = first_image_in_val_batch.permute(1, 2, 0).numpy().astype('uint8')
first_label_in_val_batch = val_batch_labels[0]

# Visualize the tensor as an image
plt.imshow(image_to_plot)
#plt.title(f"Label: {int_to_label[first_label_in_val_batch.item()]}")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(17.5), np.float64(17.5), np.float64(-0.5))

# %% [markdown]
# ### Define model

# %%
class PixelPreservingNet(nn.Module):
    def __init__(self, in_channels=3):
        super(PixelPreservingNet, self).__init__()
        
        # Convolutional layers
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=16, kernel_size=3, padding=1), 
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.pool = nn.AvgPool2d(kernel_size=2, stride=2)  # Shape is reduced by half

        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )  # Shape remains same after padding

        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Dropout(0.3)  
        )

        # Fully connected layers
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)  # Global Average Pooling layer
        self.fc1 = nn.Sequential(
            nn.Linear(256, 512), #256->512
            nn.ReLU(),
            nn.Dropout(0.4)
        )
        self.fc2 = nn.Sequential(
            nn.Linear(512, 256), #512->256
            nn.ReLU(),
            nn.Dropout(0.4)
        )

        # Output layer
        self.output = nn.Linear(256, 4) #256->4
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = self.pool(x)
        x = self.conv3(x)
        x = self.pool(x)
        x = self.conv4(x)
        x = self.pool(x)
        x = self.conv5(x)
        
        # Global Average Pooling
        x = self.global_avg_pool(x)
        x = torch.flatten(x, 1)
        
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.output(x)
        return x

model = PixelPreservingNet(in_channels=3).to(device)

# %% [markdown]
# ### Define train loop

# %%
def train_loop(dataloader, model, loss_fn, optimizer, scheduler=None):
    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for X, y in dataloader:
        X = X.to(torch.float32).to(device)
        y = y.to(torch.long).to(device)

        optimizer.zero_grad()

        outputs = model(X)
        loss = loss_fn(outputs, y)

        # Confidence penalty
        softmax_probs = F.softmax(outputs, dim=1)
        entropy = -torch.sum(softmax_probs * torch.log(softmax_probs + 1e-10), dim=1)
        penalty = torch.mean(entropy)
        total_loss_with_penalty = loss - 0.15 * penalty

        total_loss_with_penalty.backward()
        optimizer.step()

        # Scheduler step (per batch)
        if scheduler is not None:
            scheduler.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        correct_train += (predicted == y).sum().item()
        total_train += y.size(0)

    avg_training_loss = running_loss / len(dataloader)
    training_accuracy = correct_train / total_train

    return avg_training_loss, training_accuracy

# %% [markdown]
# ### Define test loop

# %%
def test_loop(dataloader, model, loss_fn):
    
    model.eval()  # Set the model to evaluation mode

    test_loss = 0.0
    correct = 0
    total = 0

    y_pred = []
    y_true = []
    
    with torch.no_grad():  # Disable gradient calculation
        for X, y in dataloader:
            
            # Prepare data
            X = X.to(torch.float32).to(device)
            y = y.to(torch.long).to(device)

            # Forward pass: predict classes
            outputs = model(X)
            
            # Compute the loss
            test_loss += loss_fn(outputs, y).item()
            
            # Apply softmax and get prediction
            probs = F.softmax(outputs, dim=1)
            confidences, predicted = probs.max(dim=1)

            # Store predictions and true labels
            y_pred.extend(predicted.cpu().numpy())
            y_true.extend(y.cpu().numpy())

            # Count correct predictions
            correct += (predicted == y).sum().item() 

            # Count total predictions
            total += y.size(0) 

    # Calculate precision and recall for each class
    precision = precision_score(y_true, y_pred, average=None, zero_division=0.0)
    recall = recall_score(y_true, y_pred, average=None, zero_division=0.0)
    macro_f1 = f1_score(y_true, y_pred, average='macro')
    mcc = matthews_corrcoef(y_true, y_pred)

    # Per_class F1
    per_class_f1 = f1_score(y_true, y_pred, average=None, zero_division=0.0)

    # Global metrics
    avg_test_loss = test_loss / len(dataloader)
    test_accuracy = correct / total
        
    return avg_test_loss, test_accuracy, precision, recall, per_class_f1, macro_f1, mcc

# %% [markdown]
# ### Define focal loss

# %%
# Focal loss
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=None, reduction='mean'):
        """
        :param gamma: focusing parameter (default=2.0)
        :param alpha: balance parameter, it can be a float or a tensor (default=None)
        :param reduction: specify the reduction to apply to the output: 'none' | 'mean' | 'sum' (default='mean')
        """
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        # Compute cross-entropy loss
        BCE_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)  # pt is the probability of the true class
        
        # Compute the focal loss
        F_loss = (1 - pt) ** self.gamma * BCE_loss
        
        # Apply class weighting (alpha) if provided
        if self.alpha is not None:
            alpha = self.alpha[targets]
            F_loss = alpha * F_loss
        
        # Apply the specified reduction
        if self.reduction == 'mean':
            return F_loss.mean()
        elif self.reduction == 'sum':
            return F_loss.sum()
        else:
            return F_loss

# %% [markdown]
# ### Define early stopping

# %%
class EarlyStoppingWithCheckpoint:
    def __init__(self, patience=10, delta=0.0, save_path=None):
        self.patience = patience
        self.delta = delta
        self.save_path = save_path
        self.best_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss, model, save_path=None):
        # Allow override save_path if given in call
        if save_path is not None:
            self.save_path = save_path

        if self.best_loss is None:
            self.best_loss = val_loss
            if self.save_path is not None:
                self.save_checkpoint(model)
        elif val_loss > self.best_loss - self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            if self.save_path is not None:
                self.save_checkpoint(model)
            self.counter = 0

    def save_checkpoint(self, model):
        torch.save(model.state_dict(), self.save_path)

# %% [markdown]
# ### Training and validation

# %%
set_seed(Seed)

# Compute class weights
def compute_class_weights(class_counts): # inverse square root frequency for mild imbalance
    class_weights = 1.0 / torch.sqrt(torch.tensor(class_counts, dtype=torch.float))
    return class_weights / class_weights.sum()

# Given class counts
#class_counts = [2401, 410, 1554, 1112]
#LossWeights = compute_class_weights(class_counts)
LossWeights = torch.tensor([0.16, 0.39, 0.20, 0.24], dtype=torch.float32) # manually set weights
LossWeights = LossWeights.to(device)

# Define the loss function, optimizer and scheduler
criterion = FocalLoss(alpha=LossWeights, gamma=2.0, reduction='mean')  # Focal loss for imbalanced classification
optimizer = optim.AdamW(model.parameters(), lr=Learner_rate, weight_decay=Weight_Decay)  # AdamW optimizer with weight decay
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,        # reduce LR by half
    patience=10,       # fewer stagnant epochs before reducing
    threshold=1e-4,    # stricter improvement requirement
    cooldown=2,        # wait a bit after LR drop before checking again
    min_lr=1e-7,       # don’t shrink forever
    verbose=True
)
model_path = os.path.join(model_folder_path, f"{Set}_NN_model.pth")
#early_stopping = EarlyStoppingWithCheckpoint(patience=15, delta=0, save_path=model_path)
best_macro_f1 = float('-inf')

# Set up performance dataframe to record loss, accuracy, precision and recall of each epoch
LossAccDF = pd.DataFrame(index=range(epochs),columns=['Epoch','TrainLoss','ValLoss','TrainAcc','ValAcc'])
PrecisionRecallDF = pd.DataFrame(columns=['Epoch','Class','Precision','Recall','Class F1','Macro F1','MCC'])

# Evaluate the model before training
avg_train_loss, train_accuracy, _, _, _, _, _ = test_loop(train_loader, model, criterion) # compute training performance
avg_val_loss, val_accuracy, precision, recall, per_class_f1, macro_f1, mcc = test_loop(val_loader, model, criterion) # compute validation performance

# Print initial performance
print(f"Before Training: "
      f"Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}",
      f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}",
      f"Macro F1: {macro_f1:.4f}, Matthews Correlation Coefficient: {mcc:.4f}")

# Record the metric in the dataframe
LossAccDF.loc[0,:]=[0,avg_train_loss,avg_val_loss,train_accuracy,val_accuracy]
index=0
for i in range(4):
    PrecisionRecallDF.loc[index]=[0, i, precision[i], recall[i], per_class_f1[i], macro_f1, mcc]
    index += 1

# Training loop
for epoch in range(epochs):

    # Training phase
    avg_train_loss, train_accuracy = train_loop(train_loader, model, criterion, optimizer)
    
    # Validation phase
    avg_val_loss, val_accuracy, precision, recall, per_class_f1, macro_f1, mcc = test_loop(val_loader, model, criterion)
    
    # Print epoch loss and accuracy
    print(f"Epoch [{epoch+1}/{epochs}], "
          f"Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}",
          f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}",
          f"Macro F1: {macro_f1:.4f}, Matthews Correlation Coefficient: {mcc:.4f}")   

    # Record the metric in the dataframe
    LossAccDF.loc[epoch+1,:]=[epoch+1,avg_train_loss,avg_val_loss,train_accuracy,val_accuracy]
    for i in range(4):
        PrecisionRecallDF.loc[index]=[epoch+1, i, precision[i], recall[i], per_class_f1[i], macro_f1, mcc]
        index += 1

    # Save best model based on macro F1
    if macro_f1 > best_macro_f1:
        best_macro_f1 = macro_f1
        torch.save(model.state_dict(), model_path)
        print(f"Best Macro F1 achieved: {best_macro_f1:.4f}")
        print(f"Saved new best model at epoch {epoch+1} with Macro F1: {macro_f1:.4f}")
        
    #Check for early stopping
    # early_stopping(avg_val_loss, model)

    # if early_stopping.early_stop:
    #    print(f"Early stopping at epoch {epoch}")
    #    break
# Out:
# /opt/conda/envs/pytorch/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Before Training: Training Loss: 0.1675, Training Accuracy: 0.2317 Validation Loss: 0.1671, Validation Accuracy: 0.2319 Macro F1: 0.0941, Matthews Correlation Coefficient: 0.0000
# Epoch [1/250], Training Loss: 0.1624, Training Accuracy: 0.3496 Validation Loss: 0.1635, Validation Accuracy: 0.4824 Macro F1: 0.2918, Matthews Correlation Coefficient: 0.2415
# Best Macro F1 achieved: 0.2918
# Saved new best model at epoch 1 with Macro F1: 0.2918
# Epoch [2/250], Training Loss: 0.1555, Training Accuracy: 0.4290 Validation Loss: 0.1489, Validation Accuracy: 0.4750 Macro F1: 0.3566, Matthews Correlation Coefficient: 0.2627
# Best Macro F1 achieved: 0.3566
# Saved new best model at epoch 2 with Macro F1: 0.3566
# Epoch [3/250], Training Loss: 0.1503, Training Accuracy: 0.4485 Validation Loss: 0.1449, Validation Accuracy: 0.5065 Macro F1: 0.3939, Matthews Correlation Coefficient: 0.3166
# Best Macro F1 achieved: 0.3939
# Saved new best model at epoch 3 with Macro F1: 0.3939
# Epoch [4/250], Training Loss: 0.1469, Training Accuracy: 0.4810 Validation Loss: 0.1427, Validation Accuracy: 0.5046 Macro F1: 0.3919, Matthews Correlation Coefficient: 0.3148
# Epoch [5/250], Training Loss: 0.1447, Training Accuracy: 0.4819 Validation Loss: 0.1395, Validation Accuracy: 0.5380 Macro F1: 0.4226, Matthews Correlation Coefficient: 0.3605
# Best Macro F1 achieved: 0.4226
# Saved new best model at epoch 5 with Macro F1: 0.4226
# Epoch [6/250], Training Loss: 0.1413, Training Accuracy: 0.4889 Validation Loss: 0.1389, Validation Accuracy: 0.5158 Macro F1: 0.4018, Matthews Correlation Coefficient: 0.3455
# Epoch [7/250], Training Loss: 0.1420, Training Accuracy: 0.4889 Validation Loss: 0.1371, Validation Accuracy: 0.5195 Macro F1: 0.4056, Matthews Correlation Coefficient: 0.3447
# Epoch [8/250], Training Loss: 0.1411, Training Accuracy: 0.5088 Validation Loss: 0.1386, Validation Accuracy: 0.5121 Macro F1: 0.4165, Matthews Correlation Coefficient: 0.3402
# Epoch [9/250], Training Loss: 0.1404, Training Accuracy: 0.4991 Validation Loss: 0.1383, Validation Accuracy: 0.5083 Macro F1: 0.4273, Matthews Correlation Coefficient: 0.3357
# Best Macro F1 achieved: 0.4273
# Saved new best model at epoch 9 with Macro F1: 0.4273
# Epoch [10/250], Training Loss: 0.1395, Training Accuracy: 0.4963 Validation Loss: 0.1366, Validation Accuracy: 0.5065 Macro F1: 0.4309, Matthews Correlation Coefficient: 0.3278
# Best Macro F1 achieved: 0.4309
# Saved new best model at epoch 10 with Macro F1: 0.4309
# Epoch [11/250], Training Loss: 0.1402, Training Accuracy: 0.4907 Validation Loss: 0.1382, Validation Accuracy: 0.4991 Macro F1: 0.4404, Matthews Correlation Coefficient: 0.3268
# Best Macro F1 achieved: 0.4404
# Saved new best model at epoch 11 with Macro F1: 0.4404
# Epoch [12/250], Training Loss: 0.1391, Training Accuracy: 0.5005 Validation Loss: 0.1361, Validation Accuracy: 0.5121 Macro F1: 0.4565, Matthews Correlation Coefficient: 0.3358
# Best Macro F1 achieved: 0.4565
# Saved new best model at epoch 12 with Macro F1: 0.4565
# Epoch [13/250], Training Loss: 0.1398, Training Accuracy: 0.5097 Validation Loss: 0.1362, Validation Accuracy: 0.5028 Macro F1: 0.4546, Matthews Correlation Coefficient: 0.3282
# Epoch [14/250], Training Loss: 0.1392, Training Accuracy: 0.4991 Validation Loss: 0.1363, Validation Accuracy: 0.5121 Macro F1: 0.4621, Matthews Correlation Coefficient: 0.3389
# Best Macro F1 achieved: 0.4621
# Saved new best model at epoch 14 with Macro F1: 0.4621
# Epoch [15/250], Training Loss: 0.1386, Training Accuracy: 0.5209 Validation Loss: 0.1358, Validation Accuracy: 0.5158 Macro F1: 0.4603, Matthews Correlation Coefficient: 0.3367
# Epoch [16/250], Training Loss: 0.1383, Training Accuracy: 0.5093 Validation Loss: 0.1366, Validation Accuracy: 0.4991 Macro F1: 0.4522, Matthews Correlation Coefficient: 0.3203
# Epoch [17/250], Training Loss: 0.1394, Training Accuracy: 0.5005 Validation Loss: 0.1369, Validation Accuracy: 0.5009 Macro F1: 0.4566, Matthews Correlation Coefficient: 0.3233
# Epoch [18/250], Training Loss: 0.1387, Training Accuracy: 0.5065 Validation Loss: 0.1363, Validation Accuracy: 0.5046 Macro F1: 0.4503, Matthews Correlation Coefficient: 0.3264
# Epoch [19/250], Training Loss: 0.1389, Training Accuracy: 0.5042 Validation Loss: 0.1359, Validation Accuracy: 0.5139 Macro F1: 0.4621, Matthews Correlation Coefficient: 0.3363
# Epoch [20/250], Training Loss: 0.1366, Training Accuracy: 0.5186 Validation Loss: 0.1349, Validation Accuracy: 0.5158 Macro F1: 0.4667, Matthews Correlation Coefficient: 0.3372
# Best Macro F1 achieved: 0.4667
# Saved new best model at epoch 20 with Macro F1: 0.4667
# Epoch [21/250], Training Loss: 0.1378, Training Accuracy: 0.5186 Validation Loss: 0.1346, Validation Accuracy: 0.5158 Macro F1: 0.4640, Matthews Correlation Coefficient: 0.3366
# Epoch [22/250], Training Loss: 0.1379, Training Accuracy: 0.4995 Validation Loss: 0.1358, Validation Accuracy: 0.4991 Macro F1: 0.4645, Matthews Correlation Coefficient: 0.3239
# Epoch [23/250], Training Loss: 0.1378, Training Accuracy: 0.5176 Validation Loss: 0.1353, Validation Accuracy: 0.5102 Macro F1: 0.4614, Matthews Correlation Coefficient: 0.3333
# Epoch [24/250], Training Loss: 0.1384, Training Accuracy: 0.4968 Validation Loss: 0.1347, Validation Accuracy: 0.5158 Macro F1: 0.4635, Matthews Correlation Coefficient: 0.3368
# Epoch [25/250], Training Loss: 0.1373, Training Accuracy: 0.5158 Validation Loss: 0.1350, Validation Accuracy: 0.5139 Macro F1: 0.4652, Matthews Correlation Coefficient: 0.3358
# Epoch [26/250], Training Loss: 0.1384, Training Accuracy: 0.5172 Validation Loss: 0.1361, Validation Accuracy: 0.4972 Macro F1: 0.4633, Matthews Correlation Coefficient: 0.3220
# Epoch [27/250], Training Loss: 0.1388, Training Accuracy: 0.5162 Validation Loss: 0.1351, Validation Accuracy: 0.5046 Macro F1: 0.4628, Matthews Correlation Coefficient: 0.3263
# Epoch [28/250], Training Loss: 0.1373, Training Accuracy: 0.5102 Validation Loss: 0.1345, Validation Accuracy: 0.5139 Macro F1: 0.4711, Matthews Correlation Coefficient: 0.3372
# Best Macro F1 achieved: 0.4711
# Saved new best model at epoch 28 with Macro F1: 0.4711
# Epoch [29/250], Training Loss: 0.1372, Training Accuracy: 0.5056 Validation Loss: 0.1351, Validation Accuracy: 0.5009 Macro F1: 0.4642, Matthews Correlation Coefficient: 0.3240
# Epoch [30/250], Training Loss: 0.1381, Training Accuracy: 0.4995 Validation Loss: 0.1360, Validation Accuracy: 0.5028 Macro F1: 0.4635, Matthews Correlation Coefficient: 0.3268
# Epoch [31/250], Training Loss: 0.1369, Training Accuracy: 0.5121 Validation Loss: 0.1350, Validation Accuracy: 0.5158 Macro F1: 0.4672, Matthews Correlation Coefficient: 0.3390
# Epoch [32/250], Training Loss: 0.1365, Training Accuracy: 0.5084 Validation Loss: 0.1354, Validation Accuracy: 0.5028 Macro F1: 0.4587, Matthews Correlation Coefficient: 0.3238
# Epoch [33/250], Training Loss: 0.1392, Training Accuracy: 0.4986 Validation Loss: 0.1361, Validation Accuracy: 0.4972 Macro F1: 0.4509, Matthews Correlation Coefficient: 0.3165
# Epoch [34/250], Training Loss: 0.1374, Training Accuracy: 0.5102 Validation Loss: 0.1358, Validation Accuracy: 0.5046 Macro F1: 0.4539, Matthews Correlation Coefficient: 0.3255
# Epoch [35/250], Training Loss: 0.1377, Training Accuracy: 0.5144 Validation Loss: 0.1351, Validation Accuracy: 0.5046 Macro F1: 0.4515, Matthews Correlation Coefficient: 0.3244
# Epoch [36/250], Training Loss: 0.1367, Training Accuracy: 0.5209 Validation Loss: 0.1352, Validation Accuracy: 0.5046 Macro F1: 0.4598, Matthews Correlation Coefficient: 0.3259
# Epoch [37/250], Training Loss: 0.1368, Training Accuracy: 0.5070 Validation Loss: 0.1351, Validation Accuracy: 0.5065 Macro F1: 0.4565, Matthews Correlation Coefficient: 0.3272
# Epoch [38/250], Training Loss: 0.1369, Training Accuracy: 0.5162 Validation Loss: 0.1345, Validation Accuracy: 0.5176 Macro F1: 0.4722, Matthews Correlation Coefficient: 0.3391
# Best Macro F1 achieved: 0.4722
# Saved new best model at epoch 38 with Macro F1: 0.4722
# Epoch [39/250], Training Loss: 0.1373, Training Accuracy: 0.5167 Validation Loss: 0.1342, Validation Accuracy: 0.5121 Macro F1: 0.4669, Matthews Correlation Coefficient: 0.3318
# Epoch [40/250], Training Loss: 0.1375, Training Accuracy: 0.5070 Validation Loss: 0.1349, Validation Accuracy: 0.5065 Macro F1: 0.4647, Matthews Correlation Coefficient: 0.3285
# Epoch [41/250], Training Loss: 0.1370, Training Accuracy: 0.5065 Validation Loss: 0.1341, Validation Accuracy: 0.5195 Macro F1: 0.4736, Matthews Correlation Coefficient: 0.3418
# Best Macro F1 achieved: 0.4736
# Saved new best model at epoch 41 with Macro F1: 0.4736
# Epoch [42/250], Training Loss: 0.1367, Training Accuracy: 0.5144 Validation Loss: 0.1343, Validation Accuracy: 0.5083 Macro F1: 0.4577, Matthews Correlation Coefficient: 0.3289
# Epoch [43/250], Training Loss: 0.1374, Training Accuracy: 0.5153 Validation Loss: 0.1351, Validation Accuracy: 0.5083 Macro F1: 0.4728, Matthews Correlation Coefficient: 0.3341
# Epoch [44/250], Training Loss: 0.1368, Training Accuracy: 0.5158 Validation Loss: 0.1346, Validation Accuracy: 0.5232 Macro F1: 0.4759, Matthews Correlation Coefficient: 0.3454
# Best Macro F1 achieved: 0.4759
# Saved new best model at epoch 44 with Macro F1: 0.4759
# Epoch [45/250], Training Loss: 0.1372, Training Accuracy: 0.5088 Validation Loss: 0.1343, Validation Accuracy: 0.5269 Macro F1: 0.4767, Matthews Correlation Coefficient: 0.3487
# Best Macro F1 achieved: 0.4767
# Saved new best model at epoch 45 with Macro F1: 0.4767
# Epoch [46/250], Training Loss: 0.1359, Training Accuracy: 0.5102 Validation Loss: 0.1348, Validation Accuracy: 0.5009 Macro F1: 0.4618, Matthews Correlation Coefficient: 0.3237
# Epoch [47/250], Training Loss: 0.1363, Training Accuracy: 0.5125 Validation Loss: 0.1346, Validation Accuracy: 0.5213 Macro F1: 0.4714, Matthews Correlation Coefficient: 0.3439
# Epoch [48/250], Training Loss: 0.1364, Training Accuracy: 0.5251 Validation Loss: 0.1354, Validation Accuracy: 0.5139 Macro F1: 0.4760, Matthews Correlation Coefficient: 0.3392
# Epoch [49/250], Training Loss: 0.1361, Training Accuracy: 0.5297 Validation Loss: 0.1348, Validation Accuracy: 0.5121 Macro F1: 0.4722, Matthews Correlation Coefficient: 0.3347
# Epoch [50/250], Training Loss: 0.1360, Training Accuracy: 0.5139 Validation Loss: 0.1344, Validation Accuracy: 0.5158 Macro F1: 0.4780, Matthews Correlation Coefficient: 0.3393
# Best Macro F1 achieved: 0.4780
# Saved new best model at epoch 50 with Macro F1: 0.4780
# Epoch [51/250], Training Loss: 0.1364, Training Accuracy: 0.5241 Validation Loss: 0.1346, Validation Accuracy: 0.5232 Macro F1: 0.4859, Matthews Correlation Coefficient: 0.3488
# Best Macro F1 achieved: 0.4859
# Saved new best model at epoch 51 with Macro F1: 0.4859
# Epoch [52/250], Training Loss: 0.1352, Training Accuracy: 0.5223 Validation Loss: 0.1350, Validation Accuracy: 0.5028 Macro F1: 0.4678, Matthews Correlation Coefficient: 0.3274
# Epoch [53/250], Training Loss: 0.1365, Training Accuracy: 0.5079 Validation Loss: 0.1342, Validation Accuracy: 0.5121 Macro F1: 0.4718, Matthews Correlation Coefficient: 0.3352
# Epoch [54/250], Training Loss: 0.1368, Training Accuracy: 0.5084 Validation Loss: 0.1350, Validation Accuracy: 0.5046 Macro F1: 0.4655, Matthews Correlation Coefficient: 0.3262
# Epoch [55/250], Training Loss: 0.1370, Training Accuracy: 0.5251 Validation Loss: 0.1346, Validation Accuracy: 0.5158 Macro F1: 0.4755, Matthews Correlation Coefficient: 0.3395
# Epoch [56/250], Training Loss: 0.1369, Training Accuracy: 0.5116 Validation Loss: 0.1355, Validation Accuracy: 0.5176 Macro F1: 0.4765, Matthews Correlation Coefficient: 0.3420
# Epoch [57/250], Training Loss: 0.1370, Training Accuracy: 0.5153 Validation Loss: 0.1341, Validation Accuracy: 0.5436 Macro F1: 0.4905, Matthews Correlation Coefficient: 0.3682
# Best Macro F1 achieved: 0.4905
# Saved new best model at epoch 57 with Macro F1: 0.4905
# Epoch [58/250], Training Loss: 0.1370, Training Accuracy: 0.4986 Validation Loss: 0.1350, Validation Accuracy: 0.5250 Macro F1: 0.4838, Matthews Correlation Coefficient: 0.3495
# Epoch [59/250], Training Loss: 0.1361, Training Accuracy: 0.5200 Validation Loss: 0.1338, Validation Accuracy: 0.5288 Macro F1: 0.4811, Matthews Correlation Coefficient: 0.3522
# Epoch [60/250], Training Loss: 0.1363, Training Accuracy: 0.5153 Validation Loss: 0.1351, Validation Accuracy: 0.5009 Macro F1: 0.4622, Matthews Correlation Coefficient: 0.3226
# Epoch [61/250], Training Loss: 0.1354, Training Accuracy: 0.5162 Validation Loss: 0.1350, Validation Accuracy: 0.4972 Macro F1: 0.4596, Matthews Correlation Coefficient: 0.3170
# Epoch [62/250], Training Loss: 0.1362, Training Accuracy: 0.5227 Validation Loss: 0.1341, Validation Accuracy: 0.5213 Macro F1: 0.4773, Matthews Correlation Coefficient: 0.3402
# Epoch [63/250], Training Loss: 0.1375, Training Accuracy: 0.5130 Validation Loss: 0.1350, Validation Accuracy: 0.5102 Macro F1: 0.4698, Matthews Correlation Coefficient: 0.3330
# Epoch [64/250], Training Loss: 0.1365, Training Accuracy: 0.5135 Validation Loss: 0.1353, Validation Accuracy: 0.5121 Macro F1: 0.4723, Matthews Correlation Coefficient: 0.3338
# Epoch [65/250], Training Loss: 0.1364, Training Accuracy: 0.5158 Validation Loss: 0.1344, Validation Accuracy: 0.5288 Macro F1: 0.4818, Matthews Correlation Coefficient: 0.3517
# Epoch [66/250], Training Loss: 0.1368, Training Accuracy: 0.5079 Validation Loss: 0.1341, Validation Accuracy: 0.5362 Macro F1: 0.4874, Matthews Correlation Coefficient: 0.3573
# Epoch [67/250], Training Loss: 0.1354, Training Accuracy: 0.5162 Validation Loss: 0.1336, Validation Accuracy: 0.5380 Macro F1: 0.4859, Matthews Correlation Coefficient: 0.3621
# Epoch [68/250], Training Loss: 0.1355, Training Accuracy: 0.5162 Validation Loss: 0.1334, Validation Accuracy: 0.5417 Macro F1: 0.4898, Matthews Correlation Coefficient: 0.3640
# Epoch [69/250], Training Loss: 0.1348, Training Accuracy: 0.5260 Validation Loss: 0.1352, Validation Accuracy: 0.5065 Macro F1: 0.4647, Matthews Correlation Coefficient: 0.3294
# Epoch [70/250], Training Loss: 0.1364, Training Accuracy: 0.5121 Validation Loss: 0.1341, Validation Accuracy: 0.5343 Macro F1: 0.4830, Matthews Correlation Coefficient: 0.3558
# Epoch [71/250], Training Loss: 0.1349, Training Accuracy: 0.5269 Validation Loss: 0.1343, Validation Accuracy: 0.5343 Macro F1: 0.4887, Matthews Correlation Coefficient: 0.3578
# Epoch [72/250], Training Loss: 0.1358, Training Accuracy: 0.5223 Validation Loss: 0.1340, Validation Accuracy: 0.5343 Macro F1: 0.4886, Matthews Correlation Coefficient: 0.3565
# Epoch [73/250], Training Loss: 0.1351, Training Accuracy: 0.5283 Validation Loss: 0.1343, Validation Accuracy: 0.5306 Macro F1: 0.4829, Matthews Correlation Coefficient: 0.3527
# Epoch [74/250], Training Loss: 0.1355, Training Accuracy: 0.5195 Validation Loss: 0.1349, Validation Accuracy: 0.5176 Macro F1: 0.4687, Matthews Correlation Coefficient: 0.3379
# Epoch [75/250], Training Loss: 0.1367, Training Accuracy: 0.5186 Validation Loss: 0.1342, Validation Accuracy: 0.5250 Macro F1: 0.4788, Matthews Correlation Coefficient: 0.3462
# Epoch [76/250], Training Loss: 0.1356, Training Accuracy: 0.5172 Validation Loss: 0.1345, Validation Accuracy: 0.5102 Macro F1: 0.4661, Matthews Correlation Coefficient: 0.3287
# Epoch [77/250], Training Loss: 0.1352, Training Accuracy: 0.5241 Validation Loss: 0.1350, Validation Accuracy: 0.5250 Macro F1: 0.4782, Matthews Correlation Coefficient: 0.3454
# Epoch [78/250], Training Loss: 0.1357, Training Accuracy: 0.5135 Validation Loss: 0.1343, Validation Accuracy: 0.5121 Macro F1: 0.4699, Matthews Correlation Coefficient: 0.3314
# Epoch [79/250], Training Loss: 0.1348, Training Accuracy: 0.5283 Validation Loss: 0.1328, Validation Accuracy: 0.5473 Macro F1: 0.4950, Matthews Correlation Coefficient: 0.3701
# Best Macro F1 achieved: 0.4950
# Saved new best model at epoch 79 with Macro F1: 0.4950
# Epoch [80/250], Training Loss: 0.1350, Training Accuracy: 0.5241 Validation Loss: 0.1357, Validation Accuracy: 0.5213 Macro F1: 0.4826, Matthews Correlation Coefficient: 0.3454
# Epoch [81/250], Training Loss: 0.1352, Training Accuracy: 0.5367 Validation Loss: 0.1347, Validation Accuracy: 0.5232 Macro F1: 0.4760, Matthews Correlation Coefficient: 0.3426
# Epoch [82/250], Training Loss: 0.1353, Training Accuracy: 0.5084 Validation Loss: 0.1341, Validation Accuracy: 0.5176 Macro F1: 0.4656, Matthews Correlation Coefficient: 0.3371
# Epoch [83/250], Training Loss: 0.1355, Training Accuracy: 0.5288 Validation Loss: 0.1337, Validation Accuracy: 0.5306 Macro F1: 0.4831, Matthews Correlation Coefficient: 0.3538
# Epoch [84/250], Training Loss: 0.1367, Training Accuracy: 0.5139 Validation Loss: 0.1342, Validation Accuracy: 0.5473 Macro F1: 0.4979, Matthews Correlation Coefficient: 0.3719
# Best Macro F1 achieved: 0.4979
# Saved new best model at epoch 84 with Macro F1: 0.4979
# Epoch [85/250], Training Loss: 0.1366, Training Accuracy: 0.5204 Validation Loss: 0.1341, Validation Accuracy: 0.5436 Macro F1: 0.4890, Matthews Correlation Coefficient: 0.3684
# Epoch [86/250], Training Loss: 0.1346, Training Accuracy: 0.5348 Validation Loss: 0.1340, Validation Accuracy: 0.5380 Macro F1: 0.4768, Matthews Correlation Coefficient: 0.3601
# Epoch [87/250], Training Loss: 0.1353, Training Accuracy: 0.5139 Validation Loss: 0.1341, Validation Accuracy: 0.5306 Macro F1: 0.4773, Matthews Correlation Coefficient: 0.3514
# Epoch [88/250], Training Loss: 0.1365, Training Accuracy: 0.5181 Validation Loss: 0.1340, Validation Accuracy: 0.5473 Macro F1: 0.4931, Matthews Correlation Coefficient: 0.3701
# Epoch [89/250], Training Loss: 0.1358, Training Accuracy: 0.5255 Validation Loss: 0.1343, Validation Accuracy: 0.5343 Macro F1: 0.4804, Matthews Correlation Coefficient: 0.3537
# Epoch [90/250], Training Loss: 0.1355, Training Accuracy: 0.5079 Validation Loss: 0.1340, Validation Accuracy: 0.5306 Macro F1: 0.4797, Matthews Correlation Coefficient: 0.3533
# Epoch [91/250], Training Loss: 0.1363, Training Accuracy: 0.5195 Validation Loss: 0.1341, Validation Accuracy: 0.5455 Macro F1: 0.4932, Matthews Correlation Coefficient: 0.3679
# Epoch [92/250], Training Loss: 0.1345, Training Accuracy: 0.5292 Validation Loss: 0.1335, Validation Accuracy: 0.5399 Macro F1: 0.4842, Matthews Correlation Coefficient: 0.3626
# Epoch [93/250], Training Loss: 0.1349, Training Accuracy: 0.5297 Validation Loss: 0.1346, Validation Accuracy: 0.5269 Macro F1: 0.4736, Matthews Correlation Coefficient: 0.3457
# Epoch [94/250], Training Loss: 0.1338, Training Accuracy: 0.5325 Validation Loss: 0.1330, Validation Accuracy: 0.5417 Macro F1: 0.4933, Matthews Correlation Coefficient: 0.3632
# Epoch [95/250], Training Loss: 0.1344, Training Accuracy: 0.5302 Validation Loss: 0.1339, Validation Accuracy: 0.5492 Macro F1: 0.4950, Matthews Correlation Coefficient: 0.3698
# Epoch [96/250], Training Loss: 0.1362, Training Accuracy: 0.5255 Validation Loss: 0.1343, Validation Accuracy: 0.5455 Macro F1: 0.4975, Matthews Correlation Coefficient: 0.3687
# Epoch [97/250], Training Loss: 0.1361, Training Accuracy: 0.5093 Validation Loss: 0.1333, Validation Accuracy: 0.5566 Macro F1: 0.4998, Matthews Correlation Coefficient: 0.3802
# Best Macro F1 achieved: 0.4998
# Saved new best model at epoch 97 with Macro F1: 0.4998
# Epoch [98/250], Training Loss: 0.1360, Training Accuracy: 0.5190 Validation Loss: 0.1339, Validation Accuracy: 0.5417 Macro F1: 0.4868, Matthews Correlation Coefficient: 0.3639
# Epoch [99/250], Training Loss: 0.1364, Training Accuracy: 0.5302 Validation Loss: 0.1339, Validation Accuracy: 0.5399 Macro F1: 0.4887, Matthews Correlation Coefficient: 0.3627
# Epoch [100/250], Training Loss: 0.1351, Training Accuracy: 0.5181 Validation Loss: 0.1341, Validation Accuracy: 0.5269 Macro F1: 0.4743, Matthews Correlation Coefficient: 0.3471
# Epoch [101/250], Training Loss: 0.1353, Training Accuracy: 0.5214 Validation Loss: 0.1336, Validation Accuracy: 0.5455 Macro F1: 0.4924, Matthews Correlation Coefficient: 0.3690
# Epoch [102/250], Training Loss: 0.1347, Training Accuracy: 0.5181 Validation Loss: 0.1350, Validation Accuracy: 0.5139 Macro F1: 0.4656, Matthews Correlation Coefficient: 0.3340
# Epoch [103/250], Training Loss: 0.1353, Training Accuracy: 0.5190 Validation Loss: 0.1343, Validation Accuracy: 0.5399 Macro F1: 0.4852, Matthews Correlation Coefficient: 0.3604
# Epoch [104/250], Training Loss: 0.1353, Training Accuracy: 0.5144 Validation Loss: 0.1348, Validation Accuracy: 0.5306 Macro F1: 0.4806, Matthews Correlation Coefficient: 0.3508
# Epoch [105/250], Training Loss: 0.1345, Training Accuracy: 0.5339 Validation Loss: 0.1353, Validation Accuracy: 0.5232 Macro F1: 0.4764, Matthews Correlation Coefficient: 0.3435
# Epoch [106/250], Training Loss: 0.1346, Training Accuracy: 0.5181 Validation Loss: 0.1338, Validation Accuracy: 0.5380 Macro F1: 0.4863, Matthews Correlation Coefficient: 0.3571
# Epoch [107/250], Training Loss: 0.1352, Training Accuracy: 0.5158 Validation Loss: 0.1353, Validation Accuracy: 0.5176 Macro F1: 0.4662, Matthews Correlation Coefficient: 0.3355
# Epoch [108/250], Training Loss: 0.1352, Training Accuracy: 0.5162 Validation Loss: 0.1352, Validation Accuracy: 0.5213 Macro F1: 0.4726, Matthews Correlation Coefficient: 0.3392
# Epoch [109/250], Training Loss: 0.1360, Training Accuracy: 0.5237 Validation Loss: 0.1344, Validation Accuracy: 0.5362 Macro F1: 0.4816, Matthews Correlation Coefficient: 0.3562
# Epoch [110/250], Training Loss: 0.1343, Training Accuracy: 0.5241 Validation Loss: 0.1337, Validation Accuracy: 0.5325 Macro F1: 0.4846, Matthews Correlation Coefficient: 0.3532
# Epoch [111/250], Training Loss: 0.1353, Training Accuracy: 0.5135 Validation Loss: 0.1336, Validation Accuracy: 0.5306 Macro F1: 0.4769, Matthews Correlation Coefficient: 0.3517
# Epoch [112/250], Training Loss: 0.1343, Training Accuracy: 0.5302 Validation Loss: 0.1335, Validation Accuracy: 0.5380 Macro F1: 0.4842, Matthews Correlation Coefficient: 0.3567
# Epoch [113/250], Training Loss: 0.1345, Training Accuracy: 0.5269 Validation Loss: 0.1340, Validation Accuracy: 0.5436 Macro F1: 0.4906, Matthews Correlation Coefficient: 0.3662
# Epoch [114/250], Training Loss: 0.1348, Training Accuracy: 0.5274 Validation Loss: 0.1344, Validation Accuracy: 0.5250 Macro F1: 0.4787, Matthews Correlation Coefficient: 0.3476
# Epoch [115/250], Training Loss: 0.1340, Training Accuracy: 0.5204 Validation Loss: 0.1334, Validation Accuracy: 0.5306 Macro F1: 0.4804, Matthews Correlation Coefficient: 0.3516
# Epoch [116/250], Training Loss: 0.1347, Training Accuracy: 0.5218 Validation Loss: 0.1339, Validation Accuracy: 0.5325 Macro F1: 0.4758, Matthews Correlation Coefficient: 0.3481
# Epoch [117/250], Training Loss: 0.1362, Training Accuracy: 0.5186 Validation Loss: 0.1339, Validation Accuracy: 0.5288 Macro F1: 0.4789, Matthews Correlation Coefficient: 0.3501
# Epoch [118/250], Training Loss: 0.1356, Training Accuracy: 0.5306 Validation Loss: 0.1340, Validation Accuracy: 0.5380 Macro F1: 0.4868, Matthews Correlation Coefficient: 0.3594
# Epoch [119/250], Training Loss: 0.1362, Training Accuracy: 0.5204 Validation Loss: 0.1339, Validation Accuracy: 0.5250 Macro F1: 0.4762, Matthews Correlation Coefficient: 0.3455
# Epoch [120/250], Training Loss: 0.1353, Training Accuracy: 0.5241 Validation Loss: 0.1345, Validation Accuracy: 0.5269 Macro F1: 0.4771, Matthews Correlation Coefficient: 0.3446
# Epoch [121/250], Training Loss: 0.1358, Training Accuracy: 0.5246 Validation Loss: 0.1339, Validation Accuracy: 0.5399 Macro F1: 0.4854, Matthews Correlation Coefficient: 0.3628
# Epoch [122/250], Training Loss: 0.1356, Training Accuracy: 0.5320 Validation Loss: 0.1343, Validation Accuracy: 0.5399 Macro F1: 0.4851, Matthews Correlation Coefficient: 0.3605
# Epoch [123/250], Training Loss: 0.1349, Training Accuracy: 0.5227 Validation Loss: 0.1335, Validation Accuracy: 0.5399 Macro F1: 0.4853, Matthews Correlation Coefficient: 0.3562
# Epoch [124/250], Training Loss: 0.1335, Training Accuracy: 0.5204 Validation Loss: 0.1344, Validation Accuracy: 0.5269 Macro F1: 0.4766, Matthews Correlation Coefficient: 0.3501
# Epoch [125/250], Training Loss: 0.1348, Training Accuracy: 0.5241 Validation Loss: 0.1345, Validation Accuracy: 0.5325 Macro F1: 0.4819, Matthews Correlation Coefficient: 0.3534
# Epoch [126/250], Training Loss: 0.1341, Training Accuracy: 0.5241 Validation Loss: 0.1346, Validation Accuracy: 0.5362 Macro F1: 0.4845, Matthews Correlation Coefficient: 0.3571
# Epoch [127/250], Training Loss: 0.1354, Training Accuracy: 0.5241 Validation Loss: 0.1338, Validation Accuracy: 0.5529 Macro F1: 0.4925, Matthews Correlation Coefficient: 0.3721
# Epoch [128/250], Training Loss: 0.1352, Training Accuracy: 0.5320 Validation Loss: 0.1342, Validation Accuracy: 0.5417 Macro F1: 0.4874, Matthews Correlation Coefficient: 0.3642
# Epoch [129/250], Training Loss: 0.1350, Training Accuracy: 0.5320 Validation Loss: 0.1345, Validation Accuracy: 0.5399 Macro F1: 0.4817, Matthews Correlation Coefficient: 0.3612
# Epoch [130/250], Training Loss: 0.1350, Training Accuracy: 0.5357 Validation Loss: 0.1344, Validation Accuracy: 0.5399 Macro F1: 0.4855, Matthews Correlation Coefficient: 0.3595
# Epoch [131/250], Training Loss: 0.1336, Training Accuracy: 0.5357 Validation Loss: 0.1344, Validation Accuracy: 0.5343 Macro F1: 0.4768, Matthews Correlation Coefficient: 0.3530
# Epoch [132/250], Training Loss: 0.1344, Training Accuracy: 0.5149 Validation Loss: 0.1347, Validation Accuracy: 0.5325 Macro F1: 0.4754, Matthews Correlation Coefficient: 0.3546
# Epoch [133/250], Training Loss: 0.1344, Training Accuracy: 0.5190 Validation Loss: 0.1354, Validation Accuracy: 0.5158 Macro F1: 0.4679, Matthews Correlation Coefficient: 0.3384
# Epoch [134/250], Training Loss: 0.1346, Training Accuracy: 0.5218 Validation Loss: 0.1337, Validation Accuracy: 0.5380 Macro F1: 0.4863, Matthews Correlation Coefficient: 0.3619
# Epoch [135/250], Training Loss: 0.1339, Training Accuracy: 0.5297 Validation Loss: 0.1339, Validation Accuracy: 0.5380 Macro F1: 0.4859, Matthews Correlation Coefficient: 0.3598
# Epoch [136/250], Training Loss: 0.1343, Training Accuracy: 0.5204 Validation Loss: 0.1356, Validation Accuracy: 0.5213 Macro F1: 0.4751, Matthews Correlation Coefficient: 0.3484
# Epoch [137/250], Training Loss: 0.1348, Training Accuracy: 0.5311 Validation Loss: 0.1340, Validation Accuracy: 0.5362 Macro F1: 0.4895, Matthews Correlation Coefficient: 0.3592
# Epoch [138/250], Training Loss: 0.1346, Training Accuracy: 0.5181 Validation Loss: 0.1336, Validation Accuracy: 0.5288 Macro F1: 0.4790, Matthews Correlation Coefficient: 0.3517
# Epoch [139/250], Training Loss: 0.1351, Training Accuracy: 0.5162 Validation Loss: 0.1332, Validation Accuracy: 0.5380 Macro F1: 0.4868, Matthews Correlation Coefficient: 0.3586
# Epoch [140/250], Training Loss: 0.1332, Training Accuracy: 0.5344 Validation Loss: 0.1334, Validation Accuracy: 0.5362 Macro F1: 0.4936, Matthews Correlation Coefficient: 0.3605
# Epoch [141/250], Training Loss: 0.1343, Training Accuracy: 0.5260 Validation Loss: 0.1343, Validation Accuracy: 0.5288 Macro F1: 0.4760, Matthews Correlation Coefficient: 0.3504
# Epoch [142/250], Training Loss: 0.1352, Training Accuracy: 0.5237 Validation Loss: 0.1335, Validation Accuracy: 0.5325 Macro F1: 0.4789, Matthews Correlation Coefficient: 0.3507
# Epoch [143/250], Training Loss: 0.1348, Training Accuracy: 0.5116 Validation Loss: 0.1344, Validation Accuracy: 0.5139 Macro F1: 0.4717, Matthews Correlation Coefficient: 0.3343
# Epoch [144/250], Training Loss: 0.1341, Training Accuracy: 0.5325 Validation Loss: 0.1340, Validation Accuracy: 0.5250 Macro F1: 0.4725, Matthews Correlation Coefficient: 0.3467
# Epoch [145/250], Training Loss: 0.1341, Training Accuracy: 0.5186 Validation Loss: 0.1343, Validation Accuracy: 0.5288 Macro F1: 0.4755, Matthews Correlation Coefficient: 0.3480
# Epoch [146/250], Training Loss: 0.1336, Training Accuracy: 0.5283 Validation Loss: 0.1345, Validation Accuracy: 0.5195 Macro F1: 0.4647, Matthews Correlation Coefficient: 0.3404
# Epoch [147/250], Training Loss: 0.1341, Training Accuracy: 0.5371 Validation Loss: 0.1334, Validation Accuracy: 0.5380 Macro F1: 0.4847, Matthews Correlation Coefficient: 0.3569
# Epoch [148/250], Training Loss: 0.1343, Training Accuracy: 0.5334 Validation Loss: 0.1338, Validation Accuracy: 0.5158 Macro F1: 0.4713, Matthews Correlation Coefficient: 0.3351
# Epoch [149/250], Training Loss: 0.1335, Training Accuracy: 0.5339 Validation Loss: 0.1326, Validation Accuracy: 0.5473 Macro F1: 0.4917, Matthews Correlation Coefficient: 0.3669
# Epoch [150/250], Training Loss: 0.1343, Training Accuracy: 0.5181 Validation Loss: 0.1337, Validation Accuracy: 0.5380 Macro F1: 0.4865, Matthews Correlation Coefficient: 0.3594
# Epoch [151/250], Training Loss: 0.1344, Training Accuracy: 0.5237 Validation Loss: 0.1343, Validation Accuracy: 0.5380 Macro F1: 0.4809, Matthews Correlation Coefficient: 0.3563
# Epoch [152/250], Training Loss: 0.1332, Training Accuracy: 0.5385 Validation Loss: 0.1338, Validation Accuracy: 0.5306 Macro F1: 0.4713, Matthews Correlation Coefficient: 0.3489
# Epoch [153/250], Training Loss: 0.1336, Training Accuracy: 0.5325 Validation Loss: 0.1341, Validation Accuracy: 0.5232 Macro F1: 0.4619, Matthews Correlation Coefficient: 0.3410
# Epoch [154/250], Training Loss: 0.1341, Training Accuracy: 0.5237 Validation Loss: 0.1347, Validation Accuracy: 0.5325 Macro F1: 0.4727, Matthews Correlation Coefficient: 0.3499
# Epoch [155/250], Training Loss: 0.1341, Training Accuracy: 0.5376 Validation Loss: 0.1344, Validation Accuracy: 0.5325 Macro F1: 0.4762, Matthews Correlation Coefficient: 0.3511
# Epoch [156/250], Training Loss: 0.1350, Training Accuracy: 0.5227 Validation Loss: 0.1341, Validation Accuracy: 0.5269 Macro F1: 0.4793, Matthews Correlation Coefficient: 0.3443
# Epoch [157/250], Training Loss: 0.1356, Training Accuracy: 0.5190 Validation Loss: 0.1343, Validation Accuracy: 0.5288 Macro F1: 0.4697, Matthews Correlation Coefficient: 0.3450
# Epoch [158/250], Training Loss: 0.1352, Training Accuracy: 0.5149 Validation Loss: 0.1339, Validation Accuracy: 0.5455 Macro F1: 0.4832, Matthews Correlation Coefficient: 0.3643
# Epoch [159/250], Training Loss: 0.1335, Training Accuracy: 0.5306 Validation Loss: 0.1345, Validation Accuracy: 0.5195 Macro F1: 0.4619, Matthews Correlation Coefficient: 0.3385
# Epoch [160/250], Training Loss: 0.1348, Training Accuracy: 0.5237 Validation Loss: 0.1344, Validation Accuracy: 0.5213 Macro F1: 0.4702, Matthews Correlation Coefficient: 0.3393
# Epoch [161/250], Training Loss: 0.1346, Training Accuracy: 0.5302 Validation Loss: 0.1332, Validation Accuracy: 0.5455 Macro F1: 0.4914, Matthews Correlation Coefficient: 0.3656
# Epoch [162/250], Training Loss: 0.1328, Training Accuracy: 0.5357 Validation Loss: 0.1352, Validation Accuracy: 0.5121 Macro F1: 0.4581, Matthews Correlation Coefficient: 0.3275
# Epoch [163/250], Training Loss: 0.1348, Training Accuracy: 0.5283 Validation Loss: 0.1331, Validation Accuracy: 0.5232 Macro F1: 0.4727, Matthews Correlation Coefficient: 0.3412
# Epoch [164/250], Training Loss: 0.1345, Training Accuracy: 0.5218 Validation Loss: 0.1352, Validation Accuracy: 0.5139 Macro F1: 0.4656, Matthews Correlation Coefficient: 0.3372
# Epoch [165/250], Training Loss: 0.1345, Training Accuracy: 0.5204 Validation Loss: 0.1339, Validation Accuracy: 0.5288 Macro F1: 0.4793, Matthews Correlation Coefficient: 0.3494
# Epoch [166/250], Training Loss: 0.1340, Training Accuracy: 0.5269 Validation Loss: 0.1333, Validation Accuracy: 0.5232 Macro F1: 0.4698, Matthews Correlation Coefficient: 0.3390
# Epoch [167/250], Training Loss: 0.1336, Training Accuracy: 0.5214 Validation Loss: 0.1348, Validation Accuracy: 0.5195 Macro F1: 0.4624, Matthews Correlation Coefficient: 0.3368
# Epoch [168/250], Training Loss: 0.1340, Training Accuracy: 0.5316 Validation Loss: 0.1342, Validation Accuracy: 0.5213 Macro F1: 0.4717, Matthews Correlation Coefficient: 0.3400
# Epoch [169/250], Training Loss: 0.1328, Training Accuracy: 0.5297 Validation Loss: 0.1344, Validation Accuracy: 0.5195 Macro F1: 0.4624, Matthews Correlation Coefficient: 0.3387
# Epoch [170/250], Training Loss: 0.1326, Training Accuracy: 0.5367 Validation Loss: 0.1334, Validation Accuracy: 0.5325 Macro F1: 0.4832, Matthews Correlation Coefficient: 0.3513
# Epoch [171/250], Training Loss: 0.1339, Training Accuracy: 0.5255 Validation Loss: 0.1339, Validation Accuracy: 0.5399 Macro F1: 0.4899, Matthews Correlation Coefficient: 0.3599
# Epoch [172/250], Training Loss: 0.1340, Training Accuracy: 0.5325 Validation Loss: 0.1342, Validation Accuracy: 0.5269 Macro F1: 0.4646, Matthews Correlation Coefficient: 0.3448
# Epoch [173/250], Training Loss: 0.1335, Training Accuracy: 0.5251 Validation Loss: 0.1336, Validation Accuracy: 0.5399 Macro F1: 0.4838, Matthews Correlation Coefficient: 0.3581
# Epoch [174/250], Training Loss: 0.1348, Training Accuracy: 0.5130 Validation Loss: 0.1353, Validation Accuracy: 0.5250 Macro F1: 0.4668, Matthews Correlation Coefficient: 0.3417
# Epoch [175/250], Training Loss: 0.1346, Training Accuracy: 0.5218 Validation Loss: 0.1336, Validation Accuracy: 0.5325 Macro F1: 0.4808, Matthews Correlation Coefficient: 0.3493
# Epoch [176/250], Training Loss: 0.1344, Training Accuracy: 0.5269 Validation Loss: 0.1337, Validation Accuracy: 0.5250 Macro F1: 0.4668, Matthews Correlation Coefficient: 0.3445
# Epoch [177/250], Training Loss: 0.1338, Training Accuracy: 0.5371 Validation Loss: 0.1328, Validation Accuracy: 0.5455 Macro F1: 0.4871, Matthews Correlation Coefficient: 0.3603
# Epoch [178/250], Training Loss: 0.1334, Training Accuracy: 0.5288 Validation Loss: 0.1343, Validation Accuracy: 0.5232 Macro F1: 0.4651, Matthews Correlation Coefficient: 0.3421
# Epoch [179/250], Training Loss: 0.1351, Training Accuracy: 0.5227 Validation Loss: 0.1342, Validation Accuracy: 0.5213 Macro F1: 0.4638, Matthews Correlation Coefficient: 0.3375
# Epoch [180/250], Training Loss: 0.1342, Training Accuracy: 0.5297 Validation Loss: 0.1331, Validation Accuracy: 0.5306 Macro F1: 0.4750, Matthews Correlation Coefficient: 0.3460
# Epoch [181/250], Training Loss: 0.1331, Training Accuracy: 0.5269 Validation Loss: 0.1338, Validation Accuracy: 0.5195 Macro F1: 0.4650, Matthews Correlation Coefficient: 0.3439
# Epoch [182/250], Training Loss: 0.1329, Training Accuracy: 0.5269 Validation Loss: 0.1342, Validation Accuracy: 0.5250 Macro F1: 0.4705, Matthews Correlation Coefficient: 0.3410
# Epoch [183/250], Training Loss: 0.1335, Training Accuracy: 0.5209 Validation Loss: 0.1332, Validation Accuracy: 0.5269 Macro F1: 0.4738, Matthews Correlation Coefficient: 0.3422
# Epoch [184/250], Training Loss: 0.1324, Training Accuracy: 0.5195 Validation Loss: 0.1334, Validation Accuracy: 0.5343 Macro F1: 0.4745, Matthews Correlation Coefficient: 0.3520
# Epoch [185/250], Training Loss: 0.1317, Training Accuracy: 0.5297 Validation Loss: 0.1321, Validation Accuracy: 0.5380 Macro F1: 0.4849, Matthews Correlation Coefficient: 0.3545
# Epoch [186/250], Training Loss: 0.1340, Training Accuracy: 0.5246 Validation Loss: 0.1337, Validation Accuracy: 0.5121 Macro F1: 0.4690, Matthews Correlation Coefficient: 0.3333
# Epoch [187/250], Training Loss: 0.1335, Training Accuracy: 0.5316 Validation Loss: 0.1324, Validation Accuracy: 0.5362 Macro F1: 0.4857, Matthews Correlation Coefficient: 0.3545
# Epoch [188/250], Training Loss: 0.1334, Training Accuracy: 0.5283 Validation Loss: 0.1336, Validation Accuracy: 0.5269 Macro F1: 0.4818, Matthews Correlation Coefficient: 0.3506
# Epoch [189/250], Training Loss: 0.1343, Training Accuracy: 0.5251 Validation Loss: 0.1328, Validation Accuracy: 0.5417 Macro F1: 0.4902, Matthews Correlation Coefficient: 0.3636
# Epoch [190/250], Training Loss: 0.1348, Training Accuracy: 0.5204 Validation Loss: 0.1324, Validation Accuracy: 0.5325 Macro F1: 0.4751, Matthews Correlation Coefficient: 0.3493
# Epoch [191/250], Training Loss: 0.1327, Training Accuracy: 0.5306 Validation Loss: 0.1334, Validation Accuracy: 0.5232 Macro F1: 0.4725, Matthews Correlation Coefficient: 0.3396
# Epoch [192/250], Training Loss: 0.1337, Training Accuracy: 0.5246 Validation Loss: 0.1345, Validation Accuracy: 0.5288 Macro F1: 0.4801, Matthews Correlation Coefficient: 0.3510
# Epoch [193/250], Training Loss: 0.1332, Training Accuracy: 0.5255 Validation Loss: 0.1324, Validation Accuracy: 0.5436 Macro F1: 0.4856, Matthews Correlation Coefficient: 0.3609
# Epoch [194/250], Training Loss: 0.1338, Training Accuracy: 0.5325 Validation Loss: 0.1339, Validation Accuracy: 0.5417 Macro F1: 0.4944, Matthews Correlation Coefficient: 0.3603
# Epoch [195/250], Training Loss: 0.1343, Training Accuracy: 0.5167 Validation Loss: 0.1343, Validation Accuracy: 0.5362 Macro F1: 0.4838, Matthews Correlation Coefficient: 0.3551
# Epoch [196/250], Training Loss: 0.1337, Training Accuracy: 0.5246 Validation Loss: 0.1342, Validation Accuracy: 0.5380 Macro F1: 0.4828, Matthews Correlation Coefficient: 0.3552
# Epoch [197/250], Training Loss: 0.1333, Training Accuracy: 0.5214 Validation Loss: 0.1339, Validation Accuracy: 0.5232 Macro F1: 0.4623, Matthews Correlation Coefficient: 0.3332
# Epoch [198/250], Training Loss: 0.1344, Training Accuracy: 0.5348 Validation Loss: 0.1336, Validation Accuracy: 0.5399 Macro F1: 0.4756, Matthews Correlation Coefficient: 0.3552
# Epoch [199/250], Training Loss: 0.1355, Training Accuracy: 0.5237 Validation Loss: 0.1341, Validation Accuracy: 0.5399 Macro F1: 0.4760, Matthews Correlation Coefficient: 0.3553
# Epoch [200/250], Training Loss: 0.1338, Training Accuracy: 0.5251 Validation Loss: 0.1339, Validation Accuracy: 0.5380 Macro F1: 0.4780, Matthews Correlation Coefficient: 0.3521
# Epoch [201/250], Training Loss: 0.1330, Training Accuracy: 0.5325 Validation Loss: 0.1336, Validation Accuracy: 0.5399 Macro F1: 0.4754, Matthews Correlation Coefficient: 0.3562
# Epoch [202/250], Training Loss: 0.1334, Training Accuracy: 0.5413 Validation Loss: 0.1335, Validation Accuracy: 0.5343 Macro F1: 0.4739, Matthews Correlation Coefficient: 0.3475
# Epoch [203/250], Training Loss: 0.1346, Training Accuracy: 0.5162 Validation Loss: 0.1338, Validation Accuracy: 0.5176 Macro F1: 0.4529, Matthews Correlation Coefficient: 0.3302
# Epoch [204/250], Training Loss: 0.1330, Training Accuracy: 0.5260 Validation Loss: 0.1348, Validation Accuracy: 0.5269 Macro F1: 0.4687, Matthews Correlation Coefficient: 0.3486
# Epoch [205/250], Training Loss: 0.1324, Training Accuracy: 0.5418 Validation Loss: 0.1325, Validation Accuracy: 0.5436 Macro F1: 0.4880, Matthews Correlation Coefficient: 0.3564
# Epoch [206/250], Training Loss: 0.1334, Training Accuracy: 0.5353 Validation Loss: 0.1337, Validation Accuracy: 0.5158 Macro F1: 0.4618, Matthews Correlation Coefficient: 0.3289
# Epoch [207/250], Training Loss: 0.1338, Training Accuracy: 0.5325 Validation Loss: 0.1339, Validation Accuracy: 0.5269 Macro F1: 0.4759, Matthews Correlation Coefficient: 0.3451
# Epoch [208/250], Training Loss: 0.1333, Training Accuracy: 0.5381 Validation Loss: 0.1338, Validation Accuracy: 0.5362 Macro F1: 0.4797, Matthews Correlation Coefficient: 0.3545
# Epoch [209/250], Training Loss: 0.1332, Training Accuracy: 0.5274 Validation Loss: 0.1339, Validation Accuracy: 0.5362 Macro F1: 0.4832, Matthews Correlation Coefficient: 0.3551
# Epoch [210/250], Training Loss: 0.1333, Training Accuracy: 0.5283 Validation Loss: 0.1337, Validation Accuracy: 0.5380 Macro F1: 0.4733, Matthews Correlation Coefficient: 0.3569
# Epoch [211/250], Training Loss: 0.1336, Training Accuracy: 0.5297 Validation Loss: 0.1346, Validation Accuracy: 0.5325 Macro F1: 0.4800, Matthews Correlation Coefficient: 0.3529
# Epoch [212/250], Training Loss: 0.1329, Training Accuracy: 0.5316 Validation Loss: 0.1337, Validation Accuracy: 0.5213 Macro F1: 0.4728, Matthews Correlation Coefficient: 0.3367
# Epoch [213/250], Training Loss: 0.1334, Training Accuracy: 0.5418 Validation Loss: 0.1339, Validation Accuracy: 0.5232 Macro F1: 0.4750, Matthews Correlation Coefficient: 0.3396
# Epoch [214/250], Training Loss: 0.1340, Training Accuracy: 0.5255 Validation Loss: 0.1321, Validation Accuracy: 0.5436 Macro F1: 0.4840, Matthews Correlation Coefficient: 0.3603
# Epoch [215/250], Training Loss: 0.1330, Training Accuracy: 0.5395 Validation Loss: 0.1333, Validation Accuracy: 0.5250 Macro F1: 0.4816, Matthews Correlation Coefficient: 0.3420
# Epoch [216/250], Training Loss: 0.1341, Training Accuracy: 0.5209 Validation Loss: 0.1341, Validation Accuracy: 0.5306 Macro F1: 0.4749, Matthews Correlation Coefficient: 0.3473
# Epoch [217/250], Training Loss: 0.1333, Training Accuracy: 0.5339 Validation Loss: 0.1328, Validation Accuracy: 0.5399 Macro F1: 0.4886, Matthews Correlation Coefficient: 0.3587
# Epoch [218/250], Training Loss: 0.1329, Training Accuracy: 0.5311 Validation Loss: 0.1329, Validation Accuracy: 0.5325 Macro F1: 0.4825, Matthews Correlation Coefficient: 0.3508
# Epoch [219/250], Training Loss: 0.1325, Training Accuracy: 0.5274 Validation Loss: 0.1327, Validation Accuracy: 0.5213 Macro F1: 0.4747, Matthews Correlation Coefficient: 0.3382
# Epoch [220/250], Training Loss: 0.1331, Training Accuracy: 0.5339 Validation Loss: 0.1322, Validation Accuracy: 0.5362 Macro F1: 0.4869, Matthews Correlation Coefficient: 0.3543
# Epoch [221/250], Training Loss: 0.1334, Training Accuracy: 0.5357 Validation Loss: 0.1340, Validation Accuracy: 0.5362 Macro F1: 0.4893, Matthews Correlation Coefficient: 0.3551
# Epoch [222/250], Training Loss: 0.1319, Training Accuracy: 0.5330 Validation Loss: 0.1332, Validation Accuracy: 0.5306 Macro F1: 0.4787, Matthews Correlation Coefficient: 0.3478
# Epoch [223/250], Training Loss: 0.1326, Training Accuracy: 0.5371 Validation Loss: 0.1344, Validation Accuracy: 0.5417 Macro F1: 0.4918, Matthews Correlation Coefficient: 0.3624
# Epoch [224/250], Training Loss: 0.1329, Training Accuracy: 0.5297 Validation Loss: 0.1335, Validation Accuracy: 0.5121 Macro F1: 0.4597, Matthews Correlation Coefficient: 0.3254
# Epoch [225/250], Training Loss: 0.1331, Training Accuracy: 0.5279 Validation Loss: 0.1337, Validation Accuracy: 0.5176 Macro F1: 0.4616, Matthews Correlation Coefficient: 0.3301
# Epoch [226/250], Training Loss: 0.1334, Training Accuracy: 0.5260 Validation Loss: 0.1343, Validation Accuracy: 0.5325 Macro F1: 0.4770, Matthews Correlation Coefficient: 0.3488
# Epoch [227/250], Training Loss: 0.1329, Training Accuracy: 0.5371 Validation Loss: 0.1331, Validation Accuracy: 0.5269 Macro F1: 0.4812, Matthews Correlation Coefficient: 0.3455
# Epoch [228/250], Training Loss: 0.1322, Training Accuracy: 0.5446 Validation Loss: 0.1333, Validation Accuracy: 0.5380 Macro F1: 0.4737, Matthews Correlation Coefficient: 0.3555
# Epoch [229/250], Training Loss: 0.1318, Training Accuracy: 0.5371 Validation Loss: 0.1336, Validation Accuracy: 0.5213 Macro F1: 0.4734, Matthews Correlation Coefficient: 0.3394
# Epoch [230/250], Training Loss: 0.1327, Training Accuracy: 0.5288 Validation Loss: 0.1325, Validation Accuracy: 0.5455 Macro F1: 0.4871, Matthews Correlation Coefficient: 0.3619
# Epoch [231/250], Training Loss: 0.1326, Training Accuracy: 0.5237 Validation Loss: 0.1332, Validation Accuracy: 0.5362 Macro F1: 0.4857, Matthews Correlation Coefficient: 0.3575
# Epoch [232/250], Training Loss: 0.1328, Training Accuracy: 0.5348 Validation Loss: 0.1335, Validation Accuracy: 0.5269 Macro F1: 0.4805, Matthews Correlation Coefficient: 0.3496
# Epoch [233/250], Training Loss: 0.1333, Training Accuracy: 0.5283 Validation Loss: 0.1336, Validation Accuracy: 0.5269 Macro F1: 0.4828, Matthews Correlation Coefficient: 0.3455
# Epoch [234/250], Training Loss: 0.1323, Training Accuracy: 0.5316 Validation Loss: 0.1327, Validation Accuracy: 0.5269 Macro F1: 0.4804, Matthews Correlation Coefficient: 0.3427
# Epoch [235/250], Training Loss: 0.1333, Training Accuracy: 0.5200 Validation Loss: 0.1333, Validation Accuracy: 0.5343 Macro F1: 0.4850, Matthews Correlation Coefficient: 0.3535
# Epoch [236/250], Training Loss: 0.1326, Training Accuracy: 0.5455 Validation Loss: 0.1330, Validation Accuracy: 0.5232 Macro F1: 0.4846, Matthews Correlation Coefficient: 0.3421
# Epoch [237/250], Training Loss: 0.1339, Training Accuracy: 0.5227 Validation Loss: 0.1329, Validation Accuracy: 0.5362 Macro F1: 0.4830, Matthews Correlation Coefficient: 0.3513
# Epoch [238/250], Training Loss: 0.1324, Training Accuracy: 0.5330 Validation Loss: 0.1324, Validation Accuracy: 0.5529 Macro F1: 0.5005, Matthews Correlation Coefficient: 0.3690
# Best Macro F1 achieved: 0.5005
# Saved new best model at epoch 238 with Macro F1: 0.5005
# Epoch [239/250], Training Loss: 0.1330, Training Accuracy: 0.5399 Validation Loss: 0.1328, Validation Accuracy: 0.5306 Macro F1: 0.4776, Matthews Correlation Coefficient: 0.3459
# Epoch [240/250], Training Loss: 0.1320, Training Accuracy: 0.5292 Validation Loss: 0.1337, Validation Accuracy: 0.5288 Macro F1: 0.4819, Matthews Correlation Coefficient: 0.3506
# Epoch [241/250], Training Loss: 0.1325, Training Accuracy: 0.5395 Validation Loss: 0.1330, Validation Accuracy: 0.5232 Macro F1: 0.4799, Matthews Correlation Coefficient: 0.3439
# Epoch [242/250], Training Loss: 0.1320, Training Accuracy: 0.5436 Validation Loss: 0.1328, Validation Accuracy: 0.5529 Macro F1: 0.4981, Matthews Correlation Coefficient: 0.3705
# Epoch [243/250], Training Loss: 0.1329, Training Accuracy: 0.5255 Validation Loss: 0.1335, Validation Accuracy: 0.5399 Macro F1: 0.4938, Matthews Correlation Coefficient: 0.3624
# Epoch [244/250], Training Loss: 0.1325, Training Accuracy: 0.5325 Validation Loss: 0.1325, Validation Accuracy: 0.5510 Macro F1: 0.4875, Matthews Correlation Coefficient: 0.3648
# Epoch [245/250], Training Loss: 0.1333, Training Accuracy: 0.5260 Validation Loss: 0.1338, Validation Accuracy: 0.5417 Macro F1: 0.4843, Matthews Correlation Coefficient: 0.3590
# Epoch [246/250], Training Loss: 0.1335, Training Accuracy: 0.5283 Validation Loss: 0.1339, Validation Accuracy: 0.5380 Macro F1: 0.4823, Matthews Correlation Coefficient: 0.3561
# Epoch [247/250], Training Loss: 0.1324, Training Accuracy: 0.5330 Validation Loss: 0.1333, Validation Accuracy: 0.5269 Macro F1: 0.4752, Matthews Correlation Coefficient: 0.3445
# Epoch [248/250], Training Loss: 0.1336, Training Accuracy: 0.5265 Validation Loss: 0.1332, Validation Accuracy: 0.5269 Macro F1: 0.4733, Matthews Correlation Coefficient: 0.3420
# Epoch [249/250], Training Loss: 0.1319, Training Accuracy: 0.5385 Validation Loss: 0.1324, Validation Accuracy: 0.5380 Macro F1: 0.4891, Matthews Correlation Coefficient: 0.3541
# Epoch [250/250], Training Loss: 0.1326, Training Accuracy: 0.5302 Validation Loss: 0.1327, Validation Accuracy: 0.5417 Macro F1: 0.4845, Matthews Correlation Coefficient: 0.3613

# %% [markdown]
# ### 5-fold cross validation

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=Seed)

# Create a full label for the full dataset
full_labels = [label_to_int[label] for label in LD['Localization'].values]

# Create the training and validation datasets    
if Set == 'Protein':
    train_dataset = MyDataset(Set, PD, PD, LD.index, full_labels, transform=transformation)
    val_dataset = MyDataset(Set, PD, PD, LD.index, full_labels)
elif Set == 'mRNA':
    train_dataset = MyDataset(Set, MD, MD, LD.index, full_labels, transform=transformation)
    val_dataset = MyDataset(Set, MD, MD, LD.index, full_labels)
elif Set == 'Protein + mRNA':
    train_dataset = MyDataset(Set, PD, MD, LD.index, full_labels, transform=transformation)
    val_dataset = MyDataset(Set, PD, MD, LD.index, full_labels)
else:
    raise ValueError("Invalid dataset selection. Choose 'Protein', 'mRNA', 'Protein + mRNA'.")

for fold, (train_ids, val_ids) in enumerate(kfold.split(train_dataset)):
    print(f'\n--- Fold {fold+1} ---')

    # Create subset loaders
    train_subsampler = torch.utils.data.Subset(train_dataset, train_ids)
    val_subsampler = torch.utils.data.Subset(val_dataset, val_ids)

    train_loader = DataLoader(train_subsampler, batch_size=Batch_size, shuffle=True)
    val_loader = DataLoader(val_subsampler, batch_size=Batch_size, shuffle=False)

    # Reset model, optimizer, scheduler per fold
    model = PixelPreservingNet(in_channels=3).to(device)  # fresh model per fold
    optimizer = optim.AdamW(model.parameters(), lr=Learner_rate, weight_decay=Weight_Decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10, threshold=1e-4, cooldown=2, min_lr=1e-7, verbose=True)
    criterion = FocalLoss(alpha=LossWeights, gamma=2.0, reduction='mean')
    #early_stopping = EarlyStoppingWithCheckpoint(patience=15, delta=0, save_path=None)

    # Initialize tracking DataFrames
    LossAccDF = pd.DataFrame(index=range(epochs),columns=['Epoch','TrainLoss','ValLoss','TrainAcc','ValAcc'])
    PrecisionRecallDF = pd.DataFrame(columns=['Epoch','Class','Precision','Recall','Class F1','Macro F1','MCC'])
    index = 0

    # Evaluate before training
    avg_train_loss, train_accuracy, _, _, _, macro_f1, mcc = test_loop(train_loader, model, criterion)
    avg_val_loss, val_accuracy, precision, recall, per_class_f1, macro_f1, mcc = test_loop(val_loader, model, criterion)

    print(f"Before Training: Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}, Macro F1: {macro_f1:.4f}, MCC: {mcc:.4f}")

    LossAccDF.loc[0, :] = [0, avg_train_loss, avg_val_loss, train_accuracy, val_accuracy]
    for i in range(4):
        PrecisionRecallDF.loc[index] = [0, i, precision[i], recall[i], per_class_f1[i], macro_f1, mcc]
        index += 1

    # Training loop
    for epoch in range(epochs):

        avg_train_loss, train_accuracy = train_loop(train_loader, model, criterion, optimizer)
        avg_val_loss, val_accuracy, precision, recall, per_class_f1, macro_f1, mcc = test_loop(val_loader, model, criterion)

        print(f"Epoch [{epoch+1}/{epochs}] Fold [{fold+1}] Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f} Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}, Macro F1: {macro_f1:.4f}, MCC: {mcc:.4f}")

        LossAccDF.loc[epoch+1, :] = [epoch+1, avg_train_loss, avg_val_loss, train_accuracy, val_accuracy]
        for i in range(4):
            PrecisionRecallDF.loc[index] = [epoch+1, i, precision[i], recall[i], per_class_f1[i], macro_f1, mcc]
            index += 1

        # Early stopping check
    #    early_stopping(avg_val_loss, model)
    #    if early_stopping.early_stop:
    #        print(f"Early stopping at epoch {epoch}")
    #        break

    # Optionally save LossAccDF, PrecisionRecallDF per fold
    LossAccDF.to_csv(cv_folder_path+f'{Set}_Fold{fold+1}_LossAcc.csv', index=False)
    PrecisionRecallDF.to_csv(cv_folder_path+f'{Set}_Fold{fold+1}_PrecisionRecall.csv', index=False)
# Out:
# --- Fold 1 ---
# /opt/conda/envs/pytorch/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Before Training: Training Loss: 0.1679, Training Accuracy: 0.0989, Validation Loss: 0.1662, Validation Accuracy: 0.0946, Macro F1: 0.0432, MCC: 0.0000
# Epoch [1/250] Fold [1] Train Loss: 0.1622, Train Acc: 0.3491 Val Loss: 0.1630, Val Acc: 0.4805, Macro F1: 0.3663, MCC: 0.2625
# Epoch [2/250] Fold [1] Train Loss: 0.1558, Train Acc: 0.4392 Val Loss: 0.1500, Val Acc: 0.4935, Macro F1: 0.3575, MCC: 0.2686
# Epoch [3/250] Fold [1] Train Loss: 0.1522, Train Acc: 0.4475 Val Loss: 0.1445, Val Acc: 0.4935, Macro F1: 0.3670, MCC: 0.2718
# Epoch [4/250] Fold [1] Train Loss: 0.1488, Train Acc: 0.4735 Val Loss: 0.1429, Val Acc: 0.4954, Macro F1: 0.3827, MCC: 0.2852
# Epoch [5/250] Fold [1] Train Loss: 0.1474, Train Acc: 0.4759 Val Loss: 0.1402, Val Acc: 0.5232, Macro F1: 0.4088, MCC: 0.3292
# Epoch [6/250] Fold [1] Train Loss: 0.1453, Train Acc: 0.4786 Val Loss: 0.1381, Val Acc: 0.5158, Macro F1: 0.4044, MCC: 0.3233
# Epoch [7/250] Fold [1] Train Loss: 0.1454, Train Acc: 0.4865 Val Loss: 0.1365, Val Acc: 0.5121, Macro F1: 0.4028, MCC: 0.3178
# Epoch [8/250] Fold [1] Train Loss: 0.1433, Train Acc: 0.4963 Val Loss: 0.1358, Val Acc: 0.5195, Macro F1: 0.4320, MCC: 0.3253
# Epoch [9/250] Fold [1] Train Loss: 0.1425, Train Acc: 0.4977 Val Loss: 0.1348, Val Acc: 0.5232, Macro F1: 0.4288, MCC: 0.3313
# Epoch [10/250] Fold [1] Train Loss: 0.1413, Train Acc: 0.5056 Val Loss: 0.1349, Val Acc: 0.5046, Macro F1: 0.4133, MCC: 0.3098
# Epoch [11/250] Fold [1] Train Loss: 0.1408, Train Acc: 0.4963 Val Loss: 0.1339, Val Acc: 0.5139, Macro F1: 0.4398, MCC: 0.3224
# Epoch [12/250] Fold [1] Train Loss: 0.1410, Train Acc: 0.4940 Val Loss: 0.1342, Val Acc: 0.4991, Macro F1: 0.4314, MCC: 0.3128
# Epoch [13/250] Fold [1] Train Loss: 0.1415, Train Acc: 0.5032 Val Loss: 0.1345, Val Acc: 0.5232, Macro F1: 0.4520, MCC: 0.3368
# Epoch [14/250] Fold [1] Train Loss: 0.1407, Train Acc: 0.5065 Val Loss: 0.1337, Val Acc: 0.5213, Macro F1: 0.4455, MCC: 0.3294
# Epoch [15/250] Fold [1] Train Loss: 0.1398, Train Acc: 0.4986 Val Loss: 0.1341, Val Acc: 0.5250, Macro F1: 0.4735, MCC: 0.3377
# Epoch [16/250] Fold [1] Train Loss: 0.1396, Train Acc: 0.5014 Val Loss: 0.1335, Val Acc: 0.5343, Macro F1: 0.4662, MCC: 0.3457
# Epoch [17/250] Fold [1] Train Loss: 0.1396, Train Acc: 0.4986 Val Loss: 0.1338, Val Acc: 0.5195, Macro F1: 0.4491, MCC: 0.3288
# Epoch [18/250] Fold [1] Train Loss: 0.1403, Train Acc: 0.5019 Val Loss: 0.1332, Val Acc: 0.5362, Macro F1: 0.4618, MCC: 0.3477
# Epoch [19/250] Fold [1] Train Loss: 0.1392, Train Acc: 0.4991 Val Loss: 0.1333, Val Acc: 0.5028, Macro F1: 0.4302, MCC: 0.3105
# Epoch [20/250] Fold [1] Train Loss: 0.1376, Train Acc: 0.5102 Val Loss: 0.1333, Val Acc: 0.5232, Macro F1: 0.4519, MCC: 0.3365
# Epoch [21/250] Fold [1] Train Loss: 0.1394, Train Acc: 0.5186 Val Loss: 0.1333, Val Acc: 0.5195, Macro F1: 0.4605, MCC: 0.3301
# Epoch [22/250] Fold [1] Train Loss: 0.1385, Train Acc: 0.5102 Val Loss: 0.1331, Val Acc: 0.5139, Macro F1: 0.4544, MCC: 0.3244
# Epoch [23/250] Fold [1] Train Loss: 0.1383, Train Acc: 0.5176 Val Loss: 0.1330, Val Acc: 0.5232, Macro F1: 0.4694, MCC: 0.3339
# Epoch [24/250] Fold [1] Train Loss: 0.1380, Train Acc: 0.5190 Val Loss: 0.1331, Val Acc: 0.5213, Macro F1: 0.4622, MCC: 0.3317
# Epoch [25/250] Fold [1] Train Loss: 0.1384, Train Acc: 0.5172 Val Loss: 0.1333, Val Acc: 0.5306, Macro F1: 0.4867, MCC: 0.3408
# Epoch [26/250] Fold [1] Train Loss: 0.1380, Train Acc: 0.5153 Val Loss: 0.1326, Val Acc: 0.5399, Macro F1: 0.4884, MCC: 0.3553
# Epoch [27/250] Fold [1] Train Loss: 0.1378, Train Acc: 0.5079 Val Loss: 0.1330, Val Acc: 0.5250, Macro F1: 0.4771, MCC: 0.3408
# Epoch [28/250] Fold [1] Train Loss: 0.1371, Train Acc: 0.5158 Val Loss: 0.1333, Val Acc: 0.5306, Macro F1: 0.4770, MCC: 0.3451
# Epoch [29/250] Fold [1] Train Loss: 0.1379, Train Acc: 0.5167 Val Loss: 0.1331, Val Acc: 0.5362, Macro F1: 0.4823, MCC: 0.3517
# Epoch [30/250] Fold [1] Train Loss: 0.1382, Train Acc: 0.5186 Val Loss: 0.1329, Val Acc: 0.5455, Macro F1: 0.4986, MCC: 0.3594
# Epoch [31/250] Fold [1] Train Loss: 0.1392, Train Acc: 0.5000 Val Loss: 0.1341, Val Acc: 0.5121, Macro F1: 0.4475, MCC: 0.3201
# Epoch [32/250] Fold [1] Train Loss: 0.1374, Train Acc: 0.5125 Val Loss: 0.1328, Val Acc: 0.5362, Macro F1: 0.4773, MCC: 0.3518
# Epoch [33/250] Fold [1] Train Loss: 0.1381, Train Acc: 0.5144 Val Loss: 0.1335, Val Acc: 0.5232, Macro F1: 0.4729, MCC: 0.3378
# Epoch [34/250] Fold [1] Train Loss: 0.1381, Train Acc: 0.5195 Val Loss: 0.1334, Val Acc: 0.5417, Macro F1: 0.4962, MCC: 0.3594
# Epoch [35/250] Fold [1] Train Loss: 0.1390, Train Acc: 0.5093 Val Loss: 0.1335, Val Acc: 0.5399, Macro F1: 0.4878, MCC: 0.3589
# Epoch [36/250] Fold [1] Train Loss: 0.1382, Train Acc: 0.5204 Val Loss: 0.1334, Val Acc: 0.5417, Macro F1: 0.4900, MCC: 0.3590
# Epoch [37/250] Fold [1] Train Loss: 0.1379, Train Acc: 0.5274 Val Loss: 0.1332, Val Acc: 0.5288, Macro F1: 0.4693, MCC: 0.3376
# Epoch [38/250] Fold [1] Train Loss: 0.1379, Train Acc: 0.5186 Val Loss: 0.1333, Val Acc: 0.5362, Macro F1: 0.4850, MCC: 0.3543
# Epoch [39/250] Fold [1] Train Loss: 0.1366, Train Acc: 0.5218 Val Loss: 0.1327, Val Acc: 0.5399, Macro F1: 0.4945, MCC: 0.3624
# Epoch [40/250] Fold [1] Train Loss: 0.1368, Train Acc: 0.5246 Val Loss: 0.1327, Val Acc: 0.5399, Macro F1: 0.4919, MCC: 0.3578
# Epoch [41/250] Fold [1] Train Loss: 0.1376, Train Acc: 0.5190 Val Loss: 0.1330, Val Acc: 0.5213, Macro F1: 0.4724, MCC: 0.3371
# Epoch [42/250] Fold [1] Train Loss: 0.1364, Train Acc: 0.5135 Val Loss: 0.1327, Val Acc: 0.5436, Macro F1: 0.4926, MCC: 0.3568
# Epoch [43/250] Fold [1] Train Loss: 0.1378, Train Acc: 0.5135 Val Loss: 0.1327, Val Acc: 0.5436, Macro F1: 0.4947, MCC: 0.3592
# Epoch [44/250] Fold [1] Train Loss: 0.1381, Train Acc: 0.5162 Val Loss: 0.1334, Val Acc: 0.5417, Macro F1: 0.4876, MCC: 0.3556
# Epoch [45/250] Fold [1] Train Loss: 0.1373, Train Acc: 0.5139 Val Loss: 0.1322, Val Acc: 0.5473, Macro F1: 0.4823, MCC: 0.3588
# Epoch [46/250] Fold [1] Train Loss: 0.1374, Train Acc: 0.5167 Val Loss: 0.1329, Val Acc: 0.5380, Macro F1: 0.4878, MCC: 0.3532
# Epoch [47/250] Fold [1] Train Loss: 0.1369, Train Acc: 0.5214 Val Loss: 0.1327, Val Acc: 0.5436, Macro F1: 0.4927, MCC: 0.3609
# Epoch [48/250] Fold [1] Train Loss: 0.1370, Train Acc: 0.5265 Val Loss: 0.1326, Val Acc: 0.5380, Macro F1: 0.4866, MCC: 0.3527
# Epoch [49/250] Fold [1] Train Loss: 0.1377, Train Acc: 0.5214 Val Loss: 0.1335, Val Acc: 0.5288, Macro F1: 0.4666, MCC: 0.3415
# Epoch [50/250] Fold [1] Train Loss: 0.1368, Train Acc: 0.5241 Val Loss: 0.1325, Val Acc: 0.5399, Macro F1: 0.4858, MCC: 0.3549
# Epoch [51/250] Fold [1] Train Loss: 0.1364, Train Acc: 0.5297 Val Loss: 0.1329, Val Acc: 0.5158, Macro F1: 0.4660, MCC: 0.3310
# Epoch [52/250] Fold [1] Train Loss: 0.1363, Train Acc: 0.5283 Val Loss: 0.1323, Val Acc: 0.5547, Macro F1: 0.4975, MCC: 0.3687
# Epoch [53/250] Fold [1] Train Loss: 0.1368, Train Acc: 0.5176 Val Loss: 0.1329, Val Acc: 0.5417, Macro F1: 0.4845, MCC: 0.3532
# Epoch [54/250] Fold [1] Train Loss: 0.1371, Train Acc: 0.5251 Val Loss: 0.1324, Val Acc: 0.5399, Macro F1: 0.4891, MCC: 0.3520
# Epoch [55/250] Fold [1] Train Loss: 0.1369, Train Acc: 0.5176 Val Loss: 0.1329, Val Acc: 0.5380, Macro F1: 0.4859, MCC: 0.3522
# Epoch [56/250] Fold [1] Train Loss: 0.1365, Train Acc: 0.5265 Val Loss: 0.1325, Val Acc: 0.5380, Macro F1: 0.4885, MCC: 0.3500
# Epoch [57/250] Fold [1] Train Loss: 0.1381, Train Acc: 0.5097 Val Loss: 0.1330, Val Acc: 0.5250, Macro F1: 0.4747, MCC: 0.3384
# Epoch [58/250] Fold [1] Train Loss: 0.1369, Train Acc: 0.5223 Val Loss: 0.1320, Val Acc: 0.5417, Macro F1: 0.4852, MCC: 0.3528
# Epoch [59/250] Fold [1] Train Loss: 0.1361, Train Acc: 0.5200 Val Loss: 0.1322, Val Acc: 0.5399, Macro F1: 0.4867, MCC: 0.3511
# Epoch [60/250] Fold [1] Train Loss: 0.1363, Train Acc: 0.5232 Val Loss: 0.1326, Val Acc: 0.5343, Macro F1: 0.4820, MCC: 0.3450
# Epoch [61/250] Fold [1] Train Loss: 0.1350, Train Acc: 0.5306 Val Loss: 0.1321, Val Acc: 0.5492, Macro F1: 0.4993, MCC: 0.3607
# Epoch [62/250] Fold [1] Train Loss: 0.1363, Train Acc: 0.5232 Val Loss: 0.1321, Val Acc: 0.5232, Macro F1: 0.4766, MCC: 0.3349
# Epoch [63/250] Fold [1] Train Loss: 0.1367, Train Acc: 0.5232 Val Loss: 0.1330, Val Acc: 0.5158, Macro F1: 0.4674, MCC: 0.3232
# Epoch [64/250] Fold [1] Train Loss: 0.1368, Train Acc: 0.5209 Val Loss: 0.1329, Val Acc: 0.5306, Macro F1: 0.4778, MCC: 0.3412
# Epoch [65/250] Fold [1] Train Loss: 0.1375, Train Acc: 0.5074 Val Loss: 0.1327, Val Acc: 0.5362, Macro F1: 0.4830, MCC: 0.3465
# Epoch [66/250] Fold [1] Train Loss: 0.1360, Train Acc: 0.5172 Val Loss: 0.1328, Val Acc: 0.5362, Macro F1: 0.4852, MCC: 0.3474
# Epoch [67/250] Fold [1] Train Loss: 0.1366, Train Acc: 0.5251 Val Loss: 0.1327, Val Acc: 0.5399, Macro F1: 0.4871, MCC: 0.3516
# Epoch [68/250] Fold [1] Train Loss: 0.1356, Train Acc: 0.5181 Val Loss: 0.1322, Val Acc: 0.5343, Macro F1: 0.4901, MCC: 0.3459
# Epoch [69/250] Fold [1] Train Loss: 0.1362, Train Acc: 0.5279 Val Loss: 0.1323, Val Acc: 0.5362, Macro F1: 0.4875, MCC: 0.3503
# Epoch [70/250] Fold [1] Train Loss: 0.1371, Train Acc: 0.5297 Val Loss: 0.1324, Val Acc: 0.5343, Macro F1: 0.4829, MCC: 0.3439
# Epoch [71/250] Fold [1] Train Loss: 0.1361, Train Acc: 0.5246 Val Loss: 0.1323, Val Acc: 0.5325, Macro F1: 0.4830, MCC: 0.3432
# Epoch [72/250] Fold [1] Train Loss: 0.1361, Train Acc: 0.5269 Val Loss: 0.1329, Val Acc: 0.5417, Macro F1: 0.4843, MCC: 0.3523
# Epoch [73/250] Fold [1] Train Loss: 0.1366, Train Acc: 0.5074 Val Loss: 0.1324, Val Acc: 0.5492, Macro F1: 0.4953, MCC: 0.3616
# Epoch [74/250] Fold [1] Train Loss: 0.1366, Train Acc: 0.5255 Val Loss: 0.1326, Val Acc: 0.5325, Macro F1: 0.4796, MCC: 0.3458
# Epoch [75/250] Fold [1] Train Loss: 0.1366, Train Acc: 0.5214 Val Loss: 0.1320, Val Acc: 0.5288, Macro F1: 0.4854, MCC: 0.3414
# Epoch [76/250] Fold [1] Train Loss: 0.1354, Train Acc: 0.5246 Val Loss: 0.1320, Val Acc: 0.5399, Macro F1: 0.4845, MCC: 0.3508
# Epoch [77/250] Fold [1] Train Loss: 0.1356, Train Acc: 0.5200 Val Loss: 0.1325, Val Acc: 0.5325, Macro F1: 0.4809, MCC: 0.3425
# Epoch [78/250] Fold [1] Train Loss: 0.1371, Train Acc: 0.5153 Val Loss: 0.1332, Val Acc: 0.5362, Macro F1: 0.4835, MCC: 0.3503
# Epoch [79/250] Fold [1] Train Loss: 0.1359, Train Acc: 0.5274 Val Loss: 0.1321, Val Acc: 0.5343, Macro F1: 0.4858, MCC: 0.3490
# Epoch [80/250] Fold [1] Train Loss: 0.1368, Train Acc: 0.5223 Val Loss: 0.1326, Val Acc: 0.5380, Macro F1: 0.4826, MCC: 0.3482
# Epoch [81/250] Fold [1] Train Loss: 0.1365, Train Acc: 0.5111 Val Loss: 0.1329, Val Acc: 0.5417, Macro F1: 0.4829, MCC: 0.3513
# Epoch [82/250] Fold [1] Train Loss: 0.1372, Train Acc: 0.5269 Val Loss: 0.1333, Val Acc: 0.5288, Macro F1: 0.4810, MCC: 0.3437
# Epoch [83/250] Fold [1] Train Loss: 0.1356, Train Acc: 0.5246 Val Loss: 0.1332, Val Acc: 0.5288, Macro F1: 0.4755, MCC: 0.3424
# Epoch [84/250] Fold [1] Train Loss: 0.1355, Train Acc: 0.5260 Val Loss: 0.1328, Val Acc: 0.5288, Macro F1: 0.4760, MCC: 0.3405
# Epoch [85/250] Fold [1] Train Loss: 0.1345, Train Acc: 0.5279 Val Loss: 0.1327, Val Acc: 0.5288, Macro F1: 0.4809, MCC: 0.3429
# Epoch [86/250] Fold [1] Train Loss: 0.1350, Train Acc: 0.5330 Val Loss: 0.1328, Val Acc: 0.5362, Macro F1: 0.4898, MCC: 0.3507
# Epoch [87/250] Fold [1] Train Loss: 0.1356, Train Acc: 0.5241 Val Loss: 0.1324, Val Acc: 0.5306, Macro F1: 0.4820, MCC: 0.3444
# Epoch [88/250] Fold [1] Train Loss: 0.1350, Train Acc: 0.5381 Val Loss: 0.1332, Val Acc: 0.5250, Macro F1: 0.4793, MCC: 0.3353
# Epoch [89/250] Fold [1] Train Loss: 0.1355, Train Acc: 0.5223 Val Loss: 0.1324, Val Acc: 0.5250, Macro F1: 0.4756, MCC: 0.3356
# Epoch [90/250] Fold [1] Train Loss: 0.1353, Train Acc: 0.5279 Val Loss: 0.1330, Val Acc: 0.5380, Macro F1: 0.4839, MCC: 0.3466
# Epoch [91/250] Fold [1] Train Loss: 0.1355, Train Acc: 0.5237 Val Loss: 0.1324, Val Acc: 0.5288, Macro F1: 0.4812, MCC: 0.3435
# Epoch [92/250] Fold [1] Train Loss: 0.1342, Train Acc: 0.5246 Val Loss: 0.1326, Val Acc: 0.5343, Macro F1: 0.4773, MCC: 0.3453
# Epoch [93/250] Fold [1] Train Loss: 0.1362, Train Acc: 0.5297 Val Loss: 0.1325, Val Acc: 0.5343, Macro F1: 0.4759, MCC: 0.3431
# Epoch [94/250] Fold [1] Train Loss: 0.1360, Train Acc: 0.5265 Val Loss: 0.1334, Val Acc: 0.5362, Macro F1: 0.4821, MCC: 0.3478
# Epoch [95/250] Fold [1] Train Loss: 0.1363, Train Acc: 0.5274 Val Loss: 0.1330, Val Acc: 0.5455, Macro F1: 0.4882, MCC: 0.3559
# Epoch [96/250] Fold [1] Train Loss: 0.1355, Train Acc: 0.5209 Val Loss: 0.1331, Val Acc: 0.5325, Macro F1: 0.4845, MCC: 0.3512
# Epoch [97/250] Fold [1] Train Loss: 0.1361, Train Acc: 0.5223 Val Loss: 0.1331, Val Acc: 0.5640, Macro F1: 0.4979, MCC: 0.3783
# Epoch [98/250] Fold [1] Train Loss: 0.1349, Train Acc: 0.5232 Val Loss: 0.1327, Val Acc: 0.5343, Macro F1: 0.4707, MCC: 0.3437
# Epoch [99/250] Fold [1] Train Loss: 0.1363, Train Acc: 0.5339 Val Loss: 0.1324, Val Acc: 0.5436, Macro F1: 0.4833, MCC: 0.3550
# Epoch [100/250] Fold [1] Train Loss: 0.1359, Train Acc: 0.5232 Val Loss: 0.1329, Val Acc: 0.5455, Macro F1: 0.4872, MCC: 0.3596
# Epoch [101/250] Fold [1] Train Loss: 0.1345, Train Acc: 0.5265 Val Loss: 0.1323, Val Acc: 0.5455, Macro F1: 0.4920, MCC: 0.3576
# Epoch [102/250] Fold [1] Train Loss: 0.1335, Train Acc: 0.5427 Val Loss: 0.1317, Val Acc: 0.5362, Macro F1: 0.4912, MCC: 0.3519
# Epoch [103/250] Fold [1] Train Loss: 0.1347, Train Acc: 0.5260 Val Loss: 0.1322, Val Acc: 0.5343, Macro F1: 0.4803, MCC: 0.3464
# Epoch [104/250] Fold [1] Train Loss: 0.1361, Train Acc: 0.5130 Val Loss: 0.1330, Val Acc: 0.5306, Macro F1: 0.4787, MCC: 0.3445
# Epoch [105/250] Fold [1] Train Loss: 0.1344, Train Acc: 0.5381 Val Loss: 0.1326, Val Acc: 0.5325, Macro F1: 0.4728, MCC: 0.3430
# Epoch [106/250] Fold [1] Train Loss: 0.1338, Train Acc: 0.5297 Val Loss: 0.1327, Val Acc: 0.5250, Macro F1: 0.4743, MCC: 0.3363
# Epoch [107/250] Fold [1] Train Loss: 0.1361, Train Acc: 0.5311 Val Loss: 0.1328, Val Acc: 0.5288, Macro F1: 0.4776, MCC: 0.3387
# Epoch [108/250] Fold [1] Train Loss: 0.1363, Train Acc: 0.5204 Val Loss: 0.1339, Val Acc: 0.5250, Macro F1: 0.4762, MCC: 0.3374
# Epoch [109/250] Fold [1] Train Loss: 0.1348, Train Acc: 0.5292 Val Loss: 0.1329, Val Acc: 0.5306, Macro F1: 0.4750, MCC: 0.3407
# Epoch [110/250] Fold [1] Train Loss: 0.1356, Train Acc: 0.5311 Val Loss: 0.1325, Val Acc: 0.5436, Macro F1: 0.4777, MCC: 0.3540
# Epoch [111/250] Fold [1] Train Loss: 0.1352, Train Acc: 0.5302 Val Loss: 0.1336, Val Acc: 0.5232, Macro F1: 0.4779, MCC: 0.3383
# Epoch [112/250] Fold [1] Train Loss: 0.1346, Train Acc: 0.5362 Val Loss: 0.1324, Val Acc: 0.5399, Macro F1: 0.4803, MCC: 0.3490
# Epoch [113/250] Fold [1] Train Loss: 0.1347, Train Acc: 0.5288 Val Loss: 0.1318, Val Acc: 0.5288, Macro F1: 0.4728, MCC: 0.3394
# Epoch [114/250] Fold [1] Train Loss: 0.1346, Train Acc: 0.5269 Val Loss: 0.1330, Val Acc: 0.5417, Macro F1: 0.4875, MCC: 0.3523
# Epoch [115/250] Fold [1] Train Loss: 0.1365, Train Acc: 0.5190 Val Loss: 0.1328, Val Acc: 0.5362, Macro F1: 0.4854, MCC: 0.3484
# Epoch [116/250] Fold [1] Train Loss: 0.1347, Train Acc: 0.5195 Val Loss: 0.1324, Val Acc: 0.5232, Macro F1: 0.4644, MCC: 0.3320
# Epoch [117/250] Fold [1] Train Loss: 0.1348, Train Acc: 0.5241 Val Loss: 0.1328, Val Acc: 0.5306, Macro F1: 0.4750, MCC: 0.3396
# Epoch [118/250] Fold [1] Train Loss: 0.1351, Train Acc: 0.5390 Val Loss: 0.1330, Val Acc: 0.5380, Macro F1: 0.4806, MCC: 0.3469
# Epoch [119/250] Fold [1] Train Loss: 0.1351, Train Acc: 0.5255 Val Loss: 0.1331, Val Acc: 0.5306, Macro F1: 0.4740, MCC: 0.3424
# Epoch [120/250] Fold [1] Train Loss: 0.1353, Train Acc: 0.5237 Val Loss: 0.1330, Val Acc: 0.5288, Macro F1: 0.4821, MCC: 0.3445
# Epoch [121/250] Fold [1] Train Loss: 0.1356, Train Acc: 0.5195 Val Loss: 0.1331, Val Acc: 0.5250, Macro F1: 0.4775, MCC: 0.3355
# Epoch [122/250] Fold [1] Train Loss: 0.1347, Train Acc: 0.5190 Val Loss: 0.1331, Val Acc: 0.5250, Macro F1: 0.4798, MCC: 0.3391
# Epoch [123/250] Fold [1] Train Loss: 0.1355, Train Acc: 0.5195 Val Loss: 0.1329, Val Acc: 0.5306, Macro F1: 0.4719, MCC: 0.3414
# Epoch [124/250] Fold [1] Train Loss: 0.1349, Train Acc: 0.5292 Val Loss: 0.1325, Val Acc: 0.5455, Macro F1: 0.4843, MCC: 0.3566
# Epoch [125/250] Fold [1] Train Loss: 0.1350, Train Acc: 0.5186 Val Loss: 0.1331, Val Acc: 0.5306, Macro F1: 0.4752, MCC: 0.3437
# Epoch [126/250] Fold [1] Train Loss: 0.1363, Train Acc: 0.5246 Val Loss: 0.1331, Val Acc: 0.5306, Macro F1: 0.4751, MCC: 0.3386
# Epoch [127/250] Fold [1] Train Loss: 0.1368, Train Acc: 0.5181 Val Loss: 0.1340, Val Acc: 0.5139, Macro F1: 0.4686, MCC: 0.3311
# Epoch [128/250] Fold [1] Train Loss: 0.1346, Train Acc: 0.5292 Val Loss: 0.1322, Val Acc: 0.5288, Macro F1: 0.4751, MCC: 0.3389
# Epoch [129/250] Fold [1] Train Loss: 0.1349, Train Acc: 0.5227 Val Loss: 0.1331, Val Acc: 0.5380, Macro F1: 0.4817, MCC: 0.3470
# Epoch [130/250] Fold [1] Train Loss: 0.1351, Train Acc: 0.5348 Val Loss: 0.1334, Val Acc: 0.5343, Macro F1: 0.4847, MCC: 0.3486
# Epoch [131/250] Fold [1] Train Loss: 0.1351, Train Acc: 0.5325 Val Loss: 0.1325, Val Acc: 0.5417, Macro F1: 0.4864, MCC: 0.3528
# Epoch [132/250] Fold [1] Train Loss: 0.1353, Train Acc: 0.5255 Val Loss: 0.1333, Val Acc: 0.5380, Macro F1: 0.4847, MCC: 0.3543
# Epoch [133/250] Fold [1] Train Loss: 0.1360, Train Acc: 0.5283 Val Loss: 0.1327, Val Acc: 0.5436, Macro F1: 0.4886, MCC: 0.3602
# Epoch [134/250] Fold [1] Train Loss: 0.1342, Train Acc: 0.5325 Val Loss: 0.1324, Val Acc: 0.5269, Macro F1: 0.4736, MCC: 0.3359
# Epoch [135/250] Fold [1] Train Loss: 0.1352, Train Acc: 0.5130 Val Loss: 0.1328, Val Acc: 0.5380, Macro F1: 0.4806, MCC: 0.3513
# Epoch [136/250] Fold [1] Train Loss: 0.1342, Train Acc: 0.5181 Val Loss: 0.1323, Val Acc: 0.5325, Macro F1: 0.4797, MCC: 0.3477
# Epoch [137/250] Fold [1] Train Loss: 0.1345, Train Acc: 0.5436 Val Loss: 0.1319, Val Acc: 0.5250, Macro F1: 0.4708, MCC: 0.3354
# Epoch [138/250] Fold [1] Train Loss: 0.1344, Train Acc: 0.5288 Val Loss: 0.1327, Val Acc: 0.5288, Macro F1: 0.4810, MCC: 0.3407
# Epoch [139/250] Fold [1] Train Loss: 0.1347, Train Acc: 0.5218 Val Loss: 0.1334, Val Acc: 0.5269, Macro F1: 0.4800, MCC: 0.3431
# Epoch [140/250] Fold [1] Train Loss: 0.1348, Train Acc: 0.5241 Val Loss: 0.1329, Val Acc: 0.5473, Macro F1: 0.4874, MCC: 0.3640
# Epoch [141/250] Fold [1] Train Loss: 0.1339, Train Acc: 0.5320 Val Loss: 0.1325, Val Acc: 0.5343, Macro F1: 0.4867, MCC: 0.3503
# Epoch [142/250] Fold [1] Train Loss: 0.1343, Train Acc: 0.5260 Val Loss: 0.1320, Val Acc: 0.5399, Macro F1: 0.4776, MCC: 0.3526
# Epoch [143/250] Fold [1] Train Loss: 0.1343, Train Acc: 0.5353 Val Loss: 0.1322, Val Acc: 0.5399, Macro F1: 0.4823, MCC: 0.3494
# Epoch [144/250] Fold [1] Train Loss: 0.1352, Train Acc: 0.5297 Val Loss: 0.1325, Val Acc: 0.5436, Macro F1: 0.4819, MCC: 0.3558
# Epoch [145/250] Fold [1] Train Loss: 0.1340, Train Acc: 0.5316 Val Loss: 0.1325, Val Acc: 0.5325, Macro F1: 0.4837, MCC: 0.3442
# Epoch [146/250] Fold [1] Train Loss: 0.1346, Train Acc: 0.5260 Val Loss: 0.1330, Val Acc: 0.5417, Macro F1: 0.4903, MCC: 0.3541
# Epoch [147/250] Fold [1] Train Loss: 0.1353, Train Acc: 0.5288 Val Loss: 0.1325, Val Acc: 0.5399, Macro F1: 0.4802, MCC: 0.3518
# Epoch [148/250] Fold [1] Train Loss: 0.1338, Train Acc: 0.5279 Val Loss: 0.1325, Val Acc: 0.5343, Macro F1: 0.4751, MCC: 0.3434
# Epoch [149/250] Fold [1] Train Loss: 0.1335, Train Acc: 0.5251 Val Loss: 0.1324, Val Acc: 0.5380, Macro F1: 0.4935, MCC: 0.3506
# Epoch [150/250] Fold [1] Train Loss: 0.1343, Train Acc: 0.5265 Val Loss: 0.1324, Val Acc: 0.5343, Macro F1: 0.4854, MCC: 0.3465
# Epoch [151/250] Fold [1] Train Loss: 0.1350, Train Acc: 0.5227 Val Loss: 0.1330, Val Acc: 0.5343, Macro F1: 0.4786, MCC: 0.3448
# Epoch [152/250] Fold [1] Train Loss: 0.1337, Train Acc: 0.5274 Val Loss: 0.1329, Val Acc: 0.5473, Macro F1: 0.4882, MCC: 0.3578
# Epoch [153/250] Fold [1] Train Loss: 0.1346, Train Acc: 0.5381 Val Loss: 0.1328, Val Acc: 0.5362, Macro F1: 0.4785, MCC: 0.3477
# Epoch [154/250] Fold [1] Train Loss: 0.1350, Train Acc: 0.5288 Val Loss: 0.1326, Val Acc: 0.5436, Macro F1: 0.4849, MCC: 0.3526
# Epoch [155/250] Fold [1] Train Loss: 0.1351, Train Acc: 0.5292 Val Loss: 0.1322, Val Acc: 0.5436, Macro F1: 0.4816, MCC: 0.3538
# Epoch [156/250] Fold [1] Train Loss: 0.1331, Train Acc: 0.5348 Val Loss: 0.1323, Val Acc: 0.5250, Macro F1: 0.4755, MCC: 0.3392
# Epoch [157/250] Fold [1] Train Loss: 0.1351, Train Acc: 0.5246 Val Loss: 0.1328, Val Acc: 0.5455, Macro F1: 0.4923, MCC: 0.3588
# Epoch [158/250] Fold [1] Train Loss: 0.1331, Train Acc: 0.5265 Val Loss: 0.1321, Val Acc: 0.5417, Macro F1: 0.4796, MCC: 0.3536
# Epoch [159/250] Fold [1] Train Loss: 0.1348, Train Acc: 0.5227 Val Loss: 0.1332, Val Acc: 0.5362, Macro F1: 0.4909, MCC: 0.3522
# Epoch [160/250] Fold [1] Train Loss: 0.1343, Train Acc: 0.5279 Val Loss: 0.1331, Val Acc: 0.5343, Macro F1: 0.4793, MCC: 0.3440
# Epoch [161/250] Fold [1] Train Loss: 0.1327, Train Acc: 0.5469 Val Loss: 0.1324, Val Acc: 0.5417, Macro F1: 0.4867, MCC: 0.3526
# Epoch [162/250] Fold [1] Train Loss: 0.1335, Train Acc: 0.5311 Val Loss: 0.1320, Val Acc: 0.5380, Macro F1: 0.4809, MCC: 0.3458
# Epoch [163/250] Fold [1] Train Loss: 0.1342, Train Acc: 0.5325 Val Loss: 0.1329, Val Acc: 0.5399, Macro F1: 0.4932, MCC: 0.3516
# Epoch [164/250] Fold [1] Train Loss: 0.1346, Train Acc: 0.5181 Val Loss: 0.1320, Val Acc: 0.5343, Macro F1: 0.4859, MCC: 0.3469
# Epoch [165/250] Fold [1] Train Loss: 0.1337, Train Acc: 0.5200 Val Loss: 0.1331, Val Acc: 0.5325, Macro F1: 0.4849, MCC: 0.3440
# Epoch [166/250] Fold [1] Train Loss: 0.1341, Train Acc: 0.5283 Val Loss: 0.1328, Val Acc: 0.5399, Macro F1: 0.4925, MCC: 0.3537
# Epoch [167/250] Fold [1] Train Loss: 0.1331, Train Acc: 0.5353 Val Loss: 0.1323, Val Acc: 0.5455, Macro F1: 0.4824, MCC: 0.3549
# Epoch [168/250] Fold [1] Train Loss: 0.1352, Train Acc: 0.5330 Val Loss: 0.1338, Val Acc: 0.5288, Macro F1: 0.4773, MCC: 0.3378
# Epoch [169/250] Fold [1] Train Loss: 0.1351, Train Acc: 0.5255 Val Loss: 0.1329, Val Acc: 0.5492, Macro F1: 0.4769, MCC: 0.3582
# Epoch [170/250] Fold [1] Train Loss: 0.1345, Train Acc: 0.5181 Val Loss: 0.1328, Val Acc: 0.5380, Macro F1: 0.4819, MCC: 0.3483
# Epoch [171/250] Fold [1] Train Loss: 0.1351, Train Acc: 0.5181 Val Loss: 0.1328, Val Acc: 0.5399, Macro F1: 0.4781, MCC: 0.3497
# Epoch [172/250] Fold [1] Train Loss: 0.1333, Train Acc: 0.5441 Val Loss: 0.1326, Val Acc: 0.5492, Macro F1: 0.4817, MCC: 0.3589
# Epoch [173/250] Fold [1] Train Loss: 0.1344, Train Acc: 0.5232 Val Loss: 0.1324, Val Acc: 0.5306, Macro F1: 0.4724, MCC: 0.3424
# Epoch [174/250] Fold [1] Train Loss: 0.1350, Train Acc: 0.5283 Val Loss: 0.1326, Val Acc: 0.5362, Macro F1: 0.4827, MCC: 0.3448
# Epoch [175/250] Fold [1] Train Loss: 0.1350, Train Acc: 0.5269 Val Loss: 0.1331, Val Acc: 0.5436, Macro F1: 0.4772, MCC: 0.3551
# Epoch [176/250] Fold [1] Train Loss: 0.1341, Train Acc: 0.5339 Val Loss: 0.1327, Val Acc: 0.5250, Macro F1: 0.4729, MCC: 0.3354
# Epoch [177/250] Fold [1] Train Loss: 0.1336, Train Acc: 0.5176 Val Loss: 0.1327, Val Acc: 0.5399, Macro F1: 0.4821, MCC: 0.3501
# Epoch [178/250] Fold [1] Train Loss: 0.1341, Train Acc: 0.5297 Val Loss: 0.1328, Val Acc: 0.5306, Macro F1: 0.4749, MCC: 0.3413
# Epoch [179/250] Fold [1] Train Loss: 0.1340, Train Acc: 0.5320 Val Loss: 0.1327, Val Acc: 0.5380, Macro F1: 0.4834, MCC: 0.3501
# Epoch [180/250] Fold [1] Train Loss: 0.1335, Train Acc: 0.5297 Val Loss: 0.1327, Val Acc: 0.5417, Macro F1: 0.4832, MCC: 0.3556
# Epoch [181/250] Fold [1] Train Loss: 0.1338, Train Acc: 0.5297 Val Loss: 0.1320, Val Acc: 0.5473, Macro F1: 0.4919, MCC: 0.3581
# Epoch [182/250] Fold [1] Train Loss: 0.1330, Train Acc: 0.5353 Val Loss: 0.1324, Val Acc: 0.5399, Macro F1: 0.4892, MCC: 0.3541
# Epoch [183/250] Fold [1] Train Loss: 0.1341, Train Acc: 0.5237 Val Loss: 0.1319, Val Acc: 0.5455, Macro F1: 0.4865, MCC: 0.3569
# Epoch [184/250] Fold [1] Train Loss: 0.1344, Train Acc: 0.5325 Val Loss: 0.1329, Val Acc: 0.5399, Macro F1: 0.4869, MCC: 0.3543
# Epoch [185/250] Fold [1] Train Loss: 0.1342, Train Acc: 0.5320 Val Loss: 0.1331, Val Acc: 0.5158, Macro F1: 0.4624, MCC: 0.3313
# Epoch [186/250] Fold [1] Train Loss: 0.1331, Train Acc: 0.5311 Val Loss: 0.1323, Val Acc: 0.5473, Macro F1: 0.4948, MCC: 0.3622
# Epoch [187/250] Fold [1] Train Loss: 0.1338, Train Acc: 0.5348 Val Loss: 0.1321, Val Acc: 0.5399, Macro F1: 0.4854, MCC: 0.3536
# Epoch [188/250] Fold [1] Train Loss: 0.1331, Train Acc: 0.5413 Val Loss: 0.1328, Val Acc: 0.5473, Macro F1: 0.4911, MCC: 0.3589
# Epoch [189/250] Fold [1] Train Loss: 0.1331, Train Acc: 0.5311 Val Loss: 0.1323, Val Acc: 0.5288, Macro F1: 0.4856, MCC: 0.3472
# Epoch [190/250] Fold [1] Train Loss: 0.1354, Train Acc: 0.5269 Val Loss: 0.1328, Val Acc: 0.5510, Macro F1: 0.4876, MCC: 0.3604
# Epoch [191/250] Fold [1] Train Loss: 0.1348, Train Acc: 0.5311 Val Loss: 0.1328, Val Acc: 0.5455, Macro F1: 0.4874, MCC: 0.3574
# Epoch [192/250] Fold [1] Train Loss: 0.1338, Train Acc: 0.5269 Val Loss: 0.1325, Val Acc: 0.5380, Macro F1: 0.4775, MCC: 0.3508
# Epoch [193/250] Fold [1] Train Loss: 0.1332, Train Acc: 0.5344 Val Loss: 0.1325, Val Acc: 0.5362, Macro F1: 0.4855, MCC: 0.3509
# Epoch [194/250] Fold [1] Train Loss: 0.1334, Train Acc: 0.5348 Val Loss: 0.1324, Val Acc: 0.5455, Macro F1: 0.4867, MCC: 0.3564
# Epoch [195/250] Fold [1] Train Loss: 0.1330, Train Acc: 0.5339 Val Loss: 0.1326, Val Acc: 0.5380, Macro F1: 0.4832, MCC: 0.3494
# Epoch [196/250] Fold [1] Train Loss: 0.1330, Train Acc: 0.5269 Val Loss: 0.1327, Val Acc: 0.5362, Macro F1: 0.4869, MCC: 0.3483
# Epoch [197/250] Fold [1] Train Loss: 0.1334, Train Acc: 0.5246 Val Loss: 0.1326, Val Acc: 0.5417, Macro F1: 0.4869, MCC: 0.3548
# Epoch [198/250] Fold [1] Train Loss: 0.1320, Train Acc: 0.5232 Val Loss: 0.1320, Val Acc: 0.5306, Macro F1: 0.4746, MCC: 0.3420
# Epoch [199/250] Fold [1] Train Loss: 0.1331, Train Acc: 0.5320 Val Loss: 0.1328, Val Acc: 0.5399, Macro F1: 0.4853, MCC: 0.3497
# Epoch [200/250] Fold [1] Train Loss: 0.1332, Train Acc: 0.5218 Val Loss: 0.1324, Val Acc: 0.5455, Macro F1: 0.4837, MCC: 0.3570
# Epoch [201/250] Fold [1] Train Loss: 0.1349, Train Acc: 0.5283 Val Loss: 0.1325, Val Acc: 0.5473, Macro F1: 0.4933, MCC: 0.3614
# Epoch [202/250] Fold [1] Train Loss: 0.1328, Train Acc: 0.5344 Val Loss: 0.1318, Val Acc: 0.5269, Macro F1: 0.4709, MCC: 0.3357
# Epoch [203/250] Fold [1] Train Loss: 0.1334, Train Acc: 0.5297 Val Loss: 0.1320, Val Acc: 0.5288, Macro F1: 0.4878, MCC: 0.3453
# Epoch [204/250] Fold [1] Train Loss: 0.1335, Train Acc: 0.5381 Val Loss: 0.1327, Val Acc: 0.5473, Macro F1: 0.4972, MCC: 0.3601
# Epoch [205/250] Fold [1] Train Loss: 0.1340, Train Acc: 0.5316 Val Loss: 0.1325, Val Acc: 0.5325, Macro F1: 0.4856, MCC: 0.3468
# Epoch [206/250] Fold [1] Train Loss: 0.1332, Train Acc: 0.5255 Val Loss: 0.1323, Val Acc: 0.5325, Macro F1: 0.4872, MCC: 0.3462
# Epoch [207/250] Fold [1] Train Loss: 0.1331, Train Acc: 0.5218 Val Loss: 0.1318, Val Acc: 0.5288, Macro F1: 0.4797, MCC: 0.3418
# Epoch [208/250] Fold [1] Train Loss: 0.1333, Train Acc: 0.5251 Val Loss: 0.1334, Val Acc: 0.5492, Macro F1: 0.4849, MCC: 0.3595
# Epoch [209/250] Fold [1] Train Loss: 0.1336, Train Acc: 0.5320 Val Loss: 0.1333, Val Acc: 0.5473, Macro F1: 0.4877, MCC: 0.3601
# Epoch [210/250] Fold [1] Train Loss: 0.1342, Train Acc: 0.5348 Val Loss: 0.1324, Val Acc: 0.5417, Macro F1: 0.4912, MCC: 0.3588
# Epoch [211/250] Fold [1] Train Loss: 0.1330, Train Acc: 0.5464 Val Loss: 0.1326, Val Acc: 0.5399, Macro F1: 0.4945, MCC: 0.3570
# Epoch [212/250] Fold [1] Train Loss: 0.1336, Train Acc: 0.5381 Val Loss: 0.1327, Val Acc: 0.5269, Macro F1: 0.4845, MCC: 0.3384
# Epoch [213/250] Fold [1] Train Loss: 0.1346, Train Acc: 0.5302 Val Loss: 0.1333, Val Acc: 0.5455, Macro F1: 0.4700, MCC: 0.3521
# Epoch [214/250] Fold [1] Train Loss: 0.1330, Train Acc: 0.5362 Val Loss: 0.1325, Val Acc: 0.5343, Macro F1: 0.4838, MCC: 0.3480
# Epoch [215/250] Fold [1] Train Loss: 0.1318, Train Acc: 0.5432 Val Loss: 0.1320, Val Acc: 0.5343, Macro F1: 0.4917, MCC: 0.3506
# Epoch [216/250] Fold [1] Train Loss: 0.1330, Train Acc: 0.5348 Val Loss: 0.1322, Val Acc: 0.5306, Macro F1: 0.4834, MCC: 0.3442
# Epoch [217/250] Fold [1] Train Loss: 0.1337, Train Acc: 0.5334 Val Loss: 0.1326, Val Acc: 0.5250, Macro F1: 0.4794, MCC: 0.3352
# Epoch [218/250] Fold [1] Train Loss: 0.1334, Train Acc: 0.5376 Val Loss: 0.1326, Val Acc: 0.5250, Macro F1: 0.4817, MCC: 0.3378
# Epoch [219/250] Fold [1] Train Loss: 0.1335, Train Acc: 0.5348 Val Loss: 0.1326, Val Acc: 0.5325, Macro F1: 0.4719, MCC: 0.3399
# Epoch [220/250] Fold [1] Train Loss: 0.1342, Train Acc: 0.5325 Val Loss: 0.1327, Val Acc: 0.5380, Macro F1: 0.4832, MCC: 0.3486
# Epoch [221/250] Fold [1] Train Loss: 0.1330, Train Acc: 0.5353 Val Loss: 0.1327, Val Acc: 0.5380, Macro F1: 0.4931, MCC: 0.3514
# Epoch [222/250] Fold [1] Train Loss: 0.1334, Train Acc: 0.5246 Val Loss: 0.1326, Val Acc: 0.5362, Macro F1: 0.4930, MCC: 0.3536
# Epoch [223/250] Fold [1] Train Loss: 0.1343, Train Acc: 0.5209 Val Loss: 0.1328, Val Acc: 0.5306, Macro F1: 0.4833, MCC: 0.3431
# Epoch [224/250] Fold [1] Train Loss: 0.1338, Train Acc: 0.5297 Val Loss: 0.1328, Val Acc: 0.5269, Macro F1: 0.4835, MCC: 0.3417
# Epoch [225/250] Fold [1] Train Loss: 0.1326, Train Acc: 0.5283 Val Loss: 0.1321, Val Acc: 0.5250, Macro F1: 0.4820, MCC: 0.3395
# Epoch [226/250] Fold [1] Train Loss: 0.1327, Train Acc: 0.5255 Val Loss: 0.1322, Val Acc: 0.5417, Macro F1: 0.4896, MCC: 0.3526
# Epoch [227/250] Fold [1] Train Loss: 0.1338, Train Acc: 0.5251 Val Loss: 0.1324, Val Acc: 0.5436, Macro F1: 0.4846, MCC: 0.3535
# Epoch [228/250] Fold [1] Train Loss: 0.1332, Train Acc: 0.5334 Val Loss: 0.1326, Val Acc: 0.5380, Macro F1: 0.4761, MCC: 0.3464
# Epoch [229/250] Fold [1] Train Loss: 0.1329, Train Acc: 0.5348 Val Loss: 0.1324, Val Acc: 0.5399, Macro F1: 0.4879, MCC: 0.3502
# Epoch [230/250] Fold [1] Train Loss: 0.1324, Train Acc: 0.5297 Val Loss: 0.1323, Val Acc: 0.5492, Macro F1: 0.4807, MCC: 0.3578
# Epoch [231/250] Fold [1] Train Loss: 0.1330, Train Acc: 0.5385 Val Loss: 0.1324, Val Acc: 0.5492, Macro F1: 0.4896, MCC: 0.3589
# Epoch [232/250] Fold [1] Train Loss: 0.1324, Train Acc: 0.5371 Val Loss: 0.1330, Val Acc: 0.5250, Macro F1: 0.4704, MCC: 0.3412
# Epoch [233/250] Fold [1] Train Loss: 0.1337, Train Acc: 0.5344 Val Loss: 0.1327, Val Acc: 0.5343, Macro F1: 0.4728, MCC: 0.3433
# Epoch [234/250] Fold [1] Train Loss: 0.1327, Train Acc: 0.5255 Val Loss: 0.1335, Val Acc: 0.5455, Macro F1: 0.4946, MCC: 0.3600
# Epoch [235/250] Fold [1] Train Loss: 0.1323, Train Acc: 0.5362 Val Loss: 0.1327, Val Acc: 0.5195, Macro F1: 0.4720, MCC: 0.3302
# Epoch [236/250] Fold [1] Train Loss: 0.1330, Train Acc: 0.5334 Val Loss: 0.1327, Val Acc: 0.5306, Macro F1: 0.4770, MCC: 0.3409
# Epoch [237/250] Fold [1] Train Loss: 0.1320, Train Acc: 0.5381 Val Loss: 0.1327, Val Acc: 0.5436, Macro F1: 0.5003, MCC: 0.3621
# Epoch [238/250] Fold [1] Train Loss: 0.1328, Train Acc: 0.5367 Val Loss: 0.1324, Val Acc: 0.5492, Macro F1: 0.4957, MCC: 0.3615
# Epoch [239/250] Fold [1] Train Loss: 0.1327, Train Acc: 0.5348 Val Loss: 0.1325, Val Acc: 0.5269, Macro F1: 0.4709, MCC: 0.3379
# Epoch [240/250] Fold [1] Train Loss: 0.1328, Train Acc: 0.5385 Val Loss: 0.1319, Val Acc: 0.5510, Macro F1: 0.4884, MCC: 0.3601
# Epoch [241/250] Fold [1] Train Loss: 0.1326, Train Acc: 0.5497 Val Loss: 0.1323, Val Acc: 0.5510, Macro F1: 0.4906, MCC: 0.3620
# Epoch [242/250] Fold [1] Train Loss: 0.1339, Train Acc: 0.5371 Val Loss: 0.1327, Val Acc: 0.5417, Macro F1: 0.4872, MCC: 0.3531
# Epoch [243/250] Fold [1] Train Loss: 0.1330, Train Acc: 0.5385 Val Loss: 0.1323, Val Acc: 0.5399, Macro F1: 0.4812, MCC: 0.3506
# Epoch [244/250] Fold [1] Train Loss: 0.1320, Train Acc: 0.5455 Val Loss: 0.1321, Val Acc: 0.5529, Macro F1: 0.4939, MCC: 0.3669
# Epoch [245/250] Fold [1] Train Loss: 0.1333, Train Acc: 0.5348 Val Loss: 0.1331, Val Acc: 0.5325, Macro F1: 0.4826, MCC: 0.3472
# Epoch [246/250] Fold [1] Train Loss: 0.1325, Train Acc: 0.5474 Val Loss: 0.1319, Val Acc: 0.5288, Macro F1: 0.4628, MCC: 0.3361
# Epoch [247/250] Fold [1] Train Loss: 0.1326, Train Acc: 0.5288 Val Loss: 0.1321, Val Acc: 0.5325, Macro F1: 0.4664, MCC: 0.3414
# Epoch [248/250] Fold [1] Train Loss: 0.1338, Train Acc: 0.5274 Val Loss: 0.1324, Val Acc: 0.5325, Macro F1: 0.4777, MCC: 0.3413
# Epoch [249/250] Fold [1] Train Loss: 0.1325, Train Acc: 0.5436 Val Loss: 0.1316, Val Acc: 0.5436, Macro F1: 0.4699, MCC: 0.3514
# Epoch [250/250] Fold [1] Train Loss: 0.1325, Train Acc: 0.5237 Val Loss: 0.1320, Val Acc: 0.5473, Macro F1: 0.4886, MCC: 0.3600
#
# --- Fold 2 ---
# /opt/conda/envs/pytorch/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Before Training: Training Loss: 0.1679, Training Accuracy: 0.3788, Validation Loss: 0.1670, Validation Accuracy: 0.3952, Macro F1: 0.1420, MCC: -0.0228
# Epoch [1/250] Fold [2] Train Loss: 0.1624, Train Acc: 0.3672 Val Loss: 0.1638, Val Acc: 0.4193, Macro F1: 0.1892, MCC: 0.0950
# Epoch [2/250] Fold [2] Train Loss: 0.1545, Train Acc: 0.4438 Val Loss: 0.1527, Val Acc: 0.4972, Macro F1: 0.3368, MCC: 0.2407
# Epoch [3/250] Fold [2] Train Loss: 0.1511, Train Acc: 0.4522 Val Loss: 0.1486, Val Acc: 0.5046, Macro F1: 0.3770, MCC: 0.2692
# Epoch [4/250] Fold [2] Train Loss: 0.1478, Train Acc: 0.4680 Val Loss: 0.1438, Val Acc: 0.5232, Macro F1: 0.4302, MCC: 0.3278
# Epoch [5/250] Fold [2] Train Loss: 0.1466, Train Acc: 0.4726 Val Loss: 0.1410, Val Acc: 0.5195, Macro F1: 0.4629, MCC: 0.3401
# Epoch [6/250] Fold [2] Train Loss: 0.1438, Train Acc: 0.4828 Val Loss: 0.1402, Val Acc: 0.5065, Macro F1: 0.4459, MCC: 0.3246
# Epoch [7/250] Fold [2] Train Loss: 0.1420, Train Acc: 0.4889 Val Loss: 0.1391, Val Acc: 0.5009, Macro F1: 0.4447, MCC: 0.3170
# Epoch [8/250] Fold [2] Train Loss: 0.1417, Train Acc: 0.4907 Val Loss: 0.1378, Val Acc: 0.5083, Macro F1: 0.4537, MCC: 0.3265
# Epoch [9/250] Fold [2] Train Loss: 0.1417, Train Acc: 0.4940 Val Loss: 0.1380, Val Acc: 0.4954, Macro F1: 0.4445, MCC: 0.3167
# Epoch [10/250] Fold [2] Train Loss: 0.1413, Train Acc: 0.4903 Val Loss: 0.1377, Val Acc: 0.5083, Macro F1: 0.4560, MCC: 0.3277
# Epoch [11/250] Fold [2] Train Loss: 0.1418, Train Acc: 0.4856 Val Loss: 0.1377, Val Acc: 0.5102, Macro F1: 0.4556, MCC: 0.3313
# Epoch [12/250] Fold [2] Train Loss: 0.1404, Train Acc: 0.5079 Val Loss: 0.1372, Val Acc: 0.5158, Macro F1: 0.4649, MCC: 0.3380
# Epoch [13/250] Fold [2] Train Loss: 0.1395, Train Acc: 0.5223 Val Loss: 0.1372, Val Acc: 0.5083, Macro F1: 0.4564, MCC: 0.3285
# Epoch [14/250] Fold [2] Train Loss: 0.1398, Train Acc: 0.5074 Val Loss: 0.1369, Val Acc: 0.5121, Macro F1: 0.4622, MCC: 0.3327
# Epoch [15/250] Fold [2] Train Loss: 0.1401, Train Acc: 0.5065 Val Loss: 0.1374, Val Acc: 0.5009, Macro F1: 0.4557, MCC: 0.3199
# Epoch [16/250] Fold [2] Train Loss: 0.1401, Train Acc: 0.5158 Val Loss: 0.1369, Val Acc: 0.5028, Macro F1: 0.4566, MCC: 0.3255
# Epoch [17/250] Fold [2] Train Loss: 0.1381, Train Acc: 0.5176 Val Loss: 0.1370, Val Acc: 0.5102, Macro F1: 0.4551, MCC: 0.3283
# Epoch [18/250] Fold [2] Train Loss: 0.1398, Train Acc: 0.5037 Val Loss: 0.1382, Val Acc: 0.4972, Macro F1: 0.4475, MCC: 0.3181
# Epoch [19/250] Fold [2] Train Loss: 0.1404, Train Acc: 0.5074 Val Loss: 0.1371, Val Acc: 0.5046, Macro F1: 0.4529, MCC: 0.3217
# Epoch [20/250] Fold [2] Train Loss: 0.1385, Train Acc: 0.5056 Val Loss: 0.1370, Val Acc: 0.4898, Macro F1: 0.4456, MCC: 0.3094
# Epoch [21/250] Fold [2] Train Loss: 0.1381, Train Acc: 0.5097 Val Loss: 0.1366, Val Acc: 0.5009, Macro F1: 0.4597, MCC: 0.3214
# Epoch [22/250] Fold [2] Train Loss: 0.1385, Train Acc: 0.5102 Val Loss: 0.1366, Val Acc: 0.5083, Macro F1: 0.4655, MCC: 0.3235
# Epoch [23/250] Fold [2] Train Loss: 0.1382, Train Acc: 0.5107 Val Loss: 0.1371, Val Acc: 0.4991, Macro F1: 0.4537, MCC: 0.3149
# Epoch [24/250] Fold [2] Train Loss: 0.1383, Train Acc: 0.5162 Val Loss: 0.1368, Val Acc: 0.5009, Macro F1: 0.4541, MCC: 0.3218
# Epoch [25/250] Fold [2] Train Loss: 0.1385, Train Acc: 0.5084 Val Loss: 0.1370, Val Acc: 0.5083, Macro F1: 0.4630, MCC: 0.3295
# Epoch [26/250] Fold [2] Train Loss: 0.1374, Train Acc: 0.5227 Val Loss: 0.1376, Val Acc: 0.4879, Macro F1: 0.4383, MCC: 0.3009
# Epoch [27/250] Fold [2] Train Loss: 0.1380, Train Acc: 0.5162 Val Loss: 0.1367, Val Acc: 0.4972, Macro F1: 0.4508, MCC: 0.3184
# Epoch [28/250] Fold [2] Train Loss: 0.1372, Train Acc: 0.5139 Val Loss: 0.1359, Val Acc: 0.5028, Macro F1: 0.4538, MCC: 0.3184
# Epoch [29/250] Fold [2] Train Loss: 0.1383, Train Acc: 0.5167 Val Loss: 0.1358, Val Acc: 0.5046, Macro F1: 0.4596, MCC: 0.3192
# Epoch [30/250] Fold [2] Train Loss: 0.1374, Train Acc: 0.5079 Val Loss: 0.1364, Val Acc: 0.4991, Macro F1: 0.4581, MCC: 0.3188
# Epoch [31/250] Fold [2] Train Loss: 0.1388, Train Acc: 0.5070 Val Loss: 0.1365, Val Acc: 0.5028, Macro F1: 0.4510, MCC: 0.3162
# Epoch [32/250] Fold [2] Train Loss: 0.1372, Train Acc: 0.5223 Val Loss: 0.1370, Val Acc: 0.5046, Macro F1: 0.4532, MCC: 0.3211
# Epoch [33/250] Fold [2] Train Loss: 0.1375, Train Acc: 0.5237 Val Loss: 0.1362, Val Acc: 0.5102, Macro F1: 0.4607, MCC: 0.3214
# Epoch [34/250] Fold [2] Train Loss: 0.1373, Train Acc: 0.5046 Val Loss: 0.1369, Val Acc: 0.5028, Macro F1: 0.4511, MCC: 0.3175
# Epoch [35/250] Fold [2] Train Loss: 0.1372, Train Acc: 0.5181 Val Loss: 0.1374, Val Acc: 0.5009, Macro F1: 0.4470, MCC: 0.3182
# Epoch [36/250] Fold [2] Train Loss: 0.1369, Train Acc: 0.5246 Val Loss: 0.1362, Val Acc: 0.4991, Macro F1: 0.4510, MCC: 0.3195
# Epoch [37/250] Fold [2] Train Loss: 0.1369, Train Acc: 0.5283 Val Loss: 0.1370, Val Acc: 0.4917, Macro F1: 0.4449, MCC: 0.3095
# Epoch [38/250] Fold [2] Train Loss: 0.1367, Train Acc: 0.5334 Val Loss: 0.1360, Val Acc: 0.5028, Macro F1: 0.4572, MCC: 0.3247
# Epoch [39/250] Fold [2] Train Loss: 0.1390, Train Acc: 0.5158 Val Loss: 0.1366, Val Acc: 0.5065, Macro F1: 0.4519, MCC: 0.3270
# Epoch [40/250] Fold [2] Train Loss: 0.1373, Train Acc: 0.5144 Val Loss: 0.1368, Val Acc: 0.4935, Macro F1: 0.4452, MCC: 0.3052
# Epoch [41/250] Fold [2] Train Loss: 0.1385, Train Acc: 0.5167 Val Loss: 0.1361, Val Acc: 0.4972, Macro F1: 0.4459, MCC: 0.3060
# Epoch [42/250] Fold [2] Train Loss: 0.1368, Train Acc: 0.5167 Val Loss: 0.1362, Val Acc: 0.4972, Macro F1: 0.4497, MCC: 0.3119
# Epoch [43/250] Fold [2] Train Loss: 0.1365, Train Acc: 0.5279 Val Loss: 0.1359, Val Acc: 0.4898, Macro F1: 0.4364, MCC: 0.2990
# Epoch [44/250] Fold [2] Train Loss: 0.1375, Train Acc: 0.5232 Val Loss: 0.1351, Val Acc: 0.5158, Macro F1: 0.4519, MCC: 0.3274
# Epoch [45/250] Fold [2] Train Loss: 0.1372, Train Acc: 0.5279 Val Loss: 0.1365, Val Acc: 0.5046, Macro F1: 0.4469, MCC: 0.3188
# Epoch [46/250] Fold [2] Train Loss: 0.1371, Train Acc: 0.5251 Val Loss: 0.1358, Val Acc: 0.5139, Macro F1: 0.4571, MCC: 0.3284
# Epoch [47/250] Fold [2] Train Loss: 0.1373, Train Acc: 0.5288 Val Loss: 0.1363, Val Acc: 0.4991, Macro F1: 0.4474, MCC: 0.3103
# Epoch [48/250] Fold [2] Train Loss: 0.1367, Train Acc: 0.5162 Val Loss: 0.1368, Val Acc: 0.4991, Macro F1: 0.4534, MCC: 0.3140
# Epoch [49/250] Fold [2] Train Loss: 0.1359, Train Acc: 0.5241 Val Loss: 0.1364, Val Acc: 0.4935, Macro F1: 0.4401, MCC: 0.3068
# Epoch [50/250] Fold [2] Train Loss: 0.1370, Train Acc: 0.5237 Val Loss: 0.1368, Val Acc: 0.4991, Macro F1: 0.4459, MCC: 0.3182
# Epoch [51/250] Fold [2] Train Loss: 0.1369, Train Acc: 0.5255 Val Loss: 0.1368, Val Acc: 0.5028, Macro F1: 0.4456, MCC: 0.3184
# Epoch [52/250] Fold [2] Train Loss: 0.1360, Train Acc: 0.5135 Val Loss: 0.1367, Val Acc: 0.4954, Macro F1: 0.4417, MCC: 0.3075
# Epoch [53/250] Fold [2] Train Loss: 0.1368, Train Acc: 0.5116 Val Loss: 0.1366, Val Acc: 0.4972, Macro F1: 0.4468, MCC: 0.3132
# Epoch [54/250] Fold [2] Train Loss: 0.1356, Train Acc: 0.5265 Val Loss: 0.1364, Val Acc: 0.4972, Macro F1: 0.4441, MCC: 0.3138
# Epoch [55/250] Fold [2] Train Loss: 0.1369, Train Acc: 0.5265 Val Loss: 0.1369, Val Acc: 0.4954, Macro F1: 0.4384, MCC: 0.3060
# Epoch [56/250] Fold [2] Train Loss: 0.1357, Train Acc: 0.5292 Val Loss: 0.1360, Val Acc: 0.4954, Macro F1: 0.4394, MCC: 0.3102
# Epoch [57/250] Fold [2] Train Loss: 0.1366, Train Acc: 0.5269 Val Loss: 0.1355, Val Acc: 0.5009, Macro F1: 0.4393, MCC: 0.3091
# Epoch [58/250] Fold [2] Train Loss: 0.1368, Train Acc: 0.5297 Val Loss: 0.1363, Val Acc: 0.4954, Macro F1: 0.4421, MCC: 0.3112
# Epoch [59/250] Fold [2] Train Loss: 0.1376, Train Acc: 0.5204 Val Loss: 0.1365, Val Acc: 0.4991, Macro F1: 0.4440, MCC: 0.3124
# Epoch [60/250] Fold [2] Train Loss: 0.1360, Train Acc: 0.5195 Val Loss: 0.1368, Val Acc: 0.4861, Macro F1: 0.4351, MCC: 0.3044
# Epoch [61/250] Fold [2] Train Loss: 0.1361, Train Acc: 0.5227 Val Loss: 0.1361, Val Acc: 0.5009, Macro F1: 0.4428, MCC: 0.3125
# Epoch [62/250] Fold [2] Train Loss: 0.1364, Train Acc: 0.5255 Val Loss: 0.1361, Val Acc: 0.4898, Macro F1: 0.4311, MCC: 0.3008
# Epoch [63/250] Fold [2] Train Loss: 0.1360, Train Acc: 0.5218 Val Loss: 0.1368, Val Acc: 0.4917, Macro F1: 0.4298, MCC: 0.3075
# Epoch [64/250] Fold [2] Train Loss: 0.1363, Train Acc: 0.5274 Val Loss: 0.1363, Val Acc: 0.4954, Macro F1: 0.4328, MCC: 0.3085
# Epoch [65/250] Fold [2] Train Loss: 0.1369, Train Acc: 0.5186 Val Loss: 0.1358, Val Acc: 0.4972, Macro F1: 0.4428, MCC: 0.3076
# Epoch [66/250] Fold [2] Train Loss: 0.1354, Train Acc: 0.5255 Val Loss: 0.1362, Val Acc: 0.4972, Macro F1: 0.4404, MCC: 0.3085
# Epoch [67/250] Fold [2] Train Loss: 0.1361, Train Acc: 0.5218 Val Loss: 0.1355, Val Acc: 0.5065, Macro F1: 0.4369, MCC: 0.3175
# Epoch [68/250] Fold [2] Train Loss: 0.1348, Train Acc: 0.5251 Val Loss: 0.1351, Val Acc: 0.5102, Macro F1: 0.4494, MCC: 0.3171
# Epoch [69/250] Fold [2] Train Loss: 0.1353, Train Acc: 0.5288 Val Loss: 0.1351, Val Acc: 0.4972, Macro F1: 0.4362, MCC: 0.3034
# Epoch [70/250] Fold [2] Train Loss: 0.1362, Train Acc: 0.5200 Val Loss: 0.1356, Val Acc: 0.4917, Macro F1: 0.4326, MCC: 0.3037
# Epoch [71/250] Fold [2] Train Loss: 0.1357, Train Acc: 0.5246 Val Loss: 0.1354, Val Acc: 0.4954, Macro F1: 0.4350, MCC: 0.3041
# Epoch [72/250] Fold [2] Train Loss: 0.1354, Train Acc: 0.5223 Val Loss: 0.1354, Val Acc: 0.4954, Macro F1: 0.4380, MCC: 0.3054
# Epoch [73/250] Fold [2] Train Loss: 0.1344, Train Acc: 0.5395 Val Loss: 0.1349, Val Acc: 0.5009, Macro F1: 0.4427, MCC: 0.3121
# Epoch [74/250] Fold [2] Train Loss: 0.1347, Train Acc: 0.5297 Val Loss: 0.1352, Val Acc: 0.4954, Macro F1: 0.4354, MCC: 0.3055
# Epoch [75/250] Fold [2] Train Loss: 0.1350, Train Acc: 0.5204 Val Loss: 0.1349, Val Acc: 0.5046, Macro F1: 0.4435, MCC: 0.3071
# Epoch [76/250] Fold [2] Train Loss: 0.1356, Train Acc: 0.5274 Val Loss: 0.1350, Val Acc: 0.5009, Macro F1: 0.4430, MCC: 0.3140
# Epoch [77/250] Fold [2] Train Loss: 0.1357, Train Acc: 0.5097 Val Loss: 0.1360, Val Acc: 0.5009, Macro F1: 0.4424, MCC: 0.3109
# Epoch [78/250] Fold [2] Train Loss: 0.1351, Train Acc: 0.5311 Val Loss: 0.1351, Val Acc: 0.5046, Macro F1: 0.4453, MCC: 0.3124
# Epoch [79/250] Fold [2] Train Loss: 0.1357, Train Acc: 0.5279 Val Loss: 0.1362, Val Acc: 0.5009, Macro F1: 0.4519, MCC: 0.3170
# Epoch [80/250] Fold [2] Train Loss: 0.1362, Train Acc: 0.5153 Val Loss: 0.1352, Val Acc: 0.4935, Macro F1: 0.4320, MCC: 0.2969
# Epoch [81/250] Fold [2] Train Loss: 0.1356, Train Acc: 0.5316 Val Loss: 0.1351, Val Acc: 0.5102, Macro F1: 0.4502, MCC: 0.3215
# Epoch [82/250] Fold [2] Train Loss: 0.1352, Train Acc: 0.5223 Val Loss: 0.1348, Val Acc: 0.5102, Macro F1: 0.4498, MCC: 0.3204
# Epoch [83/250] Fold [2] Train Loss: 0.1346, Train Acc: 0.5227 Val Loss: 0.1357, Val Acc: 0.5028, Macro F1: 0.4409, MCC: 0.3140
# Epoch [84/250] Fold [2] Train Loss: 0.1348, Train Acc: 0.5325 Val Loss: 0.1344, Val Acc: 0.5121, Macro F1: 0.4492, MCC: 0.3183
# Epoch [85/250] Fold [2] Train Loss: 0.1364, Train Acc: 0.5176 Val Loss: 0.1358, Val Acc: 0.5083, Macro F1: 0.4424, MCC: 0.3209
# Epoch [86/250] Fold [2] Train Loss: 0.1360, Train Acc: 0.5200 Val Loss: 0.1349, Val Acc: 0.5213, Macro F1: 0.4540, MCC: 0.3284
# Epoch [87/250] Fold [2] Train Loss: 0.1351, Train Acc: 0.5362 Val Loss: 0.1357, Val Acc: 0.4991, Macro F1: 0.4385, MCC: 0.3120
# Epoch [88/250] Fold [2] Train Loss: 0.1348, Train Acc: 0.5269 Val Loss: 0.1351, Val Acc: 0.5028, Macro F1: 0.4323, MCC: 0.3088
# Epoch [89/250] Fold [2] Train Loss: 0.1357, Train Acc: 0.5167 Val Loss: 0.1353, Val Acc: 0.5083, Macro F1: 0.4512, MCC: 0.3201
# Epoch [90/250] Fold [2] Train Loss: 0.1350, Train Acc: 0.5274 Val Loss: 0.1353, Val Acc: 0.5028, Macro F1: 0.4405, MCC: 0.3130
# Epoch [91/250] Fold [2] Train Loss: 0.1361, Train Acc: 0.5251 Val Loss: 0.1359, Val Acc: 0.5046, Macro F1: 0.4315, MCC: 0.3140
# Epoch [92/250] Fold [2] Train Loss: 0.1360, Train Acc: 0.5339 Val Loss: 0.1357, Val Acc: 0.5083, Macro F1: 0.4378, MCC: 0.3158
# Epoch [93/250] Fold [2] Train Loss: 0.1350, Train Acc: 0.5302 Val Loss: 0.1354, Val Acc: 0.4991, Macro F1: 0.4345, MCC: 0.3071
# Epoch [94/250] Fold [2] Train Loss: 0.1345, Train Acc: 0.5320 Val Loss: 0.1358, Val Acc: 0.5046, Macro F1: 0.4479, MCC: 0.3158
# Epoch [95/250] Fold [2] Train Loss: 0.1345, Train Acc: 0.5330 Val Loss: 0.1358, Val Acc: 0.4954, Macro F1: 0.4418, MCC: 0.3096
# Epoch [96/250] Fold [2] Train Loss: 0.1344, Train Acc: 0.5283 Val Loss: 0.1354, Val Acc: 0.5102, Macro F1: 0.4499, MCC: 0.3212
# Epoch [97/250] Fold [2] Train Loss: 0.1340, Train Acc: 0.5297 Val Loss: 0.1356, Val Acc: 0.4991, Macro F1: 0.4420, MCC: 0.3142
# Epoch [98/250] Fold [2] Train Loss: 0.1356, Train Acc: 0.5241 Val Loss: 0.1355, Val Acc: 0.5028, Macro F1: 0.4478, MCC: 0.3154
# Epoch [99/250] Fold [2] Train Loss: 0.1349, Train Acc: 0.5209 Val Loss: 0.1353, Val Acc: 0.5028, Macro F1: 0.4465, MCC: 0.3125
# Epoch [100/250] Fold [2] Train Loss: 0.1345, Train Acc: 0.5302 Val Loss: 0.1353, Val Acc: 0.4954, Macro F1: 0.4344, MCC: 0.3012
# Epoch [101/250] Fold [2] Train Loss: 0.1345, Train Acc: 0.5413 Val Loss: 0.1346, Val Acc: 0.5028, Macro F1: 0.4322, MCC: 0.3067
# Epoch [102/250] Fold [2] Train Loss: 0.1348, Train Acc: 0.5288 Val Loss: 0.1358, Val Acc: 0.5028, Macro F1: 0.4382, MCC: 0.3167
# Epoch [103/250] Fold [2] Train Loss: 0.1351, Train Acc: 0.5395 Val Loss: 0.1349, Val Acc: 0.5269, Macro F1: 0.4505, MCC: 0.3345
# Epoch [104/250] Fold [2] Train Loss: 0.1340, Train Acc: 0.5288 Val Loss: 0.1363, Val Acc: 0.4917, Macro F1: 0.4256, MCC: 0.3033
# Epoch [105/250] Fold [2] Train Loss: 0.1353, Train Acc: 0.5306 Val Loss: 0.1359, Val Acc: 0.4917, Macro F1: 0.4357, MCC: 0.3006
# Epoch [106/250] Fold [2] Train Loss: 0.1341, Train Acc: 0.5413 Val Loss: 0.1352, Val Acc: 0.4991, Macro F1: 0.4450, MCC: 0.3127
# Epoch [107/250] Fold [2] Train Loss: 0.1351, Train Acc: 0.5214 Val Loss: 0.1352, Val Acc: 0.5213, Macro F1: 0.4632, MCC: 0.3392
# Epoch [108/250] Fold [2] Train Loss: 0.1340, Train Acc: 0.5232 Val Loss: 0.1367, Val Acc: 0.4898, Macro F1: 0.4285, MCC: 0.3082
# Epoch [109/250] Fold [2] Train Loss: 0.1337, Train Acc: 0.5209 Val Loss: 0.1349, Val Acc: 0.5195, Macro F1: 0.4491, MCC: 0.3290
# Epoch [110/250] Fold [2] Train Loss: 0.1350, Train Acc: 0.5200 Val Loss: 0.1360, Val Acc: 0.4861, Macro F1: 0.4280, MCC: 0.2969
# Epoch [111/250] Fold [2] Train Loss: 0.1347, Train Acc: 0.5292 Val Loss: 0.1359, Val Acc: 0.4879, Macro F1: 0.4298, MCC: 0.3039
# Epoch [112/250] Fold [2] Train Loss: 0.1350, Train Acc: 0.5283 Val Loss: 0.1347, Val Acc: 0.5158, Macro F1: 0.4499, MCC: 0.3218
# Epoch [113/250] Fold [2] Train Loss: 0.1337, Train Acc: 0.5297 Val Loss: 0.1348, Val Acc: 0.5139, Macro F1: 0.4490, MCC: 0.3235
# Epoch [114/250] Fold [2] Train Loss: 0.1339, Train Acc: 0.5409 Val Loss: 0.1352, Val Acc: 0.5102, Macro F1: 0.4422, MCC: 0.3179
# Epoch [115/250] Fold [2] Train Loss: 0.1347, Train Acc: 0.5237 Val Loss: 0.1357, Val Acc: 0.5046, Macro F1: 0.4383, MCC: 0.3131
# Epoch [116/250] Fold [2] Train Loss: 0.1357, Train Acc: 0.5186 Val Loss: 0.1357, Val Acc: 0.5250, Macro F1: 0.4610, MCC: 0.3368
# Epoch [117/250] Fold [2] Train Loss: 0.1337, Train Acc: 0.5311 Val Loss: 0.1354, Val Acc: 0.5009, Macro F1: 0.4373, MCC: 0.3039
# Epoch [118/250] Fold [2] Train Loss: 0.1332, Train Acc: 0.5409 Val Loss: 0.1349, Val Acc: 0.5139, Macro F1: 0.4622, MCC: 0.3243
# Epoch [119/250] Fold [2] Train Loss: 0.1336, Train Acc: 0.5325 Val Loss: 0.1356, Val Acc: 0.4991, Macro F1: 0.4410, MCC: 0.3114
# Epoch [120/250] Fold [2] Train Loss: 0.1344, Train Acc: 0.5395 Val Loss: 0.1355, Val Acc: 0.5139, Macro F1: 0.4449, MCC: 0.3223
# ...
# Epoch [126/250] Fold [5] Train Loss: 0.1359, Train Acc: 0.5258 Val Loss: 0.1347, Val Acc: 0.5297, Macro F1: 0.4794, MCC: 0.3513
# Epoch [127/250] Fold [5] Train Loss: 0.1352, Train Acc: 0.5165 Val Loss: 0.1342, Val Acc: 0.5428, Macro F1: 0.4960, MCC: 0.3731
# Epoch [128/250] Fold [5] Train Loss: 0.1353, Train Acc: 0.5276 Val Loss: 0.1345, Val Acc: 0.5353, Macro F1: 0.4896, MCC: 0.3652
# Epoch [129/250] Fold [5] Train Loss: 0.1373, Train Acc: 0.5179 Val Loss: 0.1344, Val Acc: 0.5409, Macro F1: 0.4916, MCC: 0.3672
# Epoch [130/250] Fold [5] Train Loss: 0.1360, Train Acc: 0.5327 Val Loss: 0.1347, Val Acc: 0.5297, Macro F1: 0.4816, MCC: 0.3602
# Epoch [131/250] Fold [5] Train Loss: 0.1363, Train Acc: 0.5202 Val Loss: 0.1338, Val Acc: 0.5502, Macro F1: 0.4961, MCC: 0.3781
# Epoch [132/250] Fold [5] Train Loss: 0.1358, Train Acc: 0.5206 Val Loss: 0.1343, Val Acc: 0.5465, Macro F1: 0.4993, MCC: 0.3785
# Epoch [133/250] Fold [5] Train Loss: 0.1360, Train Acc: 0.5267 Val Loss: 0.1343, Val Acc: 0.5502, Macro F1: 0.4992, MCC: 0.3814
# Epoch [134/250] Fold [5] Train Loss: 0.1360, Train Acc: 0.5169 Val Loss: 0.1336, Val Acc: 0.5613, Macro F1: 0.5039, MCC: 0.3889
# Epoch [135/250] Fold [5] Train Loss: 0.1358, Train Acc: 0.5258 Val Loss: 0.1343, Val Acc: 0.5520, Macro F1: 0.4986, MCC: 0.3807
# Epoch [136/250] Fold [5] Train Loss: 0.1354, Train Acc: 0.5174 Val Loss: 0.1340, Val Acc: 0.5502, Macro F1: 0.4971, MCC: 0.3764
# Epoch [137/250] Fold [5] Train Loss: 0.1353, Train Acc: 0.5295 Val Loss: 0.1345, Val Acc: 0.5539, Macro F1: 0.4992, MCC: 0.3822
# Epoch [138/250] Fold [5] Train Loss: 0.1342, Train Acc: 0.5151 Val Loss: 0.1350, Val Acc: 0.5279, Macro F1: 0.4799, MCC: 0.3572
# Epoch [139/250] Fold [5] Train Loss: 0.1357, Train Acc: 0.5169 Val Loss: 0.1355, Val Acc: 0.5279, Macro F1: 0.4798, MCC: 0.3579
# Epoch [140/250] Fold [5] Train Loss: 0.1353, Train Acc: 0.5202 Val Loss: 0.1331, Val Acc: 0.5818, Macro F1: 0.5217, MCC: 0.4128
# Epoch [141/250] Fold [5] Train Loss: 0.1348, Train Acc: 0.5253 Val Loss: 0.1338, Val Acc: 0.5632, Macro F1: 0.5108, MCC: 0.3964
# Epoch [142/250] Fold [5] Train Loss: 0.1357, Train Acc: 0.5206 Val Loss: 0.1341, Val Acc: 0.5706, Macro F1: 0.5136, MCC: 0.4043
# Epoch [143/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5211 Val Loss: 0.1333, Val Acc: 0.5632, Macro F1: 0.5067, MCC: 0.3949
# Epoch [144/250] Fold [5] Train Loss: 0.1349, Train Acc: 0.5271 Val Loss: 0.1336, Val Acc: 0.5465, Macro F1: 0.4903, MCC: 0.3754
# Epoch [145/250] Fold [5] Train Loss: 0.1346, Train Acc: 0.5225 Val Loss: 0.1346, Val Acc: 0.5520, Macro F1: 0.5069, MCC: 0.3859
# Epoch [146/250] Fold [5] Train Loss: 0.1345, Train Acc: 0.5336 Val Loss: 0.1338, Val Acc: 0.5520, Macro F1: 0.5010, MCC: 0.3812
# Epoch [147/250] Fold [5] Train Loss: 0.1350, Train Acc: 0.5202 Val Loss: 0.1337, Val Acc: 0.5613, Macro F1: 0.5137, MCC: 0.3948
# Epoch [148/250] Fold [5] Train Loss: 0.1356, Train Acc: 0.5206 Val Loss: 0.1349, Val Acc: 0.5428, Macro F1: 0.4931, MCC: 0.3748
# Epoch [149/250] Fold [5] Train Loss: 0.1342, Train Acc: 0.5262 Val Loss: 0.1330, Val Acc: 0.5595, Macro F1: 0.5081, MCC: 0.3893
# Epoch [150/250] Fold [5] Train Loss: 0.1349, Train Acc: 0.5271 Val Loss: 0.1332, Val Acc: 0.5613, Macro F1: 0.5114, MCC: 0.3927
# Epoch [151/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5239 Val Loss: 0.1327, Val Acc: 0.5651, Macro F1: 0.5141, MCC: 0.3967
# Epoch [152/250] Fold [5] Train Loss: 0.1356, Train Acc: 0.5169 Val Loss: 0.1334, Val Acc: 0.5520, Macro F1: 0.5017, MCC: 0.3819
# Epoch [153/250] Fold [5] Train Loss: 0.1355, Train Acc: 0.5244 Val Loss: 0.1347, Val Acc: 0.5446, Macro F1: 0.5001, MCC: 0.3766
# Epoch [154/250] Fold [5] Train Loss: 0.1360, Train Acc: 0.5183 Val Loss: 0.1342, Val Acc: 0.5613, Macro F1: 0.5088, MCC: 0.3937
# Epoch [155/250] Fold [5] Train Loss: 0.1354, Train Acc: 0.5267 Val Loss: 0.1335, Val Acc: 0.5651, Macro F1: 0.5129, MCC: 0.3980
# Epoch [156/250] Fold [5] Train Loss: 0.1355, Train Acc: 0.5183 Val Loss: 0.1336, Val Acc: 0.5669, Macro F1: 0.5136, MCC: 0.4019
# Epoch [157/250] Fold [5] Train Loss: 0.1358, Train Acc: 0.5392 Val Loss: 0.1337, Val Acc: 0.5613, Macro F1: 0.5017, MCC: 0.3905
# Epoch [158/250] Fold [5] Train Loss: 0.1350, Train Acc: 0.5234 Val Loss: 0.1339, Val Acc: 0.5669, Macro F1: 0.5165, MCC: 0.4006
# Epoch [159/250] Fold [5] Train Loss: 0.1355, Train Acc: 0.5197 Val Loss: 0.1342, Val Acc: 0.5558, Macro F1: 0.5039, MCC: 0.3839
# Epoch [160/250] Fold [5] Train Loss: 0.1360, Train Acc: 0.5155 Val Loss: 0.1341, Val Acc: 0.5632, Macro F1: 0.5035, MCC: 0.3889
# Epoch [161/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5364 Val Loss: 0.1343, Val Acc: 0.5595, Macro F1: 0.5093, MCC: 0.3908
# Epoch [162/250] Fold [5] Train Loss: 0.1341, Train Acc: 0.5323 Val Loss: 0.1331, Val Acc: 0.5632, Macro F1: 0.5074, MCC: 0.3912
# Epoch [163/250] Fold [5] Train Loss: 0.1342, Train Acc: 0.5276 Val Loss: 0.1337, Val Acc: 0.5428, Macro F1: 0.4963, MCC: 0.3691
# Epoch [164/250] Fold [5] Train Loss: 0.1342, Train Acc: 0.5318 Val Loss: 0.1326, Val Acc: 0.5502, Macro F1: 0.4977, MCC: 0.3756
# Epoch [165/250] Fold [5] Train Loss: 0.1363, Train Acc: 0.5114 Val Loss: 0.1344, Val Acc: 0.5595, Macro F1: 0.5104, MCC: 0.3907
# Epoch [166/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5220 Val Loss: 0.1329, Val Acc: 0.5539, Macro F1: 0.5050, MCC: 0.3841
# Epoch [167/250] Fold [5] Train Loss: 0.1348, Train Acc: 0.5327 Val Loss: 0.1333, Val Acc: 0.5520, Macro F1: 0.5004, MCC: 0.3784
# Epoch [168/250] Fold [5] Train Loss: 0.1348, Train Acc: 0.5188 Val Loss: 0.1338, Val Acc: 0.5428, Macro F1: 0.4953, MCC: 0.3710
# Epoch [169/250] Fold [5] Train Loss: 0.1349, Train Acc: 0.5374 Val Loss: 0.1336, Val Acc: 0.5428, Macro F1: 0.4918, MCC: 0.3741
# Epoch [170/250] Fold [5] Train Loss: 0.1358, Train Acc: 0.5230 Val Loss: 0.1342, Val Acc: 0.5428, Macro F1: 0.4976, MCC: 0.3738
# Epoch [171/250] Fold [5] Train Loss: 0.1354, Train Acc: 0.5267 Val Loss: 0.1339, Val Acc: 0.5706, Macro F1: 0.5092, MCC: 0.4012
# Epoch [172/250] Fold [5] Train Loss: 0.1348, Train Acc: 0.5253 Val Loss: 0.1330, Val Acc: 0.5613, Macro F1: 0.4923, MCC: 0.3868
# Epoch [173/250] Fold [5] Train Loss: 0.1337, Train Acc: 0.5383 Val Loss: 0.1327, Val Acc: 0.5520, Macro F1: 0.5031, MCC: 0.3796
# Epoch [174/250] Fold [5] Train Loss: 0.1330, Train Acc: 0.5211 Val Loss: 0.1330, Val Acc: 0.5465, Macro F1: 0.5000, MCC: 0.3805
# Epoch [175/250] Fold [5] Train Loss: 0.1344, Train Acc: 0.5179 Val Loss: 0.1333, Val Acc: 0.5465, Macro F1: 0.5012, MCC: 0.3758
# Epoch [176/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5304 Val Loss: 0.1335, Val Acc: 0.5502, Macro F1: 0.5022, MCC: 0.3774
# Epoch [177/250] Fold [5] Train Loss: 0.1368, Train Acc: 0.5169 Val Loss: 0.1340, Val Acc: 0.5372, Macro F1: 0.4927, MCC: 0.3642
# Epoch [178/250] Fold [5] Train Loss: 0.1348, Train Acc: 0.5276 Val Loss: 0.1334, Val Acc: 0.5446, Macro F1: 0.4919, MCC: 0.3710
# Epoch [179/250] Fold [5] Train Loss: 0.1347, Train Acc: 0.5206 Val Loss: 0.1341, Val Acc: 0.5483, Macro F1: 0.4948, MCC: 0.3767
# Epoch [180/250] Fold [5] Train Loss: 0.1350, Train Acc: 0.5239 Val Loss: 0.1340, Val Acc: 0.5372, Macro F1: 0.4884, MCC: 0.3648
# Epoch [181/250] Fold [5] Train Loss: 0.1344, Train Acc: 0.5206 Val Loss: 0.1324, Val Acc: 0.5632, Macro F1: 0.4997, MCC: 0.3890
# Epoch [182/250] Fold [5] Train Loss: 0.1349, Train Acc: 0.5155 Val Loss: 0.1335, Val Acc: 0.5446, Macro F1: 0.4972, MCC: 0.3747
# Epoch [183/250] Fold [5] Train Loss: 0.1346, Train Acc: 0.5188 Val Loss: 0.1334, Val Acc: 0.5558, Macro F1: 0.5064, MCC: 0.3853
# Epoch [184/250] Fold [5] Train Loss: 0.1353, Train Acc: 0.5202 Val Loss: 0.1338, Val Acc: 0.5688, Macro F1: 0.5076, MCC: 0.3961
# Epoch [185/250] Fold [5] Train Loss: 0.1350, Train Acc: 0.5211 Val Loss: 0.1338, Val Acc: 0.5613, Macro F1: 0.5088, MCC: 0.3913
# Epoch [186/250] Fold [5] Train Loss: 0.1355, Train Acc: 0.5146 Val Loss: 0.1344, Val Acc: 0.5446, Macro F1: 0.4948, MCC: 0.3752
# Epoch [187/250] Fold [5] Train Loss: 0.1347, Train Acc: 0.5262 Val Loss: 0.1336, Val Acc: 0.5613, Macro F1: 0.5023, MCC: 0.3870
# Epoch [188/250] Fold [5] Train Loss: 0.1350, Train Acc: 0.5137 Val Loss: 0.1344, Val Acc: 0.5595, Macro F1: 0.5079, MCC: 0.3892
# Epoch [189/250] Fold [5] Train Loss: 0.1354, Train Acc: 0.5211 Val Loss: 0.1348, Val Acc: 0.5595, Macro F1: 0.5060, MCC: 0.3960
# Epoch [190/250] Fold [5] Train Loss: 0.1348, Train Acc: 0.5160 Val Loss: 0.1340, Val Acc: 0.5539, Macro F1: 0.4941, MCC: 0.3854
# Epoch [191/250] Fold [5] Train Loss: 0.1349, Train Acc: 0.5295 Val Loss: 0.1347, Val Acc: 0.5409, Macro F1: 0.4854, MCC: 0.3688
# Epoch [192/250] Fold [5] Train Loss: 0.1349, Train Acc: 0.5234 Val Loss: 0.1342, Val Acc: 0.5688, Macro F1: 0.5169, MCC: 0.3997
# Epoch [193/250] Fold [5] Train Loss: 0.1349, Train Acc: 0.5276 Val Loss: 0.1330, Val Acc: 0.5613, Macro F1: 0.5116, MCC: 0.3912
# Epoch [194/250] Fold [5] Train Loss: 0.1329, Train Acc: 0.5355 Val Loss: 0.1329, Val Acc: 0.5502, Macro F1: 0.5012, MCC: 0.3777
# Epoch [195/250] Fold [5] Train Loss: 0.1334, Train Acc: 0.5411 Val Loss: 0.1325, Val Acc: 0.5669, Macro F1: 0.5138, MCC: 0.3966
# Epoch [196/250] Fold [5] Train Loss: 0.1342, Train Acc: 0.5304 Val Loss: 0.1329, Val Acc: 0.5669, Macro F1: 0.5106, MCC: 0.3938
# Epoch [197/250] Fold [5] Train Loss: 0.1336, Train Acc: 0.5313 Val Loss: 0.1343, Val Acc: 0.5297, Macro F1: 0.4790, MCC: 0.3544
# Epoch [198/250] Fold [5] Train Loss: 0.1345, Train Acc: 0.5304 Val Loss: 0.1340, Val Acc: 0.5576, Macro F1: 0.5054, MCC: 0.3857
# Epoch [199/250] Fold [5] Train Loss: 0.1340, Train Acc: 0.5239 Val Loss: 0.1332, Val Acc: 0.5465, Macro F1: 0.4970, MCC: 0.3743
# Epoch [200/250] Fold [5] Train Loss: 0.1354, Train Acc: 0.5290 Val Loss: 0.1336, Val Acc: 0.5409, Macro F1: 0.4939, MCC: 0.3685
# Epoch [201/250] Fold [5] Train Loss: 0.1353, Train Acc: 0.5401 Val Loss: 0.1333, Val Acc: 0.5446, Macro F1: 0.4961, MCC: 0.3737
# Epoch [202/250] Fold [5] Train Loss: 0.1337, Train Acc: 0.5290 Val Loss: 0.1330, Val Acc: 0.5595, Macro F1: 0.5067, MCC: 0.3912
# Epoch [203/250] Fold [5] Train Loss: 0.1344, Train Acc: 0.5290 Val Loss: 0.1333, Val Acc: 0.5576, Macro F1: 0.5019, MCC: 0.3861
# Epoch [204/250] Fold [5] Train Loss: 0.1364, Train Acc: 0.5188 Val Loss: 0.1344, Val Acc: 0.5613, Macro F1: 0.5091, MCC: 0.3916
# Epoch [205/250] Fold [5] Train Loss: 0.1348, Train Acc: 0.5225 Val Loss: 0.1335, Val Acc: 0.5595, Macro F1: 0.4979, MCC: 0.3888
# Epoch [206/250] Fold [5] Train Loss: 0.1351, Train Acc: 0.5318 Val Loss: 0.1334, Val Acc: 0.5576, Macro F1: 0.4969, MCC: 0.3841
# Epoch [207/250] Fold [5] Train Loss: 0.1352, Train Acc: 0.5281 Val Loss: 0.1342, Val Acc: 0.5558, Macro F1: 0.5042, MCC: 0.3854
# Epoch [208/250] Fold [5] Train Loss: 0.1361, Train Acc: 0.5193 Val Loss: 0.1343, Val Acc: 0.5502, Macro F1: 0.4976, MCC: 0.3814
# Epoch [209/250] Fold [5] Train Loss: 0.1350, Train Acc: 0.5290 Val Loss: 0.1339, Val Acc: 0.5595, Macro F1: 0.5076, MCC: 0.3916
# Epoch [210/250] Fold [5] Train Loss: 0.1341, Train Acc: 0.5230 Val Loss: 0.1335, Val Acc: 0.5520, Macro F1: 0.4982, MCC: 0.3832
# Epoch [211/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5271 Val Loss: 0.1335, Val Acc: 0.5706, Macro F1: 0.5075, MCC: 0.4016
# Epoch [212/250] Fold [5] Train Loss: 0.1329, Train Acc: 0.5378 Val Loss: 0.1331, Val Acc: 0.5688, Macro F1: 0.5125, MCC: 0.4032
# Epoch [213/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5336 Val Loss: 0.1335, Val Acc: 0.5632, Macro F1: 0.5043, MCC: 0.3919
# Epoch [214/250] Fold [5] Train Loss: 0.1342, Train Acc: 0.5262 Val Loss: 0.1332, Val Acc: 0.5613, Macro F1: 0.5027, MCC: 0.3901
# Epoch [215/250] Fold [5] Train Loss: 0.1345, Train Acc: 0.5230 Val Loss: 0.1334, Val Acc: 0.5390, Macro F1: 0.4863, MCC: 0.3677
# Epoch [216/250] Fold [5] Train Loss: 0.1337, Train Acc: 0.5304 Val Loss: 0.1337, Val Acc: 0.5669, Macro F1: 0.4965, MCC: 0.3939
# Epoch [217/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5420 Val Loss: 0.1341, Val Acc: 0.5632, Macro F1: 0.5082, MCC: 0.3941
# Epoch [218/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5318 Val Loss: 0.1339, Val Acc: 0.5576, Macro F1: 0.5004, MCC: 0.3831
# Epoch [219/250] Fold [5] Train Loss: 0.1341, Train Acc: 0.5304 Val Loss: 0.1338, Val Acc: 0.5390, Macro F1: 0.4924, MCC: 0.3684
# Epoch [220/250] Fold [5] Train Loss: 0.1348, Train Acc: 0.5197 Val Loss: 0.1333, Val Acc: 0.5335, Macro F1: 0.4840, MCC: 0.3618
# Epoch [221/250] Fold [5] Train Loss: 0.1344, Train Acc: 0.5281 Val Loss: 0.1338, Val Acc: 0.5483, Macro F1: 0.4960, MCC: 0.3735
# Epoch [222/250] Fold [5] Train Loss: 0.1352, Train Acc: 0.5225 Val Loss: 0.1336, Val Acc: 0.5613, Macro F1: 0.5082, MCC: 0.3884
# Epoch [223/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5244 Val Loss: 0.1341, Val Acc: 0.5428, Macro F1: 0.4942, MCC: 0.3761
# Epoch [224/250] Fold [5] Train Loss: 0.1339, Train Acc: 0.5323 Val Loss: 0.1337, Val Acc: 0.5353, Macro F1: 0.4825, MCC: 0.3629
# Epoch [225/250] Fold [5] Train Loss: 0.1338, Train Acc: 0.5258 Val Loss: 0.1338, Val Acc: 0.5520, Macro F1: 0.5037, MCC: 0.3839
# Epoch [226/250] Fold [5] Train Loss: 0.1342, Train Acc: 0.5290 Val Loss: 0.1331, Val Acc: 0.5409, Macro F1: 0.4930, MCC: 0.3680
# Epoch [227/250] Fold [5] Train Loss: 0.1340, Train Acc: 0.5299 Val Loss: 0.1341, Val Acc: 0.5465, Macro F1: 0.4933, MCC: 0.3770
# Epoch [228/250] Fold [5] Train Loss: 0.1347, Train Acc: 0.5220 Val Loss: 0.1335, Val Acc: 0.5446, Macro F1: 0.4893, MCC: 0.3687
# Epoch [229/250] Fold [5] Train Loss: 0.1339, Train Acc: 0.5336 Val Loss: 0.1336, Val Acc: 0.5520, Macro F1: 0.4960, MCC: 0.3812
# Epoch [230/250] Fold [5] Train Loss: 0.1345, Train Acc: 0.5318 Val Loss: 0.1337, Val Acc: 0.5539, Macro F1: 0.5009, MCC: 0.3799
# Epoch [231/250] Fold [5] Train Loss: 0.1340, Train Acc: 0.5309 Val Loss: 0.1339, Val Acc: 0.5465, Macro F1: 0.4985, MCC: 0.3771
# Epoch [232/250] Fold [5] Train Loss: 0.1344, Train Acc: 0.5197 Val Loss: 0.1345, Val Acc: 0.5558, Macro F1: 0.5016, MCC: 0.3829
# Epoch [233/250] Fold [5] Train Loss: 0.1353, Train Acc: 0.5202 Val Loss: 0.1339, Val Acc: 0.5558, Macro F1: 0.5030, MCC: 0.3860
# Epoch [234/250] Fold [5] Train Loss: 0.1337, Train Acc: 0.5313 Val Loss: 0.1328, Val Acc: 0.5595, Macro F1: 0.5033, MCC: 0.3883
# Epoch [235/250] Fold [5] Train Loss: 0.1345, Train Acc: 0.5290 Val Loss: 0.1338, Val Acc: 0.5520, Macro F1: 0.5045, MCC: 0.3800
# Epoch [236/250] Fold [5] Train Loss: 0.1345, Train Acc: 0.5239 Val Loss: 0.1338, Val Acc: 0.5669, Macro F1: 0.5131, MCC: 0.3974
# Epoch [237/250] Fold [5] Train Loss: 0.1348, Train Acc: 0.5248 Val Loss: 0.1340, Val Acc: 0.5595, Macro F1: 0.5071, MCC: 0.3890
# Epoch [238/250] Fold [5] Train Loss: 0.1344, Train Acc: 0.5304 Val Loss: 0.1345, Val Acc: 0.5483, Macro F1: 0.5005, MCC: 0.3814
# Epoch [239/250] Fold [5] Train Loss: 0.1339, Train Acc: 0.5230 Val Loss: 0.1337, Val Acc: 0.5576, Macro F1: 0.5071, MCC: 0.3875
# Epoch [240/250] Fold [5] Train Loss: 0.1355, Train Acc: 0.5174 Val Loss: 0.1343, Val Acc: 0.5465, Macro F1: 0.4995, MCC: 0.3770
# Epoch [241/250] Fold [5] Train Loss: 0.1336, Train Acc: 0.5281 Val Loss: 0.1341, Val Acc: 0.5539, Macro F1: 0.5068, MCC: 0.3871
# Epoch [242/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5183 Val Loss: 0.1336, Val Acc: 0.5483, Macro F1: 0.4980, MCC: 0.3820
# Epoch [243/250] Fold [5] Train Loss: 0.1333, Train Acc: 0.5378 Val Loss: 0.1336, Val Acc: 0.5632, Macro F1: 0.4995, MCC: 0.3923
# Epoch [244/250] Fold [5] Train Loss: 0.1341, Train Acc: 0.5406 Val Loss: 0.1333, Val Acc: 0.5613, Macro F1: 0.5084, MCC: 0.3909
# Epoch [245/250] Fold [5] Train Loss: 0.1336, Train Acc: 0.5360 Val Loss: 0.1346, Val Acc: 0.5242, Macro F1: 0.4811, MCC: 0.3578
# Epoch [246/250] Fold [5] Train Loss: 0.1344, Train Acc: 0.5304 Val Loss: 0.1340, Val Acc: 0.5520, Macro F1: 0.5063, MCC: 0.3830
# Epoch [247/250] Fold [5] Train Loss: 0.1342, Train Acc: 0.5197 Val Loss: 0.1340, Val Acc: 0.5576, Macro F1: 0.5001, MCC: 0.3841
# Epoch [248/250] Fold [5] Train Loss: 0.1325, Train Acc: 0.5323 Val Loss: 0.1348, Val Acc: 0.5390, Macro F1: 0.4891, MCC: 0.3653
# Epoch [249/250] Fold [5] Train Loss: 0.1343, Train Acc: 0.5202 Val Loss: 0.1344, Val Acc: 0.5576, Macro F1: 0.5070, MCC: 0.3939
# Epoch [250/250] Fold [5] Train Loss: 0.1336, Train Acc: 0.5313 Val Loss: 0.1331, Val Acc: 0.5428, Macro F1: 0.4944, MCC: 0.3683

# %% [markdown]
# ### Caculating metrics helper function

# %%
# Function to calculate the precision and recall
def calculate_metrics(dataloader, model):
    y_pred = []
    y_true = []
    
    model.eval()
    with torch.no_grad():
        
        # iterate over validation data
        for X, y in dataloader:
            
            X = X.to(torch.float32)
            X = X.to(device)
            output = model(X)  # Feed Network

            output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
            y_pred.extend(output)  # Save Prediction

            labels = y.cpu().numpy()
            y_true.extend(labels)  # Save Truth

    # Calculate confusion matrix
    cf_matrix = confusion_matrix(y_true, y_pred)

    # Calculate precision and recall for each class
    precision = precision_score(y_true, y_pred, average=None, zero_division=0)
    recall = recall_score(y_true, y_pred, average=None, zero_division=0)
    macro_f1 = f1_score(y_true, y_pred, average='macro')
    mcc = matthews_corrcoef(y_true, y_pred)

    return cf_matrix, precision, recall, macro_f1, mcc

# %% [markdown]
# ### Confusion matrix

# %%
# make a function that visualize 5 confusion matrices from 5 data loaders, and stack them into one figure, 3 by 2
def plot_confusion_matrices(cf_matrices, labels, title):
    fig, axes = plt.subplots(2, 3, figsize=(10, 6))
    axes = axes.flatten()
    
    for i, cf_matrix in enumerate(cf_matrices):
        sns.heatmap(cf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
                    xticklabels=labels, yticklabels=labels, ax=axes[i])
        #axes[i].set_xlabel('Predicted')
        #axes[i].set_ylabel('True')
        axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
        axes[i].set_title(title[i])
    
    # remove the last empty subplot
    for j in range(i+1, len(axes)):
        fig.delaxes(axes[j])

    # set an overall x and y label for the entire figure
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to make space for the title
    fig.subplots_adjust(hspace=0.4, wspace=0.4)
    fig.text(0.5, 0, 'Predicted', ha='center', fontdict={'size': 16})
    fig.text(0, 0.5, 'True', va='center', rotation='vertical', fontdict={'size': 16})

    #fig.xlabel('Predicted')
    #fig.ylabel('True')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Testing

# %%
model_path
# Out:
# '/home/ec2-user/Feb2025/saved_models/Protein_NN_model.pth'

# %%
# Load the model
last_model = PixelPreservingNet(in_channels=3)
last_model.load_state_dict(torch.load(model_path))
last_model.to(device)
# Out:
# /tmp/ipykernel_3756/3050491375.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   last_model.load_state_dict(torch.load(model_path))
# PixelPreservingNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (conv5): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#   )
#   (global_avg_pool): AdaptiveAvgPool2d(output_size=1)
#   (fc1): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#   )
#   (output): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
# Read in the synthetic data
# Mertins 
#   proteome
M_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'M_PD_synthetic_kde_qttumor.csv'))
M_PD_synthetic.index = M_PD_synthetic.loc[:,'Index']
M_PD_synthetic = M_PD_synthetic.loc[:, M_PD_synthetic.columns!='Index']

#   transcriptome
M_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'M_MD_synthetic_kde_qttumor.csv'))
M_MD_synthetic.index = M_MD_synthetic.loc[:,'gene_name']
M_MD_synthetic = M_MD_synthetic.loc[:, M_MD_synthetic.columns!='gene_name']

# LCSCC tumor
#   proteome
lung_tumor_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_tumor_PD_synthetic_kde_qttumor.csv'))
lung_tumor_PD_synthetic.index = lung_tumor_PD_synthetic.loc[:,'Gene']
lung_tumor_PD_synthetic = lung_tumor_PD_synthetic.loc[:, lung_tumor_PD_synthetic.columns!='Gene']

#   transcriptome
lung_tumor_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_tumor_MD_synthetic_kde_qttumor.csv'))
lung_tumor_MD_synthetic.index = lung_tumor_MD_synthetic.loc[:,'gene_name']
lung_tumor_MD_synthetic = lung_tumor_MD_synthetic.loc[:, lung_tumor_MD_synthetic.columns!='gene_name']

# LCSCC NAT
#   proteome
lung_nat_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_nat_PD_synthetic_kde_qttumor.csv'))
lung_nat_PD_synthetic.index = lung_nat_PD_synthetic.loc[:,'Gene']
lung_nat_PD_synthetic = lung_nat_PD_synthetic.loc[:, lung_nat_PD_synthetic.columns!='Gene']

#   transcriptome
lung_nat_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'lung_nat_MD_synthetic_kde_qttumor.csv'))
lung_nat_MD_synthetic.index = lung_nat_MD_synthetic.loc[:,'gene_name']
lung_nat_MD_synthetic = lung_nat_MD_synthetic.loc[:, lung_nat_MD_synthetic.columns!='gene_name']

# Brain glioma
#   proteome
glioma_PD_synthetic = pd.read_csv(Path(dataset_folder_path+'glioma_tumor_PD_synthetic_kde_qttumor.csv'))
glioma_PD_synthetic.index = glioma_PD_synthetic.loc[:,'gene_name']
glioma_PD_synthetic = glioma_PD_synthetic.loc[:, glioma_PD_synthetic.columns!='gene_name']

#   transcriptome
glioma_MD_synthetic = pd.read_csv(Path(dataset_folder_path+'glioma_tumor_MD_synthetic_kde_qttumor.csv'))
glioma_MD_synthetic.index = glioma_MD_synthetic.loc[:,'gene_name']
glioma_MD_synthetic = glioma_MD_synthetic.loc[:, glioma_MD_synthetic.columns!='gene_name']

# %%
# Breast
# Read in the label
LD_mcf7 = pd.read_csv(Path(label_path+'markers.txt'), sep='\t')
LD_mcf7.index = LD_mcf7.loc[:,'Protein']
LD_mcf7 = LD_mcf7.loc[:,LD_mcf7.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_mcf7.loc[:,'Localization'] != 'Unclassified'
LD_mcf7 = LD_mcf7.loc[NotUnclassInd,:]

# Lung
LD_h322 = pd.read_csv(Path(label_path+'markers.txt'), sep='\t')
LD_h322.index = LD_h322.loc[:,'Protein']
LD_h322 = LD_h322.loc[:,LD_h322.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_h322.loc[:,'Localization'] != 'Unclassified'
LD_h322 = LD_h322.loc[NotUnclassInd,:]

# Lung
LD_u251 = pd.read_csv(Path(label_path+'markers.txt'), sep='\t')
LD_u251.index = LD_u251.loc[:,'Protein']
LD_u251 = LD_u251.loc[:,LD_u251.columns!='Protein']

# Remove unclassified
NotUnclassInd = LD_u251.loc[:,'Localization'] != 'Unclassified'
LD_u251 = LD_u251.loc[NotUnclassInd,:]

# %%
M_common_indices = list(set(M_PD_synthetic.index).intersection(set(M_MD_synthetic.index).intersection(set(LD_mcf7.index))))
M_LD = LD_mcf7.loc[LD_mcf7.index.isin(M_common_indices)]
M_PD_synthetic = M_PD_synthetic.loc[M_PD_synthetic.index.isin(M_common_indices)]
M_MD_synthetic = M_MD_synthetic.loc[M_MD_synthetic.index.isin(M_common_indices)]

lung_tumor_common_indices = list(set(lung_tumor_PD_synthetic.index).intersection(set(lung_tumor_MD_synthetic.index).intersection(set(LD_h322.index))))
lung_tumor_LD = LD_h322.loc[LD_h322.index.isin(lung_tumor_common_indices)]
lung_tumor_PD_synthetic = lung_tumor_PD_synthetic.loc[lung_tumor_PD_synthetic.index.isin(lung_tumor_common_indices)]
lung_tumor_MD_synthetic = lung_tumor_MD_synthetic.loc[lung_tumor_MD_synthetic.index.isin(lung_tumor_common_indices)]

lung_nat_common_indices = list(set(lung_nat_PD_synthetic.index).intersection(set(lung_nat_MD_synthetic.index).intersection(set(LD_h322.index))))
lung_nat_LD = LD_h322.loc[LD_h322.index.isin(lung_nat_common_indices)]
lung_nat_PD_synthetic = lung_nat_PD_synthetic.loc[lung_nat_PD_synthetic.index.isin(lung_nat_common_indices)]
lung_nat_MD_synthetic = lung_nat_MD_synthetic.loc[lung_nat_MD_synthetic.index.isin(lung_nat_common_indices)]

glioma_common_indices = list(set(glioma_PD_synthetic.index).intersection(set(glioma_MD_synthetic.index).intersection(set(LD_u251.index))))
glioma_LD = LD_u251.loc[LD_u251.index.isin(glioma_common_indices)]
glioma_PD_synthetic = glioma_PD_synthetic.loc[glioma_PD_synthetic.index.isin(glioma_common_indices)]
glioma_MD_synthetic = glioma_MD_synthetic.loc[glioma_MD_synthetic.index.isin(glioma_common_indices)]

# Convert string labels to integers
M_test_labels = [label_to_int[label] for label in M_LD['Localization'].values]
lung_tumor_test_labels = [label_to_int[label] for label in lung_tumor_LD['Localization'].values]
lung_nat_test_labels = [label_to_int[label] for label in lung_nat_LD['Localization'].values]
glioma_test_labels = [label_to_int[label] for label in glioma_LD['Localization'].values]

# Create the test datasets
if Set == 'Protein':
    M_test_dataset = MyDataset(Set, M_PD_synthetic, M_PD_synthetic, M_PD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = MyDataset(Set, lung_tumor_PD_synthetic, lung_tumor_PD_synthetic, lung_tumor_PD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = MyDataset(Set, lung_nat_PD_synthetic, lung_nat_PD_synthetic, lung_nat_PD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = MyDataset(Set, glioma_PD_synthetic, glioma_PD_synthetic, glioma_PD_synthetic.index, glioma_test_labels)
elif Set == 'mRNA':
    M_test_dataset = MyDataset(Set, M_MD_synthetic, M_MD_synthetic, M_MD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = MyDataset(Set, lung_tumor_MD_synthetic, lung_tumor_MD_synthetic, lung_tumor_MD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = MyDataset(Set, lung_nat_MD_synthetic, lung_nat_MD_synthetic, lung_nat_MD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = MyDataset(Set, glioma_MD_synthetic, glioma_MD_synthetic, glioma_MD_synthetic.index, glioma_test_labels)
elif Set == 'Protein + mRNA':
    M_test_dataset = MyDataset(Set, M_PD_synthetic, M_MD_synthetic, M_PD_synthetic.index, M_test_labels)
    lung_tumor_test_dataset = MyDataset(Set, lung_tumor_PD_synthetic, lung_tumor_MD_synthetic, lung_tumor_PD_synthetic.index, lung_tumor_test_labels)
    lung_nat_test_dataset = MyDataset(Set, lung_nat_PD_synthetic, lung_nat_MD_synthetic, lung_nat_PD_synthetic.index, lung_nat_test_labels)
    glioma_test_dataset = MyDataset(Set, glioma_PD_synthetic, glioma_MD_synthetic, glioma_PD_synthetic.index, glioma_test_labels)
else:
    raise ValueError("Invalid dataset selection. Choose 'Protein', 'mRNA', 'Protein + mRNA', 'Protein + mRNA Stack'.")

# Create the test data loaders
set_seed(Seed)
M_test_loader = DataLoader(M_test_dataset, batch_size=Batch_size, shuffle=False)
lung_tumor_test_loader = DataLoader(lung_tumor_test_dataset, batch_size=Batch_size, shuffle=False)
lung_nat_test_loader = DataLoader(lung_nat_test_dataset, batch_size=Batch_size, shuffle=False)
glioma_test_loader = DataLoader(glioma_test_dataset, batch_size=Batch_size, shuffle=False)

# %% [markdown]
# ## Metrics

# %% [markdown]
# ### Fig: 5-fold CV

# %%
precision_per_class = [[] for _ in range(4)]
recall_per_class = [[] for _ in range(4)]
f1_per_class = [[] for _ in range(4)]

for fold in range(5):  # 5 folds
    df = pd.read_csv(cv_folder_path + f'{Set}_Fold{fold+1}_PrecisionRecall.csv')
    max_epoch = df['Epoch'].max()
    df_last = df[df['Epoch'] == max_epoch]
    
    for class_idx in range(4):
        class_df = df_last[df_last['Class'] == class_idx]
        precision_per_class[class_idx].append(class_df['Precision'].values[0])
        recall_per_class[class_idx].append(class_df['Recall'].values[0])
        f1_per_class[class_idx].append(class_df['Class F1'].values[0])

# Prepare for plotting
fig, ax = plt.subplots(figsize=(8, 4))

# Colors
precision_color = '#1f77b4'  # blue
recall_color = '#ff7f0e'     # orange
f1_color = '#d62728'         # red
class_labels = ['Cytosol', 'Mitochondria', 'Nucleus', 'Secretory']

# Positions setup
positions = []
data = []
colors = []

for i in range(4): 
    base = i * 4
    positions += [base - 0.55, base, base + 0.55]
    data += [
        np.array(precision_per_class[i]),
        np.array(recall_per_class[i]),
        np.array(f1_per_class[i])
    ]
    colors += [precision_color, recall_color, f1_color]


# Boxplot
bp = ax.boxplot(data, positions=positions, widths=0.5, patch_artist=True, showfliers=False,
                boxprops=dict(linewidth=1),
                medianprops=dict(color='black', linewidth=1),
                whiskerprops=dict(linewidth=1),
                capprops=dict(linewidth=1))

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.8)

# X-ticks
class_centers = [(i * 4) for i in range(4)]
ax.set_xticks(class_centers)
ax.set_xticklabels(class_labels, fontsize=16)

# Axes labels and limits
ax.set_ylabel('Score', fontsize=18)
ax.set_ylim(0, 1.05)
ax.set_yticks([0.0, 0.25, 0.5, 0.75, 1.0])
ax.tick_params(axis='both', which='major', labelsize=16)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add dashed horizontal threshold lines (class-specific)
ci_baselines = [0.43314056, 0.09879518, 0.30857335, 0.20966921]
for i, y_val in enumerate(ci_baselines):
    left = i * 4 - 1
    right = i * 4 + 1
    ax.hlines(y=y_val, xmin=left, xmax=right, colors='gray', linestyles=(0, (5, 5)), linewidth=1)

# Legend handles
legend_handles = [
    mpatches.Patch(color=precision_color, label='Precision'),
    mpatches.Patch(color=recall_color, label='Recall'),
    mpatches.Patch(color=f1_color, label='F1'),
    plt.Line2D([0], [0], color='gray', linestyle=(0, (5, 5)), linewidth=1, label='95% CI')
]

# Legend outside the plot
ax.legend(handles=legend_handles, loc='center left', bbox_to_anchor=(1.01, 0.5), frameon=False, fontsize=14)

# Save figure
plt.tight_layout()
plt.savefig(fig_bank_path + f'{Set}_CV_Boxplot.pdf', dpi=600, bbox_inches='tight')

# %% [markdown]
# ### Fig: training and validation loss

# %%
# Find last completed epoch
last_epoch = LossAccDF['Epoch'].max()

# Create figure
fig, ax = plt.subplots(figsize=(8, 4))

# Plot curves
ax.plot(LossAccDF['Epoch'], LossAccDF['TrainLoss'], label='Training', color='tab:blue', linewidth=2)
ax.plot(LossAccDF['Epoch'], LossAccDF['ValLoss'], label='Validation', color='tab:orange', linewidth=2, linestyle='--')

# Axes labels
ax.set_xlabel('Epoch', fontsize=18)
ax.set_ylabel('Loss', fontsize=18)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Ticks
ax.set_xlim([0, last_epoch])
ax.set_xticks(range(0, last_epoch+1, max(1, last_epoch // 5)))  # adaptive ticks
ax.tick_params(axis='both', which='major', labelsize=16)

# Legend outside the plot
ax.legend(frameon=False, fontsize=14, loc='center left', bbox_to_anchor=(1.02, 0.5))

# Tight layout
plt.tight_layout()

# Save high-quality figure
fig.savefig(Path(fig_bank_path) / f"{Set}_Loss.pdf", dpi=600, bbox_inches='tight')

# %% [markdown]
# ### Fig: training and validation accuracy

# %%
# Find last completed epoch
last_epoch = LossAccDF['Epoch'].max()

# Create figure
fig, ax = plt.subplots(figsize=(8, 4))  # Compact

# Plot accuracy curves (scale to %)
ax.plot(LossAccDF['Epoch'], LossAccDF['TrainAcc'] * 100, label='Training', color='tab:blue', linewidth=2)
ax.plot(LossAccDF['Epoch'], LossAccDF['ValAcc'] * 100, label='Validation', color='tab:orange', linewidth=2, linestyle='--')

# Axes labels
ax.set_xlabel('Epoch', fontsize=18)
ax.set_ylabel('Accuracy (%)', fontsize=18)

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# X and Y limits
ax.set_xlim([0, last_epoch])
ax.set_ylim([0, 100])

# Ticks
ax.set_xticks(range(0, last_epoch + 1, max(1, last_epoch // 5)))
ax.set_yticks([0, 25, 50, 75, 100])
ax.tick_params(axis='both', which='major', labelsize=16)

# Legend outside the plot
ax.legend(frameon=False, fontsize=14, loc='center left', bbox_to_anchor=(1.02, 0.5))

# Tight layout
plt.tight_layout()

# Save figure
fig.savefig(Path(fig_bank_path) / f"{Set}_Acc.pdf", dpi=600, bbox_inches='tight')

# %% [markdown]
# ### Fig: confusion matrices

# %%
# Set seed
set_seed(Seed)

# Get the confusion matrix and precision and recall for the validation loader and all test loaders
cf_matrix_val, precision_val, recall_val, macro_f1_val, mcc_val = calculate_metrics(val_loader, last_model)
cf_matrix_M, precision_M, recall_M, macro_f1_M, mcc_M = calculate_metrics(M_test_loader, last_model)
cf_matrix_lung_tumor, precision_lung_tumor, recall_lung_tumor, macro_f1_lung_tumor, mcc_lung_tumor = calculate_metrics(lung_tumor_test_loader, last_model)
cf_matrix_lung_nat, precision_lung_nat, recall_lung_nat, macro_f1_lung_nat, mcc_lung_nat = calculate_metrics(lung_nat_test_loader, last_model)
cf_matrix_glioma, precision_glioma, recall_glioma, macro_f1_glioma, mcc_glioma = calculate_metrics(glioma_test_loader, last_model)

# Put them into a list
cf_matrices = [cf_matrix_val, cf_matrix_M, cf_matrix_lung_tumor, cf_matrix_lung_nat, cf_matrix_glioma]
titles = ['Krug Validation', 'Mertins Test ', 'Lung Tumor Test', 'Lung NAT Test', 'Glioma Test']

# Plot the confusion matrices
plot_confusion_matrices(cf_matrices, labels=int_to_label.values(), title=titles)

# Save figure into figure bank
figure3 = plt.gcf()
figure3.savefig(Path(fig_bank_path+Set+'_Confusion_Matrices.png'), dpi=300)

# %% [markdown]
# ### Fig: macro F1 and MCC

# %%
# Find last completed epoch
last_epoch = int(PrecisionRecallDF['Epoch'].max())

# Create figure
fig, ax = plt.subplots(figsize=(6, 4))  # Compact and tight

# Plot Macro F1 and MCC curves
ax.plot(PrecisionRecallDF['Epoch'], PrecisionRecallDF['Macro F1'], label='Macro F1', color='tab:blue', linewidth=2)
ax.plot(PrecisionRecallDF['Epoch'], PrecisionRecallDF['MCC'], label='MCC', color='tab:orange', linewidth=2, linestyle='--')

# Axes labels
ax.set_xlabel('Epoch', fontsize=14)
ax.set_ylabel('Score', fontsize=14)

# Limits
ax.set_xlim([0, last_epoch])
ax.set_ylim([-1.05, 1.05])  # Slightly more padding for aesthetics

# Ticks
ax.set_xticks(range(0, last_epoch+1, max(1, last_epoch // 10)))
ax.set_yticks([-1.0, -0.5, 0.0, 0.5, 1.0])
ax.tick_params(axis='both', which='major', labelsize=12)

# Legend
ax.legend(frameon=False, fontsize=12, loc='lower right')

# Tight layout
plt.tight_layout()

# Save figure
fig.savefig(Path(fig_bank_path) / f"{Set}_MacroF1_MCC.png", dpi=600, bbox_inches='tight')

# %% [markdown]
# ### Fig: Precision and recall of validation and testing

# %%
set_seed(Seed)

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()

compartment_class = ['Cytosol', 'Mitochondria', 'Nucleus', 'Secretory']
colormaps = [cm.Blues, cm.Oranges, cm.Greens, cm.Purples]

# Filter improvement epochs
def filter_improvement_epochs(df):
    improved_epochs = []
    for class_label in df['Class'].unique():
        class_df = df[df['Class'] == class_label].copy()
        class_df = class_df.sort_values(by='Epoch')
        max_precision = float('-inf')
        for _, row in class_df.iterrows():
            if row['Precision'] >= max_precision:
                max_precision = row['Precision']
                improved_epochs.append(row)
    start_epoch = df[df['Epoch'] == 0]
    last_epoch = df[df['Epoch'] == df['Epoch'].max()]
    return pd.concat([start_epoch, pd.DataFrame(improved_epochs), last_epoch]).drop_duplicates()

improved_epochs_df = filter_improvement_epochs(PrecisionRecallDF)

for i, f1_score in enumerate(np.array([0.43314056, 0.09879518, 0.30857335, 0.20966921])):
    ax = axes[i]
    class_metrics = improved_epochs_df[improved_epochs_df['Class'] == i]
    norm = plt.Normalize(class_metrics['Epoch'].min(), class_metrics['Epoch'].max())

    # # Scatter points
    # for _, row in class_metrics.iterrows():
    #     color = colormaps[i](norm(row['Epoch']))
    #     edge_color = colormaps[i](0.8)
    #     ax.scatter(row['Recall'], row['Precision'], s=100, color=color, edgecolors=edge_color, linewidths=1)

    # # Connect dots
    # ax.plot(class_metrics['Recall'], class_metrics['Precision'], color=colormaps[i](0.5), linewidth=2)

    # Plot F1 curve
    x_left = np.linspace(0, f1_score / 2, 10000)
    x_right = np.linspace(f1_score / 2, 1, 10000)
    y_right = f1_score * x_right / (2 * x_right - f1_score)
    ax.plot(x_right, y_right, color=colormaps[i](0.5), linestyle='--', linewidth=2)
    ax.fill_between(x_left, 0, 1, color=colormaps[i](0.5), alpha=0.2)
    ax.fill_between(x_right, 0, y_right, color=colormaps[i](0.5), alpha=0.2)

    # Add external test points
    ax.scatter(recall_M[i], precision_M[i], s=75, color='red', edgecolors='red', marker='s', label='Mertins test set')
    ax.scatter(recall_lung_tumor[i], precision_lung_tumor[i], s=75, color='purple', edgecolors='purple', marker='s', label='LSCC Tumor')
    ax.scatter(recall_lung_nat[i], precision_lung_nat[i], s=75, color='orange', edgecolors='orange', marker='s', label='LSCC NAT')
    ax.scatter(recall_glioma[i], precision_glioma[i], s=75, color='green', edgecolors='green', marker='s', label='Glioma')

    # Plot settings
    ax.set_title(compartment_class[i], fontsize=18)
    ax.set_xlim([0, 1])
    ax.set_ylim([0, 1])
    ax.set_xlabel('Recall (Sensitivity)', fontsize=18)
    ax.set_ylabel('Precision\n(Positive Predictive Value)', fontsize=18)
    ax.tick_params(axis='both', labelsize=16)
    ax.grid(True, linestyle='--', alpha=0.4)

    # Remove top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Legend (only once per subplot)
    mertins_handle = mlines.Line2D([], [], color='red', marker='s', linestyle='None', markersize=8, label='Breast Tumor')
    lung_tumor_handle = mlines.Line2D([], [], color='purple', marker='s', linestyle='None', markersize=8, label='Lung Tumor')
    lung_nat_handle = mlines.Line2D([], [], color='orange', marker='s', linestyle='None', markersize=8, label='Lung NAT')
    glioma_handle = mlines.Line2D([], [], color='green', marker='s', linestyle='None', markersize=8, label='Brain Tumor')

# Global legend outside the subplots
fig.legend(handles=[mertins_handle, lung_tumor_handle, lung_nat_handle, glioma_handle],
           loc='center left', bbox_to_anchor=(1.01, 0.5), fontsize=16, frameon=False)

# Tight layout
plt.tight_layout()  # reserve space on the right

# Save figure at high quality
fig.savefig(Path(fig_bank_path) / f"{Set}_Precision_Recall_F1curve.pdf", dpi=600, bbox_inches='tight')
# Out:
# /tmp/ipykernel_3756/2455325278.py:43: RuntimeWarning: divide by zero encountered in divide
#   y_right = f1_score * x_right / (2 * x_right - f1_score)

# %%
# export dataframes
LossAccDF.to_excel(Path(fig_bank_path + Set+ f'LossAccDF.xlsx'), index=False)
PrecisionRecallDF.to_excel(Path(fig_bank_path + Set+ f'PrecisionRecallDF.xlsx'), index=False)
